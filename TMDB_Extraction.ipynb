# %% [markdown]
# Para poder abordar el análisis deseado, hemos encontrado la siguiente [plataforma](https://www.themoviedb.org/?language=es) de la que extraer los datos:
#
# <br>
#
# ![Logo TMDB](https://www.themoviedb.org/assets/2/v4/logos/v2/blue_long_2-9665a76b1ae401a510ec1e0ca40ddcb3b0cfe45f1d51b77a308fea0845885648.svg)
#
# <br>
#
# A continuación, y puesto que la obtención de la información necesaria para abordar las hipótesis de nuestro EDA no es inmediata, mostramos la explicación de cómo hacerlo paso a paso, partiendo de la base de que para poder realizar las peticiones a dicha API hemos obtenido nuestra **API KEY** y que, si alguien quisiera replicar el proceso explicado, debería obtener la suya propia [aquí](https://developer.themoviedb.org/v4/reference/intro/getting-started) y almacenarla en la variable que a lo largo del Jupiter Notebook denotamos como *headers_users*.
#
# **Anotación**: A lo largo del documento hemos incluido la explicación para las extracciones de los datos no sólo para ```Netflix``` y ```Amazon Prime Video```, sino también para ```Disney+``` y ```Max```, con el objetivo de utilizarlas en un proyecto futuro que abarque el análisis de más servicios de streaming en España.

# %%
#Importamos los paquetes necesarios para la obtención de los datos de nuestro EDA
import requests
import pandas as pd
import numpy as np
import os
import math
from utils import tvseries

# %% [markdown]
# # Regiones:
#
# Puesto que nuestro análisis se va a limitar a la geografía de **España**, necesitamos saber cómo filtraremos las películas y las series disponibles en dicha región. Para ello, necesitamos acceder al siguiente endpoint:
#
#
# ![API Regiones](./images/endpoint-regions.png)

# %%
url_regions = "https://api.themoviedb.org/3/watch/providers/regions"
res_url_regions = requests.get(url_regions, headers = headers_user)
print(res_url_regions)
# Out:
# <Response [200]>

# %%
res_url_regions.json()
# Out:
# {'results': [{'iso_3166_1': 'AD',
#    'english_name': 'Andorra',
#    'native_name': 'Andorra'},
#   {'iso_3166_1': 'AE',
#    'english_name': 'United Arab Emirates',
#    'native_name': 'United Arab Emirates'},
#   {'iso_3166_1': 'AG',
#    'english_name': 'Antigua and Barbuda',
#    'native_name': 'Antigua & Barbuda'},
#   {'iso_3166_1': 'AL', 'english_name': 'Albania', 'native_name': 'Albania'},
#   {'iso_3166_1': 'AO', 'english_name': 'Angola', 'native_name': 'Angola'},
#   {'iso_3166_1': 'AR',
#    'english_name': 'Argentina',
#    'native_name': 'Argentina'},
#   {'iso_3166_1': 'AT', 'english_name': 'Austria', 'native_name': 'Austria'},
#   {'iso_3166_1': 'AU',
#    'english_name': 'Australia',
#    'native_name': 'Australia'},
#   {'iso_3166_1': 'AZ',
#    'english_name': 'Azerbaijan',
#    'native_name': 'Azerbaijan'},
#   {'iso_3166_1': 'BA',
#    'english_name': 'Bosnia and Herzegovina',
#    'native_name': 'Bosnia & Herzegovina'},
#   {'iso_3166_1': 'BB', 'english_name': 'Barbados', 'native_name': 'Barbados'},
#   {'iso_3166_1': 'BE', 'english_name': 'Belgium', 'native_name': 'Belgium'},
#   {'iso_3166_1': 'BF',
#    'english_name': 'Burkina Faso',
#    'native_name': 'Burkina Faso'},
#   {'iso_3166_1': 'BG', 'english_name': 'Bulgaria', 'native_name': 'Bulgaria'},
#   {'iso_3166_1': 'BH', 'english_name': 'Bahrain', 'native_name': 'Bahrain'},
#   {'iso_3166_1': 'BM', 'english_name': 'Bermuda', 'native_name': 'Bermuda'},
#   {'iso_3166_1': 'BO', 'english_name': 'Bolivia', 'native_name': 'Bolivia'},
#   {'iso_3166_1': 'BR', 'english_name': 'Brazil', 'native_name': 'Brazil'},
#   {'iso_3166_1': 'BS', 'english_name': 'Bahamas', 'native_name': 'Bahamas'},
#   {'iso_3166_1': 'BY', 'english_name': 'Belarus', 'native_name': 'Belarus'},
#   {'iso_3166_1': 'BZ', 'english_name': 'Belize', 'native_name': 'Belize'},
#   {'iso_3166_1': 'CA', 'english_name': 'Canada', 'native_name': 'Canada'},
#   {'iso_3166_1': 'CD',
#    'english_name': 'Congo',
#    'native_name': 'Democratic Republic of the Congo (Kinshasa)'},
#   {'iso_3166_1': 'CH',
#    'english_name': 'Switzerland',
#    'native_name': 'Switzerland'},
#   {'iso_3166_1': 'CI',
#    'english_name': "Cote D'Ivoire",
#    'native_name': 'Côte d’Ivoire'},
#   {'iso_3166_1': 'CL', 'english_name': 'Chile', 'native_name': 'Chile'},
#   {'iso_3166_1': 'CM', 'english_name': 'Cameroon', 'native_name': 'Cameroon'},
#   {'iso_3166_1': 'CO', 'english_name': 'Colombia', 'native_name': 'Colombia'},
#   {'iso_3166_1': 'CR',
#    'english_name': 'Costa Rica',
#    'native_name': 'Costa Rica'},
#   {'iso_3166_1': 'CU', 'english_name': 'Cuba', 'native_name': 'Cuba'},
#   {'iso_3166_1': 'CV',
#    'english_name': 'Cape Verde',
#    'native_name': 'Cape Verde'},
#   {'iso_3166_1': 'CY', 'english_name': 'Cyprus', 'native_name': 'Cyprus'},
#   {'iso_3166_1': 'CZ',
#    'english_name': 'Czech Republic',
#    'native_name': 'Czech Republic'},
#   {'iso_3166_1': 'DE', 'english_name': 'Germany', 'native_name': 'Germany'},
#   {'iso_3166_1': 'DK', 'english_name': 'Denmark', 'native_name': 'Denmark'},
#   {'iso_3166_1': 'DO',
#    'english_name': 'Dominican Republic',
#    'native_name': 'Dominican Republic'},
#   {'iso_3166_1': 'DZ', 'english_name': 'Algeria', 'native_name': 'Algeria'},
#   {'iso_3166_1': 'EC', 'english_name': 'Ecuador', 'native_name': 'Ecuador'},
#   {'iso_3166_1': 'EE', 'english_name': 'Estonia', 'native_name': 'Estonia'},
#   {'iso_3166_1': 'EG', 'english_name': 'Egypt', 'native_name': 'Egypt'},
#   {'iso_3166_1': 'ES', 'english_name': 'Spain', 'native_name': 'Spain'},
#   {'iso_3166_1': 'FI', 'english_name': 'Finland', 'native_name': 'Finland'},
#   {'iso_3166_1': 'FJ', 'english_name': 'Fiji', 'native_name': 'Fiji'},
#   {'iso_3166_1': 'FR', 'english_name': 'France', 'native_name': 'France'},
#   {'iso_3166_1': 'GB',
#    'english_name': 'United Kingdom',
#    'native_name': 'United Kingdom'},
#   {'iso_3166_1': 'GF',
#    'english_name': 'French Guiana',
#    'native_name': 'French Guiana'},
#   {'iso_3166_1': 'GH', 'english_name': 'Ghana', 'native_name': 'Ghana'},
#   {'iso_3166_1': 'GI',
#    'english_name': 'Gibraltar',
#    'native_name': 'Gibraltar'},
#   {'iso_3166_1': 'GP',
#    'english_name': 'Guadaloupe',
#    'native_name': 'Guadeloupe'},
#   {'iso_3166_1': 'GQ',
#    'english_name': 'Equatorial Guinea',
#    'native_name': 'Equatorial Guinea'},
#   {'iso_3166_1': 'GR', 'english_name': 'Greece', 'native_name': 'Greece'},
#   {'iso_3166_1': 'GT',
#    'english_name': 'Guatemala',
#    'native_name': 'Guatemala'},
#   {'iso_3166_1': 'GY', 'english_name': 'Guyana', 'native_name': 'Guyana'},
#   {'iso_3166_1': 'HK',
#    'english_name': 'Hong Kong',
#    'native_name': 'Hong Kong SAR China'},
#   {'iso_3166_1': 'HN', 'english_name': 'Honduras', 'native_name': 'Honduras'},
#   {'iso_3166_1': 'HR', 'english_name': 'Croatia', 'native_name': 'Croatia'},
#   {'iso_3166_1': 'HU', 'english_name': 'Hungary', 'native_name': 'Hungary'},
#   {'iso_3166_1': 'ID',
#    'english_name': 'Indonesia',
#    'native_name': 'Indonesia'},
#   {'iso_3166_1': 'IE', 'english_name': 'Ireland', 'native_name': 'Ireland'},
#   {'iso_3166_1': 'IL', 'english_name': 'Israel', 'native_name': 'Israel'},
#   {'iso_3166_1': 'IN', 'english_name': 'India', 'native_name': 'India'},
#   {'iso_3166_1': 'IQ', 'english_name': 'Iraq', 'native_name': 'Iraq'},
#   {'iso_3166_1': 'IS', 'english_name': 'Iceland', 'native_name': 'Iceland'},
#   {'iso_3166_1': 'IT', 'english_name': 'Italy', 'native_name': 'Italy'},
#   {'iso_3166_1': 'JM', 'english_name': 'Jamaica', 'native_name': 'Jamaica'},
#   {'iso_3166_1': 'JO', 'english_name': 'Jordan', 'native_name': 'Jordan'},
#   {'iso_3166_1': 'JP', 'english_name': 'Japan', 'native_name': 'Japan'},
#   {'iso_3166_1': 'KE', 'english_name': 'Kenya', 'native_name': 'Kenya'},
#   {'iso_3166_1': 'KR',
#    'english_name': 'South Korea',
#    'native_name': 'South Korea'},
#   {'iso_3166_1': 'KW', 'english_name': 'Kuwait', 'native_name': 'Kuwait'},
#   {'iso_3166_1': 'LB', 'english_name': 'Lebanon', 'native_name': 'Lebanon'},
#   {'iso_3166_1': 'LC',
#    'english_name': 'St. Lucia',
#    'native_name': 'St. Lucia'},
#   {'iso_3166_1': 'LI',
#    'english_name': 'Liechtenstein',
#    'native_name': 'Liechtenstein'},
#   {'iso_3166_1': 'LT',
#    'english_name': 'Lithuania',
#    'native_name': 'Lithuania'},
#   {'iso_3166_1': 'LU',
#    'english_name': 'Luxembourg',
#    'native_name': 'Luxembourg'},
#   {'iso_3166_1': 'LV', 'english_name': 'Latvia', 'native_name': 'Latvia'},
#   {'iso_3166_1': 'LY',
#    'english_name': 'Libyan Arab Jamahiriya',
#    'native_name': 'Libya'},
#   {'iso_3166_1': 'MA', 'english_name': 'Morocco', 'native_name': 'Morocco'},
#   {'iso_3166_1': 'MC', 'english_name': 'Monaco', 'native_name': 'Monaco'},
#   {'iso_3166_1': 'MD', 'english_name': 'Moldova', 'native_name': 'Moldova'},
#   {'iso_3166_1': 'ME',
#    'english_name': 'Montenegro',
#    'native_name': 'Montenegro'},
#   {'iso_3166_1': 'MG',
#    'english_name': 'Madagascar',
#    'native_name': 'Madagascar'},
#   {'iso_3166_1': 'MK',
#    'english_name': 'Macedonia',
#    'native_name': 'Macedonia'},
#   {'iso_3166_1': 'ML', 'english_name': 'Mali', 'native_name': 'Mali'},
#   {'iso_3166_1': 'MT', 'english_name': 'Malta', 'native_name': 'Malta'},
#   {'iso_3166_1': 'MU',
#    'english_name': 'Mauritius',
#    'native_name': 'Mauritius'},
#   {'iso_3166_1': 'MW', 'english_name': 'Malawi', 'native_name': 'Malawi'},
#   {'iso_3166_1': 'MX', 'english_name': 'Mexico', 'native_name': 'Mexico'},
#   {'iso_3166_1': 'MY', 'english_name': 'Malaysia', 'native_name': 'Malaysia'},
#   {'iso_3166_1': 'MZ',
#    'english_name': 'Mozambique',
#    'native_name': 'Mozambique'},
#   {'iso_3166_1': 'NE', 'english_name': 'Niger', 'native_name': 'Niger'},
#   {'iso_3166_1': 'NG', 'english_name': 'Nigeria', 'native_name': 'Nigeria'},
#   {'iso_3166_1': 'NI',
#    'english_name': 'Nicaragua',
#    'native_name': 'Nicaragua'},
#   {'iso_3166_1': 'NL',
#    'english_name': 'Netherlands',
#    'native_name': 'Netherlands'},
#   {'iso_3166_1': 'NO', 'english_name': 'Norway', 'native_name': 'Norway'},
#   {'iso_3166_1': 'NZ',
#    'english_name': 'New Zealand',
#    'native_name': 'New Zealand'},
#   {'iso_3166_1': 'OM', 'english_name': 'Oman', 'native_name': 'Oman'},
#   {'iso_3166_1': 'PA', 'english_name': 'Panama', 'native_name': 'Panama'},
#   {'iso_3166_1': 'PE', 'english_name': 'Peru', 'native_name': 'Peru'},
#   {'iso_3166_1': 'PF',
#    'english_name': 'French Polynesia',
#    'native_name': 'French Polynesia'},
#   {'iso_3166_1': 'PG',
#    'english_name': 'Papua New Guinea',
#    'native_name': 'Papua New Guinea'},
#   {'iso_3166_1': 'PH',
#    'english_name': 'Philippines',
#    'native_name': 'Philippines'},
#   {'iso_3166_1': 'PK', 'english_name': 'Pakistan', 'native_name': 'Pakistan'},
#   {'iso_3166_1': 'PL', 'english_name': 'Poland', 'native_name': 'Poland'},
#   {'iso_3166_1': 'PS',
#    'english_name': 'Palestinian Territory',
#    'native_name': 'Palestinian Territories'},
#   {'iso_3166_1': 'PT', 'english_name': 'Portugal', 'native_name': 'Portugal'},
#   {'iso_3166_1': 'PY', 'english_name': 'Paraguay', 'native_name': 'Paraguay'},
#   {'iso_3166_1': 'QA', 'english_name': 'Qatar', 'native_name': 'Qatar'},
#   {'iso_3166_1': 'RO', 'english_name': 'Romania', 'native_name': 'Romania'},
#   {'iso_3166_1': 'RS', 'english_name': 'Serbia', 'native_name': 'Serbia'},
#   {'iso_3166_1': 'RU', 'english_name': 'Russia', 'native_name': 'Russia'},
#   {'iso_3166_1': 'SA',
#    'english_name': 'Saudi Arabia',
#    'native_name': 'Saudi Arabia'},
#   {'iso_3166_1': 'SC',
#    'english_name': 'Seychelles',
#    'native_name': 'Seychelles'},
#   {'iso_3166_1': 'SE', 'english_name': 'Sweden', 'native_name': 'Sweden'},
#   {'iso_3166_1': 'SG',
#    'english_name': 'Singapore',
#    'native_name': 'Singapore'},
#   {'iso_3166_1': 'SI', 'english_name': 'Slovenia', 'native_name': 'Slovenia'},
#   {'iso_3166_1': 'SK', 'english_name': 'Slovakia', 'native_name': 'Slovakia'},
#   {'iso_3166_1': 'SM',
#    'english_name': 'San Marino',
#    'native_name': 'San Marino'},
#   {'iso_3166_1': 'SN', 'english_name': 'Senegal', 'native_name': 'Senegal'},
#   {'iso_3166_1': 'SV',
#    'english_name': 'El Salvador',
#    'native_name': 'El Salvador'},
#   {'iso_3166_1': 'TC',
#    'english_name': 'Turks and Caicos Islands',
#    'native_name': 'Turks & Caicos Islands'},
#   {'iso_3166_1': 'TD', 'english_name': 'Chad', 'native_name': 'Chad'},
#   {'iso_3166_1': 'TH', 'english_name': 'Thailand', 'native_name': 'Thailand'},
#   {'iso_3166_1': 'TN', 'english_name': 'Tunisia', 'native_name': 'Tunisia'},
#   {'iso_3166_1': 'TR', 'english_name': 'Turkey', 'native_name': 'Turkey'},
#   {'iso_3166_1': 'TT',
#    'english_name': 'Trinidad and Tobago',
#    'native_name': 'Trinidad & Tobago'},
#   {'iso_3166_1': 'TW', 'english_name': 'Taiwan', 'native_name': 'Taiwan'},
#   {'iso_3166_1': 'TZ', 'english_name': 'Tanzania', 'native_name': 'Tanzania'},
#   {'iso_3166_1': 'UA', 'english_name': 'Ukraine', 'native_name': 'Ukraine'},
#   {'iso_3166_1': 'UG', 'english_name': 'Uganda', 'native_name': 'Uganda'},
#   {'iso_3166_1': 'US',
#    'english_name': 'United States of America',
#    'native_name': 'United States'},
#   {'iso_3166_1': 'UY', 'english_name': 'Uruguay', 'native_name': 'Uruguay'},
#   {'iso_3166_1': 'VA',
#    'english_name': 'Holy See',
#    'native_name': 'Vatican City'},
#   {'iso_3166_1': 'VE',
#    'english_name': 'Venezuela',
#    'native_name': 'Venezuela'},
#   {'iso_3166_1': 'XK', 'english_name': 'Kosovo', 'native_name': 'Kosovo'},
#   {'iso_3166_1': 'YE', 'english_name': 'Yemen', 'native_name': 'Yemen'},
#   {'iso_3166_1': 'ZA',
#    'english_name': 'South Africa',
#    'native_name': 'South Africa'},
#   {'iso_3166_1': 'ZM', 'english_name': 'Zambia', 'native_name': 'Zambia'},
#   {'iso_3166_1': 'ZW', 'english_name': 'Zimbabwe', 'native_name': 'Zimbabwe'}]}

# %%
res_url_regions.json().keys()
# Out:
# dict_keys(['results'])

# %%
res_url_regions.json()["results"]
# Out:
# [{'iso_3166_1': 'AD', 'english_name': 'Andorra', 'native_name': 'Andorra'},
#  {'iso_3166_1': 'AE',
#   'english_name': 'United Arab Emirates',
#   'native_name': 'United Arab Emirates'},
#  {'iso_3166_1': 'AG',
#   'english_name': 'Antigua and Barbuda',
#   'native_name': 'Antigua & Barbuda'},
#  {'iso_3166_1': 'AL', 'english_name': 'Albania', 'native_name': 'Albania'},
#  {'iso_3166_1': 'AO', 'english_name': 'Angola', 'native_name': 'Angola'},
#  {'iso_3166_1': 'AR', 'english_name': 'Argentina', 'native_name': 'Argentina'},
#  {'iso_3166_1': 'AT', 'english_name': 'Austria', 'native_name': 'Austria'},
#  {'iso_3166_1': 'AU', 'english_name': 'Australia', 'native_name': 'Australia'},
#  {'iso_3166_1': 'AZ',
#   'english_name': 'Azerbaijan',
#   'native_name': 'Azerbaijan'},
#  {'iso_3166_1': 'BA',
#   'english_name': 'Bosnia and Herzegovina',
#   'native_name': 'Bosnia & Herzegovina'},
#  {'iso_3166_1': 'BB', 'english_name': 'Barbados', 'native_name': 'Barbados'},
#  {'iso_3166_1': 'BE', 'english_name': 'Belgium', 'native_name': 'Belgium'},
#  {'iso_3166_1': 'BF',
#   'english_name': 'Burkina Faso',
#   'native_name': 'Burkina Faso'},
#  {'iso_3166_1': 'BG', 'english_name': 'Bulgaria', 'native_name': 'Bulgaria'},
#  {'iso_3166_1': 'BH', 'english_name': 'Bahrain', 'native_name': 'Bahrain'},
#  {'iso_3166_1': 'BM', 'english_name': 'Bermuda', 'native_name': 'Bermuda'},
#  {'iso_3166_1': 'BO', 'english_name': 'Bolivia', 'native_name': 'Bolivia'},
#  {'iso_3166_1': 'BR', 'english_name': 'Brazil', 'native_name': 'Brazil'},
#  {'iso_3166_1': 'BS', 'english_name': 'Bahamas', 'native_name': 'Bahamas'},
#  {'iso_3166_1': 'BY', 'english_name': 'Belarus', 'native_name': 'Belarus'},
#  {'iso_3166_1': 'BZ', 'english_name': 'Belize', 'native_name': 'Belize'},
#  {'iso_3166_1': 'CA', 'english_name': 'Canada', 'native_name': 'Canada'},
#  {'iso_3166_1': 'CD',
#   'english_name': 'Congo',
#   'native_name': 'Democratic Republic of the Congo (Kinshasa)'},
#  {'iso_3166_1': 'CH',
#   'english_name': 'Switzerland',
#   'native_name': 'Switzerland'},
#  {'iso_3166_1': 'CI',
#   'english_name': "Cote D'Ivoire",
#   'native_name': 'Côte d’Ivoire'},
#  {'iso_3166_1': 'CL', 'english_name': 'Chile', 'native_name': 'Chile'},
#  {'iso_3166_1': 'CM', 'english_name': 'Cameroon', 'native_name': 'Cameroon'},
#  {'iso_3166_1': 'CO', 'english_name': 'Colombia', 'native_name': 'Colombia'},
#  {'iso_3166_1': 'CR',
#   'english_name': 'Costa Rica',
#   'native_name': 'Costa Rica'},
#  {'iso_3166_1': 'CU', 'english_name': 'Cuba', 'native_name': 'Cuba'},
#  {'iso_3166_1': 'CV',
#   'english_name': 'Cape Verde',
#   'native_name': 'Cape Verde'},
#  {'iso_3166_1': 'CY', 'english_name': 'Cyprus', 'native_name': 'Cyprus'},
#  {'iso_3166_1': 'CZ',
#   'english_name': 'Czech Republic',
#   'native_name': 'Czech Republic'},
#  {'iso_3166_1': 'DE', 'english_name': 'Germany', 'native_name': 'Germany'},
#  {'iso_3166_1': 'DK', 'english_name': 'Denmark', 'native_name': 'Denmark'},
#  {'iso_3166_1': 'DO',
#   'english_name': 'Dominican Republic',
#   'native_name': 'Dominican Republic'},
#  {'iso_3166_1': 'DZ', 'english_name': 'Algeria', 'native_name': 'Algeria'},
#  {'iso_3166_1': 'EC', 'english_name': 'Ecuador', 'native_name': 'Ecuador'},
#  {'iso_3166_1': 'EE', 'english_name': 'Estonia', 'native_name': 'Estonia'},
#  {'iso_3166_1': 'EG', 'english_name': 'Egypt', 'native_name': 'Egypt'},
#  {'iso_3166_1': 'ES', 'english_name': 'Spain', 'native_name': 'Spain'},
#  {'iso_3166_1': 'FI', 'english_name': 'Finland', 'native_name': 'Finland'},
#  {'iso_3166_1': 'FJ', 'english_name': 'Fiji', 'native_name': 'Fiji'},
#  {'iso_3166_1': 'FR', 'english_name': 'France', 'native_name': 'France'},
#  {'iso_3166_1': 'GB',
#   'english_name': 'United Kingdom',
#   'native_name': 'United Kingdom'},
#  {'iso_3166_1': 'GF',
#   'english_name': 'French Guiana',
#   'native_name': 'French Guiana'},
#  {'iso_3166_1': 'GH', 'english_name': 'Ghana', 'native_name': 'Ghana'},
#  {'iso_3166_1': 'GI', 'english_name': 'Gibraltar', 'native_name': 'Gibraltar'},
#  {'iso_3166_1': 'GP',
#   'english_name': 'Guadaloupe',
#   'native_name': 'Guadeloupe'},
#  {'iso_3166_1': 'GQ',
#   'english_name': 'Equatorial Guinea',
#   'native_name': 'Equatorial Guinea'},
#  {'iso_3166_1': 'GR', 'english_name': 'Greece', 'native_name': 'Greece'},
#  {'iso_3166_1': 'GT', 'english_name': 'Guatemala', 'native_name': 'Guatemala'},
#  {'iso_3166_1': 'GY', 'english_name': 'Guyana', 'native_name': 'Guyana'},
#  {'iso_3166_1': 'HK',
#   'english_name': 'Hong Kong',
#   'native_name': 'Hong Kong SAR China'},
#  {'iso_3166_1': 'HN', 'english_name': 'Honduras', 'native_name': 'Honduras'},
#  {'iso_3166_1': 'HR', 'english_name': 'Croatia', 'native_name': 'Croatia'},
#  {'iso_3166_1': 'HU', 'english_name': 'Hungary', 'native_name': 'Hungary'},
#  {'iso_3166_1': 'ID', 'english_name': 'Indonesia', 'native_name': 'Indonesia'},
#  {'iso_3166_1': 'IE', 'english_name': 'Ireland', 'native_name': 'Ireland'},
#  {'iso_3166_1': 'IL', 'english_name': 'Israel', 'native_name': 'Israel'},
#  {'iso_3166_1': 'IN', 'english_name': 'India', 'native_name': 'India'},
#  {'iso_3166_1': 'IQ', 'english_name': 'Iraq', 'native_name': 'Iraq'},
#  {'iso_3166_1': 'IS', 'english_name': 'Iceland', 'native_name': 'Iceland'},
#  {'iso_3166_1': 'IT', 'english_name': 'Italy', 'native_name': 'Italy'},
#  {'iso_3166_1': 'JM', 'english_name': 'Jamaica', 'native_name': 'Jamaica'},
#  {'iso_3166_1': 'JO', 'english_name': 'Jordan', 'native_name': 'Jordan'},
#  {'iso_3166_1': 'JP', 'english_name': 'Japan', 'native_name': 'Japan'},
#  {'iso_3166_1': 'KE', 'english_name': 'Kenya', 'native_name': 'Kenya'},
#  {'iso_3166_1': 'KR',
#   'english_name': 'South Korea',
#   'native_name': 'South Korea'},
#  {'iso_3166_1': 'KW', 'english_name': 'Kuwait', 'native_name': 'Kuwait'},
#  {'iso_3166_1': 'LB', 'english_name': 'Lebanon', 'native_name': 'Lebanon'},
#  {'iso_3166_1': 'LC', 'english_name': 'St. Lucia', 'native_name': 'St. Lucia'},
#  {'iso_3166_1': 'LI',
#   'english_name': 'Liechtenstein',
#   'native_name': 'Liechtenstein'},
#  {'iso_3166_1': 'LT', 'english_name': 'Lithuania', 'native_name': 'Lithuania'},
#  {'iso_3166_1': 'LU',
#   'english_name': 'Luxembourg',
#   'native_name': 'Luxembourg'},
#  {'iso_3166_1': 'LV', 'english_name': 'Latvia', 'native_name': 'Latvia'},
#  {'iso_3166_1': 'LY',
#   'english_name': 'Libyan Arab Jamahiriya',
#   'native_name': 'Libya'},
#  {'iso_3166_1': 'MA', 'english_name': 'Morocco', 'native_name': 'Morocco'},
#  {'iso_3166_1': 'MC', 'english_name': 'Monaco', 'native_name': 'Monaco'},
#  {'iso_3166_1': 'MD', 'english_name': 'Moldova', 'native_name': 'Moldova'},
#  {'iso_3166_1': 'ME',
#   'english_name': 'Montenegro',
#   'native_name': 'Montenegro'},
#  {'iso_3166_1': 'MG',
#   'english_name': 'Madagascar',
#   'native_name': 'Madagascar'},
#  {'iso_3166_1': 'MK', 'english_name': 'Macedonia', 'native_name': 'Macedonia'},
#  {'iso_3166_1': 'ML', 'english_name': 'Mali', 'native_name': 'Mali'},
#  {'iso_3166_1': 'MT', 'english_name': 'Malta', 'native_name': 'Malta'},
#  {'iso_3166_1': 'MU', 'english_name': 'Mauritius', 'native_name': 'Mauritius'},
#  {'iso_3166_1': 'MW', 'english_name': 'Malawi', 'native_name': 'Malawi'},
#  {'iso_3166_1': 'MX', 'english_name': 'Mexico', 'native_name': 'Mexico'},
#  {'iso_3166_1': 'MY', 'english_name': 'Malaysia', 'native_name': 'Malaysia'},
#  {'iso_3166_1': 'MZ',
#   'english_name': 'Mozambique',
#   'native_name': 'Mozambique'},
#  {'iso_3166_1': 'NE', 'english_name': 'Niger', 'native_name': 'Niger'},
#  {'iso_3166_1': 'NG', 'english_name': 'Nigeria', 'native_name': 'Nigeria'},
#  {'iso_3166_1': 'NI', 'english_name': 'Nicaragua', 'native_name': 'Nicaragua'},
#  {'iso_3166_1': 'NL',
#   'english_name': 'Netherlands',
#   'native_name': 'Netherlands'},
#  {'iso_3166_1': 'NO', 'english_name': 'Norway', 'native_name': 'Norway'},
#  {'iso_3166_1': 'NZ',
#   'english_name': 'New Zealand',
#   'native_name': 'New Zealand'},
#  {'iso_3166_1': 'OM', 'english_name': 'Oman', 'native_name': 'Oman'},
#  {'iso_3166_1': 'PA', 'english_name': 'Panama', 'native_name': 'Panama'},
#  {'iso_3166_1': 'PE', 'english_name': 'Peru', 'native_name': 'Peru'},
#  {'iso_3166_1': 'PF',
#   'english_name': 'French Polynesia',
#   'native_name': 'French Polynesia'},
#  {'iso_3166_1': 'PG',
#   'english_name': 'Papua New Guinea',
#   'native_name': 'Papua New Guinea'},
#  {'iso_3166_1': 'PH',
#   'english_name': 'Philippines',
#   'native_name': 'Philippines'},
#  {'iso_3166_1': 'PK', 'english_name': 'Pakistan', 'native_name': 'Pakistan'},
#  {'iso_3166_1': 'PL', 'english_name': 'Poland', 'native_name': 'Poland'},
#  {'iso_3166_1': 'PS',
#   'english_name': 'Palestinian Territory',
#   'native_name': 'Palestinian Territories'},
#  {'iso_3166_1': 'PT', 'english_name': 'Portugal', 'native_name': 'Portugal'},
#  {'iso_3166_1': 'PY', 'english_name': 'Paraguay', 'native_name': 'Paraguay'},
#  {'iso_3166_1': 'QA', 'english_name': 'Qatar', 'native_name': 'Qatar'},
#  {'iso_3166_1': 'RO', 'english_name': 'Romania', 'native_name': 'Romania'},
#  {'iso_3166_1': 'RS', 'english_name': 'Serbia', 'native_name': 'Serbia'},
#  {'iso_3166_1': 'RU', 'english_name': 'Russia', 'native_name': 'Russia'},
#  {'iso_3166_1': 'SA',
#   'english_name': 'Saudi Arabia',
#   'native_name': 'Saudi Arabia'},
#  {'iso_3166_1': 'SC',
#   'english_name': 'Seychelles',
#   'native_name': 'Seychelles'},
#  {'iso_3166_1': 'SE', 'english_name': 'Sweden', 'native_name': 'Sweden'},
#  {'iso_3166_1': 'SG', 'english_name': 'Singapore', 'native_name': 'Singapore'},
#  {'iso_3166_1': 'SI', 'english_name': 'Slovenia', 'native_name': 'Slovenia'},
#  {'iso_3166_1': 'SK', 'english_name': 'Slovakia', 'native_name': 'Slovakia'},
#  {'iso_3166_1': 'SM',
#   'english_name': 'San Marino',
#   'native_name': 'San Marino'},
#  {'iso_3166_1': 'SN', 'english_name': 'Senegal', 'native_name': 'Senegal'},
#  {'iso_3166_1': 'SV',
#   'english_name': 'El Salvador',
#   'native_name': 'El Salvador'},
#  {'iso_3166_1': 'TC',
#   'english_name': 'Turks and Caicos Islands',
#   'native_name': 'Turks & Caicos Islands'},
#  {'iso_3166_1': 'TD', 'english_name': 'Chad', 'native_name': 'Chad'},
#  {'iso_3166_1': 'TH', 'english_name': 'Thailand', 'native_name': 'Thailand'},
#  {'iso_3166_1': 'TN', 'english_name': 'Tunisia', 'native_name': 'Tunisia'},
#  {'iso_3166_1': 'TR', 'english_name': 'Turkey', 'native_name': 'Turkey'},
#  {'iso_3166_1': 'TT',
#   'english_name': 'Trinidad and Tobago',
#   'native_name': 'Trinidad & Tobago'},
#  {'iso_3166_1': 'TW', 'english_name': 'Taiwan', 'native_name': 'Taiwan'},
#  {'iso_3166_1': 'TZ', 'english_name': 'Tanzania', 'native_name': 'Tanzania'},
#  {'iso_3166_1': 'UA', 'english_name': 'Ukraine', 'native_name': 'Ukraine'},
#  {'iso_3166_1': 'UG', 'english_name': 'Uganda', 'native_name': 'Uganda'},
#  {'iso_3166_1': 'US',
#   'english_name': 'United States of America',
#   'native_name': 'United States'},
#  {'iso_3166_1': 'UY', 'english_name': 'Uruguay', 'native_name': 'Uruguay'},
#  {'iso_3166_1': 'VA',
#   'english_name': 'Holy See',
#   'native_name': 'Vatican City'},
#  {'iso_3166_1': 'VE', 'english_name': 'Venezuela', 'native_name': 'Venezuela'},
#  {'iso_3166_1': 'XK', 'english_name': 'Kosovo', 'native_name': 'Kosovo'},
#  {'iso_3166_1': 'YE', 'english_name': 'Yemen', 'native_name': 'Yemen'},
#  {'iso_3166_1': 'ZA',
#   'english_name': 'South Africa',
#   'native_name': 'South Africa'},
#  {'iso_3166_1': 'ZM', 'english_name': 'Zambia', 'native_name': 'Zambia'},
#  {'iso_3166_1': 'ZW', 'english_name': 'Zimbabwe', 'native_name': 'Zimbabwe'}]

# %%
regions_df = pd.DataFrame(res_url_regions.json()["results"])
regions_df
# Out:
#     iso_3166_1          english_name           native_name
# 0           AD               Andorra               Andorra
# 1           AE  United Arab Emirates  United Arab Emirates
# 2           AG   Antigua and Barbuda     Antigua & Barbuda
# 3           AL               Albania               Albania
# 4           AO                Angola                Angola
# ..         ...                   ...                   ...
# 134         XK                Kosovo                Kosovo
# 135         YE                 Yemen                 Yemen
# 136         ZA          South Africa          South Africa
# 137         ZM                Zambia                Zambia
# 138         ZW              Zimbabwe              Zimbabwe
#
# [139 rows x 3 columns]

# %%
#Para poder filtrar, necesitamos el código ISO de España
regions_df[regions_df["native_name"] == "Spain"]
# Out:
#    iso_3166_1 english_name native_name
# 40         ES        Spain       Spain

# %% [markdown]
# # IDs de las plataformas de streaming:
#
# Puesto que nuestro análisis se va a limitar a las plataformas de **Netflix**, **Amazon Prime Video**, **Disney+** y **Max**, necesitamos conocer el identificador de cada una de ellas.

# %% [markdown]
# ## Series:
# Para los identificadores a nivel **serie**, accedemos al siguiente endpoint:
#
#
# ![API Plataformas para Series](./images/endpoint-tvproviders.png)

# %%
#Petición a la bbdd para la obtención de las plataformas de streaming existentes para las series en España
url_series_spain_providers= 'https://api.themoviedb.org/3/watch/providers/tv?watch_region=ES'
res_url_series_spain_providers = requests.get(url_series_spain_providers, headers=headers_user)
print(res_url_series_spain_providers)
# Out:
# <Response [200]>

# %%
res_url_series_spain_providers.json()
# Out:
# {'results': [{'display_priorities': {'AD': 7,
#     'AL': 7,
#     'AR': 0,
#     'AT': 2,
#     'AU': 0,
#     'BA': 7,
#     'BE': 0,
#     'BG': 16,
#     'BO': 2,
#     'BR': 0,
#     'BZ': 2,
#     'CA': 1,
#     'CH': 2,
#     'CL': 0,
#     'CO': 0,
#     'CR': 2,
#     'CZ': 0,
#     'DK': 0,
#     'DE': 2,
#     'DO': 24,
#     'EC': 1,
#     'EE': 23,
#     'ES': 0,
#     'FI': 0,
#     'EG': 45,
#     'FR': 0,
#     'GB': 1,
#     'GT': 1,
#     'GR': 20,
#     'HN': 2,
#     'HU': 0,
#     'HK': 32,
#     'HR': 31,
#     'IE': 2,
#     'IT': 0,
#     'IS': 1,
#     'JP': 2,
#     'JM': 26,
#     'KR': 2,
#     'LC': 13,
#     'LU': 3,
#     'LI': 25,
#     'LT': 24,
#     'LV': 23,
#     'ME': 1,
#     'MK': 7,
#     'MT': 7,
#     'MX': 0,
#     'NI': 2,
#     'NL': 1,
#     'NO': 0,
#     'NZ': 0,
#     'PE': 0,
#     'PA': 27,
#     'PL': 0,
#     'PT': 0,
#     'PH': 30,
#     'PY': 2,
#     'RO': 0,
#     'RS': 7,
#     'SG': 2,
#     'SI': 7,
#     'SE': 0,
#     'SK': 0,
#     'SV': 27,
#     'SM': 25,
#     'TR': 0,
#     'TT': 14,
#     'TW': 2,
#     'US': 0,
#     'VE': 1,
#     'UY': 27},
#    'display_priority': 27,
#    'logo_path': '/97yvRBw1GzX7fXprcF80er19ot.jpg',
#    'provider_name': 'Disney Plus',
#    'provider_id': 337},
#   {'display_priorities': {'AE': 2,
#     'AG': 11,
#     'AR': 5,
#     'AT': 5,
#     'AZ': 3,
#     'AU': 11,
#     'BE': 9,
#     'BG': 3,
#     'BO': 3,
#     'BH': 49,
#     'BM': 27,
#     'BR': 9,
#     'BY': 3,
#     'BZ': 4,
#     'BS': 25,
#     'CA': 7,
#     'CH': 18,
#     'CL': 5,
#     'CO': 5,
#     'CR': 3,
#     'CY': 4,
#     'CV': 10,
#     'CZ': 7,
#     'DE': 3,
#     'DK': 10,
#     'DO': 31,
#     'EC': 7,
#     'EE': 7,
#     'EG': 3,
#     'ES': 1,
#     'FI': 12,
#     'FJ': 11,
#     'FR': 3,
#     'GB': 3,
#     'GH': 13,
#     'GR': 5,
#     'GT': 3,
#     'HN': 3,
#     'HK': 16,
#     'HU': 7,
#     'IE': 5,
#     'IN': 2,
#     'ID': 12,
#     'IL': 25,
#     'IT': 5,
#     'JP': 10,
#     'JO': 50,
#     'KR': 5,
#     'LB': 28,
#     'LU': 5,
#     'LT': 7,
#     'LV': 7,
#     'MD': 25,
#     'MU': 12,
#     'MT': 25,
#     'MX': 3,
#     'MY': 11,
#     'MZ': 13,
#     'NI': 5,
#     'NL': 10,
#     'NO': 6,
#     'NZ': 5,
#     'PE': 6,
#     'PA': 25,
#     'OM': 49,
#     'PL': 3,
#     'PH': 11,
#     'PT': 11,
#     'PY': 4,
#     'RU': 3,
#     'SA': 2,
#     'QA': 49,
#     'SE': 5,
#     'SG': 11,
#     'SI': 24,
#     'SK': 5,
#     'SV': 31,
#     'TH': 10,
#     'TT': 11,
#     'TW': 15,
#     'UA': 1,
#     'UG': 13,
#     'US': 2,
#     'VE': 5,
#     'ZA': 9},
#    'display_priority': 9,
#    'logo_path': '/2E03IAZsX4ZaUqM7tXlctEPMGWS.jpg',
#    'provider_name': 'Apple TV Plus',
#    'provider_id': 350},
#   {'display_priorities': {'AD': 1,
#     'AG': 1,
#     'AL': 1,
#     'AE': 9,
#     'AO': 1,
#     'AR': 2,
#     'AU': 2,
#     'BA': 1,
#     'BB': 1,
#     'BE': 2,
#     'BF': 1,
#     'BG': 1,
#     'BH': 1,
#     'BM': 1,
#     'BO': 1,
#     'BR': 1,
#     'BS': 1,
#     'BY': 2,
#     'BZ': 3,
#     'CA': 2,
#     'CD': 0,
#     'CH': 1,
#     'CI': 1,
#     'CL': 2,
#     'CO': 1,
#     'CM': 1,
#     'CR': 1,
#     'CU': 1,
#     'CV': 1,
#     'CY': 3,
#     'CZ': 2,
#     'DK': 2,
#     'DO': 1,
#     'DZ': 1,
#     'EC': 2,
#     'EE': 1,
#     'EG': 1,
#     'ES': 2,
#     'FI': 2,
#     'FJ': 1,
#     'FR': 2,
#     'GF': 1,
#     'GG': 1,
#     'GH': 1,
#     'GI': 1,
#     'GQ': 1,
#     'GR': 1,
#     'GT': 2,
#     'GY': 0,
#     'HK': 5,
#     'HN': 1,
#     'HR': 1,
#     'HU': 2,
#     'IE': 1,
#     'ID': 7,
#     'IL': 1,
#     'IN': 1,
#     'IQ': 1,
#     'IT': 2,
#     'IS': 2,
#     'JM': 1,
#     'JO': 1,
#     'KE': 1,
#     'KR': 1,
#     'KW': 1,
#     'LB': 1,
#     'LC': 1,
#     'LI': 1,
#     'LT': 1,
#     'MA': 1,
#     'LV': 1,
#     'LY': 1,
#     'MC': 1,
#     'MD': 1,
#     'MG': 1,
#     'ML': 2,
#     'MK': 1,
#     'MT': 1,
#     'MW': 0,
#     'MX': 1,
#     'MZ': 1,
#     'NE': 1,
#     'MY': 9,
#     'NG': 1,
#     'NI': 4,
#     'NL': 2,
#     'NO': 2,
#     'NZ': 2,
#     'OM': 1,
#     'PA': 1,
#     'PE': 1,
#     'PG': 1,
#     'PK': 1,
#     'PF': 1,
#     'PL': 5,
#     'PH': 1,
#     'PS': 1,
#     'PT': 2,
#     'PY': 1,
#     'QA': 1,
#     'RO': 2,
#     'RS': 1,
#     'SC': 1,
#     'SA': 23,
#     'SI': 1,
#     'SG': 1,
#     'SE': 2,
#     'SN': 1,
#     'SV': 1,
#     'SK': 2,
#     'SM': 1,
#     'TC': 1,
#     'TH': 3,
#     'TD': 2,
#     'TN': 1,
#     'TR': 6,
#     'TT': 1,
#     'TW': 1,
#     'TZ': 1,
#     'UG': 1,
#     'VA': 0,
#     'UY': 1,
#     'VE': 2,
#     'YE': 1,
#     'ZA': 1,
#     'ZM': 1,
#     'ZW': 2},
#    'display_priority': 1,
#    'logo_path': '/dQeAar5H991VYporEjUspolDarG.jpg',
#    'provider_name': 'Amazon Prime Video',
#    'provider_id': 119},
#   {'display_priorities': {'ES': 3},
#    'display_priority': 3,
#    'logo_path': '/jse4MOi92Jgetym7nbXFZZBI6LK.jpg',
#    'provider_name': 'Movistar Plus+ €9.99',
#    'provider_id': 2241},
#   {'display_priorities': {'AL': 8,
#     'AT': 9,
#     'BA': 8,
#     'BE': 10,
#     'CH': 9,
#     'CY': 2,
#     'DE': 16,
#     'DK': 14,
#     'CZ': 34,
#     'ES': 4,
#     'FI': 14,
#     'FR': 21,
#     'GB': 5,
#     'GR': 24,
#     'HU': 27,
#     'IE': 12,
#     'IT': 3,
#     'LU': 2,
#     'ME': 0,
#     'MK': 8,
#     'MT': 8,
#     'NL': 15,
#     'NO': 14,
#     'PT': 8,
#     'PL': 37,
#     'RO': 23,
#     'RS': 8,
#     'SI': 8,
#     'SE': 15,
#     'SK': 39,
#     'UA': 4},
#    'display_priority': 4,
#    'logo_path': '/bZvc9dXrXNly7cA0V4D9pR8yJwm.jpg',
#    'provider_name': 'Rakuten TV',
#    'provider_id': 35},
#   {'display_priorities': {'ES': 5},
#    'display_priority': 5,
#    'logo_path': '/f6TRLB3H4jDpFEZ0z2KWSSvu1SB.jpg',
#    'provider_name': 'Movistar Plus+',
#    'provider_id': 149},
#   {'display_priorities': {'CA': 97, 'ES': 7, 'US': 8},
#    'display_priority': 8,
#    'logo_path': '/9BgaNQRMDvVlji1JBZi6tcfxpKx.jpg',
#    'provider_name': 'fuboTV',
#    'provider_id': 257},
#   {'display_priorities': {'AD': 24,
#     'AL': 26,
#     'BA': 26,
#     'BG': 19,
#     'CZ': 26,
#     'DK': 36,
#     'ES': 8,
#     'FI': 37,
#     'HU': 24,
#     'HR': 33,
#     'MK': 25,
#     'NL': 11,
#     'NO': 7,
#     'PL': 7,
#     'PT': 32,
#     'RO': 20,
#     'RS': 27,
#     'SE': 7,
#     'SI': 27,
#     'SK': 35,
#     'XK': 3},
#    'display_priority': 3,
#    'logo_path': '/gQbqEYd0C9uprYxEUqTM589qn8g.jpg',
#    'provider_name': 'SkyShowtime',
#    'provider_id': 1773},
#   {'display_priorities': {'ES': 9, 'PT': 27},
#    'display_priority': 27,
#    'logo_path': '/kO2SWXvDCHAquaUuTJBuZkTBAuU.jpg',
#    'provider_name': 'Filmin',
#    'provider_id': 63},
#   {'display_priorities': {'AU': 4,
#     'AT': 67,
#     'BE': 3,
#     'CA': 3,
#     'CH': 52,
#     'DK': 3,
#     'CZ': 35,
#     'DE': 21,
#     'ES': 12,
#     'FI': 3,
#     'FR': 14,
#     'GB': 33,
#     'HK': 9,
#     'HU': 28,
#     'IE': 3,
#     'IT': 6,
#     'LU': 4,
#     'NL': 3,
#     'NO': 3,
#     'PH': 2,
#     'PL': 38,
#     'RO': 24,
#     'SG': 3,
#     'SE': 3},
#    'display_priority': 3,
#    'logo_path': '/jxIBXlxRbCcy7Y4GvOZKszCd0dv.jpg',
#    'provider_name': 'Hayu',
#    'provider_id': 223},
#   {'display_priorities': {'ES': 13},
#    'display_priority': 13,
#    'logo_path': '/oN6g8QorcoYo3mx4BulU22ghKq4.jpg',
#    'provider_name': 'Atres Player',
#    'provider_id': 62},
#   {'display_priorities': {'AD': 2,
#     'AL': 2,
#     'BA': 2,
#     'BB': 2,
#     'BH': 2,
#     'BM': 2,
#     'BS': 2,
#     'CI': 2,
#     'DO': 2,
#     'DZ': 2,
#     'EG': 5,
#     'ES': 15,
#     'GF': 2,
#     'GI': 2,
#     'HR': 4,
#     'IL': 2,
#     'IQ': 2,
#     'IS': 5,
#     'JM': 2,
#     'JO': 2,
#     'KW': 2,
#     'LB': 2,
#     'LI': 2,
#     'MA': 2,
#     'LY': 2,
#     'MC': 2,
#     'MD': 2,
#     'MK': 2,
#     'MT': 2,
#     'NE': 2,
#     'NG': 2,
#     'OM': 2,
#     'PA': 2,
#     'PS': 2,
#     'QA': 2,
#     'RS': 2,
#     'SA': 4,
#     'SI': 2,
#     'SV': 2,
#     'SM': 2,
#     'SK': 7,
#     'TN': 2,
#     'TW': 10,
#     'TZ': 19,
#     'UY': 4,
#     'YE': 2},
#    'display_priority': 2,
#    'logo_path': '/ozMgkAAoi6aDI5ce8KKA2k8TGvB.jpg',
#    'provider_name': 'FlixOlé',
#    'provider_id': 393},
#   {'display_priorities': {'AG': 12,
#     'AD': 27,
#     'BA': 29,
#     'AR': 61,
#     'BB': 25,
#     'BG': 22,
#     'BO': 32,
#     'BR': 7,
#     'BZ': 10,
#     'BS': 26,
#     'CL': 7,
#     'CO': 6,
#     'CR': 4,
#     'CZ': 36,
#     'DO': 32,
#     'DK': 43,
#     'EC': 5,
#     'FI': 45,
#     'ES': 16,
#     'FR': 116,
#     'GT': 4,
#     'GY': 4,
#     'HN': 32,
#     'HU': 29,
#     'HR': 36,
#     'JM': 24,
#     'LC': 11,
#     'MC': 27,
#     'ME': 7,
#     'MD': 27,
#     'MK': 28,
#     'MX': 5,
#     'NI': 14,
#     'NO': 44,
#     'PE': 7,
#     'NL': 89,
#     'PA': 32,
#     'PL': 40,
#     'PY': 31,
#     'RO': 25,
#     'PT': 62,
#     'RS': 30,
#     'SI': 30,
#     'SE': 48,
#     'SV': 32,
#     'TC': 11,
#     'SK': 40,
#     'TT': 12,
#     'US': 9,
#     'UY': 3,
#     'VE': 30,
#     'BE': 67},
#    'display_priority': 30,
#    'logo_path': '/fksCUZ9QDWZMUwL2LgMtLckROUN.jpg',
#    'provider_name': 'Max',
#    'provider_id': 1899},
#   {'display_priorities': {'AT': 12,
#     'AU': 17,
#     'BR': 16,
#     'CH': 6,
#     'CA': 23,
#     'DK': 8,
#     'DE': 32,
#     'ES': 17,
#     'FI': 10,
#     'FR': 15,
#     'GB': 18,
#     'IE': 14,
#     'IT': 22,
#     'JP': 7,
#     'MX': 13,
#     'NL': 14,
#     'NO': 9,
#     'NZ': 9,
#     'SE': 8,
#     'US': 45},
#    'display_priority': 45,
#    'logo_path': '/5vfrJQgNe9UnHVgVNAwZTy0Jo9o.jpg',
#    'provider_name': 'Microsoft Store',
#    'provider_id': 68},
#   {'display_priorities': {'AT': 13,
#     'AU': 14,
#     'BE': 8,
#     'CH': 20,
#     'CA': 39,
#     'DK': 13,
#     'DE': 20,
#     'FI': 7,
#     'ES': 20,
#     'FR': 17,
#     'GB': 31,
#     'HU': 6,
#     'HK': 28,
#     'IE': 20,
#     'IT': 21,
#     'MX': 10,
#     'NZ': 7,
#     'NO': 13,
#     'PT': 6,
#     'RU': 8,
#     'SE': 14,
#     'TR': 2,
#     'TW': 27,
#     'US': 33},
#    'display_priority': 33,
#    'logo_path': '/rMb93u1tBeErSYLv79zSTR07UdO.jpg',
#    'provider_name': 'YouTube Premium',
#    'provider_id': 188},
#   {'display_priorities': {'AD': 8,
#     'AL': 9,
#     'AR': 11,
#     'AT': 24,
#     'AU': 36,
#     'BA': 9,
#     'BB': 6,
#     'BE': 14,
#     'BG': 5,
#     'BH': 6,
#     'BM': 6,
#     'BO': 13,
#     'BS': 6,
#     'BR': 18,
#     'CI': 7,
#     'CH': 23,
#     'CA': 53,
#     'CL': 11,
#     'CO': 11,
#     'CR': 7,
#     'CZ': 8,
#     'DO': 6,
#     'DK': 18,
#     'DZ': 6,
#     'DE': 43,
#     'EC': 11,
#     'EE': 9,
#     'EG': 10,
#     'ES': 21,
#     'FI': 17,
#     'FR': 26,
#     'GF': 6,
#     'GB': 40,
#     'GI': 6,
#     'GR': 6,
#     'GT': 7,
#     'HK': 13,
#     'HN': 4,
#     'HR': 9,
#     'HU': 8,
#     'IL': 7,
#     'ID': 17,
#     'IE': 21,
#     'IN': 21,
#     'IQ': 7,
#     'IS': 9,
#     'IT': 26,
#     'JM': 6,
#     'JO': 6,
#     'JP': 11,
#     'KR': 12,
#     'KW': 6,
#     'LB': 7,
#     'LI': 6,
#     'LT': 9,
#     'MA': 6,
#     'LV': 9,
#     'LY': 6,
#     'MC': 6,
#     'MD': 6,
#     'MK': 9,
#     'MT': 9,
#     'MX': 20,
#     'NE': 7,
#     'MY': 15,
#     'NG': 7,
#     'NL': 22,
#     'NO': 19,
#     'NZ': 20,
#     'OM': 6,
#     'PA': 6,
#     'PE': 11,
#     'PL': 9,
#     'PH': 13,
#     'PS': 7,
#     'PT': 14,
#     'PY': 6,
#     'QA': 6,
#     'RO': 4,
#     'RS': 9,
#     'RU': 9,
#     'SA': 8,
#     'SI': 9,
#     'SG': 14,
#     'SE': 19,
#     'SV': 6,
#     'SM': 6,
#     'SK': 12,
#     'TH': 13,
#     'TN': 6,
#     'TR': 10,
#     'TW': 12,
#     'TZ': 20,
#     'UY': 8,
#     'VE': 8,
#     'YE': 6,
#     'US': 51,
#     'ZA': 11},
#    'display_priority': 51,
#    'logo_path': '/oR1aNm1Qu9jQBkW4VrGPWhqbC3P.jpg',
#    'provider_name': 'Curiosity Stream',
#    'provider_id': 190},
#   {'display_priorities': {'ES': 22},
#    'display_priority': 22,
#    'logo_path': '/273VHxSrDdEwLTXJrsnE6yJMqNZ.jpg',
#    'provider_name': 'Mitele ',
#    'provider_id': 456},
#   {'display_priorities': {'AR': 18,
#     'AT': 26,
#     'AU': 35,
#     'BE': 17,
#     'BG': 7,
#     'BH': 9,
#     'BM': 9,
#     'BO': 8,
#     'BS': 9,
#     'BR': 22,
#     'CH': 24,
#     'CA': 55,
#     'CL': 14,
#     'CO': 15,
#     'CR': 12,
#     'CZ': 10,
#     'DO': 9,
#     'DK': 19,
#     'DZ': 9,
#     'DE': 44,
#     'EC': 14,
#     'EE': 11,
#     'ES': 23,
#     'FI': 19,
#     'FR': 28,
#     'GF': 9,
#     'GB': 44,
#     'GI': 9,
#     'GR': 8,
#     'GT': 12,
#     'HN': 11,
#     'HR': 12,
#     'HU': 10,
#     'ID': 18,
#     'IE': 23,
#     'IN': 24,
#     'IS': 12,
#     'IT': 27,
#     'JO': 9,
#     'JP': 13,
#     'KR': 14,
#     'KW': 9,
#     'LI': 9,
#     'LT': 11,
#     'MA': 9,
#     'LV': 11,
#     'LY': 9,
#     'MC': 9,
#     'MD': 9,
#     'MX': 27,
#     'MY': 16,
#     'NL': 24,
#     'NO': 20,
#     'NZ': 21,
#     'OM': 9,
#     'PA': 9,
#     'PE': 15,
#     'PL': 10,
#     'PH': 15,
#     'PT': 16,
#     'PY': 11,
#     'RO': 6,
#     'QA': 9,
#     'RU': 11,
#     'SG': 16,
#     'SE': 21,
#     'SV': 9,
#     'SM': 9,
#     'SK': 15,
#     'TH': 14,
#     'TN': 9,
#     'TR': 13,
#     'TW': 28,
#     'TZ': 22,
#     'UY': 12,
#     'VE': 12,
#     'YE': 9,
#     'ZA': 13,
#     'US': 132},
#    'display_priority': 132,
#    'logo_path': '/5zqbck5mo8PuVbGu2ngBUdn5Yga.jpg',
#    'provider_name': 'DOCSVILLE',
#    'provider_id': 475},
#   {'display_priorities': {'ES': 25},
#    'display_priority': 25,
#    'logo_path': '/3QQKYFUDt13Q2Zm6JM2cOjlbd27.jpg',
#    'provider_name': 'rtve',
#    'provider_id': 541},
#   {'display_priorities': {'AG': 13,
#     'AD': 26,
#     'AO': 5,
#     'AL': 28,
#     'AZ': 5,
#     'AU': 47,
#     'BA': 28,
#     'AR': 62,
#     'AT': 64,
#     'BF': 5,
#     'BB': 26,
#     'BG': 21,
#     'BE': 64,
#     'BM': 28,
#     'BO': 33,
#     'BY': 8,
#     'BZ': 11,
#     'BS': 27,
#     'CI': 27,
#     'BR': 85,
#     'CH': 50,
#     'CA': 87,
#     'CM': 5,
#     'CL': 34,
#     'CO': 35,
#     'CR': 33,
#     'CY': 9,
#     'CV': 13,
#     'CZ': 33,
#     'DO': 33,
#     'DK': 41,
#     'DE': 55,
#     'DZ': 29,
#     'EC': 33,
#     'EE': 27,
#     'ES': 26,
#     'FI': 43,
#     'FJ': 13,
#     'FR': 30,
#     'GB': 48,
#     'GF': 29,
#     'GG': 11,
#     'GH': 16,
#     'GI': 27,
#     'GQ': 14,
#     'GR': 23,
#     'GY': 5,
#     'GT': 33,
#     'HK': 39,
#     'HN': 33,
#     'HU': 26,
#     'HR': 35,
#     'IL': 27,
#     'IN': 31,
#     'ID': 40,
#     'IE': 44,
#     'IT': 29,
#     'IS': 32,
#     'IQ': 49,
#     'JM': 25,
#     'KE': 15,
#     'JP': 53,
#     'JO': 51,
#     'KR': 15,
#     'LC': 12,
#     'LB': 29,
#     'KW': 50,
#     'LI': 29,
#     'LU': 11,
#     'LT': 28,
#     'LV': 27,
#     'MA': 28,
#     'LY': 29,
#     'MC': 26,
#     'ME': 6,
#     'MG': 5,
#     'ML': 6,
#     'MD': 26,
#     'MW': 3,
#     'MK': 27,
#     'MU': 15,
#     'MT': 26,
#     'MZ': 17,
#     'MY': 32,
#     'NE': 27,
#     'NG': 30,
#     'NI': 15,
#     'MX': 78,
#     'NZ': 37,
#     'NO': 42,
#     'NL': 86,
#     'PA': 33,
#     'PG': 6,
#     'PE': 34,
#     'OM': 50,
#     'PK': 8,
#     'PF': 12,
#     'PL': 34,
#     'PH': 33,
#     'PS': 28,
#     'PY': 32,
#     'RO': 22,
#     'PT': 60,
#     'RS': 29,
#     'RU': 30,
#     'SC': 14,
#     'SI': 29,
#     'SG': 31,
#     'SN': 14,
#     'SE': 47,
#     'SV': 33,
#     'TC': 12,
#     'SM': 28,
#     'SK': 38,
#     'TD': 7,
#     'TH': 30,
#     'TT': 13,
#     'TN': 29,
#     'UA': 8,
#     'TW': 39,
#     'TZ': 32,
#     'UG': 16,
#     'XK': 5,
#     'VA': 7,
#     'UY': 32,
#     'VE': 31,
#     'YE': 28,
#     'ZW': 6,
#     'ZM': 14,
#     'ZA': 30,
#     'US': 140},
#    'display_priority': 140,
#    'logo_path': '/vLZKlXUNDcZR7ilvfY9Wr9k80FZ.jpg',
#    'provider_name': 'Plex',
#    'provider_id': 538},
#   {'display_priorities': {'AD': 14,
#     'AL': 15,
#     'AR': 20,
#     'AT': 31,
#     'AU': 38,
#     'BA': 15,
#     'BE': 20,
#     'BM': 11,
#     'BO': 6,
#     'BR': 28,
#     'CI': 11,
#     'CH': 28,
#     'CA': 63,
#     'CL': 16,
#     'CO': 17,
#     'CR': 14,
#     'CZ': 11,
#     'DK': 21,
#     'DE': 56,
#     'EC': 16,
#     'EE': 12,
#     'ES': 27,
#     'FI': 23,
#     'FR': 31,
#     'GF': 11,
#     'GB': 49,
#     'GI': 11,
#     'GR': 9,
#     'GT': 14,
#     'HN': 13,
#     'HU': 11,
#     'ID': 21,
#     'IL': 13,
#     'IE': 24,
#     'IN': 32,
#     'IQ': 15,
#     'IS': 13,
#     'IT': 30,
#     'JP': 14,
#     'KR': 16,
#     'KW': 11,
#     'LB': 15,
#     'LI': 11,
#     'LT': 12,
#     'LV': 12,
#     'MK': 14,
#     'MT': 14,
#     'MY': 17,
#     'MX': 30,
#     'NE': 11,
#     'NG': 12,
#     'NL': 27,
#     'NO': 22,
#     'NZ': 22,
#     'PE': 17,
#     'PL': 14,
#     'PH': 17,
#     'PS': 15,
#     'PT': 18,
#     'PY': 13,
#     'RO': 7,
#     'RU': 12,
#     'RS': 15,
#     'SI': 15,
#     'SG': 17,
#     'SE': 26,
#     'SM': 11,
#     'TH': 15,
#     'TN': 11,
#     'TR': 14,
#     'VE': 13,
#     'YE': 11,
#     'ZA': 14,
#     'US': 142},
#    'display_priority': 142,
#    'logo_path': '/6dET59jNU0ADysghEjl8Unuc7Ca.jpg',
#    'provider_name': 'WOW Presents Plus',
#    'provider_id': 546},
#   {'display_priorities': {'AD': 12,
#     'AL': 13,
#     'AR': 19,
#     'AT': 32,
#     'AU': 39,
#     'BA': 13,
#     'BB': 10,
#     'BE': 21,
#     'BH': 11,
#     'BM': 12,
#     'BO': 14,
#     'BS': 11,
#     'BR': 29,
#     'CH': 29,
#     'CA': 65,
#     'CL': 17,
#     'CO': 18,
#     'CR': 15,
#     'CZ': 12,
#     'DO': 11,
#     'DK': 22,
#     'DZ': 11,
#     'DE': 58,
#     'EC': 17,
#     'EE': 13,
#     'EG': 14,
#     'ES': 28,
#     'FI': 24,
#     'FR': 33,
#     'GF': 12,
#     'GB': 50,
#     'GI': 12,
#     'GR': 10,
#     'GT': 15,
#     'HK': 20,
#     'HN': 14,
#     'HR': 14,
#     'HU': 12,
#     'IL': 11,
#     'ID': 22,
#     'IE': 25,
#     'IN': 33,
#     'IQ': 13,
#     'IS': 15,
#     'IT': 31,
#     'JM': 10,
#     'JO': 11,
#     'JP': 15,
#     'KR': 17,
#     'KW': 12,
#     'LB': 13,
#     'LI': 12,
#     'LT': 13,
#     'MA': 11,
#     'LV': 13,
#     'LY': 11,
#     'MC': 11,
#     'MD': 11,
#     'MK': 12,
#     'MT': 12,
#     'MY': 18,
#     'MX': 29,
#     'NG': 10,
#     'NL': 29,
#     'NO': 23,
#     'NZ': 23,
#     'OM': 11,
#     'PA': 12,
#     'PE': 18,
#     'PL': 16,
#     'PH': 18,
#     'PS': 13,
#     'PT': 19,
#     'PY': 14,
#     'RO': 8,
#     'QA': 11,
#     'RU': 13,
#     'RS': 13,
#     'SA': 12,
#     'SI': 13,
#     'SG': 18,
#     'SE': 27,
#     'SV': 12,
#     'SM': 12,
#     'SK': 17,
#     'TH': 16,
#     'TN': 12,
#     'TR': 15,
#     'TW': 19,
#     'TZ': 26,
#     'UY': 15,
#     'VE': 14,
#     'YE': 12,
#     'ZA': 15,
#     'US': 143},
#    'display_priority': 143,
#    'logo_path': '/mSH24WQcRDJ2fsL5iucXqqRnSRb.jpg',
#    'provider_name': 'Magellan TV',
#    'provider_id': 551},
#   {'display_priorities': {'AD': 13,
#     'AL': 14,
#     'AR': 21,
#     'AT': 33,
#     'AU': 40,
#     'BA': 14,
#     'BB': 11,
#     'BE': 22,
#     'BG': 6,
#     'BH': 12,
#     'BO': 7,
#     'BM': 13,
#     'BS': 12,
#     'BR': 30,
#     'CI': 10,
#     'CH': 30,
#     'CA': 66,
#     'CL': 19,
#     'CO': 19,
#     'CR': 13,
#     'CZ': 13,
#     'DO': 12,
#     'DK': 23,
#     'DZ': 12,
#     'DE': 59,
#     'EC': 18,
#     'EE': 14,
#     'EG': 15,
#     'ES': 29,
#     'FI': 25,
#     'FR': 34,
#     'GF': 13,
#     'GB': 51,
#     'GI': 13,
#     'GR': 11,
#     'GT': 13,
#     'HN': 12,
#     'HK': 24,
#     'HR': 15,
#     'HU': 13,
#     'IL': 12,
#     'ID': 23,
#     'IE': 27,
#     'IN': 34,
#     'IQ': 14,
#     'IS': 16,
#     'IT': 32,
#     'JM': 11,
#     'JO': 12,
#     'JP': 16,
#     'KR': 18,
#     'KW': 13,
#     'LB': 14,
#     'LI': 13,
#     'LT': 15,
#     'MA': 12,
#     'LV': 14,
#     'LY': 12,
#     'MC': 12,
#     'MD': 12,
#     'MK': 13,
#     'MT': 13,
#     'NE': 10,
#     'MY': 19,
#     'MX': 31,
#     'NG': 11,
#     'NL': 30,
#     'NO': 24,
#     'NZ': 24,
#     'OM': 12,
#     'PA': 13,
#     'PE': 19,
#     'PL': 17,
#     'PH': 19,
#     'PS': 14,
#     'PT': 20,
#     'PY': 12,
#     'RO': 9,
#     'QA': 12,
#     'RU': 14,
#     'RS': 14,
#     'SA': 13,
#     'SI': 14,
#     'SG': 19,
#     'SE': 28,
#     'SV': 13,
#     'SM': 13,
#     'SK': 18,
#     'TH': 17,
#     'TN': 13,
#     'TR': 16,
#     'TW': 23,
#     'TZ': 27,
#     'UY': 16,
#     'VE': 15,
#     'YE': 13,
#     'ZA': 16,
#     'US': 144},
#    'display_priority': 144,
#    'logo_path': '/6IYZ4NjwPikxN7J9cfSmuyeHeMm.jpg',
#    'provider_name': 'BroadwayHD',
#    'provider_id': 554},
#   {'display_priorities': {'AD': 15,
#     'AL': 16,
#     'AR': 23,
#     'AT': 35,
#     'AU': 42,
#     'BA': 16,
#     'BB': 12,
#     'BE': 24,
#     'BG': 8,
#     'BH': 13,
#     'BO': 9,
#     'BM': 14,
#     'BS': 13,
#     'BR': 33,
#     'CI': 12,
#     'CH': 32,
#     'CA': 68,
#     'CL': 20,
#     'CO': 21,
#     'CR': 11,
#     'CZ': 15,
#     'DO': 13,
#     'DK': 25,
#     'DZ': 13,
#     'DE': 62,
#     'EC': 20,
#     'EE': 16,
#     'ES': 31,
#     'FI': 27,
#     'FR': 36,
#     'GF': 14,
#     'GB': 56,
#     'GI': 14,
#     'GR': 13,
#     'GT': 11,
#     'HN': 10,
#     'HK': 21,
#     'HR': 16,
#     'HU': 15,
#     'IL': 14,
#     'ID': 25,
#     'IE': 29,
#     'IN': 38,
#     'IQ': 16,
#     'IS': 17,
#     'IT': 34,
#     'JM': 12,
#     'JO': 13,
#     'JP': 18,
#     'KR': 20,
#     'KW': 14,
#     'LB': 16,
#     'LI': 14,
#     'LT': 17,
#     'MA': 13,
#     'LV': 16,
#     'LY': 13,
#     'MC': 13,
#     'MD': 13,
#     'MK': 15,
#     'MT': 15,
#     'NE': 12,
#     'MY': 21,
#     'MX': 33,
#     'NG': 13,
#     'NL': 33,
#     'NZ': 26,
#     'NO': 27,
#     'OM': 13,
#     'PA': 14,
#     'PE': 21,
#     'PL': 19,
#     'PH': 21,
#     'PS': 16,
#     'PT': 22,
#     'PY': 10,
#     'RO': 11,
#     'QA': 13,
#     'RS': 16,
#     'RU': 16,
#     'SI': 16,
#     'SG': 21,
#     'SE': 30,
#     'SV': 14,
#     'SM': 14,
#     'SK': 19,
#     'TH': 19,
#     'TN': 14,
#     'TR': 18,
#     'TW': 20,
#     'TZ': 21,
#     'UY': 17,
#     'VE': 17,
#     'YE': 14,
#     'ZA': 18,
#     'US': 87},
#    'display_priority': 87,
#    'logo_path': '/x6nRFzF32hCzMHaVM4RHRo7lsgS.jpg',
#    'provider_name': 'Dekkoo',
#    'provider_id': 444},
#   {'display_priorities': {'AD': 19,
#     'AL': 20,
#     'AR': 27,
#     'AT': 39,
#     'AU': 46,
#     'BA': 20,
#     'BB': 16,
#     'BE': 28,
#     'BH': 17,
#     'BM': 18,
#     'BO': 17,
#     'BS': 17,
#     'BR': 37,
#     'CI': 16,
#     'CH': 35,
#     'CA': 72,
#     'CL': 23,
#     'CO': 24,
#     'CR': 18,
#     'CZ': 18,
#     'DO': 17,
#     'DK': 28,
#     'DZ': 16,
#     'DE': 66,
#     'EC': 23,
#     'EE': 19,
#     'EG': 19,
#     'ES': 34,
#     'FI': 30,
#     'FR': 41,
#     'GF': 18,
#     'GB': 59,
#     'GI': 18,
#     'GR': 16,
#     'GT': 18,
#     'HK': 17,
#     'HN': 17,
#     'HR': 21,
#     'HU': 18,
#     'IN': 18,
#     'IL': 18,
#     'ID': 29,
#     'IE': 32,
#     'IQ': 20,
#     'IS': 22,
#     'IT': 37,
#     'JM': 16,
#     'JO': 17,
#     'JP': 21,
#     'KR': 23,
#     'KW': 18,
#     'LB': 20,
#     'LI': 18,
#     'LT': 20,
#     'MA': 16,
#     'LV': 19,
#     'LY': 16,
#     'MC': 17,
#     'MD': 17,
#     'MK': 19,
#     'MT': 19,
#     'MY': 24,
#     'NE': 16,
#     'MX': 37,
#     'NG': 17,
#     'NL': 36,
#     'NZ': 29,
#     'NO': 31,
#     'OM': 17,
#     'PA': 18,
#     'PE': 24,
#     'PL': 22,
#     'PH': 24,
#     'PS': 20,
#     'PT': 25,
#     'PY': 17,
#     'RO': 14,
#     'QA': 17,
#     'SA': 18,
#     'RS': 20,
#     'RU': 21,
#     'SI': 20,
#     'SG': 24,
#     'SE': 33,
#     'SV': 18,
#     'SM': 18,
#     'SK': 24,
#     'TH': 22,
#     'TN': 17,
#     'TR': 21,
#     'TW': 16,
#     'TZ': 29,
#     'UY': 21,
#     'VE': 20,
#     'YE': 18,
#     'ZA': 21,
#     'US': 153},
#    'display_priority': 153,
#    'logo_path': '/u7dwMceEbjxd1N3TLEUBILSK2x6.jpg',
#    'provider_name': 'Hoichoi',
#    'provider_id': 315},
#   {'display_priorities': {'AR': 28,
#     'AT': 40,
#     'BO': 23,
#     'BR': 38,
#     'CH': 37,
#     'CL': 24,
#     'CO': 25,
#     'CA': 121,
#     'CR': 24,
#     'CZ': 19,
#     'DO': 19,
#     'DK': 35,
#     'DE': 67,
#     'EC': 24,
#     'ES': 36,
#     'FR': 43,
#     'GB': 75,
#     'GT': 24,
#     'HN': 23,
#     'IT': 39,
#     'MX': 38,
#     'NI': 3,
#     'NO': 37,
#     'PA': 20,
#     'PE': 25,
#     'PY': 23,
#     'SE': 39,
#     'SV': 20,
#     'UY': 23,
#     'VE': 21,
#     'US': 81},
#    'display_priority': 81,
#    'logo_path': '/dB8G41Q6tSL5NBisrIeqByfepBc.jpg',
#    'provider_name': 'Pluto TV',
#    'provider_id': 300},
#   {'display_priorities': {'AT': 56,
#     'DK': 42,
#     'DE': 113,
#     'ES': 37,
#     'FI': 32,
#     'GB': 84,
#     'IE': 39,
#     'IT': 23,
#     'NL': 39,
#     'NO': 32,
#     'SE': 34},
#    'display_priority': 34,
#    'logo_path': '/bPW3J8KlLrot95sLzadnpzVe61f.jpg',
#    'provider_name': 'Discovery+',
#    'provider_id': 524},
#   {'display_priorities': {'AU': 80,
#     'CA': 26,
#     'ES': 39,
#     'GB': 34,
#     'FR': 48,
#     'IT': 52},
#    'display_priority': 52,
#    'logo_path': '/2eyS8KsZF9Or7z4248Ktq36Pr8v.jpg',
#    'provider_name': 'Hayu Amazon Channel',
#    'provider_id': 296},
#   {'display_priorities': {'AE': 0,
#     'AD': 0,
#     'AG': 0,
#     'AL': 0,
#     'AO': 4,
#     'AR': 1,
#     'AT': 0,
#     'AU': 1,
#     'AZ': 2,
#     'BA': 0,
#     'BB': 0,
#     'BE': 1,
#     'BG': 0,
#     'BH': 0,
#     'BM': 0,
#     'BO': 0,
#     'BR': 2,
#     'BS': 0,
#     'BY': 6,
#     'BZ': 7,
#     'CA': 0,
#     'CH': 0,
#     'CI': 0,
#     'CL': 1,
#     'CO': 2,
#     'CM': 4,
#     'CR': 0,
#     'CU': 0,
#     'CV': 0,
#     'CZ': 1,
#     'CY': 7,
#     'DE': 0,
#     'DK': 1,
#     'DO': 0,
#     'DZ': 0,
#     'EC': 0,
#     'EE': 0,
#     'EG': 0,
#     'ES': 40,
#     'FI': 1,
#     'FJ': 0,
#     'FR': 1,
#     'GB': 0,
#     'GF': 0,
#     'GG': 0,
#     'GH': 0,
#     'GI': 0,
#     'GQ': 0,
#     'GR': 0,
#     'GT': 0,
#     'HK': 1,
#     'HN': 0,
#     'HR': 0,
#     'HU': 1,
#     'ID': 0,
#     'IE': 0,
#     'IL': 0,
#     'IN': 0,
#     'IQ': 0,
#     'IT': 1,
#     'IS': 0,
#     'JM': 0,
#     'JP': 0,
#     'JO': 0,
#     'KE': 0,
#     'KR': 0,
#     'KW': 0,
#     'LB': 0,
#     'LC': 0,
#     'LI': 0,
#     'LT': 0,
#     'LU': 8,
#     'MA': 0,
#     'LV': 0,
#     'LY': 0,
#     'MC': 0,
#     'ME': 4,
#     'MD': 0,
#     'MG': 4,
#     'MK': 0,
#     'MT': 0,
#     'ML': 5,
#     'MU': 0,
#     'MX': 8,
#     'MZ': 0,
#     'MY': 1,
#     'NE': 0,
#     'NG': 0,
#     'NL': 0,
#     'NI': 11,
#     'NO': 1,
#     'NZ': 1,
#     'OM': 0,
#     'PA': 0,
#     'PE': 2,
#     'PK': 0,
#     'PF': 0,
#     'PL': 1,
#     'PH': 0,
#     'PS': 0,
#     'PT': 1,
#     'PY': 0,
#     'QA': 0,
#     'RO': 1,
#     'RS': 0,
#     'SA': 0,
#     'SC': 0,
#     'SI': 0,
#     'SG': 0,
#     'SE': 1,
#     'SN': 0,
#     'SV': 0,
#     'SK': 1,
#     'SM': 0,
#     'TC': 0,
#     'TH': 1,
#     'TD': 5,
#     'TN': 0,
#     'TR': 3,
#     'TT': 0,
#     'TW': 0,
#     'TZ': 0,
#     'UA': 0,
#     'UG': 0,
#     'US': 7,
#     'UY': 0,
#     'VE': 0,
#     'YE': 0,
#     'ZA': 0,
#     'ZM': 0,
#     'ZW': 5},
#    'display_priority': 5,
#    'logo_path': '/pbpMk2JmcoNnQwx5JGpXngfoWtp.jpg',
#    'provider_name': 'Netflix',
#    'provider_id': 8},
#   {'display_priorities': {'AU': 83, 'CA': 80, 'DE': 120, 'ES': 42, 'GB': 109},
#    'display_priority': 109,
#    'logo_path': '/d0KmcInHpiF44ahOLrXCQATEFmD.jpg',
#    'provider_name': 'OUTtv Amazon Channel',
#    'provider_id': 607},
#   {'display_priorities': {'AU': 28,
#     'CA': 28,
#     'ES': 43,
#     'GB': 55,
#     'MX': 41,
#     'US': 96},
#    'display_priority': 96,
#    'logo_path': '/1wYmvbAuVZz2JnKvYfYN8Qolnb.jpg',
#    'provider_name': 'AcornTV Amazon Channel',
#    'provider_id': 196},
#   {'display_priorities': {'ES': 44},
#    'display_priority': 44,
#    'logo_path': '/2GQVxfaiWA4n93I7sJDJf1b6NqS.jpg',
#    'provider_name': 'FlixOlé Amazon Channel',
#    'provider_id': 684},
#   {'display_priorities': {'AG': 8,
#     'AE': 11,
#     'AD': 21,
#     'AL': 22,
#     'AR': 30,
#     'AT': 43,
#     'AU': 49,
#     'BA': 22,
#     'BB': 21,
#     'BG': 14,
#     'BE': 31,
#     'BH': 22,
#     'BM': 23,
#     'BO': 25,
#     'BS': 21,
#     'BR': 43,
#     'CI': 20,
#     'CH': 39,
#     'CA': 89,
#     'CL': 26,
#     'CO': 27,
#     'CR': 26,
#     'CU': 8,
#     'CV': 8,
#     'CZ': 21,
#     'DO': 22,
#     'DK': 32,
#     'DZ': 21,
#     'EC': 26,
#     'DE': 75,
#     'EE': 21,
#     'EG': 26,
#     'FI': 34,
#     'ES': 46,
#     'FJ': 8,
#     'FR': 49,
#     'GF': 23,
#     'GG': 9,
#     'GH': 7,
#     'GB': 78,
#     'GI': 23,
#     'GQ': 7,
#     'GR': 18,
#     'GT': 26,
#     'HN': 25,
#     'HK': 34,
#     'HU': 20,
#     'HR': 28,
#     'IL': 20,
#     'ID': 31,
#     'IE': 35,
#     'IN': 45,
#     'IQ': 22,
#     'IS': 27,
#     'IT': 42,
#     'JM': 20,
#     'JP': 23,
#     'JO': 22,
#     'KE': 7,
#     'KR': 25,
#     'LC': 8,
#     'KW': 23,
#     'LB': 22,
#     'LI': 23,
#     'LT': 22,
#     'LV': 21,
#     'MA': 21,
#     'LY': 21,
#     'MC': 22,
#     'MD': 21,
#     'MK': 21,
#     'MU': 9,
#     'MT': 21,
#     'MZ': 7,
#     'MY': 27,
#     'NE': 20,
#     'MX': 42,
#     'NG': 22,
#     'NL': 42,
#     'NZ': 31,
#     'NO': 34,
#     'OM': 22,
#     'PA': 23,
#     'PE': 27,
#     'PK': 6,
#     'PF': 8,
#     'PL': 25,
#     'PH': 26,
#     'PS': 22,
#     'PT': 29,
#     'PY': 25,
#     'RO': 16,
#     'QA': 22,
#     'RS': 22,
#     'RU': 24,
#     'SA': 25,
#     'SC': 10,
#     'SI': 22,
#     'SN': 7,
#     'SG': 27,
#     'SE': 36,
#     'SV': 23,
#     'TC': 8,
#     'SM': 23,
#     'SK': 31,
#     'TH': 25,
#     'TT': 8,
#     'TN': 22,
#     'TR': 23,
#     'TZ': 9,
#     'TW': 34,
#     'UG': 7,
#     'XK': 2,
#     'VA': 6,
#     'UY': 26,
#     'VE': 23,
#     'YE': 23,
#     'ZM': 7,
#     'ZA': 23,
#     'US': 158},
#    'display_priority': 158,
#    'logo_path': '/uauVx3dGWt0GICqdMCBYJObd3Mo.jpg',
#    'provider_name': 'Cultpix',
#    'provider_id': 692},
#   {'display_priorities': {'AG': 7,
#     'AE': 12,
#     'AL': 24,
#     'AO': 3,
#     'AZ': 0,
#     'AR': 31,
#     'AT': 44,
#     'AU': 50,
#     'BF': 3,
#     'BB': 22,
#     'BG': 15,
#     'BE': 32,
#     'BH': 23,
#     'BM': 24,
#     'BO': 26,
#     'BY': 5,
#     'BZ': 6,
#     'BS': 22,
#     'BR': 44,
#     'CI': 22,
#     'CH': 40,
#     'CM': 3,
#     'CA': 90,
#     'CL': 27,
#     'CO': 28,
#     'CR': 27,
#     'CU': 7,
#     'CY': 6,
#     'CV': 7,
#     'CZ': 23,
#     'DO': 23,
#     'DK': 33,
#     'DZ': 23,
#     'EC': 27,
#     'DE': 76,
#     'EE': 22,
#     'EG': 27,
#     'FI': 35,
#     'ES': 47,
#     'FJ': 7,
#     'FR': 51,
#     'GG': 7,
#     'GF': 26,
#     'GH': 9,
#     'GB': 79,
#     'GI': 24,
#     'GQ': 9,
#     'GR': 19,
#     'GY': 2,
#     'GT': 27,
#     'HN': 26,
#     'HK': 36,
#     'HU': 21,
#     'HR': 29,
#     'ID': 32,
#     'IE': 36,
#     'IN': 46,
#     'IQ': 24,
#     'IS': 28,
#     'IT': 44,
#     'JM': 21,
#     'JP': 24,
#     'JO': 23,
#     'KE': 10,
#     'KR': 26,
#     'LC': 7,
#     'KW': 24,
#     'LB': 24,
#     'LI': 24,
#     'LU': 7,
#     'LT': 23,
#     'LV': 22,
#     'MA': 22,
#     'LY': 23,
#     'MC': 23,
#     'ME': 3,
#     'MG': 3,
#     'ML': 4,
#     'MD': 22,
#     'MU': 7,
#     'MW': 2,
#     'MK': 23,
#     'MZ': 9,
#     'MY': 28,
#     'NE': 22,
#     'MX': 43,
#     'NI': 7,
#     'NG': 25,
#     'NL': 44,
#     'NZ': 32,
#     'NO': 35,
#     'OM': 23,
#     'PA': 24,
#     'PE': 28,
#     'PG': 3,
#     'PK': 7,
#     'PF': 7,
#     'PL': 26,
#     'PH': 27,
#     'PS': 24,
#     'PT': 30,
#     'PY': 26,
#     'RO': 17,
#     'QA': 23,
#     'RS': 25,
#     'RU': 25,
#     'SA': 26,
#     'SC': 8,
#     'SN': 9,
#     'SG': 28,
#     'SE': 37,
#     'SV': 24,
#     'TC': 7,
#     'SM': 24,
#     'SK': 32,
#     'TD': 4,
#     'TH': 26,
#     'TT': 7,
#     'TN': 23,
#     'TR': 23,
#     'UA': 6,
#     'TZ': 17,
#     'TW': 36,
#     'UG': 9,
#     'UY': 28,
#     'VE': 24,
#     'YE': 24,
#     'ZM': 9,
#     'ZW': 4,
#     'ZA': 24,
#     'US': 160},
#    'display_priority': 160,
#    'logo_path': '/fbveJTcro9Xw2KuPIIoPPePHiwy.jpg',
#    'provider_name': 'FilmBox+',
#    'provider_id': 701},
#   {'display_priorities': {'ES': 48},
#    'display_priority': 48,
#    'logo_path': '/8vES2nJNwOF57muvqLByDLm6snp.jpg',
#    'provider_name': 'Acontra Plus',
#    'provider_id': 1717},
#   {'display_priorities': {'ES': 52},
#    'display_priority': 52,
#    'logo_path': '/4s8njawy9i5sVseo5pO862bHKuM.jpg',
#    'provider_name': 'Pash Amazon Channel',
#    'provider_id': 1739},
#   {'display_priorities': {'ES': 53},
#    'display_priority': 53,
#    'logo_path': '/yISpVXhf6axqiHh6lBvJ8RRrZ8v.jpg',
#    'provider_name': 'Planet Horror Amazon Channel',
#    'provider_id': 1740},
#   {'display_priorities': {'ES': 54},
#    'display_priority': 54,
#    'logo_path': '/tM1HabyA45cnckBEhLS7hAVga5g.jpg',
#    'provider_name': 'Dizi Amazon Channel',
#    'provider_id': 1741},
#   {'display_priorities': {'ES': 55},
#    'display_priority': 55,
#    'logo_path': '/tGvAD4O9obFP3DfOrDn8NaRQ6eT.jpg',
#    'provider_name': 'Acontra Plus Amazon Channel',
#    'provider_id': 1742},
#   {'display_priorities': {'ES': 56},
#    'display_priority': 56,
#    'logo_path': '/aJECXkHekrkuRZ7ABF5YR9DVDd8.jpg',
#    'provider_name': 'Historia y Actualidad Amazon Channel',
#    'provider_id': 1743},
#   {'display_priorities': {'AD': 4,
#     'AL': 4,
#     'AG': 3,
#     'AE': 6,
#     'AU': 29,
#     'BA': 4,
#     'AR': 33,
#     'AT': 51,
#     'BB': 5,
#     'BH': 5,
#     'BE': 34,
#     'BG': 18,
#     'BM': 5,
#     'BO': 28,
#     'BS': 5,
#     'BR': 46,
#     'CI': 4,
#     'CA': 47,
#     'CH': 45,
#     'CL': 29,
#     'CO': 30,
#     'CU': 3,
#     'CR': 29,
#     'CV': 3,
#     'CZ': 25,
#     'DO': 5,
#     'DZ': 5,
#     'DK': 38,
#     'EC': 29,
#     'EG': 11,
#     'EE': 25,
#     'DE': 101,
#     'FI': 39,
#     'FJ': 3,
#     'ES': 62,
#     'GF': 5,
#     'GG': 3,
#     'FR': 72,
#     'GH': 3,
#     'GI': 5,
#     'GB': 98,
#     'GQ': 3,
#     'GR': 21,
#     'GT': 29,
#     'HK': 10,
#     'HR': 10,
#     'HN': 28,
#     'HU': 23,
#     'IL': 4,
#     'IN': 17,
#     'ID': 34,
#     'IE': 38,
#     'IQ': 4,
#     'IS': 10,
#     'JM': 5,
#     'IT': 63,
#     'JO': 5,
#     'JP': 26,
#     'KE': 3,
#     'KW': 5,
#     'LB': 4,
#     'KR': 28,
#     'LC': 3,
#     'LI': 5,
#     'LT': 26,
#     'MA': 5,
#     'LY': 5,
#     'MC': 5,
#     'LV': 25,
#     'MD': 5,
#     'MK': 4,
#     'MT': 4,
#     'MU': 2,
#     'MZ': 3,
#     'NE': 4,
#     'MY': 12,
#     'NG': 4,
#     'MX': 45,
#     'NZ': 15,
#     'NL': 46,
#     'NO': 39,
#     'OM': 5,
#     'PA': 5,
#     'PE': 30,
#     'PK': 3,
#     'PF': 3,
#     'PS': 4,
#     'PL': 28,
#     'PH': 29,
#     'PT': 33,
#     'QA': 5,
#     'PY': 27,
#     'RO': 19,
#     'RS': 4,
#     'SA': 9,
#     'SC': 3,
#     'RU': 27,
#     'SI': 4,
#     'SG': 12,
#     'SN': 3,
#     'SE': 41,
#     'SV': 5,
#     'SM': 5,
#     'SK': 13,
#     'TC': 3,
#     'TN': 5,
#     'TH': 28,
#     'TT': 3,
#     'TR': 27,
#     'TW': 9,
#     'TZ': 3,
#     'UG': 3,
#     'XK': 0,
#     'VA': 2,
#     'UY': 7,
#     'YE': 5,
#     'US': 46,
#     'VE': 26,
#     'ZA': 10,
#     'ZM': 3},
#    'display_priority': 46,
#    'logo_path': '/6KEQzITx2RrCAQt5Nw9WrL1OI8z.jpg',
#    'provider_name': 'Sun Nxt',
#    'provider_id': 309},
#   {'display_priorities': {'AU': 53,
#     'BR': 47,
#     'CA': 111,
#     'DE': 103,
#     'ES': 63,
#     'FR': 73,
#     'GB': 100,
#     'IT': 64,
#     'JP': 27,
#     'KR': 29,
#     'MX': 46,
#     'US': 181},
#    'display_priority': 181,
#    'logo_path': '/kICQccvOh8AIBMHGkBXJ047xeHN.jpg',
#    'provider_name': 'Netflix basic with Ads',
#    'provider_id': 1796},
#   {'display_priorities': {'ES': 68},
#    'display_priority': 68,
#    'logo_path': '/8VhN4PeHU7yfMNoWK0DnwdS1HlS.jpg',
#    'provider_name': 'Tivify',
#    'provider_id': 1838},
#   {'display_priorities': {'AR': 45,
#     'BO': 29,
#     'BZ': 8,
#     'BR': 63,
#     'CL': 30,
#     'CO': 31,
#     'CA': 124,
#     'CR': 30,
#     'DO': 27,
#     'EC': 30,
#     'ES': 72,
#     'FR': 90,
#     'GB': 108,
#     'GT': 30,
#     'HN': 29,
#     'NI': 8,
#     'MX': 63,
#     'PA': 28,
#     'PE': 31,
#     'PY': 28,
#     'SV': 28,
#     'UY': 30,
#     'VE': 27,
#     'US': 197},
#    'display_priority': 197,
#    'logo_path': '/oJRCAz1WKkKM9Ge7mX5KFnegTNY.jpg',
#    'provider_name': 'Runtime',
#    'provider_id': 1875},
#   {'display_priorities': {'AG': 10,
#     'AE': 25,
#     'AD': 25,
#     'AL': 27,
#     'AZ': 4,
#     'AR': 46,
#     'BA': 27,
#     'AT': 58,
#     'AU': 58,
#     'BF': 4,
#     'BB': 24,
#     'BG': 20,
#     'BE': 41,
#     'BH': 36,
#     'BM': 26,
#     'BO': 30,
#     'BR': 11,
#     'BY': 7,
#     'BZ': 9,
#     'BS': 24,
#     'CD': 2,
#     'CI': 26,
#     'CH': 47,
#     'CL': 31,
#     'CO': 32,
#     'CA': 125,
#     'CR': 31,
#     'CY': 8,
#     'CV': 12,
#     'DE': 6,
#     'CZ': 27,
#     'DO': 28,
#     'DK': 39,
#     'DZ': 28,
#     'EC': 31,
#     'EE': 26,
#     'EG': 40,
#     'FI': 40,
#     'FJ': 10,
#     'FR': 5,
#     'ES': 73,
#     'GB': 6,
#     'GF': 28,
#     'GG': 10,
#     'GH': 15,
#     'GI': 26,
#     'GQ': 13,
#     'GY': 3,
#     'GR': 22,
#     'GT': 31,
#     'HK': 38,
#     'HN': 30,
#     'HU': 25,
#     'HR': 34,
#     'IN': 4,
#     'IL': 26,
#     'ID': 35,
#     'IE': 40,
#     'IQ': 35,
#     'IS': 31,
#     'JM': 23,
#     'IT': 74,
#     'KE': 14,
#     'JO': 36,
#     'KR': 30,
#     'LC': 10,
#     'LB': 27,
#     'KW': 36,
#     'LI': 27,
#     'LU': 9,
#     'LT': 27,
#     'LV': 26,
#     'MA': 27,
#     'LY': 28,
#     'MC': 25,
#     'ME': 5,
#     'MD': 24,
#     'MK': 26,
#     'MU': 14,
#     'MX': 4,
#     'MZ': 15,
#     'MY': 30,
#     'NE': 26,
#     'NI': 9,
#     'NG': 29,
#     'NZ': 35,
#     'NO': 41,
#     'NL': 67,
#     'PA': 29,
#     'OM': 36,
#     'PG': 4,
#     'PE': 32,
#     'PF': 10,
#     'PL': 29,
#     'PH': 31,
#     'PS': 27,
#     'PT': 39,
#     'PY': 29,
#     'RO': 21,
#     'QA': 36,
#     'RS': 28,
#     'RU': 28,
#     'SC': 13,
#     'SI': 28,
#     'SG': 30,
#     'SN': 13,
#     'SE': 42,
#     'SV': 29,
#     'TC': 10,
#     'SM': 27,
#     'SK': 36,
#     'TD': 6,
#     'TH': 29,
#     'TT': 10,
#     'TN': 28,
#     'TR': 43,
#     'UA': 7,
#     'TW': 38,
#     'TZ': 31,
#     'UG': 15,
#     'US': 6,
#     'XK': 4,
#     'UY': 31,
#     'VE': 28,
#     'YE': 27,
#     'ZM': 13,
#     'ZA': 28,
#     'MT': 24},
#    'display_priority': 28,
#    'logo_path': '/mXeC4TrcgdU6ltE9bCBCEORwSQR.jpg',
#    'provider_name': 'Crunchyroll',
#    'provider_id': 283},
#   {'display_priorities': {'AU': 55, 'CA': 91, 'ES': 74, 'US': 26},
#    'display_priority': 26,
#    'logo_path': '/2ino0WmHA4GROB7NYKzT6PGqLcb.jpg',
#    'provider_name': 'AMC+ Amazon Channel',
#    'provider_id': 528},
#   {'display_priorities': {'AU': 82, 'BR': 42, 'CA': 81, 'ES': 75, 'MX': 40},
#    'display_priority': 40,
#    'logo_path': '/bSy9zFiZtbKBHIyOu0H2Fs5cJmx.jpg',
#    'provider_name': 'Love Nature Amazon Channel',
#    'provider_id': 608},
#   {'display_priorities': {'AU': 84, 'ES': 76},
#    'display_priority': 76,
#    'logo_path': '/3EFwJrJalr0YEgN1ENwrYbIar3Q.jpg',
#    'provider_name': 'Hopster Amazon Channel',
#    'provider_id': 1890},
#   {'display_priorities': {'AE': 14,
#     'AR': 56,
#     'AU': 60,
#     'BH': 28,
#     'BR': 78,
#     'CI': 24,
#     'CA': 135,
#     'DZ': 25,
#     'EG': 30,
#     'FI': 41,
#     'DE': 141,
#     'ES': 88,
#     'GH': 11,
#     'FR': 100,
#     'GQ': 11,
#     'GB': 121,
#     'IL': 9,
#     'ID': 36,
#     'IQ': 10,
#     'IN': 64,
#     'JO': 28,
#     'IT': 92,
#     'KE': 12,
#     'LB': 10,
#     'KW': 29,
#     'MA': 24,
#     'LY': 25,
#     'MU': 10,
#     'MZ': 11,
#     'NE': 24,
#     'NG': 27,
#     'MX': 70,
#     'OM': 28,
#     'PS': 10,
#     'PL': 32,
#     'PH': 32,
#     'QA': 28,
#     'RU': 29,
#     'SA': 28,
#     'SC': 11,
#     'SN': 11,
#     'TN': 25,
#     'TZ': 10,
#     'TR': 55,
#     'UG': 11,
#     'ZM': 11,
#     'ZA': 26,
#     'US': 221},
#    'display_priority': 221,
#    'logo_path': '/7qZED0kLBtiV8mLRNBtW4PQCAqW.jpg',
#    'provider_name': 'Shahid VIP',
#    'provider_id': 1715},
#   {'display_priorities': {'AU': 64,
#     'CA': 141,
#     'ES': 93,
#     'GB': 131,
#     'MX': 78,
#     'US': 238},
#    'display_priority': 238,
#    'logo_path': '/kx8rGgFYxX6aJkG7RHx2mtijglC.jpg',
#    'provider_name': 'Acorn TV Apple TV',
#    'provider_id': 2034},
#   {'display_priorities': {'AU': 57, 'CA': 119, 'ES': 94, 'US': 22},
#    'display_priority': 22,
#    'logo_path': '/oTQdXIqM9iewlN4MC2nhKB0gHw.jpg',
#    'provider_name': 'AMC Plus Apple TV Channel ',
#    'provider_id': 1854},
#   {'display_priorities': {'AR': 14,
#     'AU': 67,
#     'BR': 13,
#     'CA': 30,
#     'CL': 12,
#     'CO': 14,
#     'EC': 13,
#     'FJ': 12,
#     'ES': 97,
#     'GB': 136,
#     'IE': 43,
#     'MX': 11,
#     'NZ': 36,
#     'PE': 14,
#     'PG': 5,
#     'PF': 11,
#     'PT': 59,
#     'US': 14,
#     'VE': 11},
#    'display_priority': 11,
#    'logo_path': '/hwsU65QW7A4dbMEWkDpgHyCNcfS.jpg',
#    'provider_name': 'Kocowa',
#    'provider_id': 464},
#   {'display_priorities': {'AT': 72,
#     'BE': 66,
#     'BR': 92,
#     'CL': 38,
#     'CO': 39,
#     'DE': 167,
#     'ES': 106,
#     'GB': 146,
#     'IT': 108,
#     'MX': 85,
#     'NL': 88},
#    'display_priority': 88,
#    'logo_path': '/efu1Cqc63XrPBoreYnf2mn0Nizj.jpg',
#    'provider_name': 'MGM Plus Amazon Channel',
#    'provider_id': 2141},
#   {'display_priorities': {'ES': 109},
#    'display_priority': 109,
#    'logo_path': '/lDvzuBuNVgpcdzDpPmmufKvrZPb.jpg',
#    'provider_name': '3Cat',
#    'provider_id': 2237}]}

# %%
res_url_series_spain_providers.json().keys()
# Out:
# dict_keys(['results'])

# %%
res_url_series_spain_providers.json()["results"]
# Out:
# [{'display_priorities': {'AD': 7,
#    'AL': 7,
#    'AR': 0,
#    'AT': 2,
#    'AU': 0,
#    'BA': 7,
#    'BE': 0,
#    'BG': 16,
#    'BO': 2,
#    'BR': 0,
#    'BZ': 2,
#    'CA': 1,
#    'CH': 2,
#    'CL': 0,
#    'CO': 0,
#    'CR': 2,
#    'CZ': 0,
#    'DK': 0,
#    'DE': 2,
#    'DO': 24,
#    'EC': 1,
#    'EE': 23,
#    'ES': 0,
#    'FI': 0,
#    'EG': 45,
#    'FR': 0,
#    'GB': 1,
#    'GT': 1,
#    'GR': 20,
#    'HN': 2,
#    'HU': 0,
#    'HK': 32,
#    'HR': 31,
#    'IE': 2,
#    'IT': 0,
#    'IS': 1,
#    'JP': 2,
#    'JM': 26,
#    'KR': 2,
#    'LC': 13,
#    'LU': 3,
#    'LI': 25,
#    'LT': 24,
#    'LV': 23,
#    'ME': 1,
#    'MK': 7,
#    'MT': 7,
#    'MX': 0,
#    'NI': 2,
#    'NL': 1,
#    'NO': 0,
#    'NZ': 0,
#    'PE': 0,
#    'PA': 27,
#    'PL': 0,
#    'PT': 0,
#    'PH': 30,
#    'PY': 2,
#    'RO': 0,
#    'RS': 7,
#    'SG': 2,
#    'SI': 7,
#    'SE': 0,
#    'SK': 0,
#    'SV': 27,
#    'SM': 25,
#    'TR': 0,
#    'TT': 14,
#    'TW': 2,
#    'US': 0,
#    'VE': 1,
#    'UY': 27},
#   'display_priority': 27,
#   'logo_path': '/97yvRBw1GzX7fXprcF80er19ot.jpg',
#   'provider_name': 'Disney Plus',
#   'provider_id': 337},
#  {'display_priorities': {'AE': 2,
#    'AG': 11,
#    'AR': 5,
#    'AT': 5,
#    'AZ': 3,
#    'AU': 11,
#    'BE': 9,
#    'BG': 3,
#    'BO': 3,
#    'BH': 49,
#    'BM': 27,
#    'BR': 9,
#    'BY': 3,
#    'BZ': 4,
#    'BS': 25,
#    'CA': 7,
#    'CH': 18,
#    'CL': 5,
#    'CO': 5,
#    'CR': 3,
#    'CY': 4,
#    'CV': 10,
#    'CZ': 7,
#    'DE': 3,
#    'DK': 10,
#    'DO': 31,
#    'EC': 7,
#    'EE': 7,
#    'EG': 3,
#    'ES': 1,
#    'FI': 12,
#    'FJ': 11,
#    'FR': 3,
#    'GB': 3,
#    'GH': 13,
#    'GR': 5,
#    'GT': 3,
#    'HN': 3,
#    'HK': 16,
#    'HU': 7,
#    'IE': 5,
#    'IN': 2,
#    'ID': 12,
#    'IL': 25,
#    'IT': 5,
#    'JP': 10,
#    'JO': 50,
#    'KR': 5,
#    'LB': 28,
#    'LU': 5,
#    'LT': 7,
#    'LV': 7,
#    'MD': 25,
#    'MU': 12,
#    'MT': 25,
#    'MX': 3,
#    'MY': 11,
#    'MZ': 13,
#    'NI': 5,
#    'NL': 10,
#    'NO': 6,
#    'NZ': 5,
#    'PE': 6,
#    'PA': 25,
#    'OM': 49,
#    'PL': 3,
#    'PH': 11,
#    'PT': 11,
#    'PY': 4,
#    'RU': 3,
#    'SA': 2,
#    'QA': 49,
#    'SE': 5,
#    'SG': 11,
#    'SI': 24,
#    'SK': 5,
#    'SV': 31,
#    'TH': 10,
#    'TT': 11,
#    'TW': 15,
#    'UA': 1,
#    'UG': 13,
#    'US': 2,
#    'VE': 5,
#    'ZA': 9},
#   'display_priority': 9,
#   'logo_path': '/2E03IAZsX4ZaUqM7tXlctEPMGWS.jpg',
#   'provider_name': 'Apple TV Plus',
#   'provider_id': 350},
#  {'display_priorities': {'AD': 1,
#    'AG': 1,
#    'AL': 1,
#    'AE': 9,
#    'AO': 1,
#    'AR': 2,
#    'AU': 2,
#    'BA': 1,
#    'BB': 1,
#    'BE': 2,
#    'BF': 1,
#    'BG': 1,
#    'BH': 1,
#    'BM': 1,
#    'BO': 1,
#    'BR': 1,
#    'BS': 1,
#    'BY': 2,
#    'BZ': 3,
#    'CA': 2,
#    'CD': 0,
#    'CH': 1,
#    'CI': 1,
#    'CL': 2,
#    'CO': 1,
#    'CM': 1,
#    'CR': 1,
#    'CU': 1,
#    'CV': 1,
#    'CY': 3,
#    'CZ': 2,
#    'DK': 2,
#    'DO': 1,
#    'DZ': 1,
#    'EC': 2,
#    'EE': 1,
#    'EG': 1,
#    'ES': 2,
#    'FI': 2,
#    'FJ': 1,
#    'FR': 2,
#    'GF': 1,
#    'GG': 1,
#    'GH': 1,
#    'GI': 1,
#    'GQ': 1,
#    'GR': 1,
#    'GT': 2,
#    'GY': 0,
#    'HK': 5,
#    'HN': 1,
#    'HR': 1,
#    'HU': 2,
#    'IE': 1,
#    'ID': 7,
#    'IL': 1,
#    'IN': 1,
#    'IQ': 1,
#    'IT': 2,
#    'IS': 2,
#    'JM': 1,
#    'JO': 1,
#    'KE': 1,
#    'KR': 1,
#    'KW': 1,
#    'LB': 1,
#    'LC': 1,
#    'LI': 1,
#    'LT': 1,
#    'MA': 1,
#    'LV': 1,
#    'LY': 1,
#    'MC': 1,
#    'MD': 1,
#    'MG': 1,
#    'ML': 2,
#    'MK': 1,
#    'MT': 1,
#    'MW': 0,
#    'MX': 1,
#    'MZ': 1,
#    'NE': 1,
#    'MY': 9,
#    'NG': 1,
#    'NI': 4,
#    'NL': 2,
#    'NO': 2,
#    'NZ': 2,
#    'OM': 1,
#    'PA': 1,
#    'PE': 1,
#    'PG': 1,
#    'PK': 1,
#    'PF': 1,
#    'PL': 5,
#    'PH': 1,
#    'PS': 1,
#    'PT': 2,
#    'PY': 1,
#    'QA': 1,
#    'RO': 2,
#    'RS': 1,
#    'SC': 1,
#    'SA': 23,
#    'SI': 1,
#    'SG': 1,
#    'SE': 2,
#    'SN': 1,
#    'SV': 1,
#    'SK': 2,
#    'SM': 1,
#    'TC': 1,
#    'TH': 3,
#    'TD': 2,
#    'TN': 1,
#    'TR': 6,
#    'TT': 1,
#    'TW': 1,
#    'TZ': 1,
#    'UG': 1,
#    'VA': 0,
#    'UY': 1,
#    'VE': 2,
#    'YE': 1,
#    'ZA': 1,
#    'ZM': 1,
#    'ZW': 2},
#   'display_priority': 1,
#   'logo_path': '/dQeAar5H991VYporEjUspolDarG.jpg',
#   'provider_name': 'Amazon Prime Video',
#   'provider_id': 119},
#  {'display_priorities': {'ES': 3},
#   'display_priority': 3,
#   'logo_path': '/jse4MOi92Jgetym7nbXFZZBI6LK.jpg',
#   'provider_name': 'Movistar Plus+ €9.99',
#   'provider_id': 2241},
#  {'display_priorities': {'AL': 8,
#    'AT': 9,
#    'BA': 8,
#    'BE': 10,
#    'CH': 9,
#    'CY': 2,
#    'DE': 16,
#    'DK': 14,
#    'CZ': 34,
#    'ES': 4,
#    'FI': 14,
#    'FR': 21,
#    'GB': 5,
#    'GR': 24,
#    'HU': 27,
#    'IE': 12,
#    'IT': 3,
#    'LU': 2,
#    'ME': 0,
#    'MK': 8,
#    'MT': 8,
#    'NL': 15,
#    'NO': 14,
#    'PT': 8,
#    'PL': 37,
#    'RO': 23,
#    'RS': 8,
#    'SI': 8,
#    'SE': 15,
#    'SK': 39,
#    'UA': 4},
#   'display_priority': 4,
#   'logo_path': '/bZvc9dXrXNly7cA0V4D9pR8yJwm.jpg',
#   'provider_name': 'Rakuten TV',
#   'provider_id': 35},
#  {'display_priorities': {'ES': 5},
#   'display_priority': 5,
#   'logo_path': '/f6TRLB3H4jDpFEZ0z2KWSSvu1SB.jpg',
#   'provider_name': 'Movistar Plus+',
#   'provider_id': 149},
#  {'display_priorities': {'CA': 97, 'ES': 7, 'US': 8},
#   'display_priority': 8,
#   'logo_path': '/9BgaNQRMDvVlji1JBZi6tcfxpKx.jpg',
#   'provider_name': 'fuboTV',
#   'provider_id': 257},
#  {'display_priorities': {'AD': 24,
#    'AL': 26,
#    'BA': 26,
#    'BG': 19,
#    'CZ': 26,
#    'DK': 36,
#    'ES': 8,
#    'FI': 37,
#    'HU': 24,
#    'HR': 33,
#    'MK': 25,
#    'NL': 11,
#    'NO': 7,
#    'PL': 7,
#    'PT': 32,
#    'RO': 20,
#    'RS': 27,
#    'SE': 7,
#    'SI': 27,
#    'SK': 35,
#    'XK': 3},
#   'display_priority': 3,
#   'logo_path': '/gQbqEYd0C9uprYxEUqTM589qn8g.jpg',
#   'provider_name': 'SkyShowtime',
#   'provider_id': 1773},
#  {'display_priorities': {'ES': 9, 'PT': 27},
#   'display_priority': 27,
#   'logo_path': '/kO2SWXvDCHAquaUuTJBuZkTBAuU.jpg',
#   'provider_name': 'Filmin',
#   'provider_id': 63},
#  {'display_priorities': {'AU': 4,
#    'AT': 67,
#    'BE': 3,
#    'CA': 3,
#    'CH': 52,
#    'DK': 3,
#    'CZ': 35,
#    'DE': 21,
#    'ES': 12,
#    'FI': 3,
#    'FR': 14,
#    'GB': 33,
#    'HK': 9,
#    'HU': 28,
#    'IE': 3,
#    'IT': 6,
#    'LU': 4,
#    'NL': 3,
#    'NO': 3,
#    'PH': 2,
#    'PL': 38,
#    'RO': 24,
#    'SG': 3,
#    'SE': 3},
#   'display_priority': 3,
#   'logo_path': '/jxIBXlxRbCcy7Y4GvOZKszCd0dv.jpg',
#   'provider_name': 'Hayu',
#   'provider_id': 223},
#  {'display_priorities': {'ES': 13},
#   'display_priority': 13,
#   'logo_path': '/oN6g8QorcoYo3mx4BulU22ghKq4.jpg',
#   'provider_name': 'Atres Player',
#   'provider_id': 62},
#  {'display_priorities': {'AD': 2,
#    'AL': 2,
#    'BA': 2,
#    'BB': 2,
#    'BH': 2,
#    'BM': 2,
#    'BS': 2,
#    'CI': 2,
#    'DO': 2,
#    'DZ': 2,
#    'EG': 5,
#    'ES': 15,
#    'GF': 2,
#    'GI': 2,
#    'HR': 4,
#    'IL': 2,
#    'IQ': 2,
#    'IS': 5,
#    'JM': 2,
#    'JO': 2,
#    'KW': 2,
#    'LB': 2,
#    'LI': 2,
#    'MA': 2,
#    'LY': 2,
#    'MC': 2,
#    'MD': 2,
#    'MK': 2,
#    'MT': 2,
#    'NE': 2,
#    'NG': 2,
#    'OM': 2,
#    'PA': 2,
#    'PS': 2,
#    'QA': 2,
#    'RS': 2,
#    'SA': 4,
#    'SI': 2,
#    'SV': 2,
#    'SM': 2,
#    'SK': 7,
#    'TN': 2,
#    'TW': 10,
#    'TZ': 19,
#    'UY': 4,
#    'YE': 2},
#   'display_priority': 2,
#   'logo_path': '/ozMgkAAoi6aDI5ce8KKA2k8TGvB.jpg',
#   'provider_name': 'FlixOlé',
#   'provider_id': 393},
#  {'display_priorities': {'AG': 12,
#    'AD': 27,
#    'BA': 29,
#    'AR': 61,
#    'BB': 25,
#    'BG': 22,
#    'BO': 32,
#    'BR': 7,
#    'BZ': 10,
#    'BS': 26,
#    'CL': 7,
#    'CO': 6,
#    'CR': 4,
#    'CZ': 36,
#    'DO': 32,
#    'DK': 43,
#    'EC': 5,
#    'FI': 45,
#    'ES': 16,
#    'FR': 116,
#    'GT': 4,
#    'GY': 4,
#    'HN': 32,
#    'HU': 29,
#    'HR': 36,
#    'JM': 24,
#    'LC': 11,
#    'MC': 27,
#    'ME': 7,
#    'MD': 27,
#    'MK': 28,
#    'MX': 5,
#    'NI': 14,
#    'NO': 44,
#    'PE': 7,
#    'NL': 89,
#    'PA': 32,
#    'PL': 40,
#    'PY': 31,
#    'RO': 25,
#    'PT': 62,
#    'RS': 30,
#    'SI': 30,
#    'SE': 48,
#    'SV': 32,
#    'TC': 11,
#    'SK': 40,
#    'TT': 12,
#    'US': 9,
#    'UY': 3,
#    'VE': 30,
#    'BE': 67},
#   'display_priority': 30,
#   'logo_path': '/fksCUZ9QDWZMUwL2LgMtLckROUN.jpg',
#   'provider_name': 'Max',
#   'provider_id': 1899},
#  {'display_priorities': {'AT': 12,
#    'AU': 17,
#    'BR': 16,
#    'CH': 6,
#    'CA': 23,
#    'DK': 8,
#    'DE': 32,
#    'ES': 17,
#    'FI': 10,
#    'FR': 15,
#    'GB': 18,
#    'IE': 14,
#    'IT': 22,
#    'JP': 7,
#    'MX': 13,
#    'NL': 14,
#    'NO': 9,
#    'NZ': 9,
#    'SE': 8,
#    'US': 45},
#   'display_priority': 45,
#   'logo_path': '/5vfrJQgNe9UnHVgVNAwZTy0Jo9o.jpg',
#   'provider_name': 'Microsoft Store',
#   'provider_id': 68},
#  {'display_priorities': {'AT': 13,
#    'AU': 14,
#    'BE': 8,
#    'CH': 20,
#    'CA': 39,
#    'DK': 13,
#    'DE': 20,
#    'FI': 7,
#    'ES': 20,
#    'FR': 17,
#    'GB': 31,
#    'HU': 6,
#    'HK': 28,
#    'IE': 20,
#    'IT': 21,
#    'MX': 10,
#    'NZ': 7,
#    'NO': 13,
#    'PT': 6,
#    'RU': 8,
#    'SE': 14,
#    'TR': 2,
#    'TW': 27,
#    'US': 33},
#   'display_priority': 33,
#   'logo_path': '/rMb93u1tBeErSYLv79zSTR07UdO.jpg',
#   'provider_name': 'YouTube Premium',
#   'provider_id': 188},
#  {'display_priorities': {'AD': 8,
#    'AL': 9,
#    'AR': 11,
#    'AT': 24,
#    'AU': 36,
#    'BA': 9,
#    'BB': 6,
#    'BE': 14,
#    'BG': 5,
#    'BH': 6,
#    'BM': 6,
#    'BO': 13,
#    'BS': 6,
#    'BR': 18,
#    'CI': 7,
#    'CH': 23,
#    'CA': 53,
#    'CL': 11,
#    'CO': 11,
#    'CR': 7,
#    'CZ': 8,
#    'DO': 6,
#    'DK': 18,
#    'DZ': 6,
#    'DE': 43,
#    'EC': 11,
#    'EE': 9,
#    'EG': 10,
#    'ES': 21,
#    'FI': 17,
#    'FR': 26,
#    'GF': 6,
#    'GB': 40,
#    'GI': 6,
#    'GR': 6,
#    'GT': 7,
#    'HK': 13,
#    'HN': 4,
#    'HR': 9,
#    'HU': 8,
#    'IL': 7,
#    'ID': 17,
#    'IE': 21,
#    'IN': 21,
#    'IQ': 7,
#    'IS': 9,
#    'IT': 26,
#    'JM': 6,
#    'JO': 6,
#    'JP': 11,
#    'KR': 12,
#    'KW': 6,
#    'LB': 7,
#    'LI': 6,
#    'LT': 9,
#    'MA': 6,
#    'LV': 9,
#    'LY': 6,
#    'MC': 6,
#    'MD': 6,
#    'MK': 9,
#    'MT': 9,
#    'MX': 20,
#    'NE': 7,
#    'MY': 15,
#    'NG': 7,
#    'NL': 22,
#    'NO': 19,
#    'NZ': 20,
#    'OM': 6,
#    'PA': 6,
#    'PE': 11,
#    'PL': 9,
#    'PH': 13,
#    'PS': 7,
#    'PT': 14,
#    'PY': 6,
#    'QA': 6,
#    'RO': 4,
#    'RS': 9,
#    'RU': 9,
#    'SA': 8,
#    'SI': 9,
#    'SG': 14,
#    'SE': 19,
#    'SV': 6,
#    'SM': 6,
#    'SK': 12,
#    'TH': 13,
#    'TN': 6,
#    'TR': 10,
#    'TW': 12,
#    'TZ': 20,
#    'UY': 8,
#    'VE': 8,
#    'YE': 6,
#    'US': 51,
#    'ZA': 11},
#   'display_priority': 51,
#   'logo_path': '/oR1aNm1Qu9jQBkW4VrGPWhqbC3P.jpg',
#   'provider_name': 'Curiosity Stream',
#   'provider_id': 190},
#  {'display_priorities': {'ES': 22},
#   'display_priority': 22,
#   'logo_path': '/273VHxSrDdEwLTXJrsnE6yJMqNZ.jpg',
#   'provider_name': 'Mitele ',
#   'provider_id': 456},
#  {'display_priorities': {'AR': 18,
#    'AT': 26,
#    'AU': 35,
#    'BE': 17,
#    'BG': 7,
#    'BH': 9,
#    'BM': 9,
#    'BO': 8,
#    'BS': 9,
#    'BR': 22,
#    'CH': 24,
#    'CA': 55,
#    'CL': 14,
#    'CO': 15,
#    'CR': 12,
#    'CZ': 10,
#    'DO': 9,
#    'DK': 19,
#    'DZ': 9,
#    'DE': 44,
#    'EC': 14,
#    'EE': 11,
#    'ES': 23,
#    'FI': 19,
#    'FR': 28,
#    'GF': 9,
#    'GB': 44,
#    'GI': 9,
#    'GR': 8,
#    'GT': 12,
#    'HN': 11,
#    'HR': 12,
#    'HU': 10,
#    'ID': 18,
#    'IE': 23,
#    'IN': 24,
#    'IS': 12,
#    'IT': 27,
#    'JO': 9,
#    'JP': 13,
#    'KR': 14,
#    'KW': 9,
#    'LI': 9,
#    'LT': 11,
#    'MA': 9,
#    'LV': 11,
#    'LY': 9,
#    'MC': 9,
#    'MD': 9,
#    'MX': 27,
#    'MY': 16,
#    'NL': 24,
#    'NO': 20,
#    'NZ': 21,
#    'OM': 9,
#    'PA': 9,
#    'PE': 15,
#    'PL': 10,
#    'PH': 15,
#    'PT': 16,
#    'PY': 11,
#    'RO': 6,
#    'QA': 9,
#    'RU': 11,
#    'SG': 16,
#    'SE': 21,
#    'SV': 9,
#    'SM': 9,
#    'SK': 15,
#    'TH': 14,
#    'TN': 9,
#    'TR': 13,
#    'TW': 28,
#    'TZ': 22,
#    'UY': 12,
#    'VE': 12,
#    'YE': 9,
#    'ZA': 13,
#    'US': 132},
#   'display_priority': 132,
#   'logo_path': '/5zqbck5mo8PuVbGu2ngBUdn5Yga.jpg',
#   'provider_name': 'DOCSVILLE',
#   'provider_id': 475},
#  {'display_priorities': {'ES': 25},
#   'display_priority': 25,
#   'logo_path': '/3QQKYFUDt13Q2Zm6JM2cOjlbd27.jpg',
#   'provider_name': 'rtve',
#   'provider_id': 541},
#  {'display_priorities': {'AG': 13,
#    'AD': 26,
#    'AO': 5,
#    'AL': 28,
#    'AZ': 5,
#    'AU': 47,
#    'BA': 28,
#    'AR': 62,
#    'AT': 64,
#    'BF': 5,
#    'BB': 26,
#    'BG': 21,
#    'BE': 64,
#    'BM': 28,
#    'BO': 33,
#    'BY': 8,
#    'BZ': 11,
#    'BS': 27,
#    'CI': 27,
#    'BR': 85,
#    'CH': 50,
#    'CA': 87,
#    'CM': 5,
#    'CL': 34,
#    'CO': 35,
#    'CR': 33,
#    'CY': 9,
#    'CV': 13,
#    'CZ': 33,
#    'DO': 33,
#    'DK': 41,
#    'DE': 55,
#    'DZ': 29,
#    'EC': 33,
#    'EE': 27,
#    'ES': 26,
#    'FI': 43,
#    'FJ': 13,
#    'FR': 30,
#    'GB': 48,
#    'GF': 29,
#    'GG': 11,
#    'GH': 16,
#    'GI': 27,
#    'GQ': 14,
#    'GR': 23,
#    'GY': 5,
#    'GT': 33,
#    'HK': 39,
#    'HN': 33,
#    'HU': 26,
#    'HR': 35,
#    'IL': 27,
#    'IN': 31,
#    'ID': 40,
#    'IE': 44,
#    'IT': 29,
#    'IS': 32,
#    'IQ': 49,
#    'JM': 25,
#    'KE': 15,
#    'JP': 53,
#    'JO': 51,
#    'KR': 15,
#    'LC': 12,
#    'LB': 29,
#    'KW': 50,
#    'LI': 29,
#    'LU': 11,
#    'LT': 28,
#    'LV': 27,
#    'MA': 28,
#    'LY': 29,
#    'MC': 26,
#    'ME': 6,
#    'MG': 5,
#    'ML': 6,
#    'MD': 26,
#    'MW': 3,
#    'MK': 27,
#    'MU': 15,
#    'MT': 26,
#    'MZ': 17,
#    'MY': 32,
#    'NE': 27,
#    'NG': 30,
#    'NI': 15,
#    'MX': 78,
#    'NZ': 37,
#    'NO': 42,
#    'NL': 86,
#    'PA': 33,
#    'PG': 6,
#    'PE': 34,
#    'OM': 50,
#    'PK': 8,
#    'PF': 12,
#    'PL': 34,
#    'PH': 33,
#    'PS': 28,
#    'PY': 32,
#    'RO': 22,
#    'PT': 60,
#    'RS': 29,
#    'RU': 30,
#    'SC': 14,
#    'SI': 29,
#    'SG': 31,
#    'SN': 14,
#    'SE': 47,
#    'SV': 33,
#    'TC': 12,
#    'SM': 28,
#    'SK': 38,
#    'TD': 7,
#    'TH': 30,
#    'TT': 13,
#    'TN': 29,
#    'UA': 8,
#    'TW': 39,
#    'TZ': 32,
#    'UG': 16,
#    'XK': 5,
#    'VA': 7,
#    'UY': 32,
#    'VE': 31,
#    'YE': 28,
#    'ZW': 6,
#    'ZM': 14,
#    'ZA': 30,
#    'US': 140},
#   'display_priority': 140,
#   'logo_path': '/vLZKlXUNDcZR7ilvfY9Wr9k80FZ.jpg',
#   'provider_name': 'Plex',
#   'provider_id': 538},
#  {'display_priorities': {'AD': 14,
#    'AL': 15,
#    'AR': 20,
#    'AT': 31,
#    'AU': 38,
#    'BA': 15,
#    'BE': 20,
#    'BM': 11,
#    'BO': 6,
#    'BR': 28,
#    'CI': 11,
#    'CH': 28,
#    'CA': 63,
#    'CL': 16,
#    'CO': 17,
#    'CR': 14,
#    'CZ': 11,
#    'DK': 21,
#    'DE': 56,
#    'EC': 16,
#    'EE': 12,
#    'ES': 27,
#    'FI': 23,
#    'FR': 31,
#    'GF': 11,
#    'GB': 49,
#    'GI': 11,
#    'GR': 9,
#    'GT': 14,
#    'HN': 13,
#    'HU': 11,
#    'ID': 21,
#    'IL': 13,
#    'IE': 24,
#    'IN': 32,
#    'IQ': 15,
#    'IS': 13,
#    'IT': 30,
#    'JP': 14,
#    'KR': 16,
#    'KW': 11,
#    'LB': 15,
#    'LI': 11,
#    'LT': 12,
#    'LV': 12,
#    'MK': 14,
#    'MT': 14,
#    'MY': 17,
#    'MX': 30,
#    'NE': 11,
#    'NG': 12,
#    'NL': 27,
#    'NO': 22,
#    'NZ': 22,
#    'PE': 17,
#    'PL': 14,
#    'PH': 17,
#    'PS': 15,
#    'PT': 18,
#    'PY': 13,
#    'RO': 7,
#    'RU': 12,
#    'RS': 15,
#    'SI': 15,
#    'SG': 17,
#    'SE': 26,
#    'SM': 11,
#    'TH': 15,
#    'TN': 11,
#    'TR': 14,
#    'VE': 13,
#    'YE': 11,
#    'ZA': 14,
#    'US': 142},
#   'display_priority': 142,
#   'logo_path': '/6dET59jNU0ADysghEjl8Unuc7Ca.jpg',
#   'provider_name': 'WOW Presents Plus',
#   'provider_id': 546},
#  {'display_priorities': {'AD': 12,
#    'AL': 13,
#    'AR': 19,
#    'AT': 32,
#    'AU': 39,
#    'BA': 13,
#    'BB': 10,
#    'BE': 21,
#    'BH': 11,
#    'BM': 12,
#    'BO': 14,
#    'BS': 11,
#    'BR': 29,
#    'CH': 29,
#    'CA': 65,
#    'CL': 17,
#    'CO': 18,
#    'CR': 15,
#    'CZ': 12,
#    'DO': 11,
#    'DK': 22,
#    'DZ': 11,
#    'DE': 58,
#    'EC': 17,
#    'EE': 13,
#    'EG': 14,
#    'ES': 28,
#    'FI': 24,
#    'FR': 33,
#    'GF': 12,
#    'GB': 50,
#    'GI': 12,
#    'GR': 10,
#    'GT': 15,
#    'HK': 20,
#    'HN': 14,
#    'HR': 14,
#    'HU': 12,
#    'IL': 11,
#    'ID': 22,
#    'IE': 25,
#    'IN': 33,
#    'IQ': 13,
#    'IS': 15,
#    'IT': 31,
#    'JM': 10,
#    'JO': 11,
#    'JP': 15,
#    'KR': 17,
#    'KW': 12,
#    'LB': 13,
#    'LI': 12,
#    'LT': 13,
#    'MA': 11,
#    'LV': 13,
#    'LY': 11,
#    'MC': 11,
#    'MD': 11,
#    'MK': 12,
#    'MT': 12,
#    'MY': 18,
#    'MX': 29,
#    'NG': 10,
#    'NL': 29,
#    'NO': 23,
#    'NZ': 23,
#    'OM': 11,
#    'PA': 12,
#    'PE': 18,
#    'PL': 16,
#    'PH': 18,
#    'PS': 13,
#    'PT': 19,
#    'PY': 14,
#    'RO': 8,
#    'QA': 11,
#    'RU': 13,
#    'RS': 13,
#    'SA': 12,
#    'SI': 13,
#    'SG': 18,
#    'SE': 27,
#    'SV': 12,
#    'SM': 12,
#    'SK': 17,
#    'TH': 16,
#    'TN': 12,
#    'TR': 15,
#    'TW': 19,
#    'TZ': 26,
#    'UY': 15,
#    'VE': 14,
#    'YE': 12,
#    'ZA': 15,
#    'US': 143},
#   'display_priority': 143,
#   'logo_path': '/mSH24WQcRDJ2fsL5iucXqqRnSRb.jpg',
#   'provider_name': 'Magellan TV',
#   'provider_id': 551},
#  {'display_priorities': {'AD': 13,
#    'AL': 14,
#    'AR': 21,
#    'AT': 33,
#    'AU': 40,
#    'BA': 14,
#    'BB': 11,
#    'BE': 22,
#    'BG': 6,
#    'BH': 12,
#    'BO': 7,
#    'BM': 13,
#    'BS': 12,
#    'BR': 30,
#    'CI': 10,
#    'CH': 30,
#    'CA': 66,
#    'CL': 19,
#    'CO': 19,
#    'CR': 13,
#    'CZ': 13,
#    'DO': 12,
#    'DK': 23,
#    'DZ': 12,
#    'DE': 59,
#    'EC': 18,
#    'EE': 14,
#    'EG': 15,
#    'ES': 29,
#    'FI': 25,
#    'FR': 34,
#    'GF': 13,
#    'GB': 51,
#    'GI': 13,
#    'GR': 11,
#    'GT': 13,
#    'HN': 12,
#    'HK': 24,
#    'HR': 15,
#    'HU': 13,
#    'IL': 12,
#    'ID': 23,
#    'IE': 27,
#    'IN': 34,
#    'IQ': 14,
#    'IS': 16,
#    'IT': 32,
#    'JM': 11,
#    'JO': 12,
#    'JP': 16,
#    'KR': 18,
#    'KW': 13,
#    'LB': 14,
#    'LI': 13,
#    'LT': 15,
#    'MA': 12,
#    'LV': 14,
#    'LY': 12,
#    'MC': 12,
#    'MD': 12,
#    'MK': 13,
#    'MT': 13,
#    'NE': 10,
#    'MY': 19,
#    'MX': 31,
#    'NG': 11,
#    'NL': 30,
#    'NO': 24,
#    'NZ': 24,
#    'OM': 12,
#    'PA': 13,
#    'PE': 19,
#    'PL': 17,
#    'PH': 19,
#    'PS': 14,
#    'PT': 20,
#    'PY': 12,
#    'RO': 9,
#    'QA': 12,
#    'RU': 14,
#    'RS': 14,
#    'SA': 13,
#    'SI': 14,
#    'SG': 19,
#    'SE': 28,
#    'SV': 13,
#    'SM': 13,
#    'SK': 18,
#    'TH': 17,
#    'TN': 13,
#    'TR': 16,
#    'TW': 23,
#    'TZ': 27,
#    'UY': 16,
#    'VE': 15,
#    'YE': 13,
#    'ZA': 16,
#    'US': 144},
#   'display_priority': 144,
#   'logo_path': '/6IYZ4NjwPikxN7J9cfSmuyeHeMm.jpg',
#   'provider_name': 'BroadwayHD',
#   'provider_id': 554},
#  {'display_priorities': {'AD': 15,
#    'AL': 16,
#    'AR': 23,
#    'AT': 35,
#    'AU': 42,
#    'BA': 16,
#    'BB': 12,
#    'BE': 24,
#    'BG': 8,
#    'BH': 13,
#    'BO': 9,
#    'BM': 14,
#    'BS': 13,
#    'BR': 33,
#    'CI': 12,
#    'CH': 32,
#    'CA': 68,
#    'CL': 20,
#    'CO': 21,
#    'CR': 11,
#    'CZ': 15,
#    'DO': 13,
#    'DK': 25,
#    'DZ': 13,
#    'DE': 62,
#    'EC': 20,
#    'EE': 16,
#    'ES': 31,
#    'FI': 27,
#    'FR': 36,
#    'GF': 14,
#    'GB': 56,
#    'GI': 14,
#    'GR': 13,
#    'GT': 11,
#    'HN': 10,
#    'HK': 21,
#    'HR': 16,
#    'HU': 15,
#    'IL': 14,
#    'ID': 25,
#    'IE': 29,
#    'IN': 38,
#    'IQ': 16,
#    'IS': 17,
#    'IT': 34,
#    'JM': 12,
#    'JO': 13,
#    'JP': 18,
#    'KR': 20,
#    'KW': 14,
#    'LB': 16,
#    'LI': 14,
#    'LT': 17,
#    'MA': 13,
#    'LV': 16,
#    'LY': 13,
#    'MC': 13,
#    'MD': 13,
#    'MK': 15,
#    'MT': 15,
#    'NE': 12,
#    'MY': 21,
#    'MX': 33,
#    'NG': 13,
#    'NL': 33,
#    'NZ': 26,
#    'NO': 27,
#    'OM': 13,
#    'PA': 14,
#    'PE': 21,
#    'PL': 19,
#    'PH': 21,
#    'PS': 16,
#    'PT': 22,
#    'PY': 10,
#    'RO': 11,
#    'QA': 13,
#    'RS': 16,
#    'RU': 16,
#    'SI': 16,
#    'SG': 21,
#    'SE': 30,
#    'SV': 14,
#    'SM': 14,
#    'SK': 19,
#    'TH': 19,
#    'TN': 14,
#    'TR': 18,
#    'TW': 20,
#    'TZ': 21,
#    'UY': 17,
#    'VE': 17,
#    'YE': 14,
#    'ZA': 18,
#    'US': 87},
#   'display_priority': 87,
#   'logo_path': '/x6nRFzF32hCzMHaVM4RHRo7lsgS.jpg',
#   'provider_name': 'Dekkoo',
#   'provider_id': 444},
#  {'display_priorities': {'AD': 19,
#    'AL': 20,
#    'AR': 27,
#    'AT': 39,
#    'AU': 46,
#    'BA': 20,
#    'BB': 16,
#    'BE': 28,
#    'BH': 17,
#    'BM': 18,
#    'BO': 17,
#    'BS': 17,
#    'BR': 37,
#    'CI': 16,
#    'CH': 35,
#    'CA': 72,
#    'CL': 23,
#    'CO': 24,
#    'CR': 18,
#    'CZ': 18,
#    'DO': 17,
#    'DK': 28,
#    'DZ': 16,
#    'DE': 66,
#    'EC': 23,
#    'EE': 19,
#    'EG': 19,
#    'ES': 34,
#    'FI': 30,
#    'FR': 41,
#    'GF': 18,
#    'GB': 59,
#    'GI': 18,
#    'GR': 16,
#    'GT': 18,
#    'HK': 17,
#    'HN': 17,
#    'HR': 21,
#    'HU': 18,
#    'IN': 18,
#    'IL': 18,
#    'ID': 29,
#    'IE': 32,
#    'IQ': 20,
#    'IS': 22,
#    'IT': 37,
#    'JM': 16,
#    'JO': 17,
#    'JP': 21,
#    'KR': 23,
#    'KW': 18,
#    'LB': 20,
#    'LI': 18,
#    'LT': 20,
#    'MA': 16,
#    'LV': 19,
#    'LY': 16,
#    'MC': 17,
#    'MD': 17,
#    'MK': 19,
#    'MT': 19,
#    'MY': 24,
#    'NE': 16,
#    'MX': 37,
#    'NG': 17,
#    'NL': 36,
#    'NZ': 29,
#    'NO': 31,
#    'OM': 17,
#    'PA': 18,
#    'PE': 24,
#    'PL': 22,
#    'PH': 24,
#    'PS': 20,
#    'PT': 25,
#    'PY': 17,
#    'RO': 14,
#    'QA': 17,
#    'SA': 18,
#    'RS': 20,
#    'RU': 21,
#    'SI': 20,
#    'SG': 24,
#    'SE': 33,
#    'SV': 18,
#    'SM': 18,
#    'SK': 24,
#    'TH': 22,
#    'TN': 17,
#    'TR': 21,
#    'TW': 16,
#    'TZ': 29,
#    'UY': 21,
#    'VE': 20,
#    'YE': 18,
#    'ZA': 21,
#    'US': 153},
#   'display_priority': 153,
#   'logo_path': '/u7dwMceEbjxd1N3TLEUBILSK2x6.jpg',
#   'provider_name': 'Hoichoi',
#   'provider_id': 315},
#  {'display_priorities': {'AR': 28,
#    'AT': 40,
#    'BO': 23,
#    'BR': 38,
#    'CH': 37,
#    'CL': 24,
#    'CO': 25,
#    'CA': 121,
#    'CR': 24,
#    'CZ': 19,
#    'DO': 19,
#    'DK': 35,
#    'DE': 67,
#    'EC': 24,
#    'ES': 36,
#    'FR': 43,
#    'GB': 75,
#    'GT': 24,
#    'HN': 23,
#    'IT': 39,
#    'MX': 38,
#    'NI': 3,
#    'NO': 37,
#    'PA': 20,
#    'PE': 25,
#    'PY': 23,
#    'SE': 39,
#    'SV': 20,
#    'UY': 23,
#    'VE': 21,
#    'US': 81},
#   'display_priority': 81,
#   'logo_path': '/dB8G41Q6tSL5NBisrIeqByfepBc.jpg',
#   'provider_name': 'Pluto TV',
#   'provider_id': 300},
#  {'display_priorities': {'AT': 56,
#    'DK': 42,
#    'DE': 113,
#    'ES': 37,
#    'FI': 32,
#    'GB': 84,
#    'IE': 39,
#    'IT': 23,
#    'NL': 39,
#    'NO': 32,
#    'SE': 34},
#   'display_priority': 34,
#   'logo_path': '/bPW3J8KlLrot95sLzadnpzVe61f.jpg',
#   'provider_name': 'Discovery+',
#   'provider_id': 524},
#  {'display_priorities': {'AU': 80,
#    'CA': 26,
#    'ES': 39,
#    'GB': 34,
#    'FR': 48,
#    'IT': 52},
#   'display_priority': 52,
#   'logo_path': '/2eyS8KsZF9Or7z4248Ktq36Pr8v.jpg',
#   'provider_name': 'Hayu Amazon Channel',
#   'provider_id': 296},
#  {'display_priorities': {'AE': 0,
#    'AD': 0,
#    'AG': 0,
#    'AL': 0,
#    'AO': 4,
#    'AR': 1,
#    'AT': 0,
#    'AU': 1,
#    'AZ': 2,
#    'BA': 0,
#    'BB': 0,
#    'BE': 1,
#    'BG': 0,
#    'BH': 0,
#    'BM': 0,
#    'BO': 0,
#    'BR': 2,
#    'BS': 0,
#    'BY': 6,
#    'BZ': 7,
#    'CA': 0,
#    'CH': 0,
#    'CI': 0,
#    'CL': 1,
#    'CO': 2,
#    'CM': 4,
#    'CR': 0,
#    'CU': 0,
#    'CV': 0,
#    'CZ': 1,
#    'CY': 7,
#    'DE': 0,
#    'DK': 1,
#    'DO': 0,
#    'DZ': 0,
#    'EC': 0,
#    'EE': 0,
#    'EG': 0,
#    'ES': 40,
#    'FI': 1,
#    'FJ': 0,
#    'FR': 1,
#    'GB': 0,
#    'GF': 0,
#    'GG': 0,
#    'GH': 0,
#    'GI': 0,
#    'GQ': 0,
#    'GR': 0,
#    'GT': 0,
#    'HK': 1,
#    'HN': 0,
#    'HR': 0,
#    'HU': 1,
#    'ID': 0,
#    'IE': 0,
#    'IL': 0,
#    'IN': 0,
#    'IQ': 0,
#    'IT': 1,
#    'IS': 0,
#    'JM': 0,
#    'JP': 0,
#    'JO': 0,
#    'KE': 0,
#    'KR': 0,
#    'KW': 0,
#    'LB': 0,
#    'LC': 0,
#    'LI': 0,
#    'LT': 0,
#    'LU': 8,
#    'MA': 0,
#    'LV': 0,
#    'LY': 0,
#    'MC': 0,
#    'ME': 4,
#    'MD': 0,
#    'MG': 4,
#    'MK': 0,
#    'MT': 0,
#    'ML': 5,
#    'MU': 0,
#    'MX': 8,
#    'MZ': 0,
#    'MY': 1,
#    'NE': 0,
#    'NG': 0,
#    'NL': 0,
#    'NI': 11,
#    'NO': 1,
#    'NZ': 1,
#    'OM': 0,
#    'PA': 0,
#    'PE': 2,
#    'PK': 0,
#    'PF': 0,
#    'PL': 1,
#    'PH': 0,
#    'PS': 0,
#    'PT': 1,
#    'PY': 0,
#    'QA': 0,
#    'RO': 1,
#    'RS': 0,
#    'SA': 0,
#    'SC': 0,
#    'SI': 0,
#    'SG': 0,
#    'SE': 1,
#    'SN': 0,
#    'SV': 0,
#    'SK': 1,
#    'SM': 0,
#    'TC': 0,
#    'TH': 1,
#    'TD': 5,
#    'TN': 0,
#    'TR': 3,
#    'TT': 0,
#    'TW': 0,
#    'TZ': 0,
#    'UA': 0,
#    'UG': 0,
#    'US': 7,
#    'UY': 0,
#    'VE': 0,
#    'YE': 0,
#    'ZA': 0,
#    'ZM': 0,
#    'ZW': 5},
#   'display_priority': 5,
#   'logo_path': '/pbpMk2JmcoNnQwx5JGpXngfoWtp.jpg',
#   'provider_name': 'Netflix',
#   'provider_id': 8},
#  {'display_priorities': {'AU': 83, 'CA': 80, 'DE': 120, 'ES': 42, 'GB': 109},
#   'display_priority': 109,
#   'logo_path': '/d0KmcInHpiF44ahOLrXCQATEFmD.jpg',
#   'provider_name': 'OUTtv Amazon Channel',
#   'provider_id': 607},
#  {'display_priorities': {'AU': 28,
#    'CA': 28,
#    'ES': 43,
#    'GB': 55,
#    'MX': 41,
#    'US': 96},
#   'display_priority': 96,
#   'logo_path': '/1wYmvbAuVZz2JnKvYfYN8Qolnb.jpg',
#   'provider_name': 'AcornTV Amazon Channel',
#   'provider_id': 196},
#  {'display_priorities': {'ES': 44},
#   'display_priority': 44,
#   'logo_path': '/2GQVxfaiWA4n93I7sJDJf1b6NqS.jpg',
#   'provider_name': 'FlixOlé Amazon Channel',
#   'provider_id': 684},
#  {'display_priorities': {'AG': 8,
#    'AE': 11,
#    'AD': 21,
#    'AL': 22,
#    'AR': 30,
#    'AT': 43,
#    'AU': 49,
#    'BA': 22,
#    'BB': 21,
#    'BG': 14,
#    'BE': 31,
#    'BH': 22,
#    'BM': 23,
#    'BO': 25,
#    'BS': 21,
#    'BR': 43,
#    'CI': 20,
#    'CH': 39,
#    'CA': 89,
#    'CL': 26,
#    'CO': 27,
#    'CR': 26,
#    'CU': 8,
#    'CV': 8,
#    'CZ': 21,
#    'DO': 22,
#    'DK': 32,
#    'DZ': 21,
#    'EC': 26,
#    'DE': 75,
#    'EE': 21,
#    'EG': 26,
#    'FI': 34,
#    'ES': 46,
#    'FJ': 8,
#    'FR': 49,
#    'GF': 23,
#    'GG': 9,
#    'GH': 7,
#    'GB': 78,
#    'GI': 23,
#    'GQ': 7,
#    'GR': 18,
#    'GT': 26,
#    'HN': 25,
#    'HK': 34,
#    'HU': 20,
#    'HR': 28,
#    'IL': 20,
#    'ID': 31,
#    'IE': 35,
#    'IN': 45,
#    'IQ': 22,
#    'IS': 27,
#    'IT': 42,
#    'JM': 20,
#    'JP': 23,
#    'JO': 22,
#    'KE': 7,
#    'KR': 25,
#    'LC': 8,
#    'KW': 23,
#    'LB': 22,
#    'LI': 23,
#    'LT': 22,
#    'LV': 21,
#    'MA': 21,
#    'LY': 21,
#    'MC': 22,
#    'MD': 21,
#    'MK': 21,
#    'MU': 9,
#    'MT': 21,
#    'MZ': 7,
#    'MY': 27,
#    'NE': 20,
#    'MX': 42,
#    'NG': 22,
#    'NL': 42,
#    'NZ': 31,
#    'NO': 34,
#    'OM': 22,
#    'PA': 23,
#    'PE': 27,
#    'PK': 6,
#    'PF': 8,
#    'PL': 25,
#    'PH': 26,
#    'PS': 22,
#    'PT': 29,
#    'PY': 25,
#    'RO': 16,
#    'QA': 22,
#    'RS': 22,
#    'RU': 24,
#    'SA': 25,
#    'SC': 10,
#    'SI': 22,
#    'SN': 7,
#    'SG': 27,
#    'SE': 36,
#    'SV': 23,
#    'TC': 8,
#    'SM': 23,
#    'SK': 31,
#    'TH': 25,
#    'TT': 8,
#    'TN': 22,
#    'TR': 23,
#    'TZ': 9,
#    'TW': 34,
#    'UG': 7,
#    'XK': 2,
#    'VA': 6,
#    'UY': 26,
#    'VE': 23,
#    'YE': 23,
#    'ZM': 7,
#    'ZA': 23,
#    'US': 158},
#   'display_priority': 158,
#   'logo_path': '/uauVx3dGWt0GICqdMCBYJObd3Mo.jpg',
#   'provider_name': 'Cultpix',
#   'provider_id': 692},
#  {'display_priorities': {'AG': 7,
#    'AE': 12,
#    'AL': 24,
#    'AO': 3,
#    'AZ': 0,
#    'AR': 31,
#    'AT': 44,
#    'AU': 50,
#    'BF': 3,
#    'BB': 22,
#    'BG': 15,
#    'BE': 32,
#    'BH': 23,
#    'BM': 24,
#    'BO': 26,
#    'BY': 5,
#    'BZ': 6,
#    'BS': 22,
#    'BR': 44,
#    'CI': 22,
#    'CH': 40,
#    'CM': 3,
#    'CA': 90,
#    'CL': 27,
#    'CO': 28,
#    'CR': 27,
#    'CU': 7,
#    'CY': 6,
#    'CV': 7,
#    'CZ': 23,
#    'DO': 23,
#    'DK': 33,
#    'DZ': 23,
#    'EC': 27,
#    'DE': 76,
#    'EE': 22,
#    'EG': 27,
#    'FI': 35,
#    'ES': 47,
#    'FJ': 7,
#    'FR': 51,
#    'GG': 7,
#    'GF': 26,
#    'GH': 9,
#    'GB': 79,
#    'GI': 24,
#    'GQ': 9,
#    'GR': 19,
#    'GY': 2,
#    'GT': 27,
#    'HN': 26,
#    'HK': 36,
#    'HU': 21,
#    'HR': 29,
#    'ID': 32,
#    'IE': 36,
#    'IN': 46,
#    'IQ': 24,
#    'IS': 28,
#    'IT': 44,
#    'JM': 21,
#    'JP': 24,
#    'JO': 23,
#    'KE': 10,
#    'KR': 26,
#    'LC': 7,
#    'KW': 24,
#    'LB': 24,
#    'LI': 24,
#    'LU': 7,
#    'LT': 23,
#    'LV': 22,
#    'MA': 22,
#    'LY': 23,
#    'MC': 23,
#    'ME': 3,
#    'MG': 3,
#    'ML': 4,
#    'MD': 22,
#    'MU': 7,
#    'MW': 2,
#    'MK': 23,
#    'MZ': 9,
#    'MY': 28,
#    'NE': 22,
#    'MX': 43,
#    'NI': 7,
#    'NG': 25,
#    'NL': 44,
#    'NZ': 32,
#    'NO': 35,
#    'OM': 23,
#    'PA': 24,
#    'PE': 28,
#    'PG': 3,
#    'PK': 7,
#    'PF': 7,
#    'PL': 26,
#    'PH': 27,
#    'PS': 24,
#    'PT': 30,
#    'PY': 26,
#    'RO': 17,
#    'QA': 23,
#    'RS': 25,
#    'RU': 25,
#    'SA': 26,
#    'SC': 8,
#    'SN': 9,
#    'SG': 28,
#    'SE': 37,
#    'SV': 24,
#    'TC': 7,
#    'SM': 24,
#    'SK': 32,
#    'TD': 4,
#    'TH': 26,
#    'TT': 7,
#    'TN': 23,
#    'TR': 23,
#    'UA': 6,
#    'TZ': 17,
#    'TW': 36,
#    'UG': 9,
#    'UY': 28,
#    'VE': 24,
#    'YE': 24,
#    'ZM': 9,
#    'ZW': 4,
#    'ZA': 24,
#    'US': 160},
#   'display_priority': 160,
#   'logo_path': '/fbveJTcro9Xw2KuPIIoPPePHiwy.jpg',
#   'provider_name': 'FilmBox+',
#   'provider_id': 701},
#  {'display_priorities': {'ES': 48},
#   'display_priority': 48,
#   'logo_path': '/8vES2nJNwOF57muvqLByDLm6snp.jpg',
#   'provider_name': 'Acontra Plus',
#   'provider_id': 1717},
#  {'display_priorities': {'ES': 52},
#   'display_priority': 52,
#   'logo_path': '/4s8njawy9i5sVseo5pO862bHKuM.jpg',
#   'provider_name': 'Pash Amazon Channel',
#   'provider_id': 1739},
#  {'display_priorities': {'ES': 53},
#   'display_priority': 53,
#   'logo_path': '/yISpVXhf6axqiHh6lBvJ8RRrZ8v.jpg',
#   'provider_name': 'Planet Horror Amazon Channel',
#   'provider_id': 1740},
#  {'display_priorities': {'ES': 54},
#   'display_priority': 54,
#   'logo_path': '/tM1HabyA45cnckBEhLS7hAVga5g.jpg',
#   'provider_name': 'Dizi Amazon Channel',
#   'provider_id': 1741},
#  {'display_priorities': {'ES': 55},
#   'display_priority': 55,
#   'logo_path': '/tGvAD4O9obFP3DfOrDn8NaRQ6eT.jpg',
#   'provider_name': 'Acontra Plus Amazon Channel',
#   'provider_id': 1742},
#  {'display_priorities': {'ES': 56},
#   'display_priority': 56,
#   'logo_path': '/aJECXkHekrkuRZ7ABF5YR9DVDd8.jpg',
#   'provider_name': 'Historia y Actualidad Amazon Channel',
#   'provider_id': 1743},
#  {'display_priorities': {'AD': 4,
#    'AL': 4,
#    'AG': 3,
#    'AE': 6,
#    'AU': 29,
#    'BA': 4,
#    'AR': 33,
#    'AT': 51,
#    'BB': 5,
#    'BH': 5,
#    'BE': 34,
#    'BG': 18,
#    'BM': 5,
#    'BO': 28,
#    'BS': 5,
#    'BR': 46,
#    'CI': 4,
#    'CA': 47,
#    'CH': 45,
#    'CL': 29,
#    'CO': 30,
#    'CU': 3,
#    'CR': 29,
#    'CV': 3,
#    'CZ': 25,
#    'DO': 5,
#    'DZ': 5,
#    'DK': 38,
#    'EC': 29,
#    'EG': 11,
#    'EE': 25,
#    'DE': 101,
#    'FI': 39,
#    'FJ': 3,
#    'ES': 62,
#    'GF': 5,
#    'GG': 3,
#    'FR': 72,
#    'GH': 3,
#    'GI': 5,
#    'GB': 98,
#    'GQ': 3,
#    'GR': 21,
#    'GT': 29,
#    'HK': 10,
#    'HR': 10,
#    'HN': 28,
#    'HU': 23,
#    'IL': 4,
#    'IN': 17,
#    'ID': 34,
#    'IE': 38,
#    'IQ': 4,
#    'IS': 10,
#    'JM': 5,
#    'IT': 63,
#    'JO': 5,
#    'JP': 26,
#    'KE': 3,
#    'KW': 5,
#    'LB': 4,
#    'KR': 28,
#    'LC': 3,
#    'LI': 5,
#    'LT': 26,
#    'MA': 5,
#    'LY': 5,
#    'MC': 5,
#    'LV': 25,
#    'MD': 5,
#    'MK': 4,
#    'MT': 4,
#    'MU': 2,
#    'MZ': 3,
#    'NE': 4,
#    'MY': 12,
#    'NG': 4,
#    'MX': 45,
#    'NZ': 15,
#    'NL': 46,
#    'NO': 39,
#    'OM': 5,
#    'PA': 5,
#    'PE': 30,
#    'PK': 3,
#    'PF': 3,
#    'PS': 4,
#    'PL': 28,
#    'PH': 29,
#    'PT': 33,
#    'QA': 5,
#    'PY': 27,
#    'RO': 19,
#    'RS': 4,
#    'SA': 9,
#    'SC': 3,
#    'RU': 27,
#    'SI': 4,
#    'SG': 12,
#    'SN': 3,
#    'SE': 41,
#    'SV': 5,
#    'SM': 5,
#    'SK': 13,
#    'TC': 3,
#    'TN': 5,
#    'TH': 28,
#    'TT': 3,
#    'TR': 27,
#    'TW': 9,
#    'TZ': 3,
#    'UG': 3,
#    'XK': 0,
#    'VA': 2,
#    'UY': 7,
#    'YE': 5,
#    'US': 46,
#    'VE': 26,
#    'ZA': 10,
#    'ZM': 3},
#   'display_priority': 46,
#   'logo_path': '/6KEQzITx2RrCAQt5Nw9WrL1OI8z.jpg',
#   'provider_name': 'Sun Nxt',
#   'provider_id': 309},
#  {'display_priorities': {'AU': 53,
#    'BR': 47,
#    'CA': 111,
#    'DE': 103,
#    'ES': 63,
#    'FR': 73,
#    'GB': 100,
#    'IT': 64,
#    'JP': 27,
#    'KR': 29,
#    'MX': 46,
#    'US': 181},
#   'display_priority': 181,
#   'logo_path': '/kICQccvOh8AIBMHGkBXJ047xeHN.jpg',
#   'provider_name': 'Netflix basic with Ads',
#   'provider_id': 1796},
#  {'display_priorities': {'ES': 68},
#   'display_priority': 68,
#   'logo_path': '/8VhN4PeHU7yfMNoWK0DnwdS1HlS.jpg',
#   'provider_name': 'Tivify',
#   'provider_id': 1838},
#  {'display_priorities': {'AR': 45,
#    'BO': 29,
#    'BZ': 8,
#    'BR': 63,
#    'CL': 30,
#    'CO': 31,
#    'CA': 124,
#    'CR': 30,
#    'DO': 27,
#    'EC': 30,
#    'ES': 72,
#    'FR': 90,
#    'GB': 108,
#    'GT': 30,
#    'HN': 29,
#    'NI': 8,
#    'MX': 63,
#    'PA': 28,
#    'PE': 31,
#    'PY': 28,
#    'SV': 28,
#    'UY': 30,
#    'VE': 27,
#    'US': 197},
#   'display_priority': 197,
#   'logo_path': '/oJRCAz1WKkKM9Ge7mX5KFnegTNY.jpg',
#   'provider_name': 'Runtime',
#   'provider_id': 1875},
#  {'display_priorities': {'AG': 10,
#    'AE': 25,
#    'AD': 25,
#    'AL': 27,
#    'AZ': 4,
#    'AR': 46,
#    'BA': 27,
#    'AT': 58,
#    'AU': 58,
#    'BF': 4,
#    'BB': 24,
#    'BG': 20,
#    'BE': 41,
#    'BH': 36,
#    'BM': 26,
#    'BO': 30,
#    'BR': 11,
#    'BY': 7,
#    'BZ': 9,
#    'BS': 24,
#    'CD': 2,
#    'CI': 26,
#    'CH': 47,
#    'CL': 31,
#    'CO': 32,
#    'CA': 125,
#    'CR': 31,
#    'CY': 8,
#    'CV': 12,
#    'DE': 6,
#    'CZ': 27,
#    'DO': 28,
#    'DK': 39,
#    'DZ': 28,
#    'EC': 31,
#    'EE': 26,
#    'EG': 40,
#    'FI': 40,
#    'FJ': 10,
#    'FR': 5,
#    'ES': 73,
#    'GB': 6,
#    'GF': 28,
#    'GG': 10,
#    'GH': 15,
#    'GI': 26,
#    'GQ': 13,
#    'GY': 3,
#    'GR': 22,
#    'GT': 31,
#    'HK': 38,
#    'HN': 30,
#    'HU': 25,
#    'HR': 34,
#    'IN': 4,
#    'IL': 26,
#    'ID': 35,
#    'IE': 40,
#    'IQ': 35,
#    'IS': 31,
#    'JM': 23,
#    'IT': 74,
#    'KE': 14,
#    'JO': 36,
#    'KR': 30,
#    'LC': 10,
#    'LB': 27,
#    'KW': 36,
#    'LI': 27,
#    'LU': 9,
#    'LT': 27,
#    'LV': 26,
#    'MA': 27,
#    'LY': 28,
#    'MC': 25,
#    'ME': 5,
#    'MD': 24,
#    'MK': 26,
#    'MU': 14,
#    'MX': 4,
#    'MZ': 15,
#    'MY': 30,
#    'NE': 26,
#    'NI': 9,
#    'NG': 29,
#    'NZ': 35,
#    'NO': 41,
#    'NL': 67,
#    'PA': 29,
#    'OM': 36,
#    'PG': 4,
#    'PE': 32,
#    'PF': 10,
#    'PL': 29,
#    'PH': 31,
#    'PS': 27,
#    'PT': 39,
#    'PY': 29,
#    'RO': 21,
#    'QA': 36,
#    'RS': 28,
#    'RU': 28,
#    'SC': 13,
#    'SI': 28,
#    'SG': 30,
#    'SN': 13,
#    'SE': 42,
#    'SV': 29,
#    'TC': 10,
#    'SM': 27,
#    'SK': 36,
#    'TD': 6,
#    'TH': 29,
#    'TT': 10,
#    'TN': 28,
#    'TR': 43,
#    'UA': 7,
#    'TW': 38,
#    'TZ': 31,
#    'UG': 15,
#    'US': 6,
#    'XK': 4,
#    'UY': 31,
#    'VE': 28,
#    'YE': 27,
#    'ZM': 13,
#    'ZA': 28,
#    'MT': 24},
#   'display_priority': 28,
#   'logo_path': '/mXeC4TrcgdU6ltE9bCBCEORwSQR.jpg',
#   'provider_name': 'Crunchyroll',
#   'provider_id': 283},
#  {'display_priorities': {'AU': 55, 'CA': 91, 'ES': 74, 'US': 26},
#   'display_priority': 26,
#   'logo_path': '/2ino0WmHA4GROB7NYKzT6PGqLcb.jpg',
#   'provider_name': 'AMC+ Amazon Channel',
#   'provider_id': 528},
#  {'display_priorities': {'AU': 82, 'BR': 42, 'CA': 81, 'ES': 75, 'MX': 40},
#   'display_priority': 40,
#   'logo_path': '/bSy9zFiZtbKBHIyOu0H2Fs5cJmx.jpg',
#   'provider_name': 'Love Nature Amazon Channel',
#   'provider_id': 608},
#  {'display_priorities': {'AU': 84, 'ES': 76},
#   'display_priority': 76,
#   'logo_path': '/3EFwJrJalr0YEgN1ENwrYbIar3Q.jpg',
#   'provider_name': 'Hopster Amazon Channel',
#   'provider_id': 1890},
#  {'display_priorities': {'AE': 14,
#    'AR': 56,
#    'AU': 60,
#    'BH': 28,
#    'BR': 78,
#    'CI': 24,
#    'CA': 135,
#    'DZ': 25,
#    'EG': 30,
#    'FI': 41,
#    'DE': 141,
#    'ES': 88,
#    'GH': 11,
#    'FR': 100,
#    'GQ': 11,
#    'GB': 121,
#    'IL': 9,
#    'ID': 36,
#    'IQ': 10,
#    'IN': 64,
#    'JO': 28,
#    'IT': 92,
#    'KE': 12,
#    'LB': 10,
#    'KW': 29,
#    'MA': 24,
#    'LY': 25,
#    'MU': 10,
#    'MZ': 11,
#    'NE': 24,
#    'NG': 27,
#    'MX': 70,
#    'OM': 28,
#    'PS': 10,
#    'PL': 32,
#    'PH': 32,
#    'QA': 28,
#    'RU': 29,
#    'SA': 28,
#    'SC': 11,
#    'SN': 11,
#    'TN': 25,
#    'TZ': 10,
#    'TR': 55,
#    'UG': 11,
#    'ZM': 11,
#    'ZA': 26,
#    'US': 221},
#   'display_priority': 221,
#   'logo_path': '/7qZED0kLBtiV8mLRNBtW4PQCAqW.jpg',
#   'provider_name': 'Shahid VIP',
#   'provider_id': 1715},
#  {'display_priorities': {'AU': 64,
#    'CA': 141,
#    'ES': 93,
#    'GB': 131,
#    'MX': 78,
#    'US': 238},
#   'display_priority': 238,
#   'logo_path': '/kx8rGgFYxX6aJkG7RHx2mtijglC.jpg',
#   'provider_name': 'Acorn TV Apple TV',
#   'provider_id': 2034},
#  {'display_priorities': {'AU': 57, 'CA': 119, 'ES': 94, 'US': 22},
#   'display_priority': 22,
#   'logo_path': '/oTQdXIqM9iewlN4MC2nhKB0gHw.jpg',
#   'provider_name': 'AMC Plus Apple TV Channel ',
#   'provider_id': 1854},
#  {'display_priorities': {'AR': 14,
#    'AU': 67,
#    'BR': 13,
#    'CA': 30,
#    'CL': 12,
#    'CO': 14,
#    'EC': 13,
#    'FJ': 12,
#    'ES': 97,
#    'GB': 136,
#    'IE': 43,
#    'MX': 11,
#    'NZ': 36,
#    'PE': 14,
#    'PG': 5,
#    'PF': 11,
#    'PT': 59,
#    'US': 14,
#    'VE': 11},
#   'display_priority': 11,
#   'logo_path': '/hwsU65QW7A4dbMEWkDpgHyCNcfS.jpg',
#   'provider_name': 'Kocowa',
#   'provider_id': 464},
#  {'display_priorities': {'AT': 72,
#    'BE': 66,
#    'BR': 92,
#    'CL': 38,
#    'CO': 39,
#    'DE': 167,
#    'ES': 106,
#    'GB': 146,
#    'IT': 108,
#    'MX': 85,
#    'NL': 88},
#   'display_priority': 88,
#   'logo_path': '/efu1Cqc63XrPBoreYnf2mn0Nizj.jpg',
#   'provider_name': 'MGM Plus Amazon Channel',
#   'provider_id': 2141},
#  {'display_priorities': {'ES': 109},
#   'display_priority': 109,
#   'logo_path': '/lDvzuBuNVgpcdzDpPmmufKvrZPb.jpg',
#   'provider_name': '3Cat',
#   'provider_id': 2237}]

# %%
#Creación del df que contiene las plataformas de streaming para las series en España
serie_spain_providers_data = pd.DataFrame(res_url_series_spain_providers.json()["results"])
serie_spain_providers_data
# Out:
#                                    display_priorities  display_priority  \
# 0   {'AD': 7, 'AL': 7, 'AR': 0, 'AT': 2, 'AU': 0, ...                27
# 1   {'AE': 2, 'AG': 11, 'AR': 5, 'AT': 5, 'AZ': 3,...                 9
# 2   {'AD': 1, 'AG': 1, 'AL': 1, 'AE': 9, 'AO': 1, ...                 1
# 3                                           {'ES': 3}                 3
# 4   {'AL': 8, 'AT': 9, 'BA': 8, 'BE': 10, 'CH': 9,...                 4
# 5                                           {'ES': 5}                 5
# 6                        {'CA': 97, 'ES': 7, 'US': 8}                 8
# 7   {'AD': 24, 'AL': 26, 'BA': 26, 'BG': 19, 'CZ':...                 3
# 8                                 {'ES': 9, 'PT': 27}                27
# 9   {'AU': 4, 'AT': 67, 'BE': 3, 'CA': 3, 'CH': 52...                 3
# 10                                         {'ES': 13}                13
# 11  {'AD': 2, 'AL': 2, 'BA': 2, 'BB': 2, 'BH': 2, ...                 2
# 12  {'AG': 12, 'AD': 27, 'BA': 29, 'AR': 61, 'BB':...                30
# 13  {'AT': 12, 'AU': 17, 'BR': 16, 'CH': 6, 'CA': ...                45
# 14  {'AT': 13, 'AU': 14, 'BE': 8, 'CH': 20, 'CA': ...                33
# 15  {'AD': 8, 'AL': 9, 'AR': 11, 'AT': 24, 'AU': 3...                51
# 16                                         {'ES': 22}                22
# 17  {'AR': 18, 'AT': 26, 'AU': 35, 'BE': 17, 'BG':...               132
# 18                                         {'ES': 25}                25
# 19  {'AG': 13, 'AD': 26, 'AO': 5, 'AL': 28, 'AZ': ...               140
# 20  {'AD': 14, 'AL': 15, 'AR': 20, 'AT': 31, 'AU':...               142
# 21  {'AD': 12, 'AL': 13, 'AR': 19, 'AT': 32, 'AU':...               143
# 22  {'AD': 13, 'AL': 14, 'AR': 21, 'AT': 33, 'AU':...               144
# 23  {'AD': 15, 'AL': 16, 'AR': 23, 'AT': 35, 'AU':...                87
# 24  {'AD': 19, 'AL': 20, 'AR': 27, 'AT': 39, 'AU':...               153
# 25  {'AR': 28, 'AT': 40, 'BO': 23, 'BR': 38, 'CH':...                81
# 26  {'AT': 56, 'DK': 42, 'DE': 113, 'ES': 37, 'FI'...                34
# 27  {'AU': 80, 'CA': 26, 'ES': 39, 'GB': 34, 'FR':...                52
# 28  {'AE': 0, 'AD': 0, 'AG': 0, 'AL': 0, 'AO': 4, ...                 5
# 29  {'AU': 83, 'CA': 80, 'DE': 120, 'ES': 42, 'GB'...               109
# 30  {'AU': 28, 'CA': 28, 'ES': 43, 'GB': 55, 'MX':...                96
# 31                                         {'ES': 44}                44
# 32  {'AG': 8, 'AE': 11, 'AD': 21, 'AL': 22, 'AR': ...               158
# 33  {'AG': 7, 'AE': 12, 'AL': 24, 'AO': 3, 'AZ': 0...               160
# 34                                         {'ES': 48}                48
# 35                                         {'ES': 52}                52
# 36                                         {'ES': 53}                53
# 37                                         {'ES': 54}                54
# 38                                         {'ES': 55}                55
# 39                                         {'ES': 56}                56
# 40  {'AD': 4, 'AL': 4, 'AG': 3, 'AE': 6, 'AU': 29,...                46
# 41  {'AU': 53, 'BR': 47, 'CA': 111, 'DE': 103, 'ES...               181
# 42                                         {'ES': 68}                68
# 43  {'AR': 45, 'BO': 29, 'BZ': 8, 'BR': 63, 'CL': ...               197
# 44  {'AG': 10, 'AE': 25, 'AD': 25, 'AL': 27, 'AZ':...                28
# 45           {'AU': 55, 'CA': 91, 'ES': 74, 'US': 26}                26
# 46  {'AU': 82, 'BR': 42, 'CA': 81, 'ES': 75, 'MX':...                40
# 47                               {'AU': 84, 'ES': 76}                76
# 48  {'AE': 14, 'AR': 56, 'AU': 60, 'BH': 28, 'BR':...               221
# 49  {'AU': 64, 'CA': 141, 'ES': 93, 'GB': 131, 'MX...               238
# 50          {'AU': 57, 'CA': 119, 'ES': 94, 'US': 22}                22
# 51  {'AR': 14, 'AU': 67, 'BR': 13, 'CA': 30, 'CL':...                11
# 52  {'AT': 72, 'BE': 66, 'BR': 92, 'CL': 38, 'CO':...                88
# 53                                        {'ES': 109}               109
#
#                            logo_path                         provider_name  \
# 0    /97yvRBw1GzX7fXprcF80er19ot.jpg                           Disney Plus
# 1   /2E03IAZsX4ZaUqM7tXlctEPMGWS.jpg                         Apple TV Plus
# 2   /dQeAar5H991VYporEjUspolDarG.jpg                    Amazon Prime Video
# 3   /jse4MOi92Jgetym7nbXFZZBI6LK.jpg                  Movistar Plus+ €9.99
# 4   /bZvc9dXrXNly7cA0V4D9pR8yJwm.jpg                            Rakuten TV
# 5   /f6TRLB3H4jDpFEZ0z2KWSSvu1SB.jpg                        Movistar Plus+
# 6   /9BgaNQRMDvVlji1JBZi6tcfxpKx.jpg                                fuboTV
# 7   /gQbqEYd0C9uprYxEUqTM589qn8g.jpg                           SkyShowtime
# 8   /kO2SWXvDCHAquaUuTJBuZkTBAuU.jpg                                Filmin
# 9   /jxIBXlxRbCcy7Y4GvOZKszCd0dv.jpg                                  Hayu
# 10  /oN6g8QorcoYo3mx4BulU22ghKq4.jpg                          Atres Player
# 11  /ozMgkAAoi6aDI5ce8KKA2k8TGvB.jpg                               FlixOlé
# 12  /fksCUZ9QDWZMUwL2LgMtLckROUN.jpg                                   Max
# 13  /5vfrJQgNe9UnHVgVNAwZTy0Jo9o.jpg                       Microsoft Store
# 14  /rMb93u1tBeErSYLv79zSTR07UdO.jpg                       YouTube Premium
# 15  /oR1aNm1Qu9jQBkW4VrGPWhqbC3P.jpg                      Curiosity Stream
# 16  /273VHxSrDdEwLTXJrsnE6yJMqNZ.jpg                               Mitele
# 17  /5zqbck5mo8PuVbGu2ngBUdn5Yga.jpg                             DOCSVILLE
# 18  /3QQKYFUDt13Q2Zm6JM2cOjlbd27.jpg                                  rtve
# 19  /vLZKlXUNDcZR7ilvfY9Wr9k80FZ.jpg                                  Plex
# 20  /6dET59jNU0ADysghEjl8Unuc7Ca.jpg                     WOW Presents Plus
# 21  /mSH24WQcRDJ2fsL5iucXqqRnSRb.jpg                           Magellan TV
# 22  /6IYZ4NjwPikxN7J9cfSmuyeHeMm.jpg                            BroadwayHD
# 23  /x6nRFzF32hCzMHaVM4RHRo7lsgS.jpg                                Dekkoo
# 24  /u7dwMceEbjxd1N3TLEUBILSK2x6.jpg                               Hoichoi
# 25  /dB8G41Q6tSL5NBisrIeqByfepBc.jpg                              Pluto TV
# 26  /bPW3J8KlLrot95sLzadnpzVe61f.jpg                            Discovery+
# 27  /2eyS8KsZF9Or7z4248Ktq36Pr8v.jpg                   Hayu Amazon Channel
# 28  /pbpMk2JmcoNnQwx5JGpXngfoWtp.jpg                               Netflix
# 29  /d0KmcInHpiF44ahOLrXCQATEFmD.jpg                  OUTtv Amazon Channel
# 30   /1wYmvbAuVZz2JnKvYfYN8Qolnb.jpg                AcornTV Amazon Channel
# 31  /2GQVxfaiWA4n93I7sJDJf1b6NqS.jpg                FlixOlé Amazon Channel
# 32  /uauVx3dGWt0GICqdMCBYJObd3Mo.jpg                               Cultpix
# 33  /fbveJTcro9Xw2KuPIIoPPePHiwy.jpg                              FilmBox+
# 34  /8vES2nJNwOF57muvqLByDLm6snp.jpg                          Acontra Plus
# 35  /4s8njawy9i5sVseo5pO862bHKuM.jpg                   Pash Amazon Channel
# 36  /yISpVXhf6axqiHh6lBvJ8RRrZ8v.jpg          Planet Horror Amazon Channel
# 37  /tM1HabyA45cnckBEhLS7hAVga5g.jpg                   Dizi Amazon Channel
# 38  /tGvAD4O9obFP3DfOrDn8NaRQ6eT.jpg           Acontra Plus Amazon Channel
# 39  /aJECXkHekrkuRZ7ABF5YR9DVDd8.jpg  Historia y Actualidad Amazon Channel
# 40  /6KEQzITx2RrCAQt5Nw9WrL1OI8z.jpg                               Sun Nxt
# 41  /kICQccvOh8AIBMHGkBXJ047xeHN.jpg                Netflix basic with Ads
# 42  /8VhN4PeHU7yfMNoWK0DnwdS1HlS.jpg                                Tivify
# 43  /oJRCAz1WKkKM9Ge7mX5KFnegTNY.jpg                               Runtime
# 44  /mXeC4TrcgdU6ltE9bCBCEORwSQR.jpg                           Crunchyroll
# 45  /2ino0WmHA4GROB7NYKzT6PGqLcb.jpg                   AMC+ Amazon Channel
# 46  /bSy9zFiZtbKBHIyOu0H2Fs5cJmx.jpg            Love Nature Amazon Channel
# 47  /3EFwJrJalr0YEgN1ENwrYbIar3Q.jpg                Hopster Amazon Channel
# 48  /7qZED0kLBtiV8mLRNBtW4PQCAqW.jpg                            Shahid VIP
# 49  /kx8rGgFYxX6aJkG7RHx2mtijglC.jpg                     Acorn TV Apple TV
# 50   /oTQdXIqM9iewlN4MC2nhKB0gHw.jpg            AMC Plus Apple TV Channel
# 51  /hwsU65QW7A4dbMEWkDpgHyCNcfS.jpg                                Kocowa
# 52  /efu1Cqc63XrPBoreYnf2mn0Nizj.jpg               MGM Plus Amazon Channel
# 53  /lDvzuBuNVgpcdzDpPmmufKvrZPb.jpg                                  3Cat
#
#     provider_id
# 0           337
# 1           350
# 2           119
# 3          2241
# 4            35
# 5           149
# 6           257
# 7          1773
# 8            63
# 9           223
# 10           62
# 11          393
# 12         1899
# 13           68
# 14          188
# 15          190
# 16          456
# 17          475
# 18          541
# 19          538
# 20          546
# 21          551
# 22          554
# 23          444
# 24          315
# 25          300
# 26          524
# 27          296
# 28            8
# 29          607
# 30          196
# 31          684
# 32          692
# 33          701
# 34         1717
# 35         1739
# 36         1740
# 37         1741
# 38         1742
# 39         1743
# 40          309
# 41         1796
# 42         1838
# 43         1875
# 44          283
# 45          528
# 46          608
# 47         1890
# 48         1715
# 49         2034
# 50         1854
# 51          464
# 52         2141
# 53         2237

# %%
serie_spain_providers_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   display_priorities  54 non-null     object
#  1   display_priority    54 non-null     int64
#  2   logo_path           54 non-null     object
#  3   provider_name       54 non-null     object
#  4   provider_id         54 non-null     int64
# dtypes: int64(2), object(3)
# memory usage: 2.2+ KB

# %%
#El ID de las plataformas es único
serie_spain_providers_data["provider_id"].nunique()
# Out:
# 54

# %%
#El nombre de las plataformas es único
serie_spain_providers_data["provider_name"].nunique()
# Out:
# 54

# %% [markdown]
# A continuación, vamos a obtener los identificadores correspondientes a los servicios de transimisión que nos interesan:

# %%
#Como no sabemos los nombres exactos para las plataformas, nos aproximamos buscándolos con la función 'contains'
serie_spain_providers_data[serie_spain_providers_data["provider_name"].str.contains("netflix|hbo|max|disney|amazon prime", case=False, regex=True)]
# Out:
#                                    display_priorities  display_priority  \
# 0   {'AD': 7, 'AL': 7, 'AR': 0, 'AT': 2, 'AU': 0, ...                27
# 2   {'AD': 1, 'AG': 1, 'AL': 1, 'AE': 9, 'AO': 1, ...                 1
# 12  {'AG': 12, 'AD': 27, 'BA': 29, 'AR': 61, 'BB':...                30
# 28  {'AE': 0, 'AD': 0, 'AG': 0, 'AL': 0, 'AO': 4, ...                 5
# 41  {'AU': 53, 'BR': 47, 'CA': 111, 'DE': 103, 'ES...               181
#
#                            logo_path           provider_name  provider_id
# 0    /97yvRBw1GzX7fXprcF80er19ot.jpg             Disney Plus          337
# 2   /dQeAar5H991VYporEjUspolDarG.jpg      Amazon Prime Video          119
# 12  /fksCUZ9QDWZMUwL2LgMtLckROUN.jpg                     Max         1899
# 28  /pbpMk2JmcoNnQwx5JGpXngfoWtp.jpg                 Netflix            8
# 41  /kICQccvOh8AIBMHGkBXJ047xeHN.jpg  Netflix basic with Ads         1796

# %% [markdown]
# De entre todos los servicios previos, vamos a quedarnos únicamente con los que nos interesan:
#
# - **Netflix** --> *provider_id = 8*
# - **Amazon Prime Video** --> *provider_id = 119*
# - **Disney Plus** --> *provider_id = 337*
# - **Max** (antes conocido como **HBO Max**) --> *provider_id = 1899*

# %%
serie_spain_providers_eda_df = serie_spain_providers_data[serie_spain_providers_data["provider_id"].isin([8, 119, 337, 1899])]
serie_spain_providers_eda_df
# Out:
#                                    display_priorities  display_priority  \
# 0   {'AD': 7, 'AL': 7, 'AR': 0, 'AT': 2, 'AU': 0, ...                27
# 2   {'AD': 1, 'AG': 1, 'AL': 1, 'AE': 9, 'AO': 1, ...                 1
# 12  {'AG': 12, 'AD': 27, 'BA': 29, 'AR': 61, 'BB':...                30
# 28  {'AE': 0, 'AD': 0, 'AG': 0, 'AL': 0, 'AO': 4, ...                 5
#
#                            logo_path       provider_name  provider_id
# 0    /97yvRBw1GzX7fXprcF80er19ot.jpg         Disney Plus          337
# 2   /dQeAar5H991VYporEjUspolDarG.jpg  Amazon Prime Video          119
# 12  /fksCUZ9QDWZMUwL2LgMtLckROUN.jpg                 Max         1899
# 28  /pbpMk2JmcoNnQwx5JGpXngfoWtp.jpg             Netflix            8

# %% [markdown]
# ## Películas:
# Para los identificadores a nivel **película**, accedemos al siguiente endpoint:
#
#
# ![API Plataformas para Películas](./images/endpoint-movie_providers.png)

# %%
#Petición a la bbdd para la obtención de las plataformas de streaming existentes para las películas en España
url_movies_spain_providers = "https://api.themoviedb.org/3/watch/providers/movie?watch_region=ES"
res_url_movies_spain_providers = requests.get(url_movies_spain_providers, headers=headers_user)
print(res_url_movies_spain_providers)
# Out:
# <Response [200]>

# %%
res_url_movies_spain_providers.json()
# Out:
# {'results': [{'display_priorities': {'AD': 7,
#     'AL': 7,
#     'AR': 0,
#     'AT': 2,
#     'AU': 0,
#     'BA': 7,
#     'BE': 0,
#     'BG': 16,
#     'BO': 2,
#     'BR': 0,
#     'BZ': 2,
#     'CA': 1,
#     'CH': 2,
#     'CL': 0,
#     'CO': 0,
#     'CR': 2,
#     'CZ': 0,
#     'DK': 0,
#     'DE': 2,
#     'DO': 24,
#     'EC': 1,
#     'EE': 23,
#     'ES': 0,
#     'FI': 0,
#     'EG': 45,
#     'FR': 0,
#     'GB': 1,
#     'GT': 1,
#     'GR': 20,
#     'HN': 2,
#     'HU': 0,
#     'HK': 32,
#     'HR': 31,
#     'IE': 2,
#     'IT': 0,
#     'IS': 1,
#     'JP': 2,
#     'JM': 26,
#     'KR': 2,
#     'LC': 13,
#     'LU': 3,
#     'LI': 25,
#     'LT': 24,
#     'LV': 23,
#     'ME': 1,
#     'MK': 7,
#     'MT': 7,
#     'MX': 0,
#     'NI': 2,
#     'NL': 1,
#     'NO': 0,
#     'NZ': 0,
#     'PE': 0,
#     'PA': 27,
#     'PL': 0,
#     'PT': 0,
#     'PH': 30,
#     'PY': 2,
#     'RO': 0,
#     'RS': 7,
#     'SG': 2,
#     'SI': 7,
#     'SE': 0,
#     'SK': 0,
#     'SV': 27,
#     'SM': 25,
#     'TR': 0,
#     'TT': 14,
#     'TW': 2,
#     'US': 0,
#     'VE': 1,
#     'UY': 27},
#    'display_priority': 27,
#    'logo_path': '/97yvRBw1GzX7fXprcF80er19ot.jpg',
#    'provider_name': 'Disney Plus',
#    'provider_id': 337},
#   {'display_priorities': {'AE': 2,
#     'AG': 11,
#     'AR': 5,
#     'AT': 5,
#     'AZ': 3,
#     'AU': 11,
#     'BE': 9,
#     'BG': 3,
#     'BO': 3,
#     'BH': 49,
#     'BM': 27,
#     'BR': 9,
#     'BY': 3,
#     'BZ': 4,
#     'BS': 25,
#     'CA': 7,
#     'CH': 18,
#     'CL': 5,
#     'CO': 5,
#     'CR': 3,
#     'CY': 4,
#     'CV': 10,
#     'CZ': 7,
#     'DE': 3,
#     'DK': 10,
#     'DO': 31,
#     'EC': 7,
#     'EE': 7,
#     'EG': 3,
#     'ES': 1,
#     'FI': 12,
#     'FJ': 11,
#     'FR': 3,
#     'GB': 3,
#     'GH': 13,
#     'GR': 5,
#     'GT': 3,
#     'HN': 3,
#     'HK': 16,
#     'HU': 7,
#     'IE': 5,
#     'IN': 2,
#     'ID': 12,
#     'IL': 25,
#     'IT': 5,
#     'JP': 10,
#     'JO': 50,
#     'KR': 5,
#     'LB': 28,
#     'LU': 5,
#     'LT': 7,
#     'LV': 7,
#     'MD': 25,
#     'MU': 12,
#     'MT': 25,
#     'MX': 3,
#     'MY': 11,
#     'MZ': 13,
#     'NI': 5,
#     'NL': 10,
#     'NO': 6,
#     'NZ': 5,
#     'PE': 6,
#     'PA': 25,
#     'OM': 49,
#     'PL': 3,
#     'PH': 11,
#     'PT': 11,
#     'PY': 4,
#     'RU': 3,
#     'SA': 2,
#     'QA': 49,
#     'SE': 5,
#     'SG': 11,
#     'SI': 24,
#     'SK': 5,
#     'SV': 31,
#     'TH': 10,
#     'TT': 11,
#     'TW': 15,
#     'UA': 1,
#     'UG': 13,
#     'US': 2,
#     'VE': 5,
#     'ZA': 9},
#    'display_priority': 9,
#    'logo_path': '/2E03IAZsX4ZaUqM7tXlctEPMGWS.jpg',
#    'provider_name': 'Apple TV Plus',
#    'provider_id': 350},
#   {'display_priorities': {'AD': 1,
#     'AG': 1,
#     'AL': 1,
#     'AE': 9,
#     'AO': 1,
#     'AR': 2,
#     'AU': 2,
#     'BA': 1,
#     'BB': 1,
#     'BE': 2,
#     'BF': 1,
#     'BG': 1,
#     'BH': 1,
#     'BM': 1,
#     'BO': 1,
#     'BR': 1,
#     'BS': 1,
#     'BY': 2,
#     'BZ': 3,
#     'CA': 2,
#     'CD': 0,
#     'CH': 1,
#     'CI': 1,
#     'CL': 2,
#     'CO': 1,
#     'CM': 1,
#     'CR': 1,
#     'CU': 1,
#     'CV': 1,
#     'CY': 3,
#     'CZ': 2,
#     'DK': 2,
#     'DO': 1,
#     'DZ': 1,
#     'EC': 2,
#     'EE': 1,
#     'EG': 1,
#     'ES': 2,
#     'FI': 2,
#     'FJ': 1,
#     'FR': 2,
#     'GF': 1,
#     'GG': 1,
#     'GH': 1,
#     'GI': 1,
#     'GQ': 1,
#     'GR': 1,
#     'GT': 2,
#     'GY': 0,
#     'HK': 5,
#     'HN': 1,
#     'HR': 1,
#     'HU': 2,
#     'IE': 1,
#     'ID': 7,
#     'IL': 1,
#     'IN': 1,
#     'IQ': 1,
#     'IT': 2,
#     'IS': 2,
#     'JM': 1,
#     'JO': 1,
#     'KE': 1,
#     'KR': 1,
#     'KW': 1,
#     'LB': 1,
#     'LC': 1,
#     'LI': 1,
#     'LT': 1,
#     'MA': 1,
#     'LV': 1,
#     'LY': 1,
#     'MC': 1,
#     'MD': 1,
#     'MG': 1,
#     'ML': 2,
#     'MK': 1,
#     'MT': 1,
#     'MW': 0,
#     'MX': 1,
#     'MZ': 1,
#     'NE': 1,
#     'MY': 9,
#     'NG': 1,
#     'NI': 4,
#     'NL': 2,
#     'NO': 2,
#     'NZ': 2,
#     'OM': 1,
#     'PA': 1,
#     'PE': 1,
#     'PG': 1,
#     'PK': 1,
#     'PF': 1,
#     'PL': 5,
#     'PH': 1,
#     'PS': 1,
#     'PT': 2,
#     'PY': 1,
#     'QA': 1,
#     'RO': 2,
#     'RS': 1,
#     'SC': 1,
#     'SA': 23,
#     'SI': 1,
#     'SG': 1,
#     'SE': 2,
#     'SN': 1,
#     'SV': 1,
#     'SK': 2,
#     'SM': 1,
#     'TC': 1,
#     'TH': 3,
#     'TD': 2,
#     'TN': 1,
#     'TR': 6,
#     'TT': 1,
#     'TW': 1,
#     'TZ': 1,
#     'UG': 1,
#     'VA': 0,
#     'UY': 1,
#     'VE': 2,
#     'YE': 1,
#     'ZA': 1,
#     'ZM': 1,
#     'ZW': 2},
#    'display_priority': 1,
#    'logo_path': '/dQeAar5H991VYporEjUspolDarG.jpg',
#    'provider_name': 'Amazon Prime Video',
#    'provider_id': 119},
#   {'display_priorities': {'ES': 3},
#    'display_priority': 3,
#    'logo_path': '/jse4MOi92Jgetym7nbXFZZBI6LK.jpg',
#    'provider_name': 'Movistar Plus+ €9.99',
#    'provider_id': 2241},
#   {'display_priorities': {'AL': 8,
#     'AT': 9,
#     'BA': 8,
#     'BE': 10,
#     'CH': 9,
#     'CY': 2,
#     'DE': 16,
#     'DK': 14,
#     'CZ': 34,
#     'ES': 4,
#     'FI': 14,
#     'FR': 21,
#     'GB': 5,
#     'GR': 24,
#     'HU': 27,
#     'IE': 12,
#     'IT': 3,
#     'LU': 2,
#     'ME': 0,
#     'MK': 8,
#     'MT': 8,
#     'NL': 15,
#     'NO': 14,
#     'PT': 8,
#     'PL': 37,
#     'RO': 23,
#     'RS': 8,
#     'SI': 8,
#     'SE': 15,
#     'SK': 39,
#     'UA': 4},
#    'display_priority': 4,
#    'logo_path': '/bZvc9dXrXNly7cA0V4D9pR8yJwm.jpg',
#    'provider_name': 'Rakuten TV',
#    'provider_id': 35},
#   {'display_priorities': {'ES': 5},
#    'display_priority': 5,
#    'logo_path': '/f6TRLB3H4jDpFEZ0z2KWSSvu1SB.jpg',
#    'provider_name': 'Movistar Plus+',
#    'provider_id': 149},
#   {'display_priorities': {'AE': 1,
#     'AR': 3,
#     'AT': 4,
#     'AU': 10,
#     'BE': 6,
#     'BG': 2,
#     'BO': 4,
#     'BR': 8,
#     'BY': 0,
#     'BZ': 0,
#     'CA': 6,
#     'CH': 4,
#     'CL': 3,
#     'CO': 4,
#     'CR': 5,
#     'CY': 0,
#     'CZ': 4,
#     'CV': 11,
#     'DE': 4,
#     'DK': 5,
#     'EC': 6,
#     'EE': 2,
#     'EG': 2,
#     'ES': 6,
#     'FI': 8,
#     'FR': 4,
#     'GB': 4,
#     'GH': 14,
#     'GR': 2,
#     'GT': 6,
#     'HK': 4,
#     'HN': 5,
#     'HU': 3,
#     'ID': 4,
#     'IE': 4,
#     'IN': 3,
#     'IL': 24,
#     'IT': 4,
#     'JP': 6,
#     'LU': 0,
#     'LT': 2,
#     'LV': 2,
#     'MU': 13,
#     'MX': 2,
#     'MY': 4,
#     'MZ': 14,
#     'NI': 0,
#     'NL': 9,
#     'NO': 5,
#     'NZ': 4,
#     'PE': 3,
#     'PL': 2,
#     'PH': 4,
#     'PT': 4,
#     'PY': 5,
#     'RU': 2,
#     'SA': 1,
#     'SG': 5,
#     'SE': 4,
#     'SI': 25,
#     'SK': 4,
#     'TH': 4,
#     'TR': 8,
#     'TW': 6,
#     'UA': 2,
#     'UG': 14,
#     'US': 3,
#     'VE': 4,
#     'ZA': 2},
#    'display_priority': 2,
#    'logo_path': '/9ghgSC0MA082EL6HLCW3GalykFD.jpg',
#    'provider_name': 'Apple TV',
#    'provider_id': 2},
#   {'display_priorities': {'CA': 97, 'ES': 7, 'US': 8},
#    'display_priority': 8,
#    'logo_path': '/9BgaNQRMDvVlji1JBZi6tcfxpKx.jpg',
#    'provider_name': 'fuboTV',
#    'provider_id': 257},
#   {'display_priorities': {'AD': 24,
#     'AL': 26,
#     'BA': 26,
#     'BG': 19,
#     'CZ': 26,
#     'DK': 36,
#     'ES': 8,
#     'FI': 37,
#     'HU': 24,
#     'HR': 33,
#     'MK': 25,
#     'NL': 11,
#     'NO': 7,
#     'PL': 7,
#     'PT': 32,
#     'RO': 20,
#     'RS': 27,
#     'SE': 7,
#     'SI': 27,
#     'SK': 35,
#     'XK': 3},
#    'display_priority': 3,
#    'logo_path': '/gQbqEYd0C9uprYxEUqTM589qn8g.jpg',
#    'provider_name': 'SkyShowtime',
#    'provider_id': 1773},
#   {'display_priorities': {'ES': 9, 'PT': 27},
#    'display_priority': 27,
#    'logo_path': '/kO2SWXvDCHAquaUuTJBuZkTBAuU.jpg',
#    'provider_name': 'Filmin',
#    'provider_id': 63},
#   {'display_priorities': {'ES': 10, 'PT': 28},
#    'display_priority': 28,
#    'logo_path': '/ozZU2vSlyL11rFGEkq1HE0yxIJq.jpg',
#    'provider_name': 'Filmin Plus',
#    'provider_id': 64},
#   {'display_priorities': {'ES': 13},
#    'display_priority': 13,
#    'logo_path': '/oN6g8QorcoYo3mx4BulU22ghKq4.jpg',
#    'provider_name': 'Atres Player',
#    'provider_id': 62},
#   {'display_priorities': {'AE': 3,
#     'AO': 0,
#     'AR': 4,
#     'AZ': 1,
#     'AT': 7,
#     'AU': 13,
#     'BF': 0,
#     'BE': 7,
#     'BO': 20,
#     'BY': 1,
#     'BR': 15,
#     'BZ': 1,
#     'CA': 8,
#     'CH': 5,
#     'CL': 4,
#     'CO': 3,
#     'CR': 21,
#     'CY': 1,
#     'CZ': 5,
#     'DK': 6,
#     'DE': 11,
#     'EC': 9,
#     'EE': 3,
#     'EG': 4,
#     'ES': 14,
#     'FI': 9,
#     'FR': 8,
#     'GB': 15,
#     'GR': 3,
#     'GT': 21,
#     'HK': 11,
#     'HR': 3,
#     'HU': 4,
#     'HN': 20,
#     'ID': 6,
#     'IE': 7,
#     'IN': 9,
#     'IS': 4,
#     'IT': 7,
#     'JP': 8,
#     'KR': 7,
#     'LU': 1,
#     'LT': 3,
#     'LV': 3,
#     'ML': 1,
#     'MY': 5,
#     'MX': 14,
#     'NI': 1,
#     'NL': 13,
#     'NZ': 6,
#     'NO': 8,
#     'PE': 4,
#     'PG': 0,
#     'PL': 4,
#     'PH': 5,
#     'PT': 5,
#     'PY': 20,
#     'RU': 4,
#     'SA': 3,
#     'SG': 6,
#     'SE': 9,
#     'SK': 6,
#     'TH': 5,
#     'TR': 7,
#     'TW': 3,
#     'UA': 3,
#     'TZ': 18,
#     'US': 16,
#     'VE': 3,
#     'ZA': 3,
#     'ZW': 1},
#    'display_priority': 1,
#    'logo_path': '/8z7rC8uIDaTM91X0ZfkRf04ydj2.jpg',
#    'provider_name': 'Google Play Movies',
#    'provider_id': 3},
#   {'display_priorities': {'AD': 2,
#     'AL': 2,
#     'BA': 2,
#     'BB': 2,
#     'BH': 2,
#     'BM': 2,
#     'BS': 2,
#     'CI': 2,
#     'DO': 2,
#     'DZ': 2,
#     'EG': 5,
#     'ES': 15,
#     'GF': 2,
#     'GI': 2,
#     'HR': 4,
#     'IL': 2,
#     'IQ': 2,
#     'IS': 5,
#     'JM': 2,
#     'JO': 2,
#     'KW': 2,
#     'LB': 2,
#     'LI': 2,
#     'MA': 2,
#     'LY': 2,
#     'MC': 2,
#     'MD': 2,
#     'MK': 2,
#     'MT': 2,
#     'NE': 2,
#     'NG': 2,
#     'OM': 2,
#     'PA': 2,
#     'PS': 2,
#     'QA': 2,
#     'RS': 2,
#     'SA': 4,
#     'SI': 2,
#     'SV': 2,
#     'SM': 2,
#     'SK': 7,
#     'TN': 2,
#     'TW': 10,
#     'TZ': 19,
#     'UY': 4,
#     'YE': 2},
#    'display_priority': 2,
#    'logo_path': '/ozMgkAAoi6aDI5ce8KKA2k8TGvB.jpg',
#    'provider_name': 'FlixOlé',
#    'provider_id': 393},
#   {'display_priorities': {'AG': 12,
#     'AD': 27,
#     'BA': 29,
#     'AR': 61,
#     'BB': 25,
#     'BG': 22,
#     'BO': 32,
#     'BR': 7,
#     'BZ': 10,
#     'BS': 26,
#     'CL': 7,
#     'CO': 6,
#     'CR': 4,
#     'CZ': 36,
#     'DO': 32,
#     'DK': 43,
#     'EC': 5,
#     'FI': 45,
#     'ES': 16,
#     'FR': 116,
#     'GT': 4,
#     'GY': 4,
#     'HN': 32,
#     'HU': 29,
#     'HR': 36,
#     'JM': 24,
#     'LC': 11,
#     'MC': 27,
#     'ME': 7,
#     'MD': 27,
#     'MK': 28,
#     'MX': 5,
#     'NI': 14,
#     'NO': 44,
#     'PE': 7,
#     'NL': 89,
#     'PA': 32,
#     'PL': 40,
#     'PY': 31,
#     'RO': 25,
#     'PT': 62,
#     'RS': 30,
#     'SI': 30,
#     'SE': 48,
#     'SV': 32,
#     'TC': 11,
#     'SK': 40,
#     'TT': 12,
#     'US': 9,
#     'UY': 3,
#     'VE': 30,
#     'BE': 67},
#    'display_priority': 30,
#    'logo_path': '/fksCUZ9QDWZMUwL2LgMtLckROUN.jpg',
#    'provider_name': 'Max',
#    'provider_id': 1899},
#   {'display_priorities': {'AT': 12,
#     'AU': 17,
#     'BR': 16,
#     'CH': 6,
#     'CA': 23,
#     'DK': 8,
#     'DE': 32,
#     'ES': 17,
#     'FI': 10,
#     'FR': 15,
#     'GB': 18,
#     'IE': 14,
#     'IT': 22,
#     'JP': 7,
#     'MX': 13,
#     'NL': 14,
#     'NO': 9,
#     'NZ': 9,
#     'SE': 8,
#     'US': 45},
#    'display_priority': 45,
#    'logo_path': '/5vfrJQgNe9UnHVgVNAwZTy0Jo9o.jpg',
#    'provider_name': 'Microsoft Store',
#    'provider_id': 68},
#   {'display_priorities': {'AE': 4,
#     'AG': 4,
#     'AD': 5,
#     'AL': 5,
#     'AO': 2,
#     'AR': 10,
#     'AT': 18,
#     'AU': 23,
#     'BA': 5,
#     'BB': 4,
#     'BF': 2,
#     'BE': 11,
#     'BG': 4,
#     'BH': 4,
#     'BM': 4,
#     'BO': 22,
#     'BS': 4,
#     'BR': 12,
#     'BY': 4,
#     'BZ': 5,
#     'CD': 1,
#     'CH': 17,
#     'CI': 5,
#     'CA': 38,
#     'CL': 10,
#     'CM': 2,
#     'CO': 10,
#     'CR': 23,
#     'CU': 4,
#     'CY': 5,
#     'CV': 4,
#     'CZ': 6,
#     'DO': 4,
#     'DK': 9,
#     'DE': 27,
#     'DZ': 4,
#     'EC': 10,
#     'EE': 4,
#     'EG': 6,
#     'ES': 18,
#     'FI': 11,
#     'FJ': 4,
#     'FR': 22,
#     'GB': 14,
#     'GF': 4,
#     'GG': 4,
#     'GH': 4,
#     'GI': 4,
#     'GQ': 4,
#     'GR': 4,
#     'GY': 1,
#     'GT': 23,
#     'HR': 5,
#     'HK': 18,
#     'HU': 5,
#     'HN': 22,
#     'ID': 9,
#     'IL': 5,
#     'IE': 15,
#     'IN': 10,
#     'IQ': 5,
#     'IS': 6,
#     'IT': 13,
#     'JM': 4,
#     'JO': 4,
#     'JP': 9,
#     'KE': 4,
#     'KR': 8,
#     'KW': 4,
#     'LB': 5,
#     'LC': 4,
#     'LI': 4,
#     'LT': 4,
#     'LU': 6,
#     'MA': 4,
#     'LV': 4,
#     'LY': 4,
#     'MC': 4,
#     'ME': 2,
#     'MD': 4,
#     'MG': 2,
#     'ML': 3,
#     'MK': 5,
#     'MT': 5,
#     'MU': 3,
#     'MW': 1,
#     'MZ': 4,
#     'MY': 7,
#     'MX': 15,
#     'NE': 5,
#     'NG': 5,
#     'NI': 6,
#     'NL': 17,
#     'NO': 10,
#     'NZ': 10,
#     'OM': 4,
#     'PA': 4,
#     'PE': 10,
#     'PG': 2,
#     'PK': 4,
#     'PF': 4,
#     'PL': 6,
#     'PH': 8,
#     'PS': 5,
#     'PT': 10,
#     'QA': 4,
#     'RO': 3,
#     'PY': 22,
#     'RS': 5,
#     'RU': 5,
#     'SA': 5,
#     'SC': 4,
#     'SI': 5,
#     'SG': 8,
#     'SE': 10,
#     'SN': 4,
#     'SV': 4,
#     'SM': 4,
#     'SK': 8,
#     'TC': 4,
#     'TD': 3,
#     'TH': 7,
#     'TN': 4,
#     'TR': 9,
#     'TT': 4,
#     'TZ': 4,
#     'TW': 17,
#     'UA': 5,
#     'UG': 4,
#     'VA': 3,
#     'UY': 6,
#     'VE': 7,
#     'YE': 4,
#     'ZA': 6,
#     'US': 64,
#     'ZM': 4,
#     'ZW': 3},
#    'display_priority': 64,
#    'logo_path': '/fj9Y8iIMFUC6952HwxbGixTQPb7.jpg',
#    'provider_name': 'MUBI',
#    'provider_id': 11},
#   {'display_priorities': {'AT': 19,
#     'AU': 26,
#     'BG': 10,
#     'BO': 11,
#     'CH': 11,
#     'CA': 40,
#     'CR': 9,
#     'DK': 11,
#     'DE': 31,
#     'EE': 5,
#     'ES': 19,
#     'FI': 13,
#     'GB': 28,
#     'GT': 9,
#     'HN': 8,
#     'HR': 7,
#     'HK': 26,
#     'ID': 8,
#     'IE': 16,
#     'IN': 13,
#     'IT': 20,
#     'KR': 9,
#     'LT': 5,
#     'LV': 5,
#     'MY': 6,
#     'MX': 17,
#     'NL': 18,
#     'NO': 11,
#     'NZ': 13,
#     'PH': 7,
#     'PL': 12,
#     'PY': 8,
#     'RU': 6,
#     'SG': 7,
#     'SE': 11,
#     'SK': 10,
#     'TH': 6,
#     'TZ': 13,
#     'TW': 25,
#     'ZA': 7,
#     'US': 62},
#    'display_priority': 62,
#    'logo_path': '/eKVmLFHW5PeNhuR7Nedd8OIxW2M.jpg',
#    'provider_name': 'GuideDoc',
#    'provider_id': 100},
#   {'display_priorities': {'AT': 13,
#     'AU': 14,
#     'BE': 8,
#     'CH': 20,
#     'CA': 39,
#     'DK': 13,
#     'DE': 20,
#     'FI': 7,
#     'ES': 20,
#     'FR': 17,
#     'GB': 31,
#     'HU': 6,
#     'HK': 28,
#     'IE': 20,
#     'IT': 21,
#     'MX': 10,
#     'NZ': 7,
#     'NO': 13,
#     'PT': 6,
#     'RU': 8,
#     'SE': 14,
#     'TR': 2,
#     'TW': 27,
#     'US': 33},
#    'display_priority': 33,
#    'logo_path': '/rMb93u1tBeErSYLv79zSTR07UdO.jpg',
#    'provider_name': 'YouTube Premium',
#    'provider_id': 188},
#   {'display_priorities': {'AD': 8,
#     'AL': 9,
#     'AR': 11,
#     'AT': 24,
#     'AU': 36,
#     'BA': 9,
#     'BB': 6,
#     'BE': 14,
#     'BG': 5,
#     'BH': 6,
#     'BM': 6,
#     'BO': 13,
#     'BS': 6,
#     'BR': 18,
#     'CI': 7,
#     'CH': 23,
#     'CA': 53,
#     'CL': 11,
#     'CO': 11,
#     'CR': 7,
#     'CZ': 8,
#     'DO': 6,
#     'DK': 18,
#     'DZ': 6,
#     'DE': 43,
#     'EC': 11,
#     'EE': 9,
#     'EG': 10,
#     'ES': 21,
#     'FI': 17,
#     'FR': 26,
#     'GF': 6,
#     'GB': 40,
#     'GI': 6,
#     'GR': 6,
#     'GT': 7,
#     'HK': 13,
#     'HN': 4,
#     'HR': 9,
#     'HU': 8,
#     'IL': 7,
#     'ID': 17,
#     'IE': 21,
#     'IN': 21,
#     'IQ': 7,
#     'IS': 9,
#     'IT': 26,
#     'JM': 6,
#     'JO': 6,
#     'JP': 11,
#     'KR': 12,
#     'KW': 6,
#     'LB': 7,
#     'LI': 6,
#     'LT': 9,
#     'MA': 6,
#     'LV': 9,
#     'LY': 6,
#     'MC': 6,
#     'MD': 6,
#     'MK': 9,
#     'MT': 9,
#     'MX': 20,
#     'NE': 7,
#     'MY': 15,
#     'NG': 7,
#     'NL': 22,
#     'NO': 19,
#     'NZ': 20,
#     'OM': 6,
#     'PA': 6,
#     'PE': 11,
#     'PL': 9,
#     'PH': 13,
#     'PS': 7,
#     'PT': 14,
#     'PY': 6,
#     'QA': 6,
#     'RO': 4,
#     'RS': 9,
#     'RU': 9,
#     'SA': 8,
#     'SI': 9,
#     'SG': 14,
#     'SE': 19,
#     'SV': 6,
#     'SM': 6,
#     'SK': 12,
#     'TH': 13,
#     'TN': 6,
#     'TR': 10,
#     'TW': 12,
#     'TZ': 20,
#     'UY': 8,
#     'VE': 8,
#     'YE': 6,
#     'US': 51,
#     'ZA': 11},
#    'display_priority': 51,
#    'logo_path': '/oR1aNm1Qu9jQBkW4VrGPWhqbC3P.jpg',
#    'provider_name': 'Curiosity Stream',
#    'provider_id': 190},
#   {'display_priorities': {'ES': 22},
#    'display_priority': 22,
#    'logo_path': '/273VHxSrDdEwLTXJrsnE6yJMqNZ.jpg',
#    'provider_name': 'Mitele ',
#    'provider_id': 456},
#   {'display_priorities': {'AR': 18,
#     'AT': 26,
#     'AU': 35,
#     'BE': 17,
#     'BG': 7,
#     'BH': 9,
#     'BM': 9,
#     'BO': 8,
#     'BS': 9,
#     'BR': 22,
#     'CH': 24,
#     'CA': 55,
#     'CL': 14,
#     'CO': 15,
#     'CR': 12,
#     'CZ': 10,
#     'DO': 9,
#     'DK': 19,
#     'DZ': 9,
#     'DE': 44,
#     'EC': 14,
#     'EE': 11,
#     'ES': 23,
#     'FI': 19,
#     'FR': 28,
#     'GF': 9,
#     'GB': 44,
#     'GI': 9,
#     'GR': 8,
#     'GT': 12,
#     'HN': 11,
#     'HR': 12,
#     'HU': 10,
#     'ID': 18,
#     'IE': 23,
#     'IN': 24,
#     'IS': 12,
#     'IT': 27,
#     'JO': 9,
#     'JP': 13,
#     'KR': 14,
#     'KW': 9,
#     'LI': 9,
#     'LT': 11,
#     'MA': 9,
#     'LV': 11,
#     'LY': 9,
#     'MC': 9,
#     'MD': 9,
#     'MX': 27,
#     'MY': 16,
#     'NL': 24,
#     'NO': 20,
#     'NZ': 21,
#     'OM': 9,
#     'PA': 9,
#     'PE': 15,
#     'PL': 10,
#     'PH': 15,
#     'PT': 16,
#     'PY': 11,
#     'RO': 6,
#     'QA': 9,
#     'RU': 11,
#     'SG': 16,
#     'SE': 21,
#     'SV': 9,
#     'SM': 9,
#     'SK': 15,
#     'TH': 14,
#     'TN': 9,
#     'TR': 13,
#     'TW': 28,
#     'TZ': 22,
#     'UY': 12,
#     'VE': 12,
#     'YE': 9,
#     'ZA': 13,
#     'US': 132},
#    'display_priority': 132,
#    'logo_path': '/5zqbck5mo8PuVbGu2ngBUdn5Yga.jpg',
#    'provider_name': 'DOCSVILLE',
#    'provider_id': 475},
#   {'display_priorities': {'AD': 9,
#     'AL': 10,
#     'AR': 13,
#     'AT': 27,
#     'AU': 37,
#     'BA': 10,
#     'BB': 8,
#     'BE': 15,
#     'BH': 8,
#     'BM': 8,
#     'BO': 15,
#     'BS': 8,
#     'BR': 20,
#     'CI': 9,
#     'CH': 26,
#     'CA': 61,
#     'CL': 15,
#     'CO': 16,
#     'CR': 16,
#     'CZ': 9,
#     'DO': 8,
#     'DK': 20,
#     'DZ': 8,
#     'DE': 50,
#     'EC': 15,
#     'EE': 10,
#     'EG': 12,
#     'ES': 24,
#     'FI': 20,
#     'FR': 27,
#     'GF': 8,
#     'GB': 46,
#     'GI': 8,
#     'GR': 7,
#     'GT': 16,
#     'HR': 11,
#     'HN': 15,
#     'HU': 9,
#     'HK': 27,
#     'ID': 13,
#     'IL': 8,
#     'IE': 22,
#     'IN': 29,
#     'IQ': 8,
#     'IS': 11,
#     'IT': 28,
#     'JM': 8,
#     'JO': 8,
#     'JP': 12,
#     'KR': 13,
#     'KW': 8,
#     'LB': 8,
#     'LI': 8,
#     'LT': 10,
#     'MA': 8,
#     'LV': 10,
#     'LY': 8,
#     'MC': 8,
#     'MD': 8,
#     'MK': 10,
#     'MT': 10,
#     'MY': 13,
#     'NE': 9,
#     'MX': 28,
#     'NG': 9,
#     'NL': 26,
#     'NZ': 16,
#     'NO': 21,
#     'OM': 8,
#     'PA': 8,
#     'PE': 16,
#     'PL': 13,
#     'PH': 14,
#     'PS': 8,
#     'PT': 17,
#     'PY': 15,
#     'RO': 5,
#     'QA': 8,
#     'RU': 10,
#     'RS': 10,
#     'SA': 10,
#     'SI': 10,
#     'SG': 15,
#     'SE': 25,
#     'SV': 8,
#     'SM': 8,
#     'SK': 14,
#     'TH': 11,
#     'TN': 8,
#     'TR': 12,
#     'TW': 26,
#     'TZ': 24,
#     'UY': 11,
#     'VE': 10,
#     'YE': 8,
#     'ZA': 12,
#     'US': 80},
#    'display_priority': 80,
#    'logo_path': '/k2YgZyxij5RcnS1qqUYEUrJB4oQ.jpg',
#    'provider_name': 'Spamflix',
#    'provider_id': 521},
#   {'display_priorities': {'ES': 25},
#    'display_priority': 25,
#    'logo_path': '/3QQKYFUDt13Q2Zm6JM2cOjlbd27.jpg',
#    'provider_name': 'rtve',
#    'provider_id': 541},
#   {'display_priorities': {'AG': 13,
#     'AD': 26,
#     'AO': 5,
#     'AL': 28,
#     'AZ': 5,
#     'AU': 47,
#     'BA': 28,
#     'AR': 62,
#     'AT': 64,
#     'BF': 5,
#     'BB': 26,
#     'BG': 21,
#     'BE': 64,
#     'BM': 28,
#     'BO': 33,
#     'BY': 8,
#     'BZ': 11,
#     'BS': 27,
#     'CI': 27,
#     'BR': 85,
#     'CH': 50,
#     'CA': 87,
#     'CM': 5,
#     'CL': 34,
#     'CO': 35,
#     'CR': 33,
#     'CY': 9,
#     'CV': 13,
#     'CZ': 33,
#     'DO': 33,
#     'DK': 41,
#     'DE': 55,
#     'DZ': 29,
#     'EC': 33,
#     'EE': 27,
#     'ES': 26,
#     'FI': 43,
#     'FJ': 13,
#     'FR': 30,
#     'GB': 48,
#     'GF': 29,
#     'GG': 11,
#     'GH': 16,
#     'GI': 27,
#     'GQ': 14,
#     'GR': 23,
#     'GY': 5,
#     'GT': 33,
#     'HK': 39,
#     'HN': 33,
#     'HU': 26,
#     'HR': 35,
#     'IL': 27,
#     'IN': 31,
#     'ID': 40,
#     'IE': 44,
#     'IT': 29,
#     'IS': 32,
#     'IQ': 49,
#     'JM': 25,
#     'KE': 15,
#     'JP': 53,
#     'JO': 51,
#     'KR': 15,
#     'LC': 12,
#     'LB': 29,
#     'KW': 50,
#     'LI': 29,
#     'LU': 11,
#     'LT': 28,
#     'LV': 27,
#     'MA': 28,
#     'LY': 29,
#     'MC': 26,
#     'ME': 6,
#     'MG': 5,
#     'ML': 6,
#     'MD': 26,
#     'MW': 3,
#     'MK': 27,
#     'MU': 15,
#     'MT': 26,
#     'MZ': 17,
#     'MY': 32,
#     'NE': 27,
#     'NG': 30,
#     'NI': 15,
#     'MX': 78,
#     'NZ': 37,
#     'NO': 42,
#     'NL': 86,
#     'PA': 33,
#     'PG': 6,
#     'PE': 34,
#     'OM': 50,
#     'PK': 8,
#     'PF': 12,
#     'PL': 34,
#     'PH': 33,
#     'PS': 28,
#     'PY': 32,
#     'RO': 22,
#     'PT': 60,
#     'RS': 29,
#     'RU': 30,
#     'SC': 14,
#     'SI': 29,
#     'SG': 31,
#     'SN': 14,
#     'SE': 47,
#     'SV': 33,
#     'TC': 12,
#     'SM': 28,
#     'SK': 38,
#     'TD': 7,
#     'TH': 30,
#     'TT': 13,
#     'TN': 29,
#     'UA': 8,
#     'TW': 39,
#     'TZ': 32,
#     'UG': 16,
#     'XK': 5,
#     'VA': 7,
#     'UY': 32,
#     'VE': 31,
#     'YE': 28,
#     'ZW': 6,
#     'ZM': 14,
#     'ZA': 30,
#     'US': 140},
#    'display_priority': 140,
#    'logo_path': '/vLZKlXUNDcZR7ilvfY9Wr9k80FZ.jpg',
#    'provider_name': 'Plex',
#    'provider_id': 538},
#   {'display_priorities': {'AD': 14,
#     'AL': 15,
#     'AR': 20,
#     'AT': 31,
#     'AU': 38,
#     'BA': 15,
#     'BE': 20,
#     'BM': 11,
#     'BO': 6,
#     'BR': 28,
#     'CI': 11,
#     'CH': 28,
#     'CA': 63,
#     'CL': 16,
#     'CO': 17,
#     'CR': 14,
#     'CZ': 11,
#     'DK': 21,
#     'DE': 56,
#     'EC': 16,
#     'EE': 12,
#     'ES': 27,
#     'FI': 23,
#     'FR': 31,
#     'GF': 11,
#     'GB': 49,
#     'GI': 11,
#     'GR': 9,
#     'GT': 14,
#     'HN': 13,
#     'HU': 11,
#     'ID': 21,
#     'IL': 13,
#     'IE': 24,
#     'IN': 32,
#     'IQ': 15,
#     'IS': 13,
#     'IT': 30,
#     'JP': 14,
#     'KR': 16,
#     'KW': 11,
#     'LB': 15,
#     'LI': 11,
#     'LT': 12,
#     'LV': 12,
#     'MK': 14,
#     'MT': 14,
#     'MY': 17,
#     'MX': 30,
#     'NE': 11,
#     'NG': 12,
#     'NL': 27,
#     'NO': 22,
#     'NZ': 22,
#     'PE': 17,
#     'PL': 14,
#     'PH': 17,
#     'PS': 15,
#     'PT': 18,
#     'PY': 13,
#     'RO': 7,
#     'RU': 12,
#     'RS': 15,
#     'SI': 15,
#     'SG': 17,
#     'SE': 26,
#     'SM': 11,
#     'TH': 15,
#     'TN': 11,
#     'TR': 14,
#     'VE': 13,
#     'YE': 11,
#     'ZA': 14,
#     'US': 142},
#    'display_priority': 142,
#    'logo_path': '/6dET59jNU0ADysghEjl8Unuc7Ca.jpg',
#    'provider_name': 'WOW Presents Plus',
#    'provider_id': 546},
#   {'display_priorities': {'AD': 12,
#     'AL': 13,
#     'AR': 19,
#     'AT': 32,
#     'AU': 39,
#     'BA': 13,
#     'BB': 10,
#     'BE': 21,
#     'BH': 11,
#     'BM': 12,
#     'BO': 14,
#     'BS': 11,
#     'BR': 29,
#     'CH': 29,
#     'CA': 65,
#     'CL': 17,
#     'CO': 18,
#     'CR': 15,
#     'CZ': 12,
#     'DO': 11,
#     'DK': 22,
#     'DZ': 11,
#     'DE': 58,
#     'EC': 17,
#     'EE': 13,
#     'EG': 14,
#     'ES': 28,
#     'FI': 24,
#     'FR': 33,
#     'GF': 12,
#     'GB': 50,
#     'GI': 12,
#     'GR': 10,
#     'GT': 15,
#     'HK': 20,
#     'HN': 14,
#     'HR': 14,
#     'HU': 12,
#     'IL': 11,
#     'ID': 22,
#     'IE': 25,
#     'IN': 33,
#     'IQ': 13,
#     'IS': 15,
#     'IT': 31,
#     'JM': 10,
#     'JO': 11,
#     'JP': 15,
#     'KR': 17,
#     'KW': 12,
#     'LB': 13,
#     'LI': 12,
#     'LT': 13,
#     'MA': 11,
#     'LV': 13,
#     'LY': 11,
#     'MC': 11,
#     'MD': 11,
#     'MK': 12,
#     'MT': 12,
#     'MY': 18,
#     'MX': 29,
#     'NG': 10,
#     'NL': 29,
#     'NO': 23,
#     'NZ': 23,
#     'OM': 11,
#     'PA': 12,
#     'PE': 18,
#     'PL': 16,
#     'PH': 18,
#     'PS': 13,
#     'PT': 19,
#     'PY': 14,
#     'RO': 8,
#     'QA': 11,
#     'RU': 13,
#     'RS': 13,
#     'SA': 12,
#     'SI': 13,
#     'SG': 18,
#     'SE': 27,
#     'SV': 12,
#     'SM': 12,
#     'SK': 17,
#     'TH': 16,
#     'TN': 12,
#     'TR': 15,
#     'TW': 19,
#     'TZ': 26,
#     'UY': 15,
#     'VE': 14,
#     'YE': 12,
#     'ZA': 15,
#     'US': 143},
#    'display_priority': 143,
#    'logo_path': '/mSH24WQcRDJ2fsL5iucXqqRnSRb.jpg',
#    'provider_name': 'Magellan TV',
#    'provider_id': 551},
#   {'display_priorities': {'AD': 13,
#     'AL': 14,
#     'AR': 21,
#     'AT': 33,
#     'AU': 40,
#     'BA': 14,
#     'BB': 11,
#     'BE': 22,
#     'BG': 6,
#     'BH': 12,
#     'BO': 7,
#     'BM': 13,
#     'BS': 12,
#     'BR': 30,
#     'CI': 10,
#     'CH': 30,
#     'CA': 66,
#     'CL': 19,
#     'CO': 19,
#     'CR': 13,
#     'CZ': 13,
#     'DO': 12,
#     'DK': 23,
#     'DZ': 12,
#     'DE': 59,
#     'EC': 18,
#     'EE': 14,
#     'EG': 15,
#     'ES': 29,
#     'FI': 25,
#     'FR': 34,
#     'GF': 13,
#     'GB': 51,
#     'GI': 13,
#     'GR': 11,
#     'GT': 13,
#     'HN': 12,
#     'HK': 24,
#     'HR': 15,
#     'HU': 13,
#     'IL': 12,
#     'ID': 23,
#     'IE': 27,
#     'IN': 34,
#     'IQ': 14,
#     'IS': 16,
#     'IT': 32,
#     'JM': 11,
#     'JO': 12,
#     'JP': 16,
#     'KR': 18,
#     'KW': 13,
#     'LB': 14,
#     'LI': 13,
#     'LT': 15,
#     'MA': 12,
#     'LV': 14,
#     'LY': 12,
#     'MC': 12,
#     'MD': 12,
#     'MK': 13,
#     'MT': 13,
#     'NE': 10,
#     'MY': 19,
#     'MX': 31,
#     'NG': 11,
#     'NL': 30,
#     'NO': 24,
#     'NZ': 24,
#     'OM': 12,
#     'PA': 13,
#     'PE': 19,
#     'PL': 17,
#     'PH': 19,
#     'PS': 14,
#     'PT': 20,
#     'PY': 12,
#     'RO': 9,
#     'QA': 12,
#     'RU': 14,
#     'RS': 14,
#     'SA': 13,
#     'SI': 14,
#     'SG': 19,
#     'SE': 28,
#     'SV': 13,
#     'SM': 13,
#     'SK': 18,
#     'TH': 17,
#     'TN': 13,
#     'TR': 16,
#     'TW': 23,
#     'TZ': 27,
#     'UY': 16,
#     'VE': 15,
#     'YE': 13,
#     'ZA': 16,
#     'US': 144},
#    'display_priority': 144,
#    'logo_path': '/6IYZ4NjwPikxN7J9cfSmuyeHeMm.jpg',
#    'provider_name': 'BroadwayHD',
#    'provider_id': 554},
#   {'display_priorities': {'AD': 16,
#     'AL': 17,
#     'AR': 22,
#     'AT': 34,
#     'AU': 41,
#     'BA': 17,
#     'BB': 13,
#     'BE': 23,
#     'BH': 14,
#     'BM': 15,
#     'BO': 16,
#     'BS': 14,
#     'BR': 31,
#     'CI': 13,
#     'CH': 31,
#     'CA': 67,
#     'CL': 18,
#     'CO': 20,
#     'CR': 17,
#     'CZ': 14,
#     'DO': 14,
#     'DK': 24,
#     'DZ': 14,
#     'DE': 60,
#     'EC': 19,
#     'EE': 15,
#     'EG': 17,
#     'ES': 30,
#     'FI': 26,
#     'FR': 35,
#     'GF': 15,
#     'GB': 52,
#     'GI': 15,
#     'GR': 12,
#     'GT': 17,
#     'HK': 19,
#     'HN': 16,
#     'HR': 18,
#     'HU': 14,
#     'ID': 24,
#     'IL': 15,
#     'IE': 28,
#     'IN': 35,
#     'IQ': 17,
#     'IS': 19,
#     'IT': 33,
#     'JM': 13,
#     'JP': 17,
#     'JO': 14,
#     'KR': 19,
#     'KW': 15,
#     'LB': 17,
#     'LI': 15,
#     'LT': 16,
#     'MA': 14,
#     'LV': 15,
#     'LY': 14,
#     'MC': 14,
#     'MD': 14,
#     'MK': 16,
#     'MT': 16,
#     'MY': 20,
#     'MX': 32,
#     'NE': 13,
#     'NG': 14,
#     'NL': 31,
#     'NO': 25,
#     'NZ': 25,
#     'OM': 14,
#     'PA': 15,
#     'PE': 20,
#     'PL': 18,
#     'PH': 20,
#     'PS': 17,
#     'PT': 21,
#     'PY': 16,
#     'RO': 10,
#     'QA': 14,
#     'SA': 15,
#     'RS': 17,
#     'SI': 17,
#     'SG': 20,
#     'SE': 29,
#     'SV': 15,
#     'SM': 15,
#     'SK': 21,
#     'TH': 18,
#     'TN': 15,
#     'TR': 17,
#     'TW': 18,
#     'TZ': 25,
#     'UY': 18,
#     'VE': 16,
#     'YE': 15,
#     'ZA': 17,
#     'US': 146},
#    'display_priority': 146,
#    'logo_path': '/eUBxtrqO26wAJfYOZJOzhQEo3mm.jpg',
#    'provider_name': 'Filmzie',
#    'provider_id': 559},
#   {'display_priorities': {'AD': 15,
#     'AL': 16,
#     'AR': 23,
#     'AT': 35,
#     'AU': 42,
#     'BA': 16,
#     'BB': 12,
#     'BE': 24,
#     'BG': 8,
#     'BH': 13,
#     'BO': 9,
#     'BM': 14,
#     'BS': 13,
#     'BR': 33,
#     'CI': 12,
#     'CH': 32,
#     'CA': 68,
#     'CL': 20,
#     'CO': 21,
#     'CR': 11,
#     'CZ': 15,
#     'DO': 13,
#     'DK': 25,
#     'DZ': 13,
#     'DE': 62,
#     'EC': 20,
#     'EE': 16,
#     'ES': 31,
#     'FI': 27,
#     'FR': 36,
#     'GF': 14,
#     'GB': 56,
#     'GI': 14,
#     'GR': 13,
#     'GT': 11,
#     'HN': 10,
#     'HK': 21,
#     'HR': 16,
#     'HU': 15,
#     'IL': 14,
#     'ID': 25,
#     'IE': 29,
#     'IN': 38,
#     'IQ': 16,
#     'IS': 17,
#     'IT': 34,
#     'JM': 12,
#     'JO': 13,
#     'JP': 18,
#     'KR': 20,
#     'KW': 14,
#     'LB': 16,
#     'LI': 14,
#     'LT': 17,
#     'MA': 13,
#     'LV': 16,
#     'LY': 13,
#     'MC': 13,
#     'MD': 13,
#     'MK': 15,
#     'MT': 15,
#     'NE': 12,
#     'MY': 21,
#     'MX': 33,
#     'NG': 13,
#     'NL': 33,
#     'NZ': 26,
#     'NO': 27,
#     'OM': 13,
#     'PA': 14,
#     'PE': 21,
#     'PL': 19,
#     'PH': 21,
#     'PS': 16,
#     'PT': 22,
#     'PY': 10,
#     'RO': 11,
#     'QA': 13,
#     'RS': 16,
#     'RU': 16,
#     'SI': 16,
#     'SG': 21,
#     'SE': 30,
#     'SV': 14,
#     'SM': 14,
#     'SK': 19,
#     'TH': 19,
#     'TN': 14,
#     'TR': 18,
#     'TW': 20,
#     'TZ': 21,
#     'UY': 17,
#     'VE': 17,
#     'YE': 14,
#     'ZA': 18,
#     'US': 87},
#    'display_priority': 87,
#    'logo_path': '/x6nRFzF32hCzMHaVM4RHRo7lsgS.jpg',
#    'provider_name': 'Dekkoo',
#    'provider_id': 444},
#   {'display_priorities': {'AD': 17,
#     'AL': 18,
#     'AR': 24,
#     'AT': 37,
#     'AU': 44,
#     'BA': 18,
#     'BB': 14,
#     'BE': 25,
#     'BG': 11,
#     'BH': 15,
#     'BM': 16,
#     'BO': 12,
#     'BS': 15,
#     'BR': 34,
#     'CI': 14,
#     'CH': 33,
#     'CA': 70,
#     'CL': 21,
#     'CO': 22,
#     'CR': 8,
#     'CZ': 16,
#     'DO': 15,
#     'DK': 26,
#     'DZ': 15,
#     'DE': 64,
#     'EC': 21,
#     'EE': 17,
#     'EG': 18,
#     'ES': 32,
#     'FI': 28,
#     'FR': 39,
#     'GF': 16,
#     'GB': 57,
#     'GI': 16,
#     'GR': 14,
#     'GT': 8,
#     'HN': 7,
#     'HK': 25,
#     'HR': 19,
#     'HU': 16,
#     'IL': 16,
#     'ID': 26,
#     'IE': 30,
#     'IN': 39,
#     'IQ': 18,
#     'IS': 20,
#     'IT': 35,
#     'JM': 14,
#     'JO': 15,
#     'JP': 19,
#     'KR': 21,
#     'KW': 16,
#     'LB': 18,
#     'LI': 16,
#     'LT': 18,
#     'MA': 15,
#     'LV': 17,
#     'LY': 15,
#     'MC': 15,
#     'MD': 15,
#     'MK': 17,
#     'MT': 17,
#     'MY': 22,
#     'NE': 14,
#     'MX': 34,
#     'NG': 15,
#     'NL': 34,
#     'NZ': 27,
#     'NO': 28,
#     'OM': 15,
#     'PA': 16,
#     'PE': 22,
#     'PL': 20,
#     'PH': 22,
#     'PS': 18,
#     'PT': 23,
#     'PY': 7,
#     'RO': 12,
#     'QA': 15,
#     'RU': 17,
#     'SA': 16,
#     'RS': 18,
#     'SI': 18,
#     'SG': 22,
#     'SE': 31,
#     'SV': 16,
#     'SM': 16,
#     'SK': 22,
#     'TH': 20,
#     'TN': 16,
#     'TR': 19,
#     'TZ': 12,
#     'TW': 24,
#     'UY': 19,
#     'VE': 18,
#     'YE': 16,
#     'ZA': 19,
#     'US': 149},
#    'display_priority': 149,
#    'logo_path': '/aRPDQvVcpeY07sjI6lAALMCL0ti.jpg',
#    'provider_name': 'True Story',
#    'provider_id': 567},
#   {'display_priorities': {'AR': 25,
#     'AT': 36,
#     'AU': 45,
#     'BB': 15,
#     'BG': 9,
#     'BE': 26,
#     'BH': 16,
#     'BO': 10,
#     'BM': 17,
#     'BS': 16,
#     'BR': 35,
#     'CH': 34,
#     'CA': 71,
#     'CL': 22,
#     'CO': 23,
#     'CR': 10,
#     'CZ': 17,
#     'DO': 16,
#     'DK': 27,
#     'DE': 65,
#     'EC': 22,
#     'EE': 18,
#     'ES': 33,
#     'FI': 29,
#     'FR': 40,
#     'GF': 17,
#     'GB': 58,
#     'GI': 17,
#     'GR': 15,
#     'GT': 10,
#     'HK': 12,
#     'HN': 9,
#     'HR': 20,
#     'HU': 17,
#     'ID': 27,
#     'IE': 31,
#     'IN': 40,
#     'IS': 21,
#     'IT': 36,
#     'JM': 15,
#     'JO': 16,
#     'JP': 20,
#     'KR': 22,
#     'KW': 17,
#     'LI': 17,
#     'LT': 19,
#     'LV': 18,
#     'MC': 16,
#     'MD': 16,
#     'MY': 23,
#     'MX': 36,
#     'NL': 35,
#     'NZ': 28,
#     'NO': 29,
#     'OM': 16,
#     'PA': 17,
#     'PE': 23,
#     'PL': 21,
#     'PH': 23,
#     'PT': 24,
#     'PY': 9,
#     'RO': 13,
#     'QA': 16,
#     'RU': 18,
#     'SA': 17,
#     'SG': 23,
#     'SE': 32,
#     'SV': 17,
#     'SM': 17,
#     'SK': 23,
#     'TH': 21,
#     'TR': 20,
#     'TW': 11,
#     'UY': 20,
#     'VE': 19,
#     'YE': 17,
#     'ZA': 20,
#     'US': 151},
#    'display_priority': 151,
#    'logo_path': '/vbXJBJVv3u3YWt6ml0l0ldDblXT.jpg',
#    'provider_name': 'DocAlliance Films',
#    'provider_id': 569},
#   {'display_priorities': {'AD': 19,
#     'AL': 20,
#     'AR': 27,
#     'AT': 39,
#     'AU': 46,
#     'BA': 20,
#     'BB': 16,
#     'BE': 28,
#     'BH': 17,
#     'BM': 18,
#     'BO': 17,
#     'BS': 17,
#     'BR': 37,
#     'CI': 16,
#     'CH': 35,
#     'CA': 72,
#     'CL': 23,
#     'CO': 24,
#     'CR': 18,
#     'CZ': 18,
#     'DO': 17,
#     'DK': 28,
#     'DZ': 16,
#     'DE': 66,
#     'EC': 23,
#     'EE': 19,
#     'EG': 19,
#     'ES': 34,
#     'FI': 30,
#     'FR': 41,
#     'GF': 18,
#     'GB': 59,
#     'GI': 18,
#     'GR': 16,
#     'GT': 18,
#     'HK': 17,
#     'HN': 17,
#     'HR': 21,
#     'HU': 18,
#     'IN': 18,
#     'IL': 18,
#     'ID': 29,
#     'IE': 32,
#     'IQ': 20,
#     'IS': 22,
#     'IT': 37,
#     'JM': 16,
#     'JO': 17,
#     'JP': 21,
#     'KR': 23,
#     'KW': 18,
#     'LB': 20,
#     'LI': 18,
#     'LT': 20,
#     'MA': 16,
#     'LV': 19,
#     'LY': 16,
#     'MC': 17,
#     'MD': 17,
#     'MK': 19,
#     'MT': 19,
#     'MY': 24,
#     'NE': 16,
#     'MX': 37,
#     'NG': 17,
#     'NL': 36,
#     'NZ': 29,
#     'NO': 31,
#     'OM': 17,
#     'PA': 18,
#     'PE': 24,
#     'PL': 22,
#     'PH': 24,
#     'PS': 20,
#     'PT': 25,
#     'PY': 17,
#     'RO': 14,
#     'QA': 17,
#     'SA': 18,
#     'RS': 20,
#     'RU': 21,
#     'SI': 20,
#     'SG': 24,
#     'SE': 33,
#     'SV': 18,
#     'SM': 18,
#     'SK': 24,
#     'TH': 22,
#     'TN': 17,
#     'TR': 21,
#     'TW': 16,
#     'TZ': 29,
#     'UY': 21,
#     'VE': 20,
#     'YE': 18,
#     'ZA': 21,
#     'US': 153},
#    'display_priority': 153,
#    'logo_path': '/u7dwMceEbjxd1N3TLEUBILSK2x6.jpg',
#    'provider_name': 'Hoichoi',
#    'provider_id': 315},
#   {'display_priorities': {'AT': 3,
#     'AU': 12,
#     'BE': 49,
#     'BR': 14,
#     'CA': 59,
#     'DE': 8,
#     'ES': 35,
#     'GB': 7,
#     'FR': 42,
#     'IN': 44,
#     'IT': 38,
#     'JP': 5,
#     'MX': 7,
#     'NL': 37,
#     'PL': 30,
#     'SE': 43,
#     'US': 15,
#     'IE': 46},
#    'display_priority': 15,
#    'logo_path': '/seGSXajazLMCKGB5hnRCidtjay1.jpg',
#    'provider_name': 'Amazon Video',
#    'provider_id': 10},
#   {'display_priorities': {'AR': 28,
#     'AT': 40,
#     'BO': 23,
#     'BR': 38,
#     'CH': 37,
#     'CL': 24,
#     'CO': 25,
#     'CA': 121,
#     'CR': 24,
#     'CZ': 19,
#     'DO': 19,
#     'DK': 35,
#     'DE': 67,
#     'EC': 24,
#     'ES': 36,
#     'FR': 43,
#     'GB': 75,
#     'GT': 24,
#     'HN': 23,
#     'IT': 39,
#     'MX': 38,
#     'NI': 3,
#     'NO': 37,
#     'PA': 20,
#     'PE': 25,
#     'PY': 23,
#     'SE': 39,
#     'SV': 20,
#     'UY': 23,
#     'VE': 21,
#     'US': 81},
#    'display_priority': 81,
#    'logo_path': '/dB8G41Q6tSL5NBisrIeqByfepBc.jpg',
#    'provider_name': 'Pluto TV',
#    'provider_id': 300},
#   {'display_priorities': {'AG': 6,
#     'AE': 10,
#     'AD': 20,
#     'AL': 21,
#     'AR': 29,
#     'AT': 41,
#     'AU': 48,
#     'BA': 21,
#     'BB': 20,
#     'BG': 13,
#     'BE': 30,
#     'BH': 21,
#     'BM': 22,
#     'BO': 24,
#     'BR': 39,
#     'CI': 19,
#     'CH': 38,
#     'CA': 88,
#     'CL': 25,
#     'CO': 26,
#     'CR': 25,
#     'CU': 6,
#     'CV': 6,
#     'CZ': 20,
#     'DO': 21,
#     'DK': 31,
#     'DZ': 20,
#     'DE': 69,
#     'EC': 25,
#     'EE': 20,
#     'EG': 25,
#     'ES': 38,
#     'FI': 33,
#     'FJ': 6,
#     'FR': 44,
#     'GF': 22,
#     'GG': 6,
#     'GH': 6,
#     'GB': 76,
#     'GI': 22,
#     'GQ': 6,
#     'GR': 17,
#     'GT': 25,
#     'HN': 24,
#     'HK': 33,
#     'HU': 19,
#     'HR': 27,
#     'IL': 19,
#     'ID': 30,
#     'IE': 34,
#     'IN': 42,
#     'IQ': 21,
#     'IS': 26,
#     'IT': 40,
#     'JM': 19,
#     'JP': 22,
#     'JO': 21,
#     'KE': 6,
#     'KR': 24,
#     'LC': 6,
#     'KW': 22,
#     'LB': 21,
#     'LI': 22,
#     'LT': 21,
#     'LV': 20,
#     'MA': 20,
#     'LY': 20,
#     'MC': 21,
#     'MD': 20,
#     'MU': 5,
#     'MK': 20,
#     'MT': 20,
#     'MZ': 6,
#     'MY': 26,
#     'NE': 19,
#     'MX': 39,
#     'NG': 20,
#     'NL': 40,
#     'NZ': 30,
#     'NO': 33,
#     'OM': 21,
#     'PA': 22,
#     'PE': 26,
#     'PF': 6,
#     'PL': 24,
#     'PH': 25,
#     'PS': 21,
#     'PT': 26,
#     'PY': 24,
#     'RO': 15,
#     'QA': 21,
#     'RS': 21,
#     'RU': 23,
#     'SA': 24,
#     'SC': 6,
#     'SI': 21,
#     'SN': 6,
#     'SG': 26,
#     'SE': 35,
#     'SV': 22,
#     'TC': 6,
#     'SM': 22,
#     'SK': 30,
#     'TH': 24,
#     'TT': 6,
#     'TN': 21,
#     'TR': 22,
#     'TZ': 6,
#     'TW': 33,
#     'UG': 6,
#     'VA': 5,
#     'UY': 25,
#     'VE': 22,
#     'YE': 22,
#     'ZM': 6,
#     'ZA': 22,
#     'US': 159},
#    'display_priority': 159,
#    'logo_path': '/fwx5Ed64TkfWiRH1SOSkc4781Ts.jpg',
#    'provider_name': 'Eventive',
#    'provider_id': 677},
#   {'display_priorities': {'AE': 0,
#     'AD': 0,
#     'AG': 0,
#     'AL': 0,
#     'AO': 4,
#     'AR': 1,
#     'AT': 0,
#     'AU': 1,
#     'AZ': 2,
#     'BA': 0,
#     'BB': 0,
#     'BE': 1,
#     'BG': 0,
#     'BH': 0,
#     'BM': 0,
#     'BO': 0,
#     'BR': 2,
#     'BS': 0,
#     'BY': 6,
#     'BZ': 7,
#     'CA': 0,
#     'CH': 0,
#     'CI': 0,
#     'CL': 1,
#     'CO': 2,
#     'CM': 4,
#     'CR': 0,
#     'CU': 0,
#     'CV': 0,
#     'CZ': 1,
#     'CY': 7,
#     'DE': 0,
#     'DK': 1,
#     'DO': 0,
#     'DZ': 0,
#     'EC': 0,
#     'EE': 0,
#     'EG': 0,
#     'ES': 40,
#     'FI': 1,
#     'FJ': 0,
#     'FR': 1,
#     'GB': 0,
#     'GF': 0,
#     'GG': 0,
#     'GH': 0,
#     'GI': 0,
#     'GQ': 0,
#     'GR': 0,
#     'GT': 0,
#     'HK': 1,
#     'HN': 0,
#     'HR': 0,
#     'HU': 1,
#     'ID': 0,
#     'IE': 0,
#     'IL': 0,
#     'IN': 0,
#     'IQ': 0,
#     'IT': 1,
#     'IS': 0,
#     'JM': 0,
#     'JP': 0,
#     'JO': 0,
#     'KE': 0,
#     'KR': 0,
#     'KW': 0,
#     'LB': 0,
#     'LC': 0,
#     'LI': 0,
#     'LT': 0,
#     'LU': 8,
#     'MA': 0,
#     'LV': 0,
#     'LY': 0,
#     'MC': 0,
#     'ME': 4,
#     'MD': 0,
#     'MG': 4,
#     'MK': 0,
#     'MT': 0,
#     'ML': 5,
#     'MU': 0,
#     'MX': 8,
#     'MZ': 0,
#     'MY': 1,
#     'NE': 0,
#     'NG': 0,
#     'NL': 0,
#     'NI': 11,
#     'NO': 1,
#     'NZ': 1,
#     'OM': 0,
#     'PA': 0,
#     'PE': 2,
#     'PK': 0,
#     'PF': 0,
#     'PL': 1,
#     'PH': 0,
#     'PS': 0,
#     'PT': 1,
#     'PY': 0,
#     'QA': 0,
#     'RO': 1,
#     'RS': 0,
#     'SA': 0,
#     'SC': 0,
#     'SI': 0,
#     'SG': 0,
#     'SE': 1,
#     'SN': 0,
#     'SV': 0,
#     'SK': 1,
#     'SM': 0,
#     'TC': 0,
#     'TH': 1,
#     'TD': 5,
#     'TN': 0,
#     'TR': 3,
#     'TT': 0,
#     'TW': 0,
#     'TZ': 0,
#     'UA': 0,
#     'UG': 0,
#     'US': 7,
#     'UY': 0,
#     'VE': 0,
#     'YE': 0,
#     'ZA': 0,
#     'ZM': 0,
#     'ZW': 5},
#    'display_priority': 5,
#    'logo_path': '/pbpMk2JmcoNnQwx5JGpXngfoWtp.jpg',
#    'provider_name': 'Netflix',
#    'provider_id': 8},
#   {'display_priorities': {'AU': 81,
#     'BR': 98,
#     'CL': 42,
#     'CO': 43,
#     'DE': 35,
#     'ES': 41,
#     'FR': 47,
#     'GB': 37,
#     'IN': 92,
#     'IT': 51,
#     'MX': 95,
#     'US': 94},
#    'display_priority': 94,
#    'logo_path': '/a4IDLKjvP5gvq7tNlg2Xw5YyEkI.jpg',
#    'provider_name': 'MUBI Amazon Channel',
#    'provider_id': 201},
#   {'display_priorities': {'AU': 83, 'CA': 80, 'DE': 120, 'ES': 42, 'GB': 109},
#    'display_priority': 109,
#    'logo_path': '/d0KmcInHpiF44ahOLrXCQATEFmD.jpg',
#    'provider_name': 'OUTtv Amazon Channel',
#    'provider_id': 607},
#   {'display_priorities': {'AU': 28,
#     'CA': 28,
#     'ES': 43,
#     'GB': 55,
#     'MX': 41,
#     'US': 96},
#    'display_priority': 96,
#    'logo_path': '/1wYmvbAuVZz2JnKvYfYN8Qolnb.jpg',
#    'provider_name': 'AcornTV Amazon Channel',
#    'provider_id': 196},
#   {'display_priorities': {'ES': 44},
#    'display_priority': 44,
#    'logo_path': '/2GQVxfaiWA4n93I7sJDJf1b6NqS.jpg',
#    'provider_name': 'FlixOlé Amazon Channel',
#    'provider_id': 684},
#   {'display_priorities': {'ES': 45},
#    'display_priority': 45,
#    'logo_path': '/32R4lsqOPclNhb3qV613J8T8mdL.jpg',
#    'provider_name': 'TVCortos Amazon Channel',
#    'provider_id': 689},
#   {'display_priorities': {'AG': 8,
#     'AE': 11,
#     'AD': 21,
#     'AL': 22,
#     'AR': 30,
#     'AT': 43,
#     'AU': 49,
#     'BA': 22,
#     'BB': 21,
#     'BG': 14,
#     'BE': 31,
#     'BH': 22,
#     'BM': 23,
#     'BO': 25,
#     'BS': 21,
#     'BR': 43,
#     'CI': 20,
#     'CH': 39,
#     'CA': 89,
#     'CL': 26,
#     'CO': 27,
#     'CR': 26,
#     'CU': 8,
#     'CV': 8,
#     'CZ': 21,
#     'DO': 22,
#     'DK': 32,
#     'DZ': 21,
#     'EC': 26,
#     'DE': 75,
#     'EE': 21,
#     'EG': 26,
#     'FI': 34,
#     'ES': 46,
#     'FJ': 8,
#     'FR': 49,
#     'GF': 23,
#     'GG': 9,
#     'GH': 7,
#     'GB': 78,
#     'GI': 23,
#     'GQ': 7,
#     'GR': 18,
#     'GT': 26,
#     'HN': 25,
#     'HK': 34,
#     'HU': 20,
#     'HR': 28,
#     'IL': 20,
#     'ID': 31,
#     'IE': 35,
#     'IN': 45,
#     'IQ': 22,
#     'IS': 27,
#     'IT': 42,
#     'JM': 20,
#     'JP': 23,
#     'JO': 22,
#     'KE': 7,
#     'KR': 25,
#     'LC': 8,
#     'KW': 23,
#     'LB': 22,
#     'LI': 23,
#     'LT': 22,
#     'LV': 21,
#     'MA': 21,
#     'LY': 21,
#     'MC': 22,
#     'MD': 21,
#     'MK': 21,
#     'MU': 9,
#     'MT': 21,
#     'MZ': 7,
#     'MY': 27,
#     'NE': 20,
#     'MX': 42,
#     'NG': 22,
#     'NL': 42,
#     'NZ': 31,
#     'NO': 34,
#     'OM': 22,
#     'PA': 23,
#     'PE': 27,
#     'PK': 6,
#     'PF': 8,
#     'PL': 25,
#     'PH': 26,
#     'PS': 22,
#     'PT': 29,
#     'PY': 25,
#     'RO': 16,
#     'QA': 22,
#     'RS': 22,
#     'RU': 24,
#     'SA': 25,
#     'SC': 10,
#     'SI': 22,
#     'SN': 7,
#     'SG': 27,
#     'SE': 36,
#     'SV': 23,
#     'TC': 8,
#     'SM': 23,
#     'SK': 31,
#     'TH': 25,
#     'TT': 8,
#     'TN': 22,
#     'TR': 23,
#     'TZ': 9,
#     'TW': 34,
#     'UG': 7,
#     'XK': 2,
#     'VA': 6,
#     'UY': 26,
#     'VE': 23,
#     'YE': 23,
#     'ZM': 7,
#     'ZA': 23,
#     'US': 158},
#    'display_priority': 158,
#    'logo_path': '/uauVx3dGWt0GICqdMCBYJObd3Mo.jpg',
#    'provider_name': 'Cultpix',
#    'provider_id': 692},
#   {'display_priorities': {'AG': 7,
#     'AE': 12,
#     'AL': 24,
#     'AO': 3,
#     'AZ': 0,
#     'AR': 31,
#     'AT': 44,
#     'AU': 50,
#     'BF': 3,
#     'BB': 22,
#     'BG': 15,
#     'BE': 32,
#     'BH': 23,
#     'BM': 24,
#     'BO': 26,
#     'BY': 5,
#     'BZ': 6,
#     'BS': 22,
#     'BR': 44,
#     'CI': 22,
#     'CH': 40,
#     'CM': 3,
#     'CA': 90,
#     'CL': 27,
#     'CO': 28,
#     'CR': 27,
#     'CU': 7,
#     'CY': 6,
#     'CV': 7,
#     'CZ': 23,
#     'DO': 23,
#     'DK': 33,
#     'DZ': 23,
#     'EC': 27,
#     'DE': 76,
#     'EE': 22,
#     'EG': 27,
#     'FI': 35,
#     'ES': 47,
#     'FJ': 7,
#     'FR': 51,
#     'GG': 7,
#     'GF': 26,
#     'GH': 9,
#     'GB': 79,
#     'GI': 24,
#     'GQ': 9,
#     'GR': 19,
#     'GY': 2,
#     'GT': 27,
#     'HN': 26,
#     'HK': 36,
#     'HU': 21,
#     'HR': 29,
#     'ID': 32,
#     'IE': 36,
#     'IN': 46,
#     'IQ': 24,
#     'IS': 28,
#     'IT': 44,
#     'JM': 21,
#     'JP': 24,
#     'JO': 23,
#     'KE': 10,
#     'KR': 26,
#     'LC': 7,
#     'KW': 24,
#     'LB': 24,
#     'LI': 24,
#     'LU': 7,
#     'LT': 23,
#     'LV': 22,
#     'MA': 22,
#     'LY': 23,
#     'MC': 23,
#     'ME': 3,
#     'MG': 3,
#     'ML': 4,
#     'MD': 22,
#     'MU': 7,
#     'MW': 2,
#     'MK': 23,
#     'MZ': 9,
#     'MY': 28,
#     'NE': 22,
#     'MX': 43,
#     'NI': 7,
#     'NG': 25,
#     'NL': 44,
#     'NZ': 32,
#     'NO': 35,
#     'OM': 23,
#     'PA': 24,
#     'PE': 28,
#     'PG': 3,
#     'PK': 7,
#     'PF': 7,
#     'PL': 26,
#     'PH': 27,
#     'PS': 24,
#     'PT': 30,
#     'PY': 26,
#     'RO': 17,
#     'QA': 23,
#     'RS': 25,
#     'RU': 25,
#     'SA': 26,
#     'SC': 8,
#     'SN': 9,
#     'SG': 28,
#     'SE': 37,
#     'SV': 24,
#     'TC': 7,
#     'SM': 24,
#     'SK': 32,
#     'TD': 4,
#     'TH': 26,
#     'TT': 7,
#     'TN': 23,
#     'TR': 23,
#     'UA': 6,
#     'TZ': 17,
#     'TW': 36,
#     'UG': 9,
#     'UY': 28,
#     'VE': 24,
#     'YE': 24,
#     'ZM': 9,
#     'ZW': 4,
#     'ZA': 24,
#     'US': 160},
#    'display_priority': 160,
#    'logo_path': '/fbveJTcro9Xw2KuPIIoPPePHiwy.jpg',
#    'provider_name': 'FilmBox+',
#    'provider_id': 701},
#   {'display_priorities': {'ES': 48},
#    'display_priority': 48,
#    'logo_path': '/8vES2nJNwOF57muvqLByDLm6snp.jpg',
#    'provider_name': 'Acontra Plus',
#    'provider_id': 1717},
#   {'display_priorities': {'ES': 53},
#    'display_priority': 53,
#    'logo_path': '/yISpVXhf6axqiHh6lBvJ8RRrZ8v.jpg',
#    'provider_name': 'Planet Horror Amazon Channel',
#    'provider_id': 1740},
#   {'display_priorities': {'ES': 54},
#    'display_priority': 54,
#    'logo_path': '/tM1HabyA45cnckBEhLS7hAVga5g.jpg',
#    'provider_name': 'Dizi Amazon Channel',
#    'provider_id': 1741},
#   {'display_priorities': {'ES': 55},
#    'display_priority': 55,
#    'logo_path': '/tGvAD4O9obFP3DfOrDn8NaRQ6eT.jpg',
#    'provider_name': 'Acontra Plus Amazon Channel',
#    'provider_id': 1742},
#   {'display_priorities': {'ES': 56},
#    'display_priority': 56,
#    'logo_path': '/aJECXkHekrkuRZ7ABF5YR9DVDd8.jpg',
#    'provider_name': 'Historia y Actualidad Amazon Channel',
#    'provider_id': 1743},
#   {'display_priorities': {'AG': 9,
#     'AE': 16,
#     'AD': 23,
#     'AL': 25,
#     'AR': 32,
#     'AT': 49,
#     'AU': 51,
#     'BA': 25,
#     'BB': 23,
#     'BE': 33,
#     'BG': 17,
#     'BH': 25,
#     'BM': 25,
#     'BO': 27,
#     'BS': 23,
#     'BR': 45,
#     'CI': 25,
#     'CH': 44,
#     'CL': 28,
#     'CA': 107,
#     'CO': 29,
#     'CR': 28,
#     'CV': 9,
#     'CZ': 24,
#     'DO': 26,
#     'DK': 37,
#     'DZ': 27,
#     'EC': 28,
#     'EE': 24,
#     'DE': 97,
#     'EG': 32,
#     'FI': 38,
#     'ES': 60,
#     'FJ': 9,
#     'GG': 8,
#     'GF': 27,
#     'FR': 69,
#     'GH': 12,
#     'GB': 93,
#     'GI': 25,
#     'GQ': 12,
#     'GT': 28,
#     'HN': 27,
#     'HK': 37,
#     'HU': 22,
#     'HR': 32,
#     'IL': 23,
#     'ID': 33,
#     'IE': 37,
#     'IN': 47,
#     'IQ': 26,
#     'IS': 30,
#     'IT': 60,
#     'JM': 22,
#     'JP': 25,
#     'JO': 25,
#     'KE': 13,
#     'KR': 27,
#     'LC': 9,
#     'KW': 26,
#     'LB': 26,
#     'LI': 26,
#     'LT': 25,
#     'LV': 24,
#     'MA': 26,
#     'LY': 27,
#     'MC': 24,
#     'MD': 23,
#     'MU': 11,
#     'MK': 24,
#     'MT': 23,
#     'MZ': 12,
#     'MY': 29,
#     'NE': 25,
#     'MX': 44,
#     'NG': 28,
#     'NL': 45,
#     'NZ': 33,
#     'NO': 38,
#     'OM': 25,
#     'PA': 26,
#     'PE': 29,
#     'PF': 9,
#     'PL': 27,
#     'PH': 28,
#     'PS': 26,
#     'PT': 31,
#     'RO': 18,
#     'QA': 25,
#     'RS': 26,
#     'RU': 26,
#     'SA': 30,
#     'SC': 12,
#     'SI': 26,
#     'SG': 29,
#     'SN': 12,
#     'SE': 40,
#     'SV': 25,
#     'TC': 9,
#     'SM': 26,
#     'SK': 34,
#     'TH': 27,
#     'TT': 9,
#     'TR': 24,
#     'TN': 27,
#     'TZ': 11,
#     'TW': 37,
#     'UG': 12,
#     'UY': 29,
#     'VE': 25,
#     'YE': 26,
#     'ZM': 12,
#     'ZA': 27,
#     'US': 173},
#    'display_priority': 173,
#    'logo_path': '/ed0vz5bryWIhQB5sHiuGvHKnHHn.jpg',
#    'provider_name': 'Takflix',
#    'provider_id': 1771},
#   {'display_priorities': {'AD': 4,
#     'AL': 4,
#     'AG': 3,
#     'AE': 6,
#     'AU': 29,
#     'BA': 4,
#     'AR': 33,
#     'AT': 51,
#     'BB': 5,
#     'BH': 5,
#     'BE': 34,
#     'BG': 18,
#     'BM': 5,
#     'BO': 28,
#     'BS': 5,
#     'BR': 46,
#     'CI': 4,
#     'CA': 47,
#     'CH': 45,
#     'CL': 29,
#     'CO': 30,
#     'CU': 3,
#     'CR': 29,
#     'CV': 3,
#     'CZ': 25,
#     'DO': 5,
#     'DZ': 5,
#     'DK': 38,
#     'EC': 29,
#     'EG': 11,
#     'EE': 25,
#     'DE': 101,
#     'FI': 39,
#     'FJ': 3,
#     'ES': 62,
#     'GF': 5,
#     'GG': 3,
#     'FR': 72,
#     'GH': 3,
#     'GI': 5,
#     'GB': 98,
#     'GQ': 3,
#     'GR': 21,
#     'GT': 29,
#     'HK': 10,
#     'HR': 10,
#     'HN': 28,
#     'HU': 23,
#     'IL': 4,
#     'IN': 17,
#     'ID': 34,
#     'IE': 38,
#     'IQ': 4,
#     'IS': 10,
#     'JM': 5,
#     'IT': 63,
#     'JO': 5,
#     'JP': 26,
#     'KE': 3,
#     'KW': 5,
#     'LB': 4,
#     'KR': 28,
#     'LC': 3,
#     'LI': 5,
#     'LT': 26,
#     'MA': 5,
#     'LY': 5,
#     'MC': 5,
#     'LV': 25,
#     'MD': 5,
#     'MK': 4,
#     'MT': 4,
#     'MU': 2,
#     'MZ': 3,
#     'NE': 4,
#     'MY': 12,
#     'NG': 4,
#     'MX': 45,
#     'NZ': 15,
#     'NL': 46,
#     'NO': 39,
#     'OM': 5,
#     'PA': 5,
#     'PE': 30,
#     'PK': 3,
#     'PF': 3,
#     'PS': 4,
#     'PL': 28,
#     'PH': 29,
#     'PT': 33,
#     'QA': 5,
#     'PY': 27,
#     'RO': 19,
#     'RS': 4,
#     'SA': 9,
#     'SC': 3,
#     'RU': 27,
#     'SI': 4,
#     'SG': 12,
#     'SN': 3,
#     'SE': 41,
#     'SV': 5,
#     'SM': 5,
#     'SK': 13,
#     'TC': 3,
#     'TN': 5,
#     'TH': 28,
#     'TT': 3,
#     'TR': 27,
#     'TW': 9,
#     'TZ': 3,
#     'UG': 3,
#     'XK': 0,
#     'VA': 2,
#     'UY': 7,
#     'YE': 5,
#     'US': 46,
#     'VE': 26,
#     'ZA': 10,
#     'ZM': 3},
#    'display_priority': 46,
#    'logo_path': '/6KEQzITx2RrCAQt5Nw9WrL1OI8z.jpg',
#    'provider_name': 'Sun Nxt',
#    'provider_id': 309},
#   {'display_priorities': {'AU': 53,
#     'BR': 47,
#     'CA': 111,
#     'DE': 103,
#     'ES': 63,
#     'FR': 73,
#     'GB': 100,
#     'IT': 64,
#     'JP': 27,
#     'KR': 29,
#     'MX': 46,
#     'US': 181},
#    'display_priority': 181,
#    'logo_path': '/kICQccvOh8AIBMHGkBXJ047xeHN.jpg',
#    'provider_name': 'Netflix basic with Ads',
#    'provider_id': 1796},
#   {'display_priorities': {'ES': 68},
#    'display_priority': 68,
#    'logo_path': '/8VhN4PeHU7yfMNoWK0DnwdS1HlS.jpg',
#    'provider_name': 'Tivify',
#    'provider_id': 1838},
#   {'display_priorities': {'AR': 45,
#     'BO': 29,
#     'BZ': 8,
#     'BR': 63,
#     'CL': 30,
#     'CO': 31,
#     'CA': 124,
#     'CR': 30,
#     'DO': 27,
#     'EC': 30,
#     'ES': 72,
#     'FR': 90,
#     'GB': 108,
#     'GT': 30,
#     'HN': 29,
#     'NI': 8,
#     'MX': 63,
#     'PA': 28,
#     'PE': 31,
#     'PY': 28,
#     'SV': 28,
#     'UY': 30,
#     'VE': 27,
#     'US': 197},
#    'display_priority': 197,
#    'logo_path': '/oJRCAz1WKkKM9Ge7mX5KFnegTNY.jpg',
#    'provider_name': 'Runtime',
#    'provider_id': 1875},
#   {'display_priorities': {'AG': 10,
#     'AE': 25,
#     'AD': 25,
#     'AL': 27,
#     'AZ': 4,
#     'AR': 46,
#     'BA': 27,
#     'AT': 58,
#     'AU': 58,
#     'BF': 4,
#     'BB': 24,
#     'BG': 20,
#     'BE': 41,
#     'BH': 36,
#     'BM': 26,
#     'BO': 30,
#     'BR': 11,
#     'BY': 7,
#     'BZ': 9,
#     'BS': 24,
#     'CD': 2,
#     'CI': 26,
#     'CH': 47,
#     'CL': 31,
#     'CO': 32,
#     'CA': 125,
#     'CR': 31,
#     'CY': 8,
#     'CV': 12,
#     'DE': 6,
#     'CZ': 27,
#     'DO': 28,
#     'DK': 39,
#     'DZ': 28,
#     'EC': 31,
#     'EE': 26,
#     'EG': 40,
#     'FI': 40,
#     'FJ': 10,
#     'FR': 5,
#     'ES': 73,
#     'GB': 6,
#     'GF': 28,
#     'GG': 10,
#     'GH': 15,
#     'GI': 26,
#     'GQ': 13,
#     'GY': 3,
#     'GR': 22,
#     'GT': 31,
#     'HK': 38,
#     'HN': 30,
#     'HU': 25,
#     'HR': 34,
#     'IN': 4,
#     'IL': 26,
#     'ID': 35,
#     'IE': 40,
#     'IQ': 35,
#     'IS': 31,
#     'JM': 23,
#     'IT': 74,
#     'KE': 14,
#     'JO': 36,
#     'KR': 30,
#     'LC': 10,
#     'LB': 27,
#     'KW': 36,
#     'LI': 27,
#     'LU': 9,
#     'LT': 27,
#     'LV': 26,
#     'MA': 27,
#     'LY': 28,
#     'MC': 25,
#     'ME': 5,
#     'MD': 24,
#     'MK': 26,
#     'MU': 14,
#     'MX': 4,
#     'MZ': 15,
#     'MY': 30,
#     'NE': 26,
#     'NI': 9,
#     'NG': 29,
#     'NZ': 35,
#     'NO': 41,
#     'NL': 67,
#     'PA': 29,
#     'OM': 36,
#     'PG': 4,
#     'PE': 32,
#     'PF': 10,
#     'PL': 29,
#     'PH': 31,
#     'PS': 27,
#     'PT': 39,
#     'PY': 29,
#     'RO': 21,
#     'QA': 36,
#     'RS': 28,
#     'RU': 28,
#     'SC': 13,
#     'SI': 28,
#     'SG': 30,
#     'SN': 13,
#     'SE': 42,
#     'SV': 29,
#     'TC': 10,
#     'SM': 27,
#     'SK': 36,
#     'TD': 6,
#     'TH': 29,
#     'TT': 10,
#     'TN': 28,
#     'TR': 43,
#     'UA': 7,
#     'TW': 38,
#     'TZ': 31,
#     'UG': 15,
#     'US': 6,
#     'XK': 4,
#     'UY': 31,
#     'VE': 28,
#     'YE': 27,
#     'ZM': 13,
#     'ZA': 28,
#     'MT': 24},
#    'display_priority': 28,
#    'logo_path': '/mXeC4TrcgdU6ltE9bCBCEORwSQR.jpg',
#    'provider_name': 'Crunchyroll',
#    'provider_id': 283},
#   {'display_priorities': {'AU': 55, 'CA': 91, 'ES': 74, 'US': 26},
#    'display_priority': 26,
#    'logo_path': '/2ino0WmHA4GROB7NYKzT6PGqLcb.jpg',
#    'provider_name': 'AMC+ Amazon Channel',
#    'provider_id': 528},
#   {'display_priorities': {'AU': 82, 'BR': 42, 'CA': 81, 'ES': 75, 'MX': 40},
#    'display_priority': 40,
#    'logo_path': '/bSy9zFiZtbKBHIyOu0H2Fs5cJmx.jpg',
#    'provider_name': 'Love Nature Amazon Channel',
#    'provider_id': 608},
#   {'display_priorities': {'AE': 14,
#     'AR': 56,
#     'AU': 60,
#     'BH': 28,
#     'BR': 78,
#     'CI': 24,
#     'CA': 135,
#     'DZ': 25,
#     'EG': 30,
#     'FI': 41,
#     'DE': 141,
#     'ES': 88,
#     'GH': 11,
#     'FR': 100,
#     'GQ': 11,
#     'GB': 121,
#     'IL': 9,
#     'ID': 36,
#     'IQ': 10,
#     'IN': 64,
#     'JO': 28,
#     'IT': 92,
#     'KE': 12,
#     'LB': 10,
#     'KW': 29,
#     'MA': 24,
#     'LY': 25,
#     'MU': 10,
#     'MZ': 11,
#     'NE': 24,
#     'NG': 27,
#     'MX': 70,
#     'OM': 28,
#     'PS': 10,
#     'PL': 32,
#     'PH': 32,
#     'QA': 28,
#     'RU': 29,
#     'SA': 28,
#     'SC': 11,
#     'SN': 11,
#     'TN': 25,
#     'TZ': 10,
#     'TR': 55,
#     'UG': 11,
#     'ZM': 11,
#     'ZA': 26,
#     'US': 221},
#    'display_priority': 221,
#    'logo_path': '/7qZED0kLBtiV8mLRNBtW4PQCAqW.jpg',
#    'provider_name': 'Shahid VIP',
#    'provider_id': 1715},
#   {'display_priorities': {'AU': 64,
#     'CA': 141,
#     'ES': 93,
#     'GB': 131,
#     'MX': 78,
#     'US': 238},
#    'display_priority': 238,
#    'logo_path': '/kx8rGgFYxX6aJkG7RHx2mtijglC.jpg',
#    'provider_name': 'Acorn TV Apple TV',
#    'provider_id': 2034},
#   {'display_priorities': {'AU': 57, 'CA': 119, 'ES': 94, 'US': 22},
#    'display_priority': 22,
#    'logo_path': '/oTQdXIqM9iewlN4MC2nhKB0gHw.jpg',
#    'provider_name': 'AMC Plus Apple TV Channel ',
#    'provider_id': 1854},
#   {'display_priorities': {'AR': 14,
#     'AU': 67,
#     'BR': 13,
#     'CA': 30,
#     'CL': 12,
#     'CO': 14,
#     'EC': 13,
#     'FJ': 12,
#     'ES': 97,
#     'GB': 136,
#     'IE': 43,
#     'MX': 11,
#     'NZ': 36,
#     'PE': 14,
#     'PG': 5,
#     'PF': 11,
#     'PT': 59,
#     'US': 14,
#     'VE': 11},
#    'display_priority': 11,
#    'logo_path': '/hwsU65QW7A4dbMEWkDpgHyCNcfS.jpg',
#    'provider_name': 'Kocowa',
#    'provider_id': 464},
#   {'display_priorities': {'AT': 69,
#     'CH': 54,
#     'DE': 30,
#     'FR': 13,
#     'ES': 105,
#     'GB': 144,
#     'IE': 45,
#     'IT': 107,
#     'PL': 39},
#    'display_priority': 39,
#    'logo_path': '/vPZrjHe7wvALuwJEXT2kwYLi0gV.jpg',
#    'provider_name': 'Arte',
#    'provider_id': 234},
#   {'display_priorities': {'AT': 72,
#     'BE': 66,
#     'BR': 92,
#     'CL': 38,
#     'CO': 39,
#     'DE': 167,
#     'ES': 106,
#     'GB': 146,
#     'IT': 108,
#     'MX': 85,
#     'NL': 88},
#    'display_priority': 88,
#    'logo_path': '/efu1Cqc63XrPBoreYnf2mn0Nizj.jpg',
#    'provider_name': 'MGM Plus Amazon Channel',
#    'provider_id': 2141},
#   {'display_priorities': {'ES': 109},
#    'display_priority': 109,
#    'logo_path': '/lDvzuBuNVgpcdzDpPmmufKvrZPb.jpg',
#    'provider_name': '3Cat',
#    'provider_id': 2237}]}

# %%
res_url_movies_spain_providers.json().keys()
# Out:
# dict_keys(['results'])

# %%
res_url_movies_spain_providers.json()["results"]
# Out:
# [{'display_priorities': {'AD': 7,
#    'AL': 7,
#    'AR': 0,
#    'AT': 2,
#    'AU': 0,
#    'BA': 7,
#    'BE': 0,
#    'BG': 16,
#    'BO': 2,
#    'BR': 0,
#    'BZ': 2,
#    'CA': 1,
#    'CH': 2,
#    'CL': 0,
#    'CO': 0,
#    'CR': 2,
#    'CZ': 0,
#    'DK': 0,
#    'DE': 2,
#    'DO': 24,
#    'EC': 1,
#    'EE': 23,
#    'ES': 0,
#    'FI': 0,
#    'EG': 45,
#    'FR': 0,
#    'GB': 1,
#    'GT': 1,
#    'GR': 20,
#    'HN': 2,
#    'HU': 0,
#    'HK': 32,
#    'HR': 31,
#    'IE': 2,
#    'IT': 0,
#    'IS': 1,
#    'JP': 2,
#    'JM': 26,
#    'KR': 2,
#    'LC': 13,
#    'LU': 3,
#    'LI': 25,
#    'LT': 24,
#    'LV': 23,
#    'ME': 1,
#    'MK': 7,
#    'MT': 7,
#    'MX': 0,
#    'NI': 2,
#    'NL': 1,
#    'NO': 0,
#    'NZ': 0,
#    'PE': 0,
#    'PA': 27,
#    'PL': 0,
#    'PT': 0,
#    'PH': 30,
#    'PY': 2,
#    'RO': 0,
#    'RS': 7,
#    'SG': 2,
#    'SI': 7,
#    'SE': 0,
#    'SK': 0,
#    'SV': 27,
#    'SM': 25,
#    'TR': 0,
#    'TT': 14,
#    'TW': 2,
#    'US': 0,
#    'VE': 1,
#    'UY': 27},
#   'display_priority': 27,
#   'logo_path': '/97yvRBw1GzX7fXprcF80er19ot.jpg',
#   'provider_name': 'Disney Plus',
#   'provider_id': 337},
#  {'display_priorities': {'AE': 2,
#    'AG': 11,
#    'AR': 5,
#    'AT': 5,
#    'AZ': 3,
#    'AU': 11,
#    'BE': 9,
#    'BG': 3,
#    'BO': 3,
#    'BH': 49,
#    'BM': 27,
#    'BR': 9,
#    'BY': 3,
#    'BZ': 4,
#    'BS': 25,
#    'CA': 7,
#    'CH': 18,
#    'CL': 5,
#    'CO': 5,
#    'CR': 3,
#    'CY': 4,
#    'CV': 10,
#    'CZ': 7,
#    'DE': 3,
#    'DK': 10,
#    'DO': 31,
#    'EC': 7,
#    'EE': 7,
#    'EG': 3,
#    'ES': 1,
#    'FI': 12,
#    'FJ': 11,
#    'FR': 3,
#    'GB': 3,
#    'GH': 13,
#    'GR': 5,
#    'GT': 3,
#    'HN': 3,
#    'HK': 16,
#    'HU': 7,
#    'IE': 5,
#    'IN': 2,
#    'ID': 12,
#    'IL': 25,
#    'IT': 5,
#    'JP': 10,
#    'JO': 50,
#    'KR': 5,
#    'LB': 28,
#    'LU': 5,
#    'LT': 7,
#    'LV': 7,
#    'MD': 25,
#    'MU': 12,
#    'MT': 25,
#    'MX': 3,
#    'MY': 11,
#    'MZ': 13,
#    'NI': 5,
#    'NL': 10,
#    'NO': 6,
#    'NZ': 5,
#    'PE': 6,
#    'PA': 25,
#    'OM': 49,
#    'PL': 3,
#    'PH': 11,
#    'PT': 11,
#    'PY': 4,
#    'RU': 3,
#    'SA': 2,
#    'QA': 49,
#    'SE': 5,
#    'SG': 11,
#    'SI': 24,
#    'SK': 5,
#    'SV': 31,
#    'TH': 10,
#    'TT': 11,
#    'TW': 15,
#    'UA': 1,
#    'UG': 13,
#    'US': 2,
#    'VE': 5,
#    'ZA': 9},
#   'display_priority': 9,
#   'logo_path': '/2E03IAZsX4ZaUqM7tXlctEPMGWS.jpg',
#   'provider_name': 'Apple TV Plus',
#   'provider_id': 350},
#  {'display_priorities': {'AD': 1,
#    'AG': 1,
#    'AL': 1,
#    'AE': 9,
#    'AO': 1,
#    'AR': 2,
#    'AU': 2,
#    'BA': 1,
#    'BB': 1,
#    'BE': 2,
#    'BF': 1,
#    'BG': 1,
#    'BH': 1,
#    'BM': 1,
#    'BO': 1,
#    'BR': 1,
#    'BS': 1,
#    'BY': 2,
#    'BZ': 3,
#    'CA': 2,
#    'CD': 0,
#    'CH': 1,
#    'CI': 1,
#    'CL': 2,
#    'CO': 1,
#    'CM': 1,
#    'CR': 1,
#    'CU': 1,
#    'CV': 1,
#    'CY': 3,
#    'CZ': 2,
#    'DK': 2,
#    'DO': 1,
#    'DZ': 1,
#    'EC': 2,
#    'EE': 1,
#    'EG': 1,
#    'ES': 2,
#    'FI': 2,
#    'FJ': 1,
#    'FR': 2,
#    'GF': 1,
#    'GG': 1,
#    'GH': 1,
#    'GI': 1,
#    'GQ': 1,
#    'GR': 1,
#    'GT': 2,
#    'GY': 0,
#    'HK': 5,
#    'HN': 1,
#    'HR': 1,
#    'HU': 2,
#    'IE': 1,
#    'ID': 7,
#    'IL': 1,
#    'IN': 1,
#    'IQ': 1,
#    'IT': 2,
#    'IS': 2,
#    'JM': 1,
#    'JO': 1,
#    'KE': 1,
#    'KR': 1,
#    'KW': 1,
#    'LB': 1,
#    'LC': 1,
#    'LI': 1,
#    'LT': 1,
#    'MA': 1,
#    'LV': 1,
#    'LY': 1,
#    'MC': 1,
#    'MD': 1,
#    'MG': 1,
#    'ML': 2,
#    'MK': 1,
#    'MT': 1,
#    'MW': 0,
#    'MX': 1,
#    'MZ': 1,
#    'NE': 1,
#    'MY': 9,
#    'NG': 1,
#    'NI': 4,
#    'NL': 2,
#    'NO': 2,
#    'NZ': 2,
#    'OM': 1,
#    'PA': 1,
#    'PE': 1,
#    'PG': 1,
#    'PK': 1,
#    'PF': 1,
#    'PL': 5,
#    'PH': 1,
#    'PS': 1,
#    'PT': 2,
#    'PY': 1,
#    'QA': 1,
#    'RO': 2,
#    'RS': 1,
#    'SC': 1,
#    'SA': 23,
#    'SI': 1,
#    'SG': 1,
#    'SE': 2,
#    'SN': 1,
#    'SV': 1,
#    'SK': 2,
#    'SM': 1,
#    'TC': 1,
#    'TH': 3,
#    'TD': 2,
#    'TN': 1,
#    'TR': 6,
#    'TT': 1,
#    'TW': 1,
#    'TZ': 1,
#    'UG': 1,
#    'VA': 0,
#    'UY': 1,
#    'VE': 2,
#    'YE': 1,
#    'ZA': 1,
#    'ZM': 1,
#    'ZW': 2},
#   'display_priority': 1,
#   'logo_path': '/dQeAar5H991VYporEjUspolDarG.jpg',
#   'provider_name': 'Amazon Prime Video',
#   'provider_id': 119},
#  {'display_priorities': {'ES': 3},
#   'display_priority': 3,
#   'logo_path': '/jse4MOi92Jgetym7nbXFZZBI6LK.jpg',
#   'provider_name': 'Movistar Plus+ €9.99',
#   'provider_id': 2241},
#  {'display_priorities': {'AL': 8,
#    'AT': 9,
#    'BA': 8,
#    'BE': 10,
#    'CH': 9,
#    'CY': 2,
#    'DE': 16,
#    'DK': 14,
#    'CZ': 34,
#    'ES': 4,
#    'FI': 14,
#    'FR': 21,
#    'GB': 5,
#    'GR': 24,
#    'HU': 27,
#    'IE': 12,
#    'IT': 3,
#    'LU': 2,
#    'ME': 0,
#    'MK': 8,
#    'MT': 8,
#    'NL': 15,
#    'NO': 14,
#    'PT': 8,
#    'PL': 37,
#    'RO': 23,
#    'RS': 8,
#    'SI': 8,
#    'SE': 15,
#    'SK': 39,
#    'UA': 4},
#   'display_priority': 4,
#   'logo_path': '/bZvc9dXrXNly7cA0V4D9pR8yJwm.jpg',
#   'provider_name': 'Rakuten TV',
#   'provider_id': 35},
#  {'display_priorities': {'ES': 5},
#   'display_priority': 5,
#   'logo_path': '/f6TRLB3H4jDpFEZ0z2KWSSvu1SB.jpg',
#   'provider_name': 'Movistar Plus+',
#   'provider_id': 149},
#  {'display_priorities': {'AE': 1,
#    'AR': 3,
#    'AT': 4,
#    'AU': 10,
#    'BE': 6,
#    'BG': 2,
#    'BO': 4,
#    'BR': 8,
#    'BY': 0,
#    'BZ': 0,
#    'CA': 6,
#    'CH': 4,
#    'CL': 3,
#    'CO': 4,
#    'CR': 5,
#    'CY': 0,
#    'CZ': 4,
#    'CV': 11,
#    'DE': 4,
#    'DK': 5,
#    'EC': 6,
#    'EE': 2,
#    'EG': 2,
#    'ES': 6,
#    'FI': 8,
#    'FR': 4,
#    'GB': 4,
#    'GH': 14,
#    'GR': 2,
#    'GT': 6,
#    'HK': 4,
#    'HN': 5,
#    'HU': 3,
#    'ID': 4,
#    'IE': 4,
#    'IN': 3,
#    'IL': 24,
#    'IT': 4,
#    'JP': 6,
#    'LU': 0,
#    'LT': 2,
#    'LV': 2,
#    'MU': 13,
#    'MX': 2,
#    'MY': 4,
#    'MZ': 14,
#    'NI': 0,
#    'NL': 9,
#    'NO': 5,
#    'NZ': 4,
#    'PE': 3,
#    'PL': 2,
#    'PH': 4,
#    'PT': 4,
#    'PY': 5,
#    'RU': 2,
#    'SA': 1,
#    'SG': 5,
#    'SE': 4,
#    'SI': 25,
#    'SK': 4,
#    'TH': 4,
#    'TR': 8,
#    'TW': 6,
#    'UA': 2,
#    'UG': 14,
#    'US': 3,
#    'VE': 4,
#    'ZA': 2},
#   'display_priority': 2,
#   'logo_path': '/9ghgSC0MA082EL6HLCW3GalykFD.jpg',
#   'provider_name': 'Apple TV',
#   'provider_id': 2},
#  {'display_priorities': {'CA': 97, 'ES': 7, 'US': 8},
#   'display_priority': 8,
#   'logo_path': '/9BgaNQRMDvVlji1JBZi6tcfxpKx.jpg',
#   'provider_name': 'fuboTV',
#   'provider_id': 257},
#  {'display_priorities': {'AD': 24,
#    'AL': 26,
#    'BA': 26,
#    'BG': 19,
#    'CZ': 26,
#    'DK': 36,
#    'ES': 8,
#    'FI': 37,
#    'HU': 24,
#    'HR': 33,
#    'MK': 25,
#    'NL': 11,
#    'NO': 7,
#    'PL': 7,
#    'PT': 32,
#    'RO': 20,
#    'RS': 27,
#    'SE': 7,
#    'SI': 27,
#    'SK': 35,
#    'XK': 3},
#   'display_priority': 3,
#   'logo_path': '/gQbqEYd0C9uprYxEUqTM589qn8g.jpg',
#   'provider_name': 'SkyShowtime',
#   'provider_id': 1773},
#  {'display_priorities': {'ES': 9, 'PT': 27},
#   'display_priority': 27,
#   'logo_path': '/kO2SWXvDCHAquaUuTJBuZkTBAuU.jpg',
#   'provider_name': 'Filmin',
#   'provider_id': 63},
#  {'display_priorities': {'ES': 10, 'PT': 28},
#   'display_priority': 28,
#   'logo_path': '/ozZU2vSlyL11rFGEkq1HE0yxIJq.jpg',
#   'provider_name': 'Filmin Plus',
#   'provider_id': 64},
#  {'display_priorities': {'ES': 13},
#   'display_priority': 13,
#   'logo_path': '/oN6g8QorcoYo3mx4BulU22ghKq4.jpg',
#   'provider_name': 'Atres Player',
#   'provider_id': 62},
#  {'display_priorities': {'AE': 3,
#    'AO': 0,
#    'AR': 4,
#    'AZ': 1,
#    'AT': 7,
#    'AU': 13,
#    'BF': 0,
#    'BE': 7,
#    'BO': 20,
#    'BY': 1,
#    'BR': 15,
#    'BZ': 1,
#    'CA': 8,
#    'CH': 5,
#    'CL': 4,
#    'CO': 3,
#    'CR': 21,
#    'CY': 1,
#    'CZ': 5,
#    'DK': 6,
#    'DE': 11,
#    'EC': 9,
#    'EE': 3,
#    'EG': 4,
#    'ES': 14,
#    'FI': 9,
#    'FR': 8,
#    'GB': 15,
#    'GR': 3,
#    'GT': 21,
#    'HK': 11,
#    'HR': 3,
#    'HU': 4,
#    'HN': 20,
#    'ID': 6,
#    'IE': 7,
#    'IN': 9,
#    'IS': 4,
#    'IT': 7,
#    'JP': 8,
#    'KR': 7,
#    'LU': 1,
#    'LT': 3,
#    'LV': 3,
#    'ML': 1,
#    'MY': 5,
#    'MX': 14,
#    'NI': 1,
#    'NL': 13,
#    'NZ': 6,
#    'NO': 8,
#    'PE': 4,
#    'PG': 0,
#    'PL': 4,
#    'PH': 5,
#    'PT': 5,
#    'PY': 20,
#    'RU': 4,
#    'SA': 3,
#    'SG': 6,
#    'SE': 9,
#    'SK': 6,
#    'TH': 5,
#    'TR': 7,
#    'TW': 3,
#    'UA': 3,
#    'TZ': 18,
#    'US': 16,
#    'VE': 3,
#    'ZA': 3,
#    'ZW': 1},
#   'display_priority': 1,
#   'logo_path': '/8z7rC8uIDaTM91X0ZfkRf04ydj2.jpg',
#   'provider_name': 'Google Play Movies',
#   'provider_id': 3},
#  {'display_priorities': {'AD': 2,
#    'AL': 2,
#    'BA': 2,
#    'BB': 2,
#    'BH': 2,
#    'BM': 2,
#    'BS': 2,
#    'CI': 2,
#    'DO': 2,
#    'DZ': 2,
#    'EG': 5,
#    'ES': 15,
#    'GF': 2,
#    'GI': 2,
#    'HR': 4,
#    'IL': 2,
#    'IQ': 2,
#    'IS': 5,
#    'JM': 2,
#    'JO': 2,
#    'KW': 2,
#    'LB': 2,
#    'LI': 2,
#    'MA': 2,
#    'LY': 2,
#    'MC': 2,
#    'MD': 2,
#    'MK': 2,
#    'MT': 2,
#    'NE': 2,
#    'NG': 2,
#    'OM': 2,
#    'PA': 2,
#    'PS': 2,
#    'QA': 2,
#    'RS': 2,
#    'SA': 4,
#    'SI': 2,
#    'SV': 2,
#    'SM': 2,
#    'SK': 7,
#    'TN': 2,
#    'TW': 10,
#    'TZ': 19,
#    'UY': 4,
#    'YE': 2},
#   'display_priority': 2,
#   'logo_path': '/ozMgkAAoi6aDI5ce8KKA2k8TGvB.jpg',
#   'provider_name': 'FlixOlé',
#   'provider_id': 393},
#  {'display_priorities': {'AG': 12,
#    'AD': 27,
#    'BA': 29,
#    'AR': 61,
#    'BB': 25,
#    'BG': 22,
#    'BO': 32,
#    'BR': 7,
#    'BZ': 10,
#    'BS': 26,
#    'CL': 7,
#    'CO': 6,
#    'CR': 4,
#    'CZ': 36,
#    'DO': 32,
#    'DK': 43,
#    'EC': 5,
#    'FI': 45,
#    'ES': 16,
#    'FR': 116,
#    'GT': 4,
#    'GY': 4,
#    'HN': 32,
#    'HU': 29,
#    'HR': 36,
#    'JM': 24,
#    'LC': 11,
#    'MC': 27,
#    'ME': 7,
#    'MD': 27,
#    'MK': 28,
#    'MX': 5,
#    'NI': 14,
#    'NO': 44,
#    'PE': 7,
#    'NL': 89,
#    'PA': 32,
#    'PL': 40,
#    'PY': 31,
#    'RO': 25,
#    'PT': 62,
#    'RS': 30,
#    'SI': 30,
#    'SE': 48,
#    'SV': 32,
#    'TC': 11,
#    'SK': 40,
#    'TT': 12,
#    'US': 9,
#    'UY': 3,
#    'VE': 30,
#    'BE': 67},
#   'display_priority': 30,
#   'logo_path': '/fksCUZ9QDWZMUwL2LgMtLckROUN.jpg',
#   'provider_name': 'Max',
#   'provider_id': 1899},
#  {'display_priorities': {'AT': 12,
#    'AU': 17,
#    'BR': 16,
#    'CH': 6,
#    'CA': 23,
#    'DK': 8,
#    'DE': 32,
#    'ES': 17,
#    'FI': 10,
#    'FR': 15,
#    'GB': 18,
#    'IE': 14,
#    'IT': 22,
#    'JP': 7,
#    'MX': 13,
#    'NL': 14,
#    'NO': 9,
#    'NZ': 9,
#    'SE': 8,
#    'US': 45},
#   'display_priority': 45,
#   'logo_path': '/5vfrJQgNe9UnHVgVNAwZTy0Jo9o.jpg',
#   'provider_name': 'Microsoft Store',
#   'provider_id': 68},
#  {'display_priorities': {'AE': 4,
#    'AG': 4,
#    'AD': 5,
#    'AL': 5,
#    'AO': 2,
#    'AR': 10,
#    'AT': 18,
#    'AU': 23,
#    'BA': 5,
#    'BB': 4,
#    'BF': 2,
#    'BE': 11,
#    'BG': 4,
#    'BH': 4,
#    'BM': 4,
#    'BO': 22,
#    'BS': 4,
#    'BR': 12,
#    'BY': 4,
#    'BZ': 5,
#    'CD': 1,
#    'CH': 17,
#    'CI': 5,
#    'CA': 38,
#    'CL': 10,
#    'CM': 2,
#    'CO': 10,
#    'CR': 23,
#    'CU': 4,
#    'CY': 5,
#    'CV': 4,
#    'CZ': 6,
#    'DO': 4,
#    'DK': 9,
#    'DE': 27,
#    'DZ': 4,
#    'EC': 10,
#    'EE': 4,
#    'EG': 6,
#    'ES': 18,
#    'FI': 11,
#    'FJ': 4,
#    'FR': 22,
#    'GB': 14,
#    'GF': 4,
#    'GG': 4,
#    'GH': 4,
#    'GI': 4,
#    'GQ': 4,
#    'GR': 4,
#    'GY': 1,
#    'GT': 23,
#    'HR': 5,
#    'HK': 18,
#    'HU': 5,
#    'HN': 22,
#    'ID': 9,
#    'IL': 5,
#    'IE': 15,
#    'IN': 10,
#    'IQ': 5,
#    'IS': 6,
#    'IT': 13,
#    'JM': 4,
#    'JO': 4,
#    'JP': 9,
#    'KE': 4,
#    'KR': 8,
#    'KW': 4,
#    'LB': 5,
#    'LC': 4,
#    'LI': 4,
#    'LT': 4,
#    'LU': 6,
#    'MA': 4,
#    'LV': 4,
#    'LY': 4,
#    'MC': 4,
#    'ME': 2,
#    'MD': 4,
#    'MG': 2,
#    'ML': 3,
#    'MK': 5,
#    'MT': 5,
#    'MU': 3,
#    'MW': 1,
#    'MZ': 4,
#    'MY': 7,
#    'MX': 15,
#    'NE': 5,
#    'NG': 5,
#    'NI': 6,
#    'NL': 17,
#    'NO': 10,
#    'NZ': 10,
#    'OM': 4,
#    'PA': 4,
#    'PE': 10,
#    'PG': 2,
#    'PK': 4,
#    'PF': 4,
#    'PL': 6,
#    'PH': 8,
#    'PS': 5,
#    'PT': 10,
#    'QA': 4,
#    'RO': 3,
#    'PY': 22,
#    'RS': 5,
#    'RU': 5,
#    'SA': 5,
#    'SC': 4,
#    'SI': 5,
#    'SG': 8,
#    'SE': 10,
#    'SN': 4,
#    'SV': 4,
#    'SM': 4,
#    'SK': 8,
#    'TC': 4,
#    'TD': 3,
#    'TH': 7,
#    'TN': 4,
#    'TR': 9,
#    'TT': 4,
#    'TZ': 4,
#    'TW': 17,
#    'UA': 5,
#    'UG': 4,
#    'VA': 3,
#    'UY': 6,
#    'VE': 7,
#    'YE': 4,
#    'ZA': 6,
#    'US': 64,
#    'ZM': 4,
#    'ZW': 3},
#   'display_priority': 64,
#   'logo_path': '/fj9Y8iIMFUC6952HwxbGixTQPb7.jpg',
#   'provider_name': 'MUBI',
#   'provider_id': 11},
#  {'display_priorities': {'AT': 19,
#    'AU': 26,
#    'BG': 10,
#    'BO': 11,
#    'CH': 11,
#    'CA': 40,
#    'CR': 9,
#    'DK': 11,
#    'DE': 31,
#    'EE': 5,
#    'ES': 19,
#    'FI': 13,
#    'GB': 28,
#    'GT': 9,
#    'HN': 8,
#    'HR': 7,
#    'HK': 26,
#    'ID': 8,
#    'IE': 16,
#    'IN': 13,
#    'IT': 20,
#    'KR': 9,
#    'LT': 5,
#    'LV': 5,
#    'MY': 6,
#    'MX': 17,
#    'NL': 18,
#    'NO': 11,
#    'NZ': 13,
#    'PH': 7,
#    'PL': 12,
#    'PY': 8,
#    'RU': 6,
#    'SG': 7,
#    'SE': 11,
#    'SK': 10,
#    'TH': 6,
#    'TZ': 13,
#    'TW': 25,
#    'ZA': 7,
#    'US': 62},
#   'display_priority': 62,
#   'logo_path': '/eKVmLFHW5PeNhuR7Nedd8OIxW2M.jpg',
#   'provider_name': 'GuideDoc',
#   'provider_id': 100},
#  {'display_priorities': {'AT': 13,
#    'AU': 14,
#    'BE': 8,
#    'CH': 20,
#    'CA': 39,
#    'DK': 13,
#    'DE': 20,
#    'FI': 7,
#    'ES': 20,
#    'FR': 17,
#    'GB': 31,
#    'HU': 6,
#    'HK': 28,
#    'IE': 20,
#    'IT': 21,
#    'MX': 10,
#    'NZ': 7,
#    'NO': 13,
#    'PT': 6,
#    'RU': 8,
#    'SE': 14,
#    'TR': 2,
#    'TW': 27,
#    'US': 33},
#   'display_priority': 33,
#   'logo_path': '/rMb93u1tBeErSYLv79zSTR07UdO.jpg',
#   'provider_name': 'YouTube Premium',
#   'provider_id': 188},
#  {'display_priorities': {'AD': 8,
#    'AL': 9,
#    'AR': 11,
#    'AT': 24,
#    'AU': 36,
#    'BA': 9,
#    'BB': 6,
#    'BE': 14,
#    'BG': 5,
#    'BH': 6,
#    'BM': 6,
#    'BO': 13,
#    'BS': 6,
#    'BR': 18,
#    'CI': 7,
#    'CH': 23,
#    'CA': 53,
#    'CL': 11,
#    'CO': 11,
#    'CR': 7,
#    'CZ': 8,
#    'DO': 6,
#    'DK': 18,
#    'DZ': 6,
#    'DE': 43,
#    'EC': 11,
#    'EE': 9,
#    'EG': 10,
#    'ES': 21,
#    'FI': 17,
#    'FR': 26,
#    'GF': 6,
#    'GB': 40,
#    'GI': 6,
#    'GR': 6,
#    'GT': 7,
#    'HK': 13,
#    'HN': 4,
#    'HR': 9,
#    'HU': 8,
#    'IL': 7,
#    'ID': 17,
#    'IE': 21,
#    'IN': 21,
#    'IQ': 7,
#    'IS': 9,
#    'IT': 26,
#    'JM': 6,
#    'JO': 6,
#    'JP': 11,
#    'KR': 12,
#    'KW': 6,
#    'LB': 7,
#    'LI': 6,
#    'LT': 9,
#    'MA': 6,
#    'LV': 9,
#    'LY': 6,
#    'MC': 6,
#    'MD': 6,
#    'MK': 9,
#    'MT': 9,
#    'MX': 20,
#    'NE': 7,
#    'MY': 15,
#    'NG': 7,
#    'NL': 22,
#    'NO': 19,
#    'NZ': 20,
#    'OM': 6,
#    'PA': 6,
#    'PE': 11,
#    'PL': 9,
#    'PH': 13,
#    'PS': 7,
#    'PT': 14,
#    'PY': 6,
#    'QA': 6,
#    'RO': 4,
#    'RS': 9,
#    'RU': 9,
#    'SA': 8,
#    'SI': 9,
#    'SG': 14,
#    'SE': 19,
#    'SV': 6,
#    'SM': 6,
#    'SK': 12,
#    'TH': 13,
#    'TN': 6,
#    'TR': 10,
#    'TW': 12,
#    'TZ': 20,
#    'UY': 8,
#    'VE': 8,
#    'YE': 6,
#    'US': 51,
#    'ZA': 11},
#   'display_priority': 51,
#   'logo_path': '/oR1aNm1Qu9jQBkW4VrGPWhqbC3P.jpg',
#   'provider_name': 'Curiosity Stream',
#   'provider_id': 190},
#  {'display_priorities': {'ES': 22},
#   'display_priority': 22,
#   'logo_path': '/273VHxSrDdEwLTXJrsnE6yJMqNZ.jpg',
#   'provider_name': 'Mitele ',
#   'provider_id': 456},
#  {'display_priorities': {'AR': 18,
#    'AT': 26,
#    'AU': 35,
#    'BE': 17,
#    'BG': 7,
#    'BH': 9,
#    'BM': 9,
#    'BO': 8,
#    'BS': 9,
#    'BR': 22,
#    'CH': 24,
#    'CA': 55,
#    'CL': 14,
#    'CO': 15,
#    'CR': 12,
#    'CZ': 10,
#    'DO': 9,
#    'DK': 19,
#    'DZ': 9,
#    'DE': 44,
#    'EC': 14,
#    'EE': 11,
#    'ES': 23,
#    'FI': 19,
#    'FR': 28,
#    'GF': 9,
#    'GB': 44,
#    'GI': 9,
#    'GR': 8,
#    'GT': 12,
#    'HN': 11,
#    'HR': 12,
#    'HU': 10,
#    'ID': 18,
#    'IE': 23,
#    'IN': 24,
#    'IS': 12,
#    'IT': 27,
#    'JO': 9,
#    'JP': 13,
#    'KR': 14,
#    'KW': 9,
#    'LI': 9,
#    'LT': 11,
#    'MA': 9,
#    'LV': 11,
#    'LY': 9,
#    'MC': 9,
#    'MD': 9,
#    'MX': 27,
#    'MY': 16,
#    'NL': 24,
#    'NO': 20,
#    'NZ': 21,
#    'OM': 9,
#    'PA': 9,
#    'PE': 15,
#    'PL': 10,
#    'PH': 15,
#    'PT': 16,
#    'PY': 11,
#    'RO': 6,
#    'QA': 9,
#    'RU': 11,
#    'SG': 16,
#    'SE': 21,
#    'SV': 9,
#    'SM': 9,
#    'SK': 15,
#    'TH': 14,
#    'TN': 9,
#    'TR': 13,
#    'TW': 28,
#    'TZ': 22,
#    'UY': 12,
#    'VE': 12,
#    'YE': 9,
#    'ZA': 13,
#    'US': 132},
#   'display_priority': 132,
#   'logo_path': '/5zqbck5mo8PuVbGu2ngBUdn5Yga.jpg',
#   'provider_name': 'DOCSVILLE',
#   'provider_id': 475},
#  {'display_priorities': {'AD': 9,
#    'AL': 10,
#    'AR': 13,
#    'AT': 27,
#    'AU': 37,
#    'BA': 10,
#    'BB': 8,
#    'BE': 15,
#    'BH': 8,
#    'BM': 8,
#    'BO': 15,
#    'BS': 8,
#    'BR': 20,
#    'CI': 9,
#    'CH': 26,
#    'CA': 61,
#    'CL': 15,
#    'CO': 16,
#    'CR': 16,
#    'CZ': 9,
#    'DO': 8,
#    'DK': 20,
#    'DZ': 8,
#    'DE': 50,
#    'EC': 15,
#    'EE': 10,
#    'EG': 12,
#    'ES': 24,
#    'FI': 20,
#    'FR': 27,
#    'GF': 8,
#    'GB': 46,
#    'GI': 8,
#    'GR': 7,
#    'GT': 16,
#    'HR': 11,
#    'HN': 15,
#    'HU': 9,
#    'HK': 27,
#    'ID': 13,
#    'IL': 8,
#    'IE': 22,
#    'IN': 29,
#    'IQ': 8,
#    'IS': 11,
#    'IT': 28,
#    'JM': 8,
#    'JO': 8,
#    'JP': 12,
#    'KR': 13,
#    'KW': 8,
#    'LB': 8,
#    'LI': 8,
#    'LT': 10,
#    'MA': 8,
#    'LV': 10,
#    'LY': 8,
#    'MC': 8,
#    'MD': 8,
#    'MK': 10,
#    'MT': 10,
#    'MY': 13,
#    'NE': 9,
#    'MX': 28,
#    'NG': 9,
#    'NL': 26,
#    'NZ': 16,
#    'NO': 21,
#    'OM': 8,
#    'PA': 8,
#    'PE': 16,
#    'PL': 13,
#    'PH': 14,
#    'PS': 8,
#    'PT': 17,
#    'PY': 15,
#    'RO': 5,
#    'QA': 8,
#    'RU': 10,
#    'RS': 10,
#    'SA': 10,
#    'SI': 10,
#    'SG': 15,
#    'SE': 25,
#    'SV': 8,
#    'SM': 8,
#    'SK': 14,
#    'TH': 11,
#    'TN': 8,
#    'TR': 12,
#    'TW': 26,
#    'TZ': 24,
#    'UY': 11,
#    'VE': 10,
#    'YE': 8,
#    'ZA': 12,
#    'US': 80},
#   'display_priority': 80,
#   'logo_path': '/k2YgZyxij5RcnS1qqUYEUrJB4oQ.jpg',
#   'provider_name': 'Spamflix',
#   'provider_id': 521},
#  {'display_priorities': {'ES': 25},
#   'display_priority': 25,
#   'logo_path': '/3QQKYFUDt13Q2Zm6JM2cOjlbd27.jpg',
#   'provider_name': 'rtve',
#   'provider_id': 541},
#  {'display_priorities': {'AG': 13,
#    'AD': 26,
#    'AO': 5,
#    'AL': 28,
#    'AZ': 5,
#    'AU': 47,
#    'BA': 28,
#    'AR': 62,
#    'AT': 64,
#    'BF': 5,
#    'BB': 26,
#    'BG': 21,
#    'BE': 64,
#    'BM': 28,
#    'BO': 33,
#    'BY': 8,
#    'BZ': 11,
#    'BS': 27,
#    'CI': 27,
#    'BR': 85,
#    'CH': 50,
#    'CA': 87,
#    'CM': 5,
#    'CL': 34,
#    'CO': 35,
#    'CR': 33,
#    'CY': 9,
#    'CV': 13,
#    'CZ': 33,
#    'DO': 33,
#    'DK': 41,
#    'DE': 55,
#    'DZ': 29,
#    'EC': 33,
#    'EE': 27,
#    'ES': 26,
#    'FI': 43,
#    'FJ': 13,
#    'FR': 30,
#    'GB': 48,
#    'GF': 29,
#    'GG': 11,
#    'GH': 16,
#    'GI': 27,
#    'GQ': 14,
#    'GR': 23,
#    'GY': 5,
#    'GT': 33,
#    'HK': 39,
#    'HN': 33,
#    'HU': 26,
#    'HR': 35,
#    'IL': 27,
#    'IN': 31,
#    'ID': 40,
#    'IE': 44,
#    'IT': 29,
#    'IS': 32,
#    'IQ': 49,
#    'JM': 25,
#    'KE': 15,
#    'JP': 53,
#    'JO': 51,
#    'KR': 15,
#    'LC': 12,
#    'LB': 29,
#    'KW': 50,
#    'LI': 29,
#    'LU': 11,
#    'LT': 28,
#    'LV': 27,
#    'MA': 28,
#    'LY': 29,
#    'MC': 26,
#    'ME': 6,
#    'MG': 5,
#    'ML': 6,
#    'MD': 26,
#    'MW': 3,
#    'MK': 27,
#    'MU': 15,
#    'MT': 26,
#    'MZ': 17,
#    'MY': 32,
#    'NE': 27,
#    'NG': 30,
#    'NI': 15,
#    'MX': 78,
#    'NZ': 37,
#    'NO': 42,
#    'NL': 86,
#    'PA': 33,
#    'PG': 6,
#    'PE': 34,
#    'OM': 50,
#    'PK': 8,
#    'PF': 12,
#    'PL': 34,
#    'PH': 33,
#    'PS': 28,
#    'PY': 32,
#    'RO': 22,
#    'PT': 60,
#    'RS': 29,
#    'RU': 30,
#    'SC': 14,
#    'SI': 29,
#    'SG': 31,
#    'SN': 14,
#    'SE': 47,
#    'SV': 33,
#    'TC': 12,
#    'SM': 28,
#    'SK': 38,
#    'TD': 7,
#    'TH': 30,
#    'TT': 13,
#    'TN': 29,
#    'UA': 8,
#    'TW': 39,
#    'TZ': 32,
#    'UG': 16,
#    'XK': 5,
#    'VA': 7,
#    'UY': 32,
#    'VE': 31,
#    'YE': 28,
#    'ZW': 6,
#    'ZM': 14,
#    'ZA': 30,
#    'US': 140},
#   'display_priority': 140,
#   'logo_path': '/vLZKlXUNDcZR7ilvfY9Wr9k80FZ.jpg',
#   'provider_name': 'Plex',
#   'provider_id': 538},
#  {'display_priorities': {'AD': 14,
#    'AL': 15,
#    'AR': 20,
#    'AT': 31,
#    'AU': 38,
#    'BA': 15,
#    'BE': 20,
#    'BM': 11,
#    'BO': 6,
#    'BR': 28,
#    'CI': 11,
#    'CH': 28,
#    'CA': 63,
#    'CL': 16,
#    'CO': 17,
#    'CR': 14,
#    'CZ': 11,
#    'DK': 21,
#    'DE': 56,
#    'EC': 16,
#    'EE': 12,
#    'ES': 27,
#    'FI': 23,
#    'FR': 31,
#    'GF': 11,
#    'GB': 49,
#    'GI': 11,
#    'GR': 9,
#    'GT': 14,
#    'HN': 13,
#    'HU': 11,
#    'ID': 21,
#    'IL': 13,
#    'IE': 24,
#    'IN': 32,
#    'IQ': 15,
#    'IS': 13,
#    'IT': 30,
#    'JP': 14,
#    'KR': 16,
#    'KW': 11,
#    'LB': 15,
#    'LI': 11,
#    'LT': 12,
#    'LV': 12,
#    'MK': 14,
#    'MT': 14,
#    'MY': 17,
#    'MX': 30,
#    'NE': 11,
#    'NG': 12,
#    'NL': 27,
#    'NO': 22,
#    'NZ': 22,
#    'PE': 17,
#    'PL': 14,
#    'PH': 17,
#    'PS': 15,
#    'PT': 18,
#    'PY': 13,
#    'RO': 7,
#    'RU': 12,
#    'RS': 15,
#    'SI': 15,
#    'SG': 17,
#    'SE': 26,
#    'SM': 11,
#    'TH': 15,
#    'TN': 11,
#    'TR': 14,
#    'VE': 13,
#    'YE': 11,
#    'ZA': 14,
#    'US': 142},
#   'display_priority': 142,
#   'logo_path': '/6dET59jNU0ADysghEjl8Unuc7Ca.jpg',
#   'provider_name': 'WOW Presents Plus',
#   'provider_id': 546},
#  {'display_priorities': {'AD': 12,
#    'AL': 13,
#    'AR': 19,
#    'AT': 32,
#    'AU': 39,
#    'BA': 13,
#    'BB': 10,
#    'BE': 21,
#    'BH': 11,
#    'BM': 12,
#    'BO': 14,
#    'BS': 11,
#    'BR': 29,
#    'CH': 29,
#    'CA': 65,
#    'CL': 17,
#    'CO': 18,
#    'CR': 15,
#    'CZ': 12,
#    'DO': 11,
#    'DK': 22,
#    'DZ': 11,
#    'DE': 58,
#    'EC': 17,
#    'EE': 13,
#    'EG': 14,
#    'ES': 28,
#    'FI': 24,
#    'FR': 33,
#    'GF': 12,
#    'GB': 50,
#    'GI': 12,
#    'GR': 10,
#    'GT': 15,
#    'HK': 20,
#    'HN': 14,
#    'HR': 14,
#    'HU': 12,
#    'IL': 11,
#    'ID': 22,
#    'IE': 25,
#    'IN': 33,
#    'IQ': 13,
#    'IS': 15,
#    'IT': 31,
#    'JM': 10,
#    'JO': 11,
#    'JP': 15,
#    'KR': 17,
#    'KW': 12,
#    'LB': 13,
#    'LI': 12,
#    'LT': 13,
#    'MA': 11,
#    'LV': 13,
#    'LY': 11,
#    'MC': 11,
#    'MD': 11,
#    'MK': 12,
#    'MT': 12,
#    'MY': 18,
#    'MX': 29,
#    'NG': 10,
#    'NL': 29,
#    'NO': 23,
#    'NZ': 23,
#    'OM': 11,
#    'PA': 12,
#    'PE': 18,
#    'PL': 16,
#    'PH': 18,
#    'PS': 13,
#    'PT': 19,
#    'PY': 14,
#    'RO': 8,
#    'QA': 11,
#    'RU': 13,
#    'RS': 13,
#    'SA': 12,
#    'SI': 13,
#    'SG': 18,
#    'SE': 27,
#    'SV': 12,
#    'SM': 12,
#    'SK': 17,
#    'TH': 16,
#    'TN': 12,
#    'TR': 15,
#    'TW': 19,
#    'TZ': 26,
#    'UY': 15,
#    'VE': 14,
#    'YE': 12,
#    'ZA': 15,
#    'US': 143},
#   'display_priority': 143,
#   'logo_path': '/mSH24WQcRDJ2fsL5iucXqqRnSRb.jpg',
#   'provider_name': 'Magellan TV',
#   'provider_id': 551},
#  {'display_priorities': {'AD': 13,
#    'AL': 14,
#    'AR': 21,
#    'AT': 33,
#    'AU': 40,
#    'BA': 14,
#    'BB': 11,
#    'BE': 22,
#    'BG': 6,
#    'BH': 12,
#    'BO': 7,
#    'BM': 13,
#    'BS': 12,
#    'BR': 30,
#    'CI': 10,
#    'CH': 30,
#    'CA': 66,
#    'CL': 19,
#    'CO': 19,
#    'CR': 13,
#    'CZ': 13,
#    'DO': 12,
#    'DK': 23,
#    'DZ': 12,
#    'DE': 59,
#    'EC': 18,
#    'EE': 14,
#    'EG': 15,
#    'ES': 29,
#    'FI': 25,
#    'FR': 34,
#    'GF': 13,
#    'GB': 51,
#    'GI': 13,
#    'GR': 11,
#    'GT': 13,
#    'HN': 12,
#    'HK': 24,
#    'HR': 15,
#    'HU': 13,
#    'IL': 12,
#    'ID': 23,
#    'IE': 27,
#    'IN': 34,
#    'IQ': 14,
#    'IS': 16,
#    'IT': 32,
#    'JM': 11,
#    'JO': 12,
#    'JP': 16,
#    'KR': 18,
#    'KW': 13,
#    'LB': 14,
#    'LI': 13,
#    'LT': 15,
#    'MA': 12,
#    'LV': 14,
#    'LY': 12,
#    'MC': 12,
#    'MD': 12,
#    'MK': 13,
#    'MT': 13,
#    'NE': 10,
#    'MY': 19,
#    'MX': 31,
#    'NG': 11,
#    'NL': 30,
#    'NO': 24,
#    'NZ': 24,
#    'OM': 12,
#    'PA': 13,
#    'PE': 19,
#    'PL': 17,
#    'PH': 19,
#    'PS': 14,
#    'PT': 20,
#    'PY': 12,
#    'RO': 9,
#    'QA': 12,
#    'RU': 14,
#    'RS': 14,
#    'SA': 13,
#    'SI': 14,
#    'SG': 19,
#    'SE': 28,
#    'SV': 13,
#    'SM': 13,
#    'SK': 18,
#    'TH': 17,
#    'TN': 13,
#    'TR': 16,
#    'TW': 23,
#    'TZ': 27,
#    'UY': 16,
#    'VE': 15,
#    'YE': 13,
#    'ZA': 16,
#    'US': 144},
#   'display_priority': 144,
#   'logo_path': '/6IYZ4NjwPikxN7J9cfSmuyeHeMm.jpg',
#   'provider_name': 'BroadwayHD',
#   'provider_id': 554},
#  {'display_priorities': {'AD': 16,
#    'AL': 17,
#    'AR': 22,
#    'AT': 34,
#    'AU': 41,
#    'BA': 17,
#    'BB': 13,
#    'BE': 23,
#    'BH': 14,
#    'BM': 15,
#    'BO': 16,
#    'BS': 14,
#    'BR': 31,
#    'CI': 13,
#    'CH': 31,
#    'CA': 67,
#    'CL': 18,
#    'CO': 20,
#    'CR': 17,
#    'CZ': 14,
#    'DO': 14,
#    'DK': 24,
#    'DZ': 14,
#    'DE': 60,
#    'EC': 19,
#    'EE': 15,
#    'EG': 17,
#    'ES': 30,
#    'FI': 26,
#    'FR': 35,
#    'GF': 15,
#    'GB': 52,
#    'GI': 15,
#    'GR': 12,
#    'GT': 17,
#    'HK': 19,
#    'HN': 16,
#    'HR': 18,
#    'HU': 14,
#    'ID': 24,
#    'IL': 15,
#    'IE': 28,
#    'IN': 35,
#    'IQ': 17,
#    'IS': 19,
#    'IT': 33,
#    'JM': 13,
#    'JP': 17,
#    'JO': 14,
#    'KR': 19,
#    'KW': 15,
#    'LB': 17,
#    'LI': 15,
#    'LT': 16,
#    'MA': 14,
#    'LV': 15,
#    'LY': 14,
#    'MC': 14,
#    'MD': 14,
#    'MK': 16,
#    'MT': 16,
#    'MY': 20,
#    'MX': 32,
#    'NE': 13,
#    'NG': 14,
#    'NL': 31,
#    'NO': 25,
#    'NZ': 25,
#    'OM': 14,
#    'PA': 15,
#    'PE': 20,
#    'PL': 18,
#    'PH': 20,
#    'PS': 17,
#    'PT': 21,
#    'PY': 16,
#    'RO': 10,
#    'QA': 14,
#    'SA': 15,
#    'RS': 17,
#    'SI': 17,
#    'SG': 20,
#    'SE': 29,
#    'SV': 15,
#    'SM': 15,
#    'SK': 21,
#    'TH': 18,
#    'TN': 15,
#    'TR': 17,
#    'TW': 18,
#    'TZ': 25,
#    'UY': 18,
#    'VE': 16,
#    'YE': 15,
#    'ZA': 17,
#    'US': 146},
#   'display_priority': 146,
#   'logo_path': '/eUBxtrqO26wAJfYOZJOzhQEo3mm.jpg',
#   'provider_name': 'Filmzie',
#   'provider_id': 559},
#  {'display_priorities': {'AD': 15,
#    'AL': 16,
#    'AR': 23,
#    'AT': 35,
#    'AU': 42,
#    'BA': 16,
#    'BB': 12,
#    'BE': 24,
#    'BG': 8,
#    'BH': 13,
#    'BO': 9,
#    'BM': 14,
#    'BS': 13,
#    'BR': 33,
#    'CI': 12,
#    'CH': 32,
#    'CA': 68,
#    'CL': 20,
#    'CO': 21,
#    'CR': 11,
#    'CZ': 15,
#    'DO': 13,
#    'DK': 25,
#    'DZ': 13,
#    'DE': 62,
#    'EC': 20,
#    'EE': 16,
#    'ES': 31,
#    'FI': 27,
#    'FR': 36,
#    'GF': 14,
#    'GB': 56,
#    'GI': 14,
#    'GR': 13,
#    'GT': 11,
#    'HN': 10,
#    'HK': 21,
#    'HR': 16,
#    'HU': 15,
#    'IL': 14,
#    'ID': 25,
#    'IE': 29,
#    'IN': 38,
#    'IQ': 16,
#    'IS': 17,
#    'IT': 34,
#    'JM': 12,
#    'JO': 13,
#    'JP': 18,
#    'KR': 20,
#    'KW': 14,
#    'LB': 16,
#    'LI': 14,
#    'LT': 17,
#    'MA': 13,
#    'LV': 16,
#    'LY': 13,
#    'MC': 13,
#    'MD': 13,
#    'MK': 15,
#    'MT': 15,
#    'NE': 12,
#    'MY': 21,
#    'MX': 33,
#    'NG': 13,
#    'NL': 33,
#    'NZ': 26,
#    'NO': 27,
#    'OM': 13,
#    'PA': 14,
#    'PE': 21,
#    'PL': 19,
#    'PH': 21,
#    'PS': 16,
#    'PT': 22,
#    'PY': 10,
#    'RO': 11,
#    'QA': 13,
#    'RS': 16,
#    'RU': 16,
#    'SI': 16,
#    'SG': 21,
#    'SE': 30,
#    'SV': 14,
#    'SM': 14,
#    'SK': 19,
#    'TH': 19,
#    'TN': 14,
#    'TR': 18,
#    'TW': 20,
#    'TZ': 21,
#    'UY': 17,
#    'VE': 17,
#    'YE': 14,
#    'ZA': 18,
#    'US': 87},
#   'display_priority': 87,
#   'logo_path': '/x6nRFzF32hCzMHaVM4RHRo7lsgS.jpg',
#   'provider_name': 'Dekkoo',
#   'provider_id': 444},
#  {'display_priorities': {'AD': 17,
#    'AL': 18,
#    'AR': 24,
#    'AT': 37,
#    'AU': 44,
#    'BA': 18,
#    'BB': 14,
#    'BE': 25,
#    'BG': 11,
#    'BH': 15,
#    'BM': 16,
#    'BO': 12,
#    'BS': 15,
#    'BR': 34,
#    'CI': 14,
#    'CH': 33,
#    'CA': 70,
#    'CL': 21,
#    'CO': 22,
#    'CR': 8,
#    'CZ': 16,
#    'DO': 15,
#    'DK': 26,
#    'DZ': 15,
#    'DE': 64,
#    'EC': 21,
#    'EE': 17,
#    'EG': 18,
#    'ES': 32,
#    'FI': 28,
#    'FR': 39,
#    'GF': 16,
#    'GB': 57,
#    'GI': 16,
#    'GR': 14,
#    'GT': 8,
#    'HN': 7,
#    'HK': 25,
#    'HR': 19,
#    'HU': 16,
#    'IL': 16,
#    'ID': 26,
#    'IE': 30,
#    'IN': 39,
#    'IQ': 18,
#    'IS': 20,
#    'IT': 35,
#    'JM': 14,
#    'JO': 15,
#    'JP': 19,
#    'KR': 21,
#    'KW': 16,
#    'LB': 18,
#    'LI': 16,
#    'LT': 18,
#    'MA': 15,
#    'LV': 17,
#    'LY': 15,
#    'MC': 15,
#    'MD': 15,
#    'MK': 17,
#    'MT': 17,
#    'MY': 22,
#    'NE': 14,
#    'MX': 34,
#    'NG': 15,
#    'NL': 34,
#    'NZ': 27,
#    'NO': 28,
#    'OM': 15,
#    'PA': 16,
#    'PE': 22,
#    'PL': 20,
#    'PH': 22,
#    'PS': 18,
#    'PT': 23,
#    'PY': 7,
#    'RO': 12,
#    'QA': 15,
#    'RU': 17,
#    'SA': 16,
#    'RS': 18,
#    'SI': 18,
#    'SG': 22,
#    'SE': 31,
#    'SV': 16,
#    'SM': 16,
#    'SK': 22,
#    'TH': 20,
#    'TN': 16,
#    'TR': 19,
#    'TZ': 12,
#    'TW': 24,
#    'UY': 19,
#    'VE': 18,
#    'YE': 16,
#    'ZA': 19,
#    'US': 149},
#   'display_priority': 149,
#   'logo_path': '/aRPDQvVcpeY07sjI6lAALMCL0ti.jpg',
#   'provider_name': 'True Story',
#   'provider_id': 567},
#  {'display_priorities': {'AR': 25,
#    'AT': 36,
#    'AU': 45,
#    'BB': 15,
#    'BG': 9,
#    'BE': 26,
#    'BH': 16,
#    'BO': 10,
#    'BM': 17,
#    'BS': 16,
#    'BR': 35,
#    'CH': 34,
#    'CA': 71,
#    'CL': 22,
#    'CO': 23,
#    'CR': 10,
#    'CZ': 17,
#    'DO': 16,
#    'DK': 27,
#    'DE': 65,
#    'EC': 22,
#    'EE': 18,
#    'ES': 33,
#    'FI': 29,
#    'FR': 40,
#    'GF': 17,
#    'GB': 58,
#    'GI': 17,
#    'GR': 15,
#    'GT': 10,
#    'HK': 12,
#    'HN': 9,
#    'HR': 20,
#    'HU': 17,
#    'ID': 27,
#    'IE': 31,
#    'IN': 40,
#    'IS': 21,
#    'IT': 36,
#    'JM': 15,
#    'JO': 16,
#    'JP': 20,
#    'KR': 22,
#    'KW': 17,
#    'LI': 17,
#    'LT': 19,
#    'LV': 18,
#    'MC': 16,
#    'MD': 16,
#    'MY': 23,
#    'MX': 36,
#    'NL': 35,
#    'NZ': 28,
#    'NO': 29,
#    'OM': 16,
#    'PA': 17,
#    'PE': 23,
#    'PL': 21,
#    'PH': 23,
#    'PT': 24,
#    'PY': 9,
#    'RO': 13,
#    'QA': 16,
#    'RU': 18,
#    'SA': 17,
#    'SG': 23,
#    'SE': 32,
#    'SV': 17,
#    'SM': 17,
#    'SK': 23,
#    'TH': 21,
#    'TR': 20,
#    'TW': 11,
#    'UY': 20,
#    'VE': 19,
#    'YE': 17,
#    'ZA': 20,
#    'US': 151},
#   'display_priority': 151,
#   'logo_path': '/vbXJBJVv3u3YWt6ml0l0ldDblXT.jpg',
#   'provider_name': 'DocAlliance Films',
#   'provider_id': 569},
#  {'display_priorities': {'AD': 19,
#    'AL': 20,
#    'AR': 27,
#    'AT': 39,
#    'AU': 46,
#    'BA': 20,
#    'BB': 16,
#    'BE': 28,
#    'BH': 17,
#    'BM': 18,
#    'BO': 17,
#    'BS': 17,
#    'BR': 37,
#    'CI': 16,
#    'CH': 35,
#    'CA': 72,
#    'CL': 23,
#    'CO': 24,
#    'CR': 18,
#    'CZ': 18,
#    'DO': 17,
#    'DK': 28,
#    'DZ': 16,
#    'DE': 66,
#    'EC': 23,
#    'EE': 19,
#    'EG': 19,
#    'ES': 34,
#    'FI': 30,
#    'FR': 41,
#    'GF': 18,
#    'GB': 59,
#    'GI': 18,
#    'GR': 16,
#    'GT': 18,
#    'HK': 17,
#    'HN': 17,
#    'HR': 21,
#    'HU': 18,
#    'IN': 18,
#    'IL': 18,
#    'ID': 29,
#    'IE': 32,
#    'IQ': 20,
#    'IS': 22,
#    'IT': 37,
#    'JM': 16,
#    'JO': 17,
#    'JP': 21,
#    'KR': 23,
#    'KW': 18,
#    'LB': 20,
#    'LI': 18,
#    'LT': 20,
#    'MA': 16,
#    'LV': 19,
#    'LY': 16,
#    'MC': 17,
#    'MD': 17,
#    'MK': 19,
#    'MT': 19,
#    'MY': 24,
#    'NE': 16,
#    'MX': 37,
#    'NG': 17,
#    'NL': 36,
#    'NZ': 29,
#    'NO': 31,
#    'OM': 17,
#    'PA': 18,
#    'PE': 24,
#    'PL': 22,
#    'PH': 24,
#    'PS': 20,
#    'PT': 25,
#    'PY': 17,
#    'RO': 14,
#    'QA': 17,
#    'SA': 18,
#    'RS': 20,
#    'RU': 21,
#    'SI': 20,
#    'SG': 24,
#    'SE': 33,
#    'SV': 18,
#    'SM': 18,
#    'SK': 24,
#    'TH': 22,
#    'TN': 17,
#    'TR': 21,
#    'TW': 16,
#    'TZ': 29,
#    'UY': 21,
#    'VE': 20,
#    'YE': 18,
#    'ZA': 21,
#    'US': 153},
#   'display_priority': 153,
#   'logo_path': '/u7dwMceEbjxd1N3TLEUBILSK2x6.jpg',
#   'provider_name': 'Hoichoi',
#   'provider_id': 315},
#  {'display_priorities': {'AT': 3,
#    'AU': 12,
#    'BE': 49,
#    'BR': 14,
#    'CA': 59,
#    'DE': 8,
#    'ES': 35,
#    'GB': 7,
#    'FR': 42,
#    'IN': 44,
#    'IT': 38,
#    'JP': 5,
#    'MX': 7,
#    'NL': 37,
#    'PL': 30,
#    'SE': 43,
#    'US': 15,
#    'IE': 46},
#   'display_priority': 15,
#   'logo_path': '/seGSXajazLMCKGB5hnRCidtjay1.jpg',
#   'provider_name': 'Amazon Video',
#   'provider_id': 10},
#  {'display_priorities': {'AR': 28,
#    'AT': 40,
#    'BO': 23,
#    'BR': 38,
#    'CH': 37,
#    'CL': 24,
#    'CO': 25,
#    'CA': 121,
#    'CR': 24,
#    'CZ': 19,
#    'DO': 19,
#    'DK': 35,
#    'DE': 67,
#    'EC': 24,
#    'ES': 36,
#    'FR': 43,
#    'GB': 75,
#    'GT': 24,
#    'HN': 23,
#    'IT': 39,
#    'MX': 38,
#    'NI': 3,
#    'NO': 37,
#    'PA': 20,
#    'PE': 25,
#    'PY': 23,
#    'SE': 39,
#    'SV': 20,
#    'UY': 23,
#    'VE': 21,
#    'US': 81},
#   'display_priority': 81,
#   'logo_path': '/dB8G41Q6tSL5NBisrIeqByfepBc.jpg',
#   'provider_name': 'Pluto TV',
#   'provider_id': 300},
#  {'display_priorities': {'AG': 6,
#    'AE': 10,
#    'AD': 20,
#    'AL': 21,
#    'AR': 29,
#    'AT': 41,
#    'AU': 48,
#    'BA': 21,
#    'BB': 20,
#    'BG': 13,
#    'BE': 30,
#    'BH': 21,
#    'BM': 22,
#    'BO': 24,
#    'BR': 39,
#    'CI': 19,
#    'CH': 38,
#    'CA': 88,
#    'CL': 25,
#    'CO': 26,
#    'CR': 25,
#    'CU': 6,
#    'CV': 6,
#    'CZ': 20,
#    'DO': 21,
#    'DK': 31,
#    'DZ': 20,
#    'DE': 69,
#    'EC': 25,
#    'EE': 20,
#    'EG': 25,
#    'ES': 38,
#    'FI': 33,
#    'FJ': 6,
#    'FR': 44,
#    'GF': 22,
#    'GG': 6,
#    'GH': 6,
#    'GB': 76,
#    'GI': 22,
#    'GQ': 6,
#    'GR': 17,
#    'GT': 25,
#    'HN': 24,
#    'HK': 33,
#    'HU': 19,
#    'HR': 27,
#    'IL': 19,
#    'ID': 30,
#    'IE': 34,
#    'IN': 42,
#    'IQ': 21,
#    'IS': 26,
#    'IT': 40,
#    'JM': 19,
#    'JP': 22,
#    'JO': 21,
#    'KE': 6,
#    'KR': 24,
#    'LC': 6,
#    'KW': 22,
#    'LB': 21,
#    'LI': 22,
#    'LT': 21,
#    'LV': 20,
#    'MA': 20,
#    'LY': 20,
#    'MC': 21,
#    'MD': 20,
#    'MU': 5,
#    'MK': 20,
#    'MT': 20,
#    'MZ': 6,
#    'MY': 26,
#    'NE': 19,
#    'MX': 39,
#    'NG': 20,
#    'NL': 40,
#    'NZ': 30,
#    'NO': 33,
#    'OM': 21,
#    'PA': 22,
#    'PE': 26,
#    'PF': 6,
#    'PL': 24,
#    'PH': 25,
#    'PS': 21,
#    'PT': 26,
#    'PY': 24,
#    'RO': 15,
#    'QA': 21,
#    'RS': 21,
#    'RU': 23,
#    'SA': 24,
#    'SC': 6,
#    'SI': 21,
#    'SN': 6,
#    'SG': 26,
#    'SE': 35,
#    'SV': 22,
#    'TC': 6,
#    'SM': 22,
#    'SK': 30,
#    'TH': 24,
#    'TT': 6,
#    'TN': 21,
#    'TR': 22,
#    'TZ': 6,
#    'TW': 33,
#    'UG': 6,
#    'VA': 5,
#    'UY': 25,
#    'VE': 22,
#    'YE': 22,
#    'ZM': 6,
#    'ZA': 22,
#    'US': 159},
#   'display_priority': 159,
#   'logo_path': '/fwx5Ed64TkfWiRH1SOSkc4781Ts.jpg',
#   'provider_name': 'Eventive',
#   'provider_id': 677},
#  {'display_priorities': {'AE': 0,
#    'AD': 0,
#    'AG': 0,
#    'AL': 0,
#    'AO': 4,
#    'AR': 1,
#    'AT': 0,
#    'AU': 1,
#    'AZ': 2,
#    'BA': 0,
#    'BB': 0,
#    'BE': 1,
#    'BG': 0,
#    'BH': 0,
#    'BM': 0,
#    'BO': 0,
#    'BR': 2,
#    'BS': 0,
#    'BY': 6,
#    'BZ': 7,
#    'CA': 0,
#    'CH': 0,
#    'CI': 0,
#    'CL': 1,
#    'CO': 2,
#    'CM': 4,
#    'CR': 0,
#    'CU': 0,
#    'CV': 0,
#    'CZ': 1,
#    'CY': 7,
#    'DE': 0,
#    'DK': 1,
#    'DO': 0,
#    'DZ': 0,
#    'EC': 0,
#    'EE': 0,
#    'EG': 0,
#    'ES': 40,
#    'FI': 1,
#    'FJ': 0,
#    'FR': 1,
#    'GB': 0,
#    'GF': 0,
#    'GG': 0,
#    'GH': 0,
#    'GI': 0,
#    'GQ': 0,
#    'GR': 0,
#    'GT': 0,
#    'HK': 1,
#    'HN': 0,
#    'HR': 0,
#    'HU': 1,
#    'ID': 0,
#    'IE': 0,
#    'IL': 0,
#    'IN': 0,
#    'IQ': 0,
#    'IT': 1,
#    'IS': 0,
#    'JM': 0,
#    'JP': 0,
#    'JO': 0,
#    'KE': 0,
#    'KR': 0,
#    'KW': 0,
#    'LB': 0,
#    'LC': 0,
#    'LI': 0,
#    'LT': 0,
#    'LU': 8,
#    'MA': 0,
#    'LV': 0,
#    'LY': 0,
#    'MC': 0,
#    'ME': 4,
#    'MD': 0,
#    'MG': 4,
#    'MK': 0,
#    'MT': 0,
#    'ML': 5,
#    'MU': 0,
#    'MX': 8,
#    'MZ': 0,
#    'MY': 1,
#    'NE': 0,
#    'NG': 0,
#    'NL': 0,
#    'NI': 11,
#    'NO': 1,
#    'NZ': 1,
#    'OM': 0,
#    'PA': 0,
#    'PE': 2,
#    'PK': 0,
#    'PF': 0,
#    'PL': 1,
#    'PH': 0,
#    'PS': 0,
#    'PT': 1,
#    'PY': 0,
#    'QA': 0,
#    'RO': 1,
#    'RS': 0,
#    'SA': 0,
#    'SC': 0,
#    'SI': 0,
#    'SG': 0,
#    'SE': 1,
#    'SN': 0,
#    'SV': 0,
#    'SK': 1,
#    'SM': 0,
#    'TC': 0,
#    'TH': 1,
#    'TD': 5,
#    'TN': 0,
#    'TR': 3,
#    'TT': 0,
#    'TW': 0,
#    'TZ': 0,
#    'UA': 0,
#    'UG': 0,
#    'US': 7,
#    'UY': 0,
#    'VE': 0,
#    'YE': 0,
#    'ZA': 0,
#    'ZM': 0,
#    'ZW': 5},
#   'display_priority': 5,
#   'logo_path': '/pbpMk2JmcoNnQwx5JGpXngfoWtp.jpg',
#   'provider_name': 'Netflix',
#   'provider_id': 8},
#  {'display_priorities': {'AU': 81,
#    'BR': 98,
#    'CL': 42,
#    'CO': 43,
#    'DE': 35,
#    'ES': 41,
#    'FR': 47,
#    'GB': 37,
#    'IN': 92,
#    'IT': 51,
#    'MX': 95,
#    'US': 94},
#   'display_priority': 94,
#   'logo_path': '/a4IDLKjvP5gvq7tNlg2Xw5YyEkI.jpg',
#   'provider_name': 'MUBI Amazon Channel',
#   'provider_id': 201},
#  {'display_priorities': {'AU': 83, 'CA': 80, 'DE': 120, 'ES': 42, 'GB': 109},
#   'display_priority': 109,
#   'logo_path': '/d0KmcInHpiF44ahOLrXCQATEFmD.jpg',
#   'provider_name': 'OUTtv Amazon Channel',
#   'provider_id': 607},
#  {'display_priorities': {'AU': 28,
#    'CA': 28,
#    'ES': 43,
#    'GB': 55,
#    'MX': 41,
#    'US': 96},
#   'display_priority': 96,
#   'logo_path': '/1wYmvbAuVZz2JnKvYfYN8Qolnb.jpg',
#   'provider_name': 'AcornTV Amazon Channel',
#   'provider_id': 196},
#  {'display_priorities': {'ES': 44},
#   'display_priority': 44,
#   'logo_path': '/2GQVxfaiWA4n93I7sJDJf1b6NqS.jpg',
#   'provider_name': 'FlixOlé Amazon Channel',
#   'provider_id': 684},
#  {'display_priorities': {'ES': 45},
#   'display_priority': 45,
#   'logo_path': '/32R4lsqOPclNhb3qV613J8T8mdL.jpg',
#   'provider_name': 'TVCortos Amazon Channel',
#   'provider_id': 689},
#  {'display_priorities': {'AG': 8,
#    'AE': 11,
#    'AD': 21,
#    'AL': 22,
#    'AR': 30,
#    'AT': 43,
#    'AU': 49,
#    'BA': 22,
#    'BB': 21,
#    'BG': 14,
#    'BE': 31,
#    'BH': 22,
#    'BM': 23,
#    'BO': 25,
#    'BS': 21,
#    'BR': 43,
#    'CI': 20,
#    'CH': 39,
#    'CA': 89,
#    'CL': 26,
#    'CO': 27,
#    'CR': 26,
#    'CU': 8,
#    'CV': 8,
#    'CZ': 21,
#    'DO': 22,
#    'DK': 32,
#    'DZ': 21,
#    'EC': 26,
#    'DE': 75,
#    'EE': 21,
#    'EG': 26,
#    'FI': 34,
#    'ES': 46,
#    'FJ': 8,
#    'FR': 49,
#    'GF': 23,
#    'GG': 9,
#    'GH': 7,
#    'GB': 78,
#    'GI': 23,
#    'GQ': 7,
#    'GR': 18,
#    'GT': 26,
#    'HN': 25,
#    'HK': 34,
#    'HU': 20,
#    'HR': 28,
#    'IL': 20,
#    'ID': 31,
#    'IE': 35,
#    'IN': 45,
#    'IQ': 22,
#    'IS': 27,
#    'IT': 42,
#    'JM': 20,
#    'JP': 23,
#    'JO': 22,
#    'KE': 7,
#    'KR': 25,
#    'LC': 8,
#    'KW': 23,
#    'LB': 22,
#    'LI': 23,
#    'LT': 22,
#    'LV': 21,
#    'MA': 21,
#    'LY': 21,
#    'MC': 22,
#    'MD': 21,
#    'MK': 21,
#    'MU': 9,
#    'MT': 21,
#    'MZ': 7,
#    'MY': 27,
#    'NE': 20,
#    'MX': 42,
#    'NG': 22,
#    'NL': 42,
#    'NZ': 31,
#    'NO': 34,
#    'OM': 22,
#    'PA': 23,
#    'PE': 27,
#    'PK': 6,
#    'PF': 8,
#    'PL': 25,
#    'PH': 26,
#    'PS': 22,
#    'PT': 29,
#    'PY': 25,
#    'RO': 16,
#    'QA': 22,
#    'RS': 22,
#    'RU': 24,
#    'SA': 25,
#    'SC': 10,
#    'SI': 22,
#    'SN': 7,
#    'SG': 27,
#    'SE': 36,
#    'SV': 23,
#    'TC': 8,
#    'SM': 23,
#    'SK': 31,
#    'TH': 25,
#    'TT': 8,
#    'TN': 22,
#    'TR': 23,
#    'TZ': 9,
#    'TW': 34,
#    'UG': 7,
#    'XK': 2,
#    'VA': 6,
#    'UY': 26,
#    'VE': 23,
#    'YE': 23,
#    'ZM': 7,
#    'ZA': 23,
#    'US': 158},
#   'display_priority': 158,
#   'logo_path': '/uauVx3dGWt0GICqdMCBYJObd3Mo.jpg',
#   'provider_name': 'Cultpix',
#   'provider_id': 692},
#  {'display_priorities': {'AG': 7,
#    'AE': 12,
#    'AL': 24,
#    'AO': 3,
#    'AZ': 0,
#    'AR': 31,
#    'AT': 44,
#    'AU': 50,
#    'BF': 3,
#    'BB': 22,
#    'BG': 15,
#    'BE': 32,
#    'BH': 23,
#    'BM': 24,
#    'BO': 26,
#    'BY': 5,
#    'BZ': 6,
#    'BS': 22,
#    'BR': 44,
#    'CI': 22,
#    'CH': 40,
#    'CM': 3,
#    'CA': 90,
#    'CL': 27,
#    'CO': 28,
#    'CR': 27,
#    'CU': 7,
#    'CY': 6,
#    'CV': 7,
#    'CZ': 23,
#    'DO': 23,
#    'DK': 33,
#    'DZ': 23,
#    'EC': 27,
#    'DE': 76,
#    'EE': 22,
#    'EG': 27,
#    'FI': 35,
#    'ES': 47,
#    'FJ': 7,
#    'FR': 51,
#    'GG': 7,
#    'GF': 26,
#    'GH': 9,
#    'GB': 79,
#    'GI': 24,
#    'GQ': 9,
#    'GR': 19,
#    'GY': 2,
#    'GT': 27,
#    'HN': 26,
#    'HK': 36,
#    'HU': 21,
#    'HR': 29,
#    'ID': 32,
#    'IE': 36,
#    'IN': 46,
#    'IQ': 24,
#    'IS': 28,
#    'IT': 44,
#    'JM': 21,
#    'JP': 24,
#    'JO': 23,
#    'KE': 10,
#    'KR': 26,
#    'LC': 7,
#    'KW': 24,
#    'LB': 24,
#    'LI': 24,
#    'LU': 7,
#    'LT': 23,
#    'LV': 22,
#    'MA': 22,
#    'LY': 23,
#    'MC': 23,
#    'ME': 3,
#    'MG': 3,
#    'ML': 4,
#    'MD': 22,
#    'MU': 7,
#    'MW': 2,
#    'MK': 23,
#    'MZ': 9,
#    'MY': 28,
#    'NE': 22,
#    'MX': 43,
#    'NI': 7,
#    'NG': 25,
#    'NL': 44,
#    'NZ': 32,
#    'NO': 35,
#    'OM': 23,
#    'PA': 24,
#    'PE': 28,
#    'PG': 3,
#    'PK': 7,
#    'PF': 7,
#    'PL': 26,
#    'PH': 27,
#    'PS': 24,
#    'PT': 30,
#    'PY': 26,
#    'RO': 17,
#    'QA': 23,
#    'RS': 25,
#    'RU': 25,
#    'SA': 26,
#    'SC': 8,
#    'SN': 9,
#    'SG': 28,
#    'SE': 37,
#    'SV': 24,
#    'TC': 7,
#    'SM': 24,
#    'SK': 32,
#    'TD': 4,
#    'TH': 26,
#    'TT': 7,
#    'TN': 23,
#    'TR': 23,
#    'UA': 6,
#    'TZ': 17,
#    'TW': 36,
#    'UG': 9,
#    'UY': 28,
#    'VE': 24,
#    'YE': 24,
#    'ZM': 9,
#    'ZW': 4,
#    'ZA': 24,
#    'US': 160},
#   'display_priority': 160,
#   'logo_path': '/fbveJTcro9Xw2KuPIIoPPePHiwy.jpg',
#   'provider_name': 'FilmBox+',
#   'provider_id': 701},
#  {'display_priorities': {'ES': 48},
#   'display_priority': 48,
#   'logo_path': '/8vES2nJNwOF57muvqLByDLm6snp.jpg',
#   'provider_name': 'Acontra Plus',
#   'provider_id': 1717},
#  {'display_priorities': {'ES': 53},
#   'display_priority': 53,
#   'logo_path': '/yISpVXhf6axqiHh6lBvJ8RRrZ8v.jpg',
#   'provider_name': 'Planet Horror Amazon Channel',
#   'provider_id': 1740},
#  {'display_priorities': {'ES': 54},
#   'display_priority': 54,
#   'logo_path': '/tM1HabyA45cnckBEhLS7hAVga5g.jpg',
#   'provider_name': 'Dizi Amazon Channel',
#   'provider_id': 1741},
#  {'display_priorities': {'ES': 55},
#   'display_priority': 55,
#   'logo_path': '/tGvAD4O9obFP3DfOrDn8NaRQ6eT.jpg',
#   'provider_name': 'Acontra Plus Amazon Channel',
#   'provider_id': 1742},
#  {'display_priorities': {'ES': 56},
#   'display_priority': 56,
#   'logo_path': '/aJECXkHekrkuRZ7ABF5YR9DVDd8.jpg',
#   'provider_name': 'Historia y Actualidad Amazon Channel',
#   'provider_id': 1743},
#  {'display_priorities': {'AG': 9,
#    'AE': 16,
#    'AD': 23,
#    'AL': 25,
#    'AR': 32,
#    'AT': 49,
#    'AU': 51,
#    'BA': 25,
#    'BB': 23,
#    'BE': 33,
#    'BG': 17,
#    'BH': 25,
#    'BM': 25,
#    'BO': 27,
#    'BS': 23,
#    'BR': 45,
#    'CI': 25,
#    'CH': 44,
#    'CL': 28,
#    'CA': 107,
#    'CO': 29,
#    'CR': 28,
#    'CV': 9,
#    'CZ': 24,
#    'DO': 26,
#    'DK': 37,
#    'DZ': 27,
#    'EC': 28,
#    'EE': 24,
#    'DE': 97,
#    'EG': 32,
#    'FI': 38,
#    'ES': 60,
#    'FJ': 9,
#    'GG': 8,
#    'GF': 27,
#    'FR': 69,
#    'GH': 12,
#    'GB': 93,
#    'GI': 25,
#    'GQ': 12,
#    'GT': 28,
#    'HN': 27,
#    'HK': 37,
#    'HU': 22,
#    'HR': 32,
#    'IL': 23,
#    'ID': 33,
#    'IE': 37,
#    'IN': 47,
#    'IQ': 26,
#    'IS': 30,
#    'IT': 60,
#    'JM': 22,
#    'JP': 25,
#    'JO': 25,
#    'KE': 13,
#    'KR': 27,
#    'LC': 9,
#    'KW': 26,
#    'LB': 26,
#    'LI': 26,
#    'LT': 25,
#    'LV': 24,
#    'MA': 26,
#    'LY': 27,
#    'MC': 24,
#    'MD': 23,
#    'MU': 11,
#    'MK': 24,
#    'MT': 23,
#    'MZ': 12,
#    'MY': 29,
#    'NE': 25,
#    'MX': 44,
#    'NG': 28,
#    'NL': 45,
#    'NZ': 33,
#    'NO': 38,
#    'OM': 25,
#    'PA': 26,
#    'PE': 29,
#    'PF': 9,
#    'PL': 27,
#    'PH': 28,
#    'PS': 26,
#    'PT': 31,
#    'RO': 18,
#    'QA': 25,
#    'RS': 26,
#    'RU': 26,
#    'SA': 30,
#    'SC': 12,
#    'SI': 26,
#    'SG': 29,
#    'SN': 12,
#    'SE': 40,
#    'SV': 25,
#    'TC': 9,
#    'SM': 26,
#    'SK': 34,
#    'TH': 27,
#    'TT': 9,
#    'TR': 24,
#    'TN': 27,
#    'TZ': 11,
#    'TW': 37,
#    'UG': 12,
#    'UY': 29,
#    'VE': 25,
#    'YE': 26,
#    'ZM': 12,
#    'ZA': 27,
#    'US': 173},
#   'display_priority': 173,
#   'logo_path': '/ed0vz5bryWIhQB5sHiuGvHKnHHn.jpg',
#   'provider_name': 'Takflix',
#   'provider_id': 1771},
#  {'display_priorities': {'AD': 4,
#    'AL': 4,
#    'AG': 3,
#    'AE': 6,
#    'AU': 29,
#    'BA': 4,
#    'AR': 33,
#    'AT': 51,
#    'BB': 5,
#    'BH': 5,
#    'BE': 34,
#    'BG': 18,
#    'BM': 5,
#    'BO': 28,
#    'BS': 5,
#    'BR': 46,
#    'CI': 4,
#    'CA': 47,
#    'CH': 45,
#    'CL': 29,
#    'CO': 30,
#    'CU': 3,
#    'CR': 29,
#    'CV': 3,
#    'CZ': 25,
#    'DO': 5,
#    'DZ': 5,
#    'DK': 38,
#    'EC': 29,
#    'EG': 11,
#    'EE': 25,
#    'DE': 101,
#    'FI': 39,
#    'FJ': 3,
#    'ES': 62,
#    'GF': 5,
#    'GG': 3,
#    'FR': 72,
#    'GH': 3,
#    'GI': 5,
#    'GB': 98,
#    'GQ': 3,
#    'GR': 21,
#    'GT': 29,
#    'HK': 10,
#    'HR': 10,
#    'HN': 28,
#    'HU': 23,
#    'IL': 4,
#    'IN': 17,
#    'ID': 34,
#    'IE': 38,
#    'IQ': 4,
#    'IS': 10,
#    'JM': 5,
#    'IT': 63,
#    'JO': 5,
#    'JP': 26,
#    'KE': 3,
#    'KW': 5,
#    'LB': 4,
#    'KR': 28,
#    'LC': 3,
#    'LI': 5,
#    'LT': 26,
#    'MA': 5,
#    'LY': 5,
#    'MC': 5,
#    'LV': 25,
#    'MD': 5,
#    'MK': 4,
#    'MT': 4,
#    'MU': 2,
#    'MZ': 3,
#    'NE': 4,
#    'MY': 12,
#    'NG': 4,
#    'MX': 45,
#    'NZ': 15,
#    'NL': 46,
#    'NO': 39,
#    'OM': 5,
#    'PA': 5,
#    'PE': 30,
#    'PK': 3,
#    'PF': 3,
#    'PS': 4,
#    'PL': 28,
#    'PH': 29,
#    'PT': 33,
#    'QA': 5,
#    'PY': 27,
#    'RO': 19,
#    'RS': 4,
#    'SA': 9,
#    'SC': 3,
#    'RU': 27,
#    'SI': 4,
#    'SG': 12,
#    'SN': 3,
#    'SE': 41,
#    'SV': 5,
#    'SM': 5,
#    'SK': 13,
#    'TC': 3,
#    'TN': 5,
#    'TH': 28,
#    'TT': 3,
#    'TR': 27,
#    'TW': 9,
#    'TZ': 3,
#    'UG': 3,
#    'XK': 0,
#    'VA': 2,
#    'UY': 7,
#    'YE': 5,
#    'US': 46,
#    'VE': 26,
#    'ZA': 10,
#    'ZM': 3},
#   'display_priority': 46,
#   'logo_path': '/6KEQzITx2RrCAQt5Nw9WrL1OI8z.jpg',
#   'provider_name': 'Sun Nxt',
#   'provider_id': 309},
#  {'display_priorities': {'AU': 53,
#    'BR': 47,
#    'CA': 111,
#    'DE': 103,
#    'ES': 63,
#    'FR': 73,
#    'GB': 100,
#    'IT': 64,
#    'JP': 27,
#    'KR': 29,
#    'MX': 46,
#    'US': 181},
#   'display_priority': 181,
#   'logo_path': '/kICQccvOh8AIBMHGkBXJ047xeHN.jpg',
#   'provider_name': 'Netflix basic with Ads',
#   'provider_id': 1796},
#  {'display_priorities': {'ES': 68},
#   'display_priority': 68,
#   'logo_path': '/8VhN4PeHU7yfMNoWK0DnwdS1HlS.jpg',
#   'provider_name': 'Tivify',
#   'provider_id': 1838},
#  {'display_priorities': {'AR': 45,
#    'BO': 29,
#    'BZ': 8,
#    'BR': 63,
#    'CL': 30,
#    'CO': 31,
#    'CA': 124,
#    'CR': 30,
#    'DO': 27,
#    'EC': 30,
#    'ES': 72,
#    'FR': 90,
#    'GB': 108,
#    'GT': 30,
#    'HN': 29,
#    'NI': 8,
#    'MX': 63,
#    'PA': 28,
#    'PE': 31,
#    'PY': 28,
#    'SV': 28,
#    'UY': 30,
#    'VE': 27,
#    'US': 197},
#   'display_priority': 197,
#   'logo_path': '/oJRCAz1WKkKM9Ge7mX5KFnegTNY.jpg',
#   'provider_name': 'Runtime',
#   'provider_id': 1875},
#  {'display_priorities': {'AG': 10,
#    'AE': 25,
#    'AD': 25,
#    'AL': 27,
#    'AZ': 4,
#    'AR': 46,
#    'BA': 27,
#    'AT': 58,
#    'AU': 58,
#    'BF': 4,
#    'BB': 24,
#    'BG': 20,
#    'BE': 41,
#    'BH': 36,
#    'BM': 26,
#    'BO': 30,
#    'BR': 11,
#    'BY': 7,
#    'BZ': 9,
#    'BS': 24,
#    'CD': 2,
#    'CI': 26,
#    'CH': 47,
#    'CL': 31,
#    'CO': 32,
#    'CA': 125,
#    'CR': 31,
#    'CY': 8,
#    'CV': 12,
#    'DE': 6,
#    'CZ': 27,
#    'DO': 28,
#    'DK': 39,
#    'DZ': 28,
#    'EC': 31,
#    'EE': 26,
#    'EG': 40,
#    'FI': 40,
#    'FJ': 10,
#    'FR': 5,
#    'ES': 73,
#    'GB': 6,
#    'GF': 28,
#    'GG': 10,
#    'GH': 15,
#    'GI': 26,
#    'GQ': 13,
#    'GY': 3,
#    'GR': 22,
#    'GT': 31,
#    'HK': 38,
#    'HN': 30,
#    'HU': 25,
#    'HR': 34,
#    'IN': 4,
#    'IL': 26,
#    'ID': 35,
#    'IE': 40,
#    'IQ': 35,
#    'IS': 31,
#    'JM': 23,
#    'IT': 74,
#    'KE': 14,
#    'JO': 36,
#    'KR': 30,
#    'LC': 10,
#    'LB': 27,
#    'KW': 36,
#    'LI': 27,
#    'LU': 9,
#    'LT': 27,
#    'LV': 26,
#    'MA': 27,
#    'LY': 28,
#    'MC': 25,
#    'ME': 5,
#    'MD': 24,
#    'MK': 26,
#    'MU': 14,
#    'MX': 4,
#    'MZ': 15,
#    'MY': 30,
#    'NE': 26,
#    'NI': 9,
#    'NG': 29,
#    'NZ': 35,
#    'NO': 41,
#    'NL': 67,
#    'PA': 29,
#    'OM': 36,
#    'PG': 4,
#    'PE': 32,
#    'PF': 10,
#    'PL': 29,
#    'PH': 31,
#    'PS': 27,
#    'PT': 39,
#    'PY': 29,
#    'RO': 21,
#    'QA': 36,
#    'RS': 28,
#    'RU': 28,
#    'SC': 13,
#    'SI': 28,
#    'SG': 30,
#    'SN': 13,
#    'SE': 42,
#    'SV': 29,
#    'TC': 10,
#    'SM': 27,
#    'SK': 36,
#    'TD': 6,
#    'TH': 29,
#    'TT': 10,
#    'TN': 28,
#    'TR': 43,
#    'UA': 7,
#    'TW': 38,
#    'TZ': 31,
#    'UG': 15,
#    'US': 6,
#    'XK': 4,
#    'UY': 31,
#    'VE': 28,
#    'YE': 27,
#    'ZM': 13,
#    'ZA': 28,
#    'MT': 24},
#   'display_priority': 28,
#   'logo_path': '/mXeC4TrcgdU6ltE9bCBCEORwSQR.jpg',
#   'provider_name': 'Crunchyroll',
#   'provider_id': 283},
#  {'display_priorities': {'AU': 55, 'CA': 91, 'ES': 74, 'US': 26},
#   'display_priority': 26,
#   'logo_path': '/2ino0WmHA4GROB7NYKzT6PGqLcb.jpg',
#   'provider_name': 'AMC+ Amazon Channel',
#   'provider_id': 528},
#  {'display_priorities': {'AU': 82, 'BR': 42, 'CA': 81, 'ES': 75, 'MX': 40},
#   'display_priority': 40,
#   'logo_path': '/bSy9zFiZtbKBHIyOu0H2Fs5cJmx.jpg',
#   'provider_name': 'Love Nature Amazon Channel',
#   'provider_id': 608},
#  {'display_priorities': {'AE': 14,
#    'AR': 56,
#    'AU': 60,
#    'BH': 28,
#    'BR': 78,
#    'CI': 24,
#    'CA': 135,
#    'DZ': 25,
#    'EG': 30,
#    'FI': 41,
#    'DE': 141,
#    'ES': 88,
#    'GH': 11,
#    'FR': 100,
#    'GQ': 11,
#    'GB': 121,
#    'IL': 9,
#    'ID': 36,
#    'IQ': 10,
#    'IN': 64,
#    'JO': 28,
#    'IT': 92,
#    'KE': 12,
#    'LB': 10,
#    'KW': 29,
#    'MA': 24,
#    'LY': 25,
#    'MU': 10,
#    'MZ': 11,
#    'NE': 24,
#    'NG': 27,
#    'MX': 70,
#    'OM': 28,
#    'PS': 10,
#    'PL': 32,
#    'PH': 32,
#    'QA': 28,
#    'RU': 29,
#    'SA': 28,
#    'SC': 11,
#    'SN': 11,
#    'TN': 25,
#    'TZ': 10,
#    'TR': 55,
#    'UG': 11,
#    'ZM': 11,
#    'ZA': 26,
#    'US': 221},
#   'display_priority': 221,
#   'logo_path': '/7qZED0kLBtiV8mLRNBtW4PQCAqW.jpg',
#   'provider_name': 'Shahid VIP',
#   'provider_id': 1715},
#  {'display_priorities': {'AU': 64,
#    'CA': 141,
#    'ES': 93,
#    'GB': 131,
#    'MX': 78,
#    'US': 238},
#   'display_priority': 238,
#   'logo_path': '/kx8rGgFYxX6aJkG7RHx2mtijglC.jpg',
#   'provider_name': 'Acorn TV Apple TV',
#   'provider_id': 2034},
#  {'display_priorities': {'AU': 57, 'CA': 119, 'ES': 94, 'US': 22},
#   'display_priority': 22,
#   'logo_path': '/oTQdXIqM9iewlN4MC2nhKB0gHw.jpg',
#   'provider_name': 'AMC Plus Apple TV Channel ',
#   'provider_id': 1854},
#  {'display_priorities': {'AR': 14,
#    'AU': 67,
#    'BR': 13,
#    'CA': 30,
#    'CL': 12,
#    'CO': 14,
#    'EC': 13,
#    'FJ': 12,
#    'ES': 97,
#    'GB': 136,
#    'IE': 43,
#    'MX': 11,
#    'NZ': 36,
#    'PE': 14,
#    'PG': 5,
#    'PF': 11,
#    'PT': 59,
#    'US': 14,
#    'VE': 11},
#   'display_priority': 11,
#   'logo_path': '/hwsU65QW7A4dbMEWkDpgHyCNcfS.jpg',
#   'provider_name': 'Kocowa',
#   'provider_id': 464},
#  {'display_priorities': {'AT': 69,
#    'CH': 54,
#    'DE': 30,
#    'FR': 13,
#    'ES': 105,
#    'GB': 144,
#    'IE': 45,
#    'IT': 107,
#    'PL': 39},
#   'display_priority': 39,
#   'logo_path': '/vPZrjHe7wvALuwJEXT2kwYLi0gV.jpg',
#   'provider_name': 'Arte',
#   'provider_id': 234},
#  {'display_priorities': {'AT': 72,
#    'BE': 66,
#    'BR': 92,
#    'CL': 38,
#    'CO': 39,
#    'DE': 167,
#    'ES': 106,
#    'GB': 146,
#    'IT': 108,
#    'MX': 85,
#    'NL': 88},
#   'display_priority': 88,
#   'logo_path': '/efu1Cqc63XrPBoreYnf2mn0Nizj.jpg',
#   'provider_name': 'MGM Plus Amazon Channel',
#   'provider_id': 2141},
#  {'display_priorities': {'ES': 109},
#   'display_priority': 109,
#   'logo_path': '/lDvzuBuNVgpcdzDpPmmufKvrZPb.jpg',
#   'provider_name': '3Cat',
#   'provider_id': 2237}]

# %%
#Creación del df que contiene las plataformas de streaming para las películas en España
movies_spain_providers_data = pd.DataFrame(res_url_movies_spain_providers.json()["results"])
movies_spain_providers_data
# Out:
#                                    display_priorities  display_priority  \
# 0   {'AD': 7, 'AL': 7, 'AR': 0, 'AT': 2, 'AU': 0, ...                27
# 1   {'AE': 2, 'AG': 11, 'AR': 5, 'AT': 5, 'AZ': 3,...                 9
# 2   {'AD': 1, 'AG': 1, 'AL': 1, 'AE': 9, 'AO': 1, ...                 1
# 3                                           {'ES': 3}                 3
# 4   {'AL': 8, 'AT': 9, 'BA': 8, 'BE': 10, 'CH': 9,...                 4
# ..                                                ...               ...
# 59          {'AU': 57, 'CA': 119, 'ES': 94, 'US': 22}                22
# 60  {'AR': 14, 'AU': 67, 'BR': 13, 'CA': 30, 'CL':...                11
# 61  {'AT': 69, 'CH': 54, 'DE': 30, 'FR': 13, 'ES':...                39
# 62  {'AT': 72, 'BE': 66, 'BR': 92, 'CL': 38, 'CO':...                88
# 63                                        {'ES': 109}               109
#
#                            logo_path               provider_name  provider_id
# 0    /97yvRBw1GzX7fXprcF80er19ot.jpg                 Disney Plus          337
# 1   /2E03IAZsX4ZaUqM7tXlctEPMGWS.jpg               Apple TV Plus          350
# 2   /dQeAar5H991VYporEjUspolDarG.jpg          Amazon Prime Video          119
# 3   /jse4MOi92Jgetym7nbXFZZBI6LK.jpg        Movistar Plus+ €9.99         2241
# 4   /bZvc9dXrXNly7cA0V4D9pR8yJwm.jpg                  Rakuten TV           35
# ..                               ...                         ...          ...
# 59   /oTQdXIqM9iewlN4MC2nhKB0gHw.jpg  AMC Plus Apple TV Channel          1854
# 60  /hwsU65QW7A4dbMEWkDpgHyCNcfS.jpg                      Kocowa          464
# 61  /vPZrjHe7wvALuwJEXT2kwYLi0gV.jpg                        Arte          234
# 62  /efu1Cqc63XrPBoreYnf2mn0Nizj.jpg     MGM Plus Amazon Channel         2141
# 63  /lDvzuBuNVgpcdzDpPmmufKvrZPb.jpg                        3Cat         2237
#
# [64 rows x 5 columns]

# %%
#Hay más plataformas de streaming para películas que para series
print("Número de plataformas de streaming para series:", len(serie_spain_providers_data))
print("Número de plataformas de streaming para películas:", len(movies_spain_providers_data))
# Out:
# Número de plataformas de streaming para series: 54
# Número de plataformas de streaming para películas: 64

# %% [markdown]
# Vamos a realizar un pequeño análisis análogo al hecho para las series, con el objetivo de obtener los IDs de los servicios correspondientes a las películas:

# %%
movies_spain_providers_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   display_priorities  64 non-null     object
#  1   display_priority    64 non-null     int64
#  2   logo_path           64 non-null     object
#  3   provider_name       64 non-null     object
#  4   provider_id         64 non-null     int64
# dtypes: int64(2), object(3)
# memory usage: 2.6+ KB

# %%
#El ID de las plataformas es único
movies_spain_providers_data["provider_id"].nunique()
# Out:
# 64

# %%
#El nombre de las plataformas es único
movies_spain_providers_data["provider_name"].nunique()
# Out:
# 64

# %% [markdown]
# A continuación, vamos a obtener los identificadores correspondientes a los servicios de transimisión que nos interesan:

# %%
#Como no sabemos los nombres exactos para las plataformas, nos aproximamos buscándolos con la función 'contains'
movies_spain_providers_data[movies_spain_providers_data["provider_name"].str.contains("netflix|hbo|max|disney|amazon prime", case=False, regex=True)]
# Out:
#                                    display_priorities  display_priority  \
# 0   {'AD': 7, 'AL': 7, 'AR': 0, 'AT': 2, 'AU': 0, ...                27
# 2   {'AD': 1, 'AG': 1, 'AL': 1, 'AE': 9, 'AO': 1, ...                 1
# 14  {'AG': 12, 'AD': 27, 'BA': 29, 'AR': 61, 'BB':...                30
# 36  {'AE': 0, 'AD': 0, 'AG': 0, 'AL': 0, 'AO': 4, ...                 5
# 51  {'AU': 53, 'BR': 47, 'CA': 111, 'DE': 103, 'ES...               181
#
#                            logo_path           provider_name  provider_id
# 0    /97yvRBw1GzX7fXprcF80er19ot.jpg             Disney Plus          337
# 2   /dQeAar5H991VYporEjUspolDarG.jpg      Amazon Prime Video          119
# 14  /fksCUZ9QDWZMUwL2LgMtLckROUN.jpg                     Max         1899
# 36  /pbpMk2JmcoNnQwx5JGpXngfoWtp.jpg                 Netflix            8
# 51  /kICQccvOh8AIBMHGkBXJ047xeHN.jpg  Netflix basic with Ads         1796

# %% [markdown]
# De entre todos los servicios previos, vamos a quedarnos únicamente con los que nos interesan:
#
# - **Netflix** --> *provider_id = 8*
# - **Amazon Prime Video** --> *provider_id = 119*
# - **Disney Plus** --> *provider_id = 337*
# - **Max** --> *provider_id = 1899*

# %%
movies_spain_providers_eda_df = movies_spain_providers_data[movies_spain_providers_data["provider_id"].isin([8, 119, 337, 1899])]
movies_spain_providers_eda_df
# Out:
#                                    display_priorities  display_priority  \
# 0   {'AD': 7, 'AL': 7, 'AR': 0, 'AT': 2, 'AU': 0, ...                27
# 2   {'AD': 1, 'AG': 1, 'AL': 1, 'AE': 9, 'AO': 1, ...                 1
# 14  {'AG': 12, 'AD': 27, 'BA': 29, 'AR': 61, 'BB':...                30
# 36  {'AE': 0, 'AD': 0, 'AG': 0, 'AL': 0, 'AO': 4, ...                 5
#
#                            logo_path       provider_name  provider_id
# 0    /97yvRBw1GzX7fXprcF80er19ot.jpg         Disney Plus          337
# 2   /dQeAar5H991VYporEjUspolDarG.jpg  Amazon Prime Video          119
# 14  /fksCUZ9QDWZMUwL2LgMtLckROUN.jpg                 Max         1899
# 36  /pbpMk2JmcoNnQwx5JGpXngfoWtp.jpg             Netflix            8

# %% [markdown]
# ## Los identificadores de los servicios de transmisión que vamos a analizar coinciden para películas y series:
#
#  - **Netflix** --> *provider_id = 8*
#  - **Amazon Prime Video** --> *provider_id = 119*
#  - **Disney+** --> *provider_id = 337*
#  - **Max** --> *provider_id = 1899*

# %%
serie_spain_providers_eda_df
# Out:
#                                    display_priorities  display_priority  \
# 0   {'AD': 7, 'AL': 7, 'AR': 0, 'AT': 2, 'AU': 0, ...                27
# 2   {'AD': 1, 'AG': 1, 'AL': 1, 'AE': 9, 'AO': 1, ...                 1
# 12  {'AG': 12, 'AD': 27, 'BA': 29, 'AR': 61, 'BB':...                30
# 28  {'AE': 0, 'AD': 0, 'AG': 0, 'AL': 0, 'AO': 4, ...                 5
#
#                            logo_path       provider_name  provider_id
# 0    /97yvRBw1GzX7fXprcF80er19ot.jpg         Disney Plus          337
# 2   /dQeAar5H991VYporEjUspolDarG.jpg  Amazon Prime Video          119
# 12  /fksCUZ9QDWZMUwL2LgMtLckROUN.jpg                 Max         1899
# 28  /pbpMk2JmcoNnQwx5JGpXngfoWtp.jpg             Netflix            8

# %%
movies_spain_providers_eda_df
# Out:
#                                    display_priorities  display_priority  \
# 0   {'AD': 7, 'AL': 7, 'AR': 0, 'AT': 2, 'AU': 0, ...                27
# 2   {'AD': 1, 'AG': 1, 'AL': 1, 'AE': 9, 'AO': 1, ...                 1
# 14  {'AG': 12, 'AD': 27, 'BA': 29, 'AR': 61, 'BB':...                30
# 36  {'AE': 0, 'AD': 0, 'AG': 0, 'AL': 0, 'AO': 4, ...                 5
#
#                            logo_path       provider_name  provider_id
# 0    /97yvRBw1GzX7fXprcF80er19ot.jpg         Disney Plus          337
# 2   /dQeAar5H991VYporEjUspolDarG.jpg  Amazon Prime Video          119
# 14  /fksCUZ9QDWZMUwL2LgMtLckROUN.jpg                 Max         1899
# 36  /pbpMk2JmcoNnQwx5JGpXngfoWtp.jpg             Netflix            8

# %% [markdown]
# # Películas y series de las plataformas de streaming:
#
# Una vez obtenidos los datos necesarios para realizar el filtrado de películas y series correcto para nuestro estudio, accedemos a los siguientes endpoints:
#
# ![API Películas](./images/endpoint-movies.png)
# ![API Series](./images/endpoint-series.png)

# %% [markdown]
# ## Netflix:

# %% [markdown]
# ### Películas:

# %%
#Petición a la bbdd para la obtención de las películas de Netflix en España
url_spain_netflix_movies = "https://api.themoviedb.org/3/discover/movie?with_watch_providers=8&watch_region=ES"
res_url_spain_netflix_movies = requests.get(url_spain_netflix_movies, headers=headers_user)
print(res_url_spain_netflix_movies)
# Out:
# <Response [200]>

# %%
res_url_spain_netflix_movies.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/3m0j3hCS8kMAaP9El6Vy5Lqnyft.jpg',
#    'genre_ids': [878, 53, 18, 27],
#    'id': 1125510,
#    'original_language': 'es',
#    'original_title': 'El hoyo 2',
#    'overview': 'After a mysterious leader imposes his law in a brutal system of vertical cells, a new arrival battles against a dubious food distribution method.',
#    'popularity': 2554.356,
#    'poster_path': '/6lTrlqGTXiVphXW8AmyndcG1pTR.jpg',
#    'release_date': '2024-09-27',
#    'title': 'The Platform 2',
#    'video': False,
#    'vote_average': 5.7,
#    'vote_count': 536},
#   {'adult': False,
#    'backdrop_path': '/vGaBqgY8YRzQVUbBMPnd5SmYvL7.jpg',
#    'genre_ids': [16, 35],
#    'id': 1329336,
#    'original_language': 'en',
#    'original_title': 'The Bad Guys: Haunted Heist',
#    'overview': 'The crafty Bad Guys crew embarks on a high-stakes Halloween heist to swipe a priceless amulet from a spooky mansion. What could go wrong?',
#    'popularity': 944.292,
#    'poster_path': '/oEJC05CqPugMxC4rFu9r6r6vg6m.jpg',
#    'release_date': '2024-10-02',
#    'title': 'The Bad Guys: Haunted Heist',
#    'video': False,
#    'vote_average': 7.4,
#    'vote_count': 47},
#   {'adult': False,
#    'backdrop_path': '/eXQ8O0ykuEB8dUJhq2WJll4vXmA.jpg',
#    'genre_ids': [28, 35, 80],
#    'id': 1210794,
#    'original_language': 'sv',
#    'original_title': 'Strul',
#    'overview': 'Wrongfully convicted of murder, a clumsy electronics salesman faces police corruption and criminal conspiracies in an attempt to prove his innocence.',
#    'popularity': 917.854,
#    'poster_path': '/ildbg7ho14EHbt1fZWAkgqIyPqy.jpg',
#    'release_date': '2024-10-02',
#    'title': 'Trouble',
#    'video': False,
#    'vote_average': 7.1,
#    'vote_count': 77},
#   {'adult': False,
#    'backdrop_path': '/igtm12Wy9EUlxFeyb4v8bRyuYSY.jpg',
#    'genre_ids': [28, 80, 18, 53],
#    'id': 1337309,
#    'original_language': 'th',
#    'original_title': 'Bangkok Breaking: ฝ่านรกเมืองเทวดา',
#    'overview': "When a dedicated rescue worker inadvertently gets caught up in the kidnapping plot of a mogul's tween daughter, he must save her from the clutches of rival gangs hunting them down with unpredictable dangers around every corner.",
#    'popularity': 664.257,
#    'poster_path': '/6VeDn4oIeUK4XwjWGWMb6qvMImQ.jpg',
#    'release_date': '2024-09-26',
#    'title': 'Bangkok Breaking: Heaven and Hell',
#    'video': False,
#    'vote_average': 6.5,
#    'vote_count': 29},
#   {'adult': False,
#    'backdrop_path': '/gZWl93sf8AxavYpVT1Un6EF3oCj.jpg',
#    'genre_ids': [80, 53, 18],
#    'id': 475557,
#    'original_language': 'en',
#    'original_title': 'Joker',
#    'overview': 'During the 1980s, a failed stand-up comedian is driven insane and turns to a life of crime and chaos in Gotham City while becoming an infamous psychopathic crime figure.',
#    'popularity': 478.179,
#    'poster_path': '/udDclJoHjfjb8Ekgsd4FDteOkCU.jpg',
#    'release_date': '2019-10-01',
#    'title': 'Joker',
#    'video': False,
#    'vote_average': 8.151,
#    'vote_count': 25441},
#   {'adult': False,
#    'backdrop_path': '/yRKyJJYIzfeiVDHBe4LXguPQCvD.jpg',
#    'genre_ids': [14, 35],
#    'id': 4011,
#    'original_language': 'en',
#    'original_title': 'Beetlejuice',
#    'overview': 'A newly dead New England couple seeks help from a deranged demon exorcist to scare an affluent New York family out of their home.',
#    'popularity': 388.911,
#    'poster_path': '/nnl6OWkyPpuMm595hmAxNW3rZFn.jpg',
#    'release_date': '1988-03-30',
#    'title': 'Beetlejuice',
#    'video': False,
#    'vote_average': 7.4,
#    'vote_count': 7317},
#   {'adult': False,
#    'backdrop_path': '/hdFIdXwS8FSN2wIsuotjW1mshI0.jpg',
#    'genre_ids': [16, 35, 12, 10751],
#    'id': 831815,
#    'original_language': 'en',
#    'original_title': 'Saving Bikini Bottom: The Sandy Cheeks Movie',
#    'overview': 'When Bikini Bottom is scooped from the ocean, scientific squirrel Sandy Cheeks and her pal SpongeBob SquarePants saddle up for Texas to save their town.',
#    'popularity': 370.09,
#    'poster_path': '/30YnfZdMNIV7noWLdvmcJS0cbnQ.jpg',
#    'release_date': '2024-10-18',
#    'title': 'Saving Bikini Bottom: The Sandy Cheeks Movie',
#    'video': False,
#    'vote_average': 6.7,
#    'vote_count': 5},
#   {'adult': False,
#    'backdrop_path': '/3tkDMNfM2YuIAJlvGO6rfIzAnfG.jpg',
#    'genre_ids': [18, 878, 53],
#    'id': 619264,
#    'original_language': 'es',
#    'original_title': 'El hoyo',
#    'overview': 'A slab of food descends down a vertical facility. The residents above eat heartily, leaving those below starving and desperate. A rebellion is imminent.',
#    'popularity': 339.031,
#    'poster_path': '/8ZX18L5m6rH5viSYpRnTSbb9eXh.jpg',
#    'release_date': '2019-11-08',
#    'title': 'The Platform',
#    'video': False,
#    'vote_average': 6.981,
#    'vote_count': 6977},
#   {'adult': False,
#    'backdrop_path': '/jfC2xCBD8a5QJNd5yY3q23E8i7U.jpg',
#    'genre_ids': [28, 80, 18],
#    'id': 1186947,
#    'original_language': 'pt',
#    'original_title': 'Bandida - A Número Um',
#    'overview': 'At the age of nine, Rebeca is sold by her grandmother to the bookseller who ran Rocinha. Disputed by bicheiros and drug dealers, the community is going through changes in power. Rebeca becomes the wife of the chief drug dealer and, with the death of her partner, his successor. The electrifying trajectory of crime, violence, drugs and love of a female drug kingpin in Rocinha, Rio de Janeiro in the 1980s.',
#    'popularity': 321.382,
#    'poster_path': '/rGS8SzheANVQicNba0GCE6w1XHb.jpg',
#    'release_date': '2024-06-20',
#    'title': 'Outlaw',
#    'video': False,
#    'vote_average': 6.0,
#    'vote_count': 79},
#   {'adult': False,
#    'backdrop_path': '/nk3RLLZiRAsUxZjtZoXTu77IN03.jpg',
#    'genre_ids': [10751, 35],
#    'id': 1030076,
#    'original_language': 'es',
#    'original_title': 'Padre no hay más que uno 4: Campanas de boda',
#    'overview': 'The eldest of the family, Sara, comes of age and brings chaos to the family by announcing her intention to marry Ocho. Javier and Marisa try to avoid it at all costs. At the same time Dani has an existential crisis, Paulita feels jealous of Cris, Carlota announces that she has found a boyfriend from a high society family and Rocio has finally managed to be cast in her first film.',
#    'popularity': 306.779,
#    'poster_path': '/hTMvGolGJLF0GQ7mlwNjbXpsPZ.jpg',
#    'release_date': '2024-07-17',
#    'title': 'Padre no hay más que uno 4: Campanas de boda',
#    'video': False,
#    'vote_average': 6.776,
#    'vote_count': 38},
#   {'adult': False,
#    'backdrop_path': '/3LVVSvAkQGbL5fvG4VM3GfMaZBe.jpg',
#    'genre_ids': [35, 9648, 878, 27],
#    'id': 1052280,
#    'original_language': 'en',
#    'original_title': "It's What's Inside",
#    'overview': 'A pre-wedding reunion descends into a psychological nightmare for a group of college friends when a surprise guest arrives with a mysterious suitcase.',
#    'popularity': 303.164,
#    'poster_path': '/32Lfs4nbLehgbXI8VTeYg5jgIQt.jpg',
#    'release_date': '2024-01-19',
#    'title': "It's What's Inside",
#    'video': False,
#    'vote_average': 6.4,
#    'vote_count': 200},
#   {'adult': False,
#    'backdrop_path': '/wSZbtiFIK1fkKZdSRtn2kz2Ttfd.jpg',
#    'genre_ids': [28, 35, 80],
#    'id': 1139817,
#    'original_language': 'ko',
#    'original_title': '무도실무관',
#    'overview': "A talented martial artist who can't walk past a person in need unites with a probation officer to fight and prevent crime as a martial arts officer.",
#    'popularity': 296.628,
#    'poster_path': '/rEaJSXAlNfdhRpDHiNcJsoUa9qE.jpg',
#    'release_date': '2024-09-10',
#    'title': 'Officer Black Belt',
#    'video': False,
#    'vote_average': 7.8,
#    'vote_count': 183},
#   {'adult': False,
#    'backdrop_path': '/VuukZLgaCrho2Ar8Scl9HtV3yD.jpg',
#    'genre_ids': [878, 28],
#    'id': 335983,
#    'original_language': 'en',
#    'original_title': 'Venom',
#    'overview': 'Investigative journalist Eddie Brock attempts a comeback following a scandal, but accidentally becomes the host of Venom, a violent, super powerful alien symbiote. Soon, he must rely on his newfound powers to protect the world from a shadowy organization looking for a symbiote of their own.',
#    'popularity': 294.702,
#    'poster_path': '/2uNW4WbgBXL25BAbXGLnLqX71Sw.jpg',
#    'release_date': '2018-09-28',
#    'title': 'Venom',
#    'video': False,
#    'vote_average': 6.827,
#    'vote_count': 15711},
#   {'adult': False,
#    'backdrop_path': '/cyKH7pDFlxIXluqRyNoHHEpxSDX.jpg',
#    'genre_ids': [80, 28, 53, 18],
#    'id': 646097,
#    'original_language': 'en',
#    'original_title': 'Rebel Ridge',
#    'overview': "A former Marine confronts corruption in a small town when local law enforcement unjustly seizes the bag of cash he needs to post his cousin's bail.",
#    'popularity': 267.277,
#    'poster_path': '/xEt2GSz9z5rSVpIHMiGdtf0czyf.jpg',
#    'release_date': '2024-08-27',
#    'title': 'Rebel Ridge',
#    'video': False,
#    'vote_average': 7.0,
#    'vote_count': 850},
#   {'adult': False,
#    'backdrop_path': '/tmU7GeKVybMWFButWEGl2M4GeiP.jpg',
#    'genre_ids': [18, 80],
#    'id': 238,
#    'original_language': 'en',
#    'original_title': 'The Godfather',
#    'overview': 'Spanning the years 1945 to 1955, a chronicle of the fictional Italian-American Corleone crime family. When organized crime family patriarch, Vito Corleone barely survives an attempt on his life, his youngest son, Michael steps in to take care of the would-be killers, launching a campaign of bloody revenge.',
#    'popularity': 237.639,
#    'poster_path': '/3bhkrj58Vtu7enYsRolD1fZdja1.jpg',
#    'release_date': '1972-03-14',
#    'title': 'The Godfather',
#    'video': False,
#    'vote_average': 8.691,
#    'vote_count': 20468},
#   {'adult': False,
#    'backdrop_path': '/u6GpYb8MIC1W3fW4ZcsOul9GjzY.jpg',
#    'genre_ids': [10749, 18],
#    'id': 959429,
#    'original_language': 'en',
#    'original_title': 'Lonely Planet',
#    'overview': "At an idyllic writers retreat in Morocco, a newly single novelist finds an unexpected connection with a younger man who's reevaluating his life choices.",
#    'popularity': 233.225,
#    'poster_path': '/sH7Orig1yqa6ojMLIzLDxA2GRkH.jpg',
#    'release_date': '2024-10-10',
#    'title': 'Lonely Planet',
#    'video': False,
#    'vote_average': 5.9,
#    'vote_count': 50},
#   {'adult': False,
#    'backdrop_path': '/4ft6TR9wA6bra0RLL6G7JFDQ5t1.jpg',
#    'genre_ids': [28, 35],
#    'id': 704239,
#    'original_language': 'en',
#    'original_title': 'The Union',
#    'overview': 'A New Jersey construction worker goes from regular guy to aspiring spy when his long-lost high school sweetheart recruits him for an espionage mission.',
#    'popularity': 228.16,
#    'poster_path': '/d9CTnTHip1RbVi2OQbA2LJJQAGI.jpg',
#    'release_date': '2024-08-15',
#    'title': 'The Union',
#    'video': False,
#    'vote_average': 6.267,
#    'vote_count': 734},
#   {'adult': False,
#    'backdrop_path': '/2wrdcWrAN53Pl7ahBWMIKMzXBFF.jpg',
#    'genre_ids': [16, 28, 12, 14, 878],
#    'id': 1134424,
#    'original_language': 'th',
#    'original_title': 'นักรบมนตรา: ตำนานแปดดวงจันทร์',
#    'overview': 'A story inspired by the original RAMAYANA, retold in a futuristic universe, involving brave warriors who possess ancient powers from another dimension.',
#    'popularity': 216.271,
#    'poster_path': '/sQE0VegwDa0GHjawfNRr1sFgVE2.jpg',
#    'release_date': '2023-10-11',
#    'title': 'Mantra Warrior: The Legend of The Eight Moons',
#    'video': False,
#    'vote_average': 6.4,
#    'vote_count': 29},
#   {'adult': False,
#    'backdrop_path': '/zBG5Mg29NH9xxpWMMG7BIvKwYhL.jpg',
#    'genre_ids': [10749, 18],
#    'id': 829557,
#    'original_language': 'pl',
#    'original_title': '365 dni: Ten dzień',
#    'overview': "Laura and Massimo are back and hotter than ever. But the reunited couple's new beginning is complicated by Massimo’s family ties and a mysterious man who enters Laura’s life to win her heart and trust, at any cost.",
#    'popularity': 206.516,
#    'poster_path': '/7qU0SOVcQ8BTJLodcAlulUAG16C.jpg',
#    'release_date': '2022-04-26',
#    'title': '365 Days: This Day',
#    'video': False,
#    'vote_average': 5.9,
#    'vote_count': 1494},
#   {'adult': False,
#    'backdrop_path': '/zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg',
#    'genre_ids': [18, 80],
#    'id': 278,
#    'original_language': 'en',
#    'original_title': 'The Shawshank Redemption',
#    'overview': 'Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#    'popularity': 206.062,
#    'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg',
#    'release_date': '1994-09-23',
#    'title': 'The Shawshank Redemption',
#    'video': False,
#    'vote_average': 8.707,
#    'vote_count': 26954}],
#  'total_pages': 281,
#  'total_results': 5619}

# %%
print("Páginas para Netflix España:",res_url_spain_netflix_movies.json()["total_pages"])
print("Resultados para Netflix España:", res_url_spain_netflix_movies.json()["total_results"])
# Out:
# Páginas para Netflix España: 281
# Resultados para Netflix España: 5619

# %%
netflix_spain_movies = pd.DataFrame(res_url_spain_netflix_movies.json()["results"])
netflix_spain_movies
# Out:
#     adult                     backdrop_path              genre_ids       id  \
# 0   False  /3m0j3hCS8kMAaP9El6Vy5Lqnyft.jpg      [878, 53, 18, 27]  1125510
# 1   False  /vGaBqgY8YRzQVUbBMPnd5SmYvL7.jpg               [16, 35]  1329336
# 2   False  /eXQ8O0ykuEB8dUJhq2WJll4vXmA.jpg           [28, 35, 80]  1210794
# 3   False  /igtm12Wy9EUlxFeyb4v8bRyuYSY.jpg       [28, 80, 18, 53]  1337309
# 4   False  /gZWl93sf8AxavYpVT1Un6EF3oCj.jpg           [80, 53, 18]   475557
# 5   False  /yRKyJJYIzfeiVDHBe4LXguPQCvD.jpg               [14, 35]     4011
# 6   False  /hdFIdXwS8FSN2wIsuotjW1mshI0.jpg    [16, 35, 12, 10751]   831815
# 7   False  /3tkDMNfM2YuIAJlvGO6rfIzAnfG.jpg          [18, 878, 53]   619264
# 8   False  /jfC2xCBD8a5QJNd5yY3q23E8i7U.jpg           [28, 80, 18]  1186947
# 9   False  /nk3RLLZiRAsUxZjtZoXTu77IN03.jpg            [10751, 35]  1030076
# 10  False  /3LVVSvAkQGbL5fvG4VM3GfMaZBe.jpg    [35, 9648, 878, 27]  1052280
# 11  False  /wSZbtiFIK1fkKZdSRtn2kz2Ttfd.jpg           [28, 35, 80]  1139817
# 12  False   /VuukZLgaCrho2Ar8Scl9HtV3yD.jpg              [878, 28]   335983
# 13  False  /cyKH7pDFlxIXluqRyNoHHEpxSDX.jpg       [80, 28, 53, 18]   646097
# 14  False  /tmU7GeKVybMWFButWEGl2M4GeiP.jpg               [18, 80]      238
# 15  False  /u6GpYb8MIC1W3fW4ZcsOul9GjzY.jpg            [10749, 18]   959429
# 16  False  /4ft6TR9wA6bra0RLL6G7JFDQ5t1.jpg               [28, 35]   704239
# 17  False  /2wrdcWrAN53Pl7ahBWMIKMzXBFF.jpg  [16, 28, 12, 14, 878]  1134424
# 18  False  /zBG5Mg29NH9xxpWMMG7BIvKwYhL.jpg            [10749, 18]   829557
# 19  False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg               [18, 80]      278
#
#    original_language                                original_title  \
# 0                 es                                     El hoyo 2
# 1                 en                   The Bad Guys: Haunted Heist
# 2                 sv                                         Strul
# 3                 th            Bangkok Breaking: ฝ่านรกเมืองเทวดา
# 4                 en                                         Joker
# 5                 en                                   Beetlejuice
# 6                 en  Saving Bikini Bottom: The Sandy Cheeks Movie
# 7                 es                                       El hoyo
# 8                 pt                         Bandida - A Número Um
# 9                 es  Padre no hay más que uno 4: Campanas de boda
# 10                en                            It's What's Inside
# 11                ko                                         무도실무관
# 12                en                                         Venom
# 13                en                                   Rebel Ridge
# 14                en                                 The Godfather
# 15                en                                 Lonely Planet
# 16                en                                     The Union
# 17                th                 นักรบมนตรา: ตำนานแปดดวงจันทร์
# 18                pl                            365 dni: Ten dzień
# 19                en                      The Shawshank Redemption
#
#                                              overview  popularity  \
# 0   After a mysterious leader imposes his law in a...    2554.356
# 1   The crafty Bad Guys crew embarks on a high-sta...     944.292
# 2   Wrongfully convicted of murder, a clumsy elect...     917.854
# 3   When a dedicated rescue worker inadvertently g...     664.257
# 4   During the 1980s, a failed stand-up comedian i...     478.179
# 5   A newly dead New England couple seeks help fro...     388.911
# 6   When Bikini Bottom is scooped from the ocean, ...     370.090
# 7   A slab of food descends down a vertical facili...     339.031
# 8   At the age of nine, Rebeca is sold by her gran...     321.382
# 9   The eldest of the family, Sara, comes of age a...     306.779
# 10  A pre-wedding reunion descends into a psycholo...     303.164
# 11  A talented martial artist who can't walk past ...     296.628
# 12  Investigative journalist Eddie Brock attempts ...     294.702
# 13  A former Marine confronts corruption in a smal...     267.277
# 14  Spanning the years 1945 to 1955, a chronicle o...     237.639
# 15  At an idyllic writers retreat in Morocco, a ne...     233.225
# 16  A New Jersey construction worker goes from reg...     228.160
# 17  A story inspired by the original RAMAYANA, ret...     216.271
# 18  Laura and Massimo are back and hotter than eve...     206.516
# 19  Imprisoned in the 1940s for the double murder ...     206.062
#
#                          poster_path release_date  \
# 0   /6lTrlqGTXiVphXW8AmyndcG1pTR.jpg   2024-09-27
# 1   /oEJC05CqPugMxC4rFu9r6r6vg6m.jpg   2024-10-02
# 2   /ildbg7ho14EHbt1fZWAkgqIyPqy.jpg   2024-10-02
# 3   /6VeDn4oIeUK4XwjWGWMb6qvMImQ.jpg   2024-09-26
# 4   /udDclJoHjfjb8Ekgsd4FDteOkCU.jpg   2019-10-01
# 5   /nnl6OWkyPpuMm595hmAxNW3rZFn.jpg   1988-03-30
# 6   /30YnfZdMNIV7noWLdvmcJS0cbnQ.jpg   2024-10-18
# 7   /8ZX18L5m6rH5viSYpRnTSbb9eXh.jpg   2019-11-08
# 8   /rGS8SzheANVQicNba0GCE6w1XHb.jpg   2024-06-20
# 9    /hTMvGolGJLF0GQ7mlwNjbXpsPZ.jpg   2024-07-17
# 10  /32Lfs4nbLehgbXI8VTeYg5jgIQt.jpg   2024-01-19
# 11  /rEaJSXAlNfdhRpDHiNcJsoUa9qE.jpg   2024-09-10
# 12  /2uNW4WbgBXL25BAbXGLnLqX71Sw.jpg   2018-09-28
# 13  /xEt2GSz9z5rSVpIHMiGdtf0czyf.jpg   2024-08-27
# 14  /3bhkrj58Vtu7enYsRolD1fZdja1.jpg   1972-03-14
# 15  /sH7Orig1yqa6ojMLIzLDxA2GRkH.jpg   2024-10-10
# 16  /d9CTnTHip1RbVi2OQbA2LJJQAGI.jpg   2024-08-15
# 17  /sQE0VegwDa0GHjawfNRr1sFgVE2.jpg   2023-10-11
# 18  /7qU0SOVcQ8BTJLodcAlulUAG16C.jpg   2022-04-26
# 19  /9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg   1994-09-23
#
#                                             title  video  vote_average  \
# 0                                  The Platform 2  False         5.700
# 1                     The Bad Guys: Haunted Heist  False         7.400
# 2                                         Trouble  False         7.100
# 3               Bangkok Breaking: Heaven and Hell  False         6.500
# 4                                           Joker  False         8.151
# 5                                     Beetlejuice  False         7.400
# 6    Saving Bikini Bottom: The Sandy Cheeks Movie  False         6.700
# 7                                    The Platform  False         6.981
# 8                                          Outlaw  False         6.000
# 9    Padre no hay más que uno 4: Campanas de boda  False         6.776
# 10                             It's What's Inside  False         6.400
# 11                             Officer Black Belt  False         7.800
# 12                                          Venom  False         6.827
# 13                                    Rebel Ridge  False         7.000
# 14                                  The Godfather  False         8.691
# 15                                  Lonely Planet  False         5.900
# 16                                      The Union  False         6.267
# 17  Mantra Warrior: The Legend of The Eight Moons  False         6.400
# 18                             365 Days: This Day  False         5.900
# 19                       The Shawshank Redemption  False         8.707
#
#     vote_count
# 0          536
# 1           47
# 2           77
# 3           29
# 4        25441
# 5         7317
# 6            5
# 7         6977
# 8           79
# 9           38
# 10         200
# 11         183
# 12       15711
# 13         850
# 14       20468
# 15          50
# 16         734
# 17          29
# 18        1494
# 19       26954

# %% [markdown]
# Con la anterior petición, sólo hemos sacado la primera página de resultados (por defecto, el endpoint coge la primera página), si bien necesitamos extraer todas las películas (o sea, la información de las 281 páginas correspondientes a Netflix España):

# %%
for i in range(2,282): #Empezamos en la página 2 porque la 1 ya la tenemos de la peticion anterior
    url = "https://api.themoviedb.org/3/discover/movie?with_watch_providers=8&watch_region=ES&page="+str(i)
    res_url = requests.get(url,headers=headers_user)
    netflix_spain_movies = pd.concat([netflix_spain_movies, pd.DataFrame(res_url.json()["results"])], ignore_index=True)
netflix_spain_movies
# Out:
#       adult                     backdrop_path          genre_ids       id  \
# 0     False  /3m0j3hCS8kMAaP9El6Vy5Lqnyft.jpg  [878, 53, 18, 27]  1125510
# 1     False  /vGaBqgY8YRzQVUbBMPnd5SmYvL7.jpg           [16, 35]  1329336
# 2     False  /eXQ8O0ykuEB8dUJhq2WJll4vXmA.jpg       [28, 35, 80]  1210794
# 3     False  /igtm12Wy9EUlxFeyb4v8bRyuYSY.jpg   [28, 80, 18, 53]  1337309
# 4     False  /gZWl93sf8AxavYpVT1Un6EF3oCj.jpg       [80, 53, 18]   475557
# ...     ...                               ...                ...      ...
# 5614  False  /tJzgYHSGCqNXS2H08n5vBlsuXaV.jpg               [99]   999044
# 5615  False                              None           [99, 36]   920782
# 5616  False   /noesJz1tuxcDV75bBjaDkU3fLO.jpg                 []   655704
# 5617  False                              None                 []   460784
# 5618  False  /fJitRwELibGT9trQ7xotDwFRjOD.jpg               [35]  1289045
#
#      original_language                                   original_title  \
# 0                   es                                        El hoyo 2
# 1                   en                      The Bad Guys: Haunted Heist
# 2                   sv                                            Strul
# 3                   th               Bangkok Breaking: ฝ่านรกเมืองเทวดา
# 4                   en                                            Joker
# ...                ...                                              ...
# 5614                nl                                  Congreso Anyway
# 5615                fr  Homo sapiens. Une nouvelle histoire de l'homme.
# 5616                pl                                    Wild Records!
# 5617                ru                                Не все кошки серы
# 5618                es                    Franco Escamilla: Ladies' man
#
#                                                overview  popularity  \
# 0     After a mysterious leader imposes his law in a...    2554.356
# 1     The crafty Bad Guys crew embarks on a high-sta...     944.292
# 2     Wrongfully convicted of murder, a clumsy elect...     917.854
# 3     When a dedicated rescue worker inadvertently g...     664.257
# 4     During the 1980s, a failed stand-up comedian i...     478.179
# ...                                                 ...         ...
# 5614                                                          0.001
# 5615  In this thought-provoking documentary, promine...       0.001
# 5616  This cartoon documentary shares trivia and fun...       0.001
# 5617                                                          0.001
# 5618  Franco Escamilla takes the stage with tales of...       0.000
#
#                            poster_path release_date  \
# 0     /6lTrlqGTXiVphXW8AmyndcG1pTR.jpg   2024-09-27
# 1     /oEJC05CqPugMxC4rFu9r6r6vg6m.jpg   2024-10-02
# 2     /ildbg7ho14EHbt1fZWAkgqIyPqy.jpg   2024-10-02
# 3     /6VeDn4oIeUK4XwjWGWMb6qvMImQ.jpg   2024-09-26
# 4     /udDclJoHjfjb8Ekgsd4FDteOkCU.jpg   2019-10-01
# ...                                ...          ...
# 5614  /cgi4CaJmW0p4K2Y2r7NccR1Qe6b.jpg   1993-04-01
# 5615  /hS1r8vLqe27j0y042ekpfkoFYVv.jpg   2005-10-29
# 5616  /jN3428zsHSxswmQeoPBu8YEVtN8.jpg   2001-02-03
# 5617  /qPL1k2zXtf5qxJJAjHUYDsZOCJS.jpg   2004-01-01
# 5618  /7sZiozbWOSLlXvgT866MtTK32Yv.jpg   2024-05-23
#
#                                   title  video  vote_average  vote_count
# 0                        The Platform 2  False         5.700         536
# 1           The Bad Guys: Haunted Heist  False         7.400          47
# 2                               Trouble  False         7.100          77
# 3     Bangkok Breaking: Heaven and Hell  False         6.500          29
# 4                                 Joker  False         8.151       25441
# ...                                 ...    ...           ...         ...
# 5614                    Congreso Anyway  False         0.000           0
# 5615     Homo Futurus: The Inside Story  False         0.000           0
# 5616                      Wild Records!  False         0.000           0
# 5617          Not all the Cats are Gray  False         0.000           0
# 5618      Franco Escamilla: Ladies' man  False         9.000          26
#
# [5619 rows x 14 columns]

# %% [markdown]
# Ya tenemos todas las películas de Netlix España. Para nuestro análisis, no necesitamos todos los campos de la tabla creada, por lo que vamos a quedarnos con aquellos que realmente necesitamos:

# %%
eda_movies_columns = ['original_title', 'title', 'id', 'genre_ids', 'release_date', 'popularity', 'vote_average', 'vote_count', 'original_language', 'adult' ]

# %%
#Generamos la tabla de las películas de Netflix España y la guardamos en un .csv
netflix_spain_movies_eda = netflix_spain_movies[eda_movies_columns]
current_path = os.getcwd()
path_def = os.path.join(current_path, 'data')
netflix_spain_movies_eda.to_csv(os.path.join(path_def,'netflix_movies.csv'))

# %% [markdown]
# ### Series:

# %%
#Petición a la bbdd para la obtención de las series de Netflix en España
url_spain_netflix_series = "https://api.themoviedb.org/3/discover/tv?with_watch_providers=8&watch_region=ES"
res_url_spain_netflix_series = requests.get(url_spain_netflix_series, headers=headers_user)
print(res_url_spain_netflix_series)
# Out:
# <Response [200]>

# %%
res_url_spain_netflix_series.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/7w165QdHmJuTHSQwEyJDBDpuDT7.jpg',
#    'genre_ids': [10759, 80, 18],
#    'id': 2288,
#    'origin_country': ['US'],
#    'original_language': 'en',
#    'original_name': 'Prison Break',
#    'overview': 'Due to a political conspiracy, an innocent man is sent to death row and his only hope is his brother, who makes it his mission to deliberately get himself sent to the same prison in order to break the both of them out, from the inside out.',
#    'popularity': 985.135,
#    'poster_path': '/5E1BhkCgjLBlqx557Z5yzcN0i88.jpg',
#    'first_air_date': '2005-08-29',
#    'name': 'Prison Break',
#    'vote_average': 8.079,
#    'vote_count': 5044},
#   {'adult': False,
#    'backdrop_path': '/tMLH2VDnTpZLYg7T4QPBjaaleVx.jpg',
#    'genre_ids': [10759, 18, 9648],
#    'id': 100757,
#    'origin_country': ['US'],
#    'original_language': 'en',
#    'original_name': 'Outer Banks',
#    'overview': "A tight-knit group of teens unearths a long-buried secret, setting off a chain of illicit events that takes them on an adventure they'll never forget.",
#    'popularity': 1165.631,
#    'poster_path': '/ovDgO2LPfwdVRfvScAqo9aMiIW.jpg',
#    'first_air_date': '2020-04-15',
#    'name': 'Outer Banks',
#    'vote_average': 8.4,
#    'vote_count': 887},
#   {'adult': False,
#    'backdrop_path': '/4msN2f5WeKVldbdxSymdndWTOmr.jpg',
#    'genre_ids': [16, 10759, 10765],
#    'id': 218843,
#    'origin_country': ['JP'],
#    'original_language': 'ja',
#    'original_name': '七つの大罪 黙示録の四騎士',
#    'overview': 'As a prophecy of doom unfolds on the peaceful land of Britannia, a purehearted boy sets out on a journey of discovery — and revenge.',
#    'popularity': 534.912,
#    'poster_path': '/6SWVJvCIC9B16u6wASZ8FEaNssz.jpg',
#    'first_air_date': '2023-10-08',
#    'name': 'The Seven Deadly Sins: Four Knights of the Apocalypse',
#    'vote_average': 8.7,
#    'vote_count': 113},
#   {'adult': False,
#    'backdrop_path': '/h324Kf6pjDzGQiUrc4W2r4YcD9L.jpg',
#    'genre_ids': [18, 80],
#    'id': 225634,
#    'origin_country': ['US'],
#    'original_language': 'en',
#    'original_name': 'Monsters',
#    'overview': 'The story of the Menéndez brothers, who were convicted in 1996 of murdering their parents José and Mary Louise “Kitty” Menéndez.',
#    'popularity': 721.391,
#    'poster_path': '/x9YC2rpXHUFMqI1hCekKDm9UE4w.jpg',
#    'first_air_date': '2024-09-19',
#    'name': 'Monsters',
#    'vote_average': 7.586,
#    'vote_count': 187},
#   {'adult': False,
#    'backdrop_path': '/cAmpVRgQL2s55CU6K8SaFcUJPNW.jpg',
#    'genre_ids': [18, 35, 10751],
#    'id': 262252,
#    'origin_country': ['CO'],
#    'original_language': 'es',
#    'original_name': 'Klass 95: El poder de la belleza',
#    'overview': 'An ambitious young woman launches a powerful modeling agency determined to change lives — but power and love are not for the faint of heart.',
#    'popularity': 388.277,
#    'poster_path': '/dsEtoQtIurztGFs3H9vsa5Tdw2R.jpg',
#    'first_air_date': '2024-08-20',
#    'name': 'KLASS 95: The Power of Beauty',
#    'vote_average': 6.8,
#    'vote_count': 6},
#   {'adult': False,
#    'backdrop_path': '/aDBRtunw49UF4XmqfyNuD9nlYIu.jpg',
#    'genre_ids': [80, 10765],
#    'id': 63174,
#    'origin_country': ['US'],
#    'original_language': 'en',
#    'original_name': 'Lucifer',
#    'overview': "Bored and unhappy as the Lord of Hell, Lucifer Morningstar abandoned his throne and retired to Los Angeles, where he has teamed up with LAPD detective Chloe Decker to take down criminals.\xa0But the longer he's away from the underworld, the greater the threat that the worst of humanity could escape.",
#    'popularity': 577.367,
#    'poster_path': '/ekZobS8isE6mA53RAiGDG93hBxL.jpg',
#    'first_air_date': '2016-01-25',
#    'name': 'Lucifer',
#    'vote_average': 8.464,
#    'vote_count': 14632},
#   {'adult': False,
#    'backdrop_path': '/iprMfJ9VHS4wMhBXyHtN7l9d2hP.jpg',
#    'genre_ids': [80, 18, 9648],
#    'id': 1405,
#    'origin_country': ['US'],
#    'original_language': 'en',
#    'original_name': 'Dexter',
#    'overview': 'Dexter Morgan, a blood spatter pattern analyst for the Miami Metro Police also leads a secret life as a serial killer, hunting down criminals who have slipped through the cracks of justice.',
#    'popularity': 574.161,
#    'poster_path': '/q8dWfc4JwQuv3HayIZeO84jAXED.jpg',
#    'first_air_date': '2006-10-01',
#    'name': 'Dexter',
#    'vote_average': 8.187,
#    'vote_count': 4222},
#   {'adult': False,
#    'backdrop_path': '/2eIlCirgcvEwmCSYh2wDfz5Sxvz.jpg',
#    'genre_ids': [18, 80, 9648],
#    'id': 46952,
#    'origin_country': ['US'],
#    'original_language': 'en',
#    'original_name': 'The Blacklist',
#    'overview': 'Raymond "Red" Reddington, one of the FBI\'s most wanted fugitives, surrenders in person at FBI Headquarters in Washington, D.C. He claims that he and the FBI have the same interests: bringing down dangerous criminals and terrorists. In the last two decades, he\'s made a list of criminals and terrorists that matter the most but the FBI cannot find because it does not know they exist. Reddington calls this "The Blacklist". Reddington will co-operate, but insists that he will speak only to Elizabeth Keen, a rookie FBI profiler.',
#    'popularity': 551.738,
#    'poster_path': '/r935SMphvXppx5bJjbIBNx02fwc.jpg',
#    'first_air_date': '2013-09-23',
#    'name': 'The Blacklist',
#    'vote_average': 7.6,
#    'vote_count': 3121},
#   {'adult': False,
#    'backdrop_path': '/f3cin9kOz4nOrlYEMxGFQhv4bdN.jpg',
#    'genre_ids': [18],
#    'id': 71712,
#    'origin_country': ['US'],
#    'original_language': 'en',
#    'original_name': 'The Good Doctor',
#    'overview': "Shaun Murphy, a young surgeon with autism and savant syndrome, relocates from a quiet country life to join a prestigious hospital's surgical unit. Unable to personally connect with those around him, Shaun uses his extraordinary medical gifts to save lives and challenge the skepticism of his colleagues.",
#    'popularity': 560.242,
#    'poster_path': '/53P8oHo9cfOsgb1cLxBi4pFY0ja.jpg',
#    'first_air_date': '2017-09-25',
#    'name': 'The Good Doctor',
#    'vote_average': 8.483,
#    'vote_count': 12332},
#   {'adult': False,
#    'backdrop_path': '/9faGSFi5jam6pDWGNd0p8JcJgXQ.jpg',
#    'genre_ids': [18, 80],
#    'id': 1396,
#    'origin_country': ['US'],
#    'original_language': 'en',
#    'original_name': 'Breaking Bad',
#    'overview': "Walter White, a New Mexico chemistry teacher, is diagnosed with Stage III cancer and given a prognosis of only two years left to live. He becomes filled with a sense of fearlessness and an unrelenting desire to secure his family's financial future at any cost as he enters the dangerous world of drugs and crime.",
#    'popularity': 548.643,
#    'poster_path': '/ztkUQFLlC19CCMYHW9o1zWhJRNq.jpg',
#    'first_air_date': '2008-01-20',
#    'name': 'Breaking Bad',
#    'vote_average': 8.915,
#    'vote_count': 14294},
#   {'adult': False,
#    'backdrop_path': '/ogMd4e3A0uSNwZADzgC23zCByoi.jpg',
#    'genre_ids': [10759, 16, 10762],
#    'id': 65334,
#    'origin_country': ['FR'],
#    'original_language': 'fr',
#    'original_name': 'Miraculous, les aventures de Ladybug et Chat Noir',
#    'overview': "Marinette and Adrien, two Parisian teenagers, are entrusted with powerful jewels in order to transform into superheroes Ladybug and Cat Noir. But neither hero knows the other's true identity — or that they're classmates!",
#    'popularity': 528.445,
#    'poster_path': '/3bxuTGk0c98gQkgBcKzC6HxQ8B6.jpg',
#    'first_air_date': '2015-10-19',
#    'name': 'Miraculous: Tales of Ladybug & Cat Noir',
#    'vote_average': 8.049,
#    'vote_count': 4384},
#   {'adult': False,
#    'backdrop_path': '/cwKuMNndfjSl8iQIcAISL0C1tDZ.jpg',
#    'genre_ids': [18],
#    'id': 37680,
#    'origin_country': ['US'],
#    'original_language': 'en',
#    'original_name': 'Suits',
#    'overview': "While running from a drug deal gone bad, Mike Ross, a brilliant young college-dropout, slips into a job interview with one of New York City's best legal closers, Harvey Specter. Tired of cookie-cutter law school grads, Harvey takes a gamble by hiring Mike on the spot after he recognizes his raw talent and photographic memory.",
#    'popularity': 520.674,
#    'poster_path': '/vQiryp6LioFxQThywxbC6TuoDjy.jpg',
#    'first_air_date': '2011-06-23',
#    'name': 'Suits',
#    'vote_average': 8.228,
#    'vote_count': 5017},
#   {'adult': False,
#    'backdrop_path': '/aq2yEMgRQBPfRkrO0Repo2qhUAT.jpg',
#    'genre_ids': [10759, 18, 10768],
#    'id': 44217,
#    'origin_country': ['CA'],
#    'original_language': 'en',
#    'original_name': 'Vikings',
#    'overview': "The adventures of Ragnar Lothbrok, the greatest hero of his age. The series tells the sagas of Ragnar's band of Viking brothers and his family, as he rises to become King of the Viking tribes. As well as being a fearless warrior, Ragnar embodies the Norse traditions of devotion to the gods. Legend has it that he was a direct descendant of Odin, the god of war and warriors.",
#    'popularity': 491.627,
#    'poster_path': '/bQLrHIRNEkE3PdIWQrZHynQZazu.jpg',
#    'first_air_date': '2013-03-03',
#    'name': 'Vikings',
#    'vote_average': 8.093,
#    'vote_count': 6860},
#   {'adult': False,
#    'backdrop_path': '/r0Q6eeN9L1ORL9QsV0Sg8ZV3vnv.jpg',
#    'genre_ids': [18, 9648, 35],
#    'id': 1408,
#    'origin_country': ['US'],
#    'original_language': 'en',
#    'original_name': 'House',
#    'overview': 'Dr. Gregory House, a drug-addicted, unconventional, misanthropic medical genius, leads a team of diagnosticians at the fictional Princeton–Plainsboro Teaching Hospital in New Jersey.',
#    'popularity': 563.834,
#    'poster_path': '/3Cz7ySOQJmqiuTdrc6CY0r65yDI.jpg',
#    'first_air_date': '2004-11-16',
#    'name': 'House',
#    'vote_average': 8.59,
#    'vote_count': 6484},
#   {'adult': False,
#    'backdrop_path': '/jBhcm0Rm5Uv1UaHt0TTWuRjG5G3.jpg',
#    'genre_ids': [9648, 10759, 18],
#    'id': 4607,
#    'origin_country': ['US'],
#    'original_language': 'en',
#    'original_name': 'Lost',
#    'overview': 'Stripped of everything, the survivors of a horrific plane crash  must work together to stay alive. But the island holds many secrets.',
#    'popularity': 622.791,
#    'poster_path': '/og6S0aTZU6YUJAbqxeKjCa3kY1E.jpg',
#    'first_air_date': '2004-09-22',
#    'name': 'Lost',
#    'vote_average': 7.9,
#    'vote_count': 4209},
#   {'adult': False,
#    'backdrop_path': '/n2t1YBYn6i3yMJJUdnV93KDPMP7.jpg',
#    'genre_ids': [18],
#    'id': 74016,
#    'origin_country': ['US'],
#    'original_language': 'en',
#    'original_name': 'The Resident',
#    'overview': 'A tough, brilliant senior resident guides an idealistic young doctor through his first day, pulling back the curtain on what really happens, both good and bad, in modern-day medicine.',
#    'popularity': 532.431,
#    'poster_path': '/2IkYQJlT26yXef2iot7dhRtavSC.jpg',
#    'first_air_date': '2018-01-21',
#    'name': 'The Resident',
#    'vote_average': 8.5,
#    'vote_count': 1207},
#   {'adult': False,
#    'backdrop_path': '/4qvNAhSEqobkNSRLbiqTvanL5c7.jpg',
#    'genre_ids': [16, 10759, 35, 10765],
#    'id': 240411,
#    'origin_country': ['JP'],
#    'original_language': 'ja',
#    'original_name': 'ダンダダン',
#    'overview': 'In a bet to prove whether ghosts or aliens exist, two high schoolers face terrifying paranormal threats, gain superpowers and maybe even fall in love?!',
#    'popularity': 494.022,
#    'poster_path': '/tiF5I6wF6tEUy39gmNtw3G1GYyz.jpg',
#    'first_air_date': '2024-10-04',
#    'name': 'Dan Da Dan',
#    'vote_average': 8.774,
#    'vote_count': 42},
#   {'adult': False,
#    'backdrop_path': '/gmECX1DvFgdUPjtio2zaL8BPYPu.jpg',
#    'genre_ids': [16, 10759, 10765],
#    'id': 95479,
#    'origin_country': ['JP'],
#    'original_language': 'ja',
#    'original_name': '呪術廻戦',
#    'overview': 'Yuji Itadori is a boy with tremendous physical strength, though he lives a completely ordinary high school life. One day, to save a classmate who has been attacked by curses, he eats the finger of Ryomen Sukuna, taking the curse into his own soul. From then on, he shares one body with Ryomen Sukuna. Guided by the most powerful of sorcerers, Satoru Gojo, Itadori is admitted to Tokyo Jujutsu High School, an organization that fights the curses... and thus begins the heroic tale of a boy who became a curse to exorcise a curse, a life from which he could never turn back.',
#    'popularity': 480.424,
#    'poster_path': '/fHpKWq9ayzSk8nSwqRuaAUemRKh.jpg',
#    'first_air_date': '2020-10-03',
#    'name': 'Jujutsu Kaisen',
#    'vote_average': 8.579,
#    'vote_count': 3549},
#   {'adult': False,
#    'backdrop_path': '/wiE9doxiLwq3WCGamDIOb2PqBqc.jpg',
#    'genre_ids': [18, 80],
#    'id': 60574,
#    'origin_country': ['GB'],
#    'original_language': 'en',
#    'original_name': 'Peaky Blinders',
#    'overview': 'A gangster family epic set in 1919 Birmingham, England and centered on a gang who sew razor blades in the peaks of their caps, and their fierce boss Tommy Shelby, who means to move up in the world.',
#    'popularity': 449.902,
#    'poster_path': '/vUUqzWa2LnHIVqkaKVlVGkVcZIW.jpg',
#    'first_air_date': '2013-09-12',
#    'name': 'Peaky Blinders',
#    'vote_average': 8.538,
#    'vote_count': 9874},
#   {'adult': False,
#    'backdrop_path': '/x4salpjB11umlUOltfNvSSrjSXm.jpg',
#    'genre_ids': [10759, 18, 10765],
#    'id': 1402,
#    'origin_country': ['US'],
#    'original_language': 'en',
#    'original_name': 'The Walking Dead',
#    'overview': "Sheriff's deputy Rick Grimes awakens from a coma to find a post-apocalyptic world dominated by flesh-eating zombies. He sets out to find his family and encounters many other survivors along the way.",
#    'popularity': 457.609,
#    'poster_path': '/n7PVu0hSz2sAsVekpOIoCnkWlbn.jpg',
#    'first_air_date': '2010-10-31',
#    'name': 'The Walking Dead',
#    'vote_average': 8.112,
#    'vote_count': 16434}],
#  'total_pages': 125,
#  'total_results': 2486}

# %%
print("Páginas para Netflix España:",res_url_spain_netflix_series.json()["total_pages"])
print("Resultados para Netflix España:", res_url_spain_netflix_series.json()["total_results"])
# Out:
# Páginas para Netflix España: 125
# Resultados para Netflix España: 2486

# %%
netflix_spain_series = pd.DataFrame(res_url_spain_netflix_series.json()["results"])
netflix_spain_series.head(2)
# Out:
#    adult                     backdrop_path          genre_ids      id  \
# 0  False  /7w165QdHmJuTHSQwEyJDBDpuDT7.jpg    [10759, 80, 18]    2288
# 1  False  /tMLH2VDnTpZLYg7T4QPBjaaleVx.jpg  [10759, 18, 9648]  100757
#
#   origin_country original_language original_name  \
# 0           [US]                en  Prison Break
# 1           [US]                en   Outer Banks
#
#                                             overview  popularity  \
# 0  Due to a political conspiracy, an innocent man...     985.135
# 1  A tight-knit group of teens unearths a long-bu...    1165.631
#
#                         poster_path first_air_date          name  \
# 0  /5E1BhkCgjLBlqx557Z5yzcN0i88.jpg     2005-08-29  Prison Break
# 1   /ovDgO2LPfwdVRfvScAqo9aMiIW.jpg     2020-04-15   Outer Banks
#
#    vote_average  vote_count
# 0         8.079        5044
# 1         8.400         887

# %% [markdown]
# Con la anterior petición, sólo hemos sacado la primera página de resultados (por defecto, el endpoint coge la primera página), si bien necesitamos extraer todas las series (o sea, la información de las 125 páginas correspondientes a Netflix España):

# %%
for i in range(2,126): #Empezamos en la página 2 porque la 1 ya la tenemos de la peticion anterior
    url = "https://api.themoviedb.org/3/discover/tv?with_watch_providers=8&watch_region=ES&page="+str(i)
    res_url = requests.get(url,headers=headers_user)
    netflix_spain_series = pd.concat([netflix_spain_series, pd.DataFrame(res_url.json()["results"])], ignore_index=True)
netflix_spain_series
# Out:
#       adult                     backdrop_path           genre_ids      id  \
# 0     False  /7w165QdHmJuTHSQwEyJDBDpuDT7.jpg     [10759, 80, 18]    2288
# 1     False  /tMLH2VDnTpZLYg7T4QPBjaaleVx.jpg   [10759, 18, 9648]  100757
# 2     False  /4msN2f5WeKVldbdxSymdndWTOmr.jpg  [16, 10759, 10765]  218843
# 3     False  /h324Kf6pjDzGQiUrc4W2r4YcD9L.jpg            [18, 80]  225634
# 4     False  /cAmpVRgQL2s55CU6K8SaFcUJPNW.jpg     [18, 35, 10751]  262252
# ...     ...                               ...                 ...     ...
# 2481  False                              None                  []  215052
# 2482  False  /xX1J1qvhpjPdQs6DBt4GyDTxQeW.jpg                  []  121657
# 2483  False                              None                  []  250132
# 2484  False                              None                  []  249088
# 2485  False                              None                  []  231382
#
#      origin_country original_language                     original_name  \
# 0              [US]                en                      Prison Break
# 1              [US]                en                       Outer Banks
# 2              [JP]                ja                     七つの大罪 黙示録の四騎士
# 3              [US]                en                          Monsters
# 4              [CO]                es  Klass 95: El poder de la belleza
# ...             ...               ...                               ...
# 2481           [US]                en   Babies 24/7: The Maternity Ward
# 2482             []                es                      Curso del 63
# 2483           [IT]                it         Chi è Jack lo Squartatore
# 2484           [IT]                it                Chi era… - Lo show
# 2485           [DE]                de                 Tief im Regenwald
#
#                                                overview  popularity  \
# 0     Due to a political conspiracy, an innocent man...     985.135
# 1     A tight-knit group of teens unearths a long-bu...    1165.631
# 2     As a prophecy of doom unfolds on the peaceful ...     534.912
# 3     The story of the Menéndez brothers, who were c...     721.391
# 4     An ambitious young woman launches a powerful m...     388.277
# ...                                                 ...         ...
# 2481  The reality of childbirth is laid bare in this...       0.140
# 2482                                                          0.019
# 2483                                                          0.036
# 2484                                                          0.015
# 2485  Filmmakers Rainer Bergomaz and Yung Sandy trav...       0.002
#
#                            poster_path first_air_date  \
# 0     /5E1BhkCgjLBlqx557Z5yzcN0i88.jpg     2005-08-29
# 1      /ovDgO2LPfwdVRfvScAqo9aMiIW.jpg     2020-04-15
# 2     /6SWVJvCIC9B16u6wASZ8FEaNssz.jpg     2023-10-08
# 3     /x9YC2rpXHUFMqI1hCekKDm9UE4w.jpg     2024-09-19
# 4     /dsEtoQtIurztGFs3H9vsa5Tdw2R.jpg     2024-08-20
# ...                                ...            ...
# 2481                              None     2022-11-22
# 2482  /A06LS444p6u5HUsDadECEHs9sKE.jpg     2009-10-06
# 2483                              None     2020-03-10
# 2484                              None     2018-07-11
# 2485                              None     2009-01-01
#
#                                                    name  vote_average  \
# 0                                          Prison Break         8.079
# 1                                           Outer Banks         8.400
# 2     The Seven Deadly Sins: Four Knights of the Apo...         8.700
# 3                                              Monsters         7.586
# 4                         KLASS 95: The Power of Beauty         6.800
# ...                                                 ...           ...
# 2481                    Babies 24/7: The Maternity Ward         2.000
# 2482                                       Curso del 63         0.000
# 2483                          Chi è Jack lo Squartatore         0.000
# 2484                                 Chi era… - Lo show         0.000
# 2485                             Deep in the Rainforest         0.000
#
#       vote_count
# 0           5044
# 1            887
# 2            113
# 3            187
# 4              6
# ...          ...
# 2481           1
# 2482           0
# 2483           0
# 2484           0
# 2485           0
#
# [2486 rows x 14 columns]

# %% [markdown]
# Ya tenemos todas las series de Netlix España. Para nuestro análisis, no necesitamos todos los campos de la tabla creada, por lo que vamos a quedarnos con aquellos que realmente necesitamos:

# %%
eda_series_columns = ['original_name', 'name', 'id', 'genre_ids', 'first_air_date', 'popularity', 'vote_average', 'vote_count', 'original_language', 'adult' ]

# %%
#Generamos la tabla de las series de Netflix España y la guardamos en un .csv
netflix_spain_series_eda = netflix_spain_series[eda_series_columns]
netflix_spain_series_eda.to_csv(os.path.join(path_def,'netflix_series.csv'))

# %% [markdown]
# Para el resto de plataformas vamos a aplicar la función ***get_products_tmdb*** definida en ***utils/tvseries.py*** , para obtener sus correspondientes listados de películas y series.

# %% [markdown]
# ## Amazon Prime Video:

# %% [markdown]
# ### Películas:

# %%
amazon_spain_movies = tvseries.get_products_tmdb("movie", 119, headers_user)
amazon_spain_movies_eda = amazon_spain_movies[eda_movies_columns]
amazon_spain_movies_eda.to_csv(os.path.join(path_def,'amazon_movies.csv'))

# %% [markdown]
# ### Series:

# %%
amazon_spain_series = tvseries.get_products_tmdb("tv", 119, headers_user)
amazon_spain_series_eda = amazon_spain_series[eda_series_columns]
amazon_spain_series_eda.to_csv(os.path.join(path_def,'amazon_series.csv'))

# %% [markdown]
# ## Disney:

# %% [markdown]
# ### Películas:

# %%
disney_spain_movies = tvseries.get_products_tmdb("movie", 337, headers_user)
disney_spain_movies_eda = disney_spain_movies[eda_movies_columns]
disney_spain_movies_eda.to_csv(os.path.join(path_def,'disney_movies.csv'))

# %% [markdown]
# ### Series:

# %%
disney_spain_series = tvseries.get_products_tmdb("tv", 337, headers_user)
disney_spain_series_eda = disney_spain_series[eda_series_columns]
disney_spain_series_eda.to_csv(os.path.join(path_def,'disney_series.csv'))

# %% [markdown]
# ## Max:

# %% [markdown]
# ### Películas:

# %%
max_spain_movies = tvseries.get_products_tmdb("movie", 1899, headers_user)
max_spain_movies_eda = max_spain_movies[eda_movies_columns]
max_spain_movies_eda.to_csv(os.path.join(path_def,'max_movies.csv'))

# %% [markdown]
# ### Series:

# %%
max_spain_series = tvseries.get_products_tmdb("tv", 1899, headers_user)
max_spain_series_eda = max_spain_series[eda_series_columns]
max_spain_series_eda.to_csv(os.path.join(path_def,'max_series.csv'))

# %% [markdown]
# # Géneros:
#
# En los datasets hasta ahora formados, sólo tenemos los IDs de los géneros, si bien no sabemos cuáles son estos. Así pues, vamos a buscar la información de estos en los siguientes endpoints:

# %% [markdown]
# ## Películas:
#
# ![API Géneros Películas](./images/endpoint-movie_genres.png)

# %%
url_movie_genres = "https://api.themoviedb.org/3/genre/movie/list"
res_url_movie_genres = requests.get(url_movie_genres, headers=headers_user)
res_url_movie_genres
# Out:
# <Response [200]>

# %%
movie_genres_df = pd.DataFrame(res_url_movie_genres.json()["genres"])
movie_genres_df
# Out:
#        id             name
# 0      28           Action
# 1      12        Adventure
# 2      16        Animation
# 3      35           Comedy
# 4      80            Crime
# 5      99      Documentary
# 6      18            Drama
# 7   10751           Family
# 8      14          Fantasy
# 9      36          History
# 10     27           Horror
# 11  10402            Music
# 12   9648          Mystery
# 13  10749          Romance
# 14    878  Science Fiction
# 15  10770         TV Movie
# 16     53         Thriller
# 17  10752              War
# 18     37          Western

# %%
#Almacenamos la tabla previa para guardarla en .csv
movie_genres_df.to_csv(os.path.join(path_def,'tmdb_movie_genres.csv'))

# %% [markdown]
# ## Series:
#
#
# ![API Películas](./images/endpoint-serie_genres.png)

# %%
url_serie_genres = "https://api.themoviedb.org/3/genre/tv/list"
res_url_serie_genres = requests.get(url_serie_genres, headers=headers_user)
res_url_serie_genres
# Out:
# <Response [200]>

# %%
serie_genres_df = pd.DataFrame(res_url_serie_genres.json()["genres"]).reset_index(drop=True)
serie_genres_df
# Out:
#        id                name
# 0   10759  Action & Adventure
# 1      16           Animation
# 2      35              Comedy
# 3      80               Crime
# 4      99         Documentary
# 5      18               Drama
# 6   10751              Family
# 7   10762                Kids
# 8    9648             Mystery
# 9   10763                News
# 10  10764             Reality
# 11  10765    Sci-Fi & Fantasy
# 12  10766                Soap
# 13  10767                Talk
# 14  10768      War & Politics
# 15     37             Western

# %%
#Almacenamos la tabla previa para guardarla en .csv
serie_genres_df.to_csv(os.path.join(path_def,'tmdb_series_genres.csv'))
